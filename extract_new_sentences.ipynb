# %% [markdown]
# Extract new sentences
# ---------------------
#
# In this notebook, we want to extract new sentences from the book [diagne_grammaire](http://wolofresources.org/language/download/diagne_grammaire_wolof.pdf), which contains many examples of Wolof sentences traduce to French. We want to extract them to augment the already sentences we got and for which the treatment is done in the following notebook [extract_sentences](extract_sentences.ipynb). We will create a class which will make working fast.

# %% [markdown]
# ### Preprocessing of the book

# %% [markdown]
# To extract the sentences from the book, we used the [Wondershare PDFElement](https://pdf.wondershare.net/fr/?gclid=Cj0KCQjwuLShBhC_ARIsAFod4fK-9pyDwLQmwNJYiw0CjsIXCMtvOX9iizTLLYpu52d6Qml12VkAKB0aAqMjEALw_wcB) software again. The author commonly used a colon to separate the Wolof sentences from their French translations (to form translation groups). We identified some problems with the extractions:
# 1. The book contains many not interesting sentences separated by a colon
# 2. Some translation groups are not separated from the rest of the text, and it won't be straightforward to recuperate them directly
# 3. Some translation groups are too long, and so they are continually at the following line(s)
# 4. Some translation groups are not complete
# 5. A colon does not separate some of them
#
# We decide to make the following preprocessing on the book for easier extraction:
# - We manually extracted the sentences with the problem numbers 3, 4, and 5 and added on them some corrections: making a translation group to be written in one line; completing some sentences; separating a translation group into multiple ones *; manually writing the translation groups that are not separated by a colon.
# - Identifying and removing the sentences with problem number 1.
# - Identifying the translation group with problem number 2 and adding many spaces to correct that problem because most translation groups are separated by more than one space.
# - Adding manual corrections to correct the different problems directly from the text file.
#
#
# *: Some sentences in the translation groups contain one of the following marks:
# - "...": To indicate that the sentence is not complete
# - "—" "," ";", "÷": To separate translations of the same sentence
# - "(...)" "/" "—": To indicate a possible completion or version of a word or sentence translation. Note that "..." in the parentheses indicate that it contains some text
# - ":" "²÷": To separate parts of the same Wolof sentence
#
# For that group translations, we have different options:
# - Rewrite them manually as different translation groups (more accurate correction)
# - Decide to separate them by the identified mark
# - Decide to create another translation group with the element to add in a sentence for completion (use more when the marks are parentheses)
# - Modify a mark with another mark
# - Delete a mark
#
# Some translation groups can contain multiple marks so that multiple corrections will be added. To make the latter, we will need to identify which mark begins first (for example, a "/" can be inside parentheses so that the parentheses will be identified first in the sentence).
#
# **Remark**: The preprocessing of the book can take some days, so we will create a class that will make corrections to a certain number of translation groups and continues at any time if the program is interrupted, for example.

# %% [markdown]
# ### Extraction

# %% [markdown]
# #### Extract groups

# %% [markdown]
# Let us load the manually processed test file and see what it contain.

# %%
with open("data/diagne_grammaire_wolof.txt", "r", encoding="utf-8") as f:
    
    txt_file = f.read()
    
print(txt_file)
# Out:
# 20         GRAMMAIRE DE WOLOF MODERNE
#
# Cette analyse phonologique procède des principes exposés dans
# le Parler de Hauteville ¹. Les phonèmes, comme entités phoniques
# indivisibles, y sont définis à partir des contrastes de substances qui
# connotent des distinctions de sens.
#
# A. — SYSTÈME CONSONANTIQUE
#
# a) INVENTAIRE DES CONSONNES ORALES ET NASALES.
#
# p   l'identification se fera par rapprochement avec b et m
# p/b    paq : coiffure de jeune fille    baq : terre humide
# p/m    matt : bois de chauffage      patt : borgne
#
# up : fermer            um : porter malchance
#
# p  est une consonne bilabiale, orale et sourde. Elle se réalise à
# partir du contact des lèvres. Elle peut être implosive ou
# explosive.
#
# b  identification par opposition à p et m :
#
# p/b   cf. ci-dessus
#
# p/m   bokk : posséder ensemble    mokk : être pulvérisé
#
# lam : bracelet          lap : se noyer
# amal : trouver quelque chose  abal : prêter
# pour quelqu'un
#
# b  a un même point d'articulation que p. C'est une consonne sonore
# et orale. Elle est attestée à toutes les positions et peut être
# implosive ou explosive.
#
# m  la consonne m se définit par opposition aux autres bilabiales de
# la langue b et p et aussi par référence à n :
#
# m/n   matt : bois de chauffage     natt : mesurer
#
#
#
# gëm : croire            gën : être meilleur
#
# La consonne bilabiale m partage avec p et b le même point
# d'articulation. Elle est caractérisée par la nasalité — l'air est expiré
# par le nez. Elle peut être sourde ou sonore selon le contexte phonique
# d'ensemble. On la retrouve à toutes les positions.
#
# ¹ Parler de Hauteville, A. MARTINET, Paris, 1936.
#
#
# ANALYSE PHONOLOGIQUE            21
#
# f  consonne labiodentale sourde. Peut se définir par opposition à
#
# p :
#
# p/f    fac : soigner            pac : soin
#
# suuf : sable            suup : teindre
#
# daf : souder            dap : rejoindre
#
# Pour réaliser la consonne f, on place la lèvre inférieure sous les
# dents. Consonne sourde et orale, f est sur ce point d'articulation le
# seul exemple manifesté par la langue.
#
# t   Son  identification  sera  faite  par  opposition  aux  unités
# phoniques dont elle partage le même point d'articulation d et n :
#
# t/d    tef : chevreau           def : faire
#
# t/n    topp : suivre           nopp : oreille
#
# wàt : traîner           wàn : montrer
#
#
#
# wàtal : traîner (pour quelqu'un)
#
# t  est une consonne occlusive sourde et orale. Apicovelaire, elle
# s'articule en plaçant le bout de la langue au niveau des alvéoles.
#
# d   Consonne occlusive à rapprocher de n autre élément d'une série
# qui compte par ailleurs la consonne t déjà étudiée :
#
# n/d    nëbb : cacher            dëbb : piller
#
# fad : ranger            fan : où ?
#
# L'opposition d/c atteste une différence de série. Ceci ressort des
# exemples qui suivent :
#
# d/c    cëgg : grappe           dëgg : piétiner
#
#
#
# L'occlusive d est une sonore orale. Elle partage avec t un même
# point d'articulation.
#
# Mais la production de l'unité phonique d requiert une vibration
# des cordes vocales.
#
# n  est une occlusive dont l'identification a été amorcée avec l'étude
# des éléments t et d. Il s'agit d'apicovelaires dans les trois cas.
#
# La nasale n se réalise en plaçant la pointe de la langue à la
# limite intérieure des alvéoles ; ceci implique comme à propos de m
# l'expiration de l'air par les fosses nasales.
#
# n/ñ donne du point de vue articulatoire une différence dans la
#
#
# 22         GRAMMAIRE DE WOLOF MODERNE
#
# position de la langue.
#
# L'individualisation de chacune de ces formes est nettement
# établie à partir des variations de sens qu'on note ci-dessous :
#
# n/ñ    nar : mentir            ñar : enduire
#
# wàn : montrer          wàñ : tordre
#
# c  est une occlusive sourde et orale. Elle appartient à une série de
# trois éléments dont j et ñ. Leur originalité articulatoire consiste
# à bloquer la cavité buccale en appliquant le dos médian de la
# langue  sur  le  palais,  d'où  la  dénomination  d'occlusives
# médiopalatales.
#
# c  s'oppose à j par son absence de sonorité :
#
# c/j     car : branche         jar : se vendre bien
# et à ñ par son oralité d'où :
#
# c/ñ    car : branche         ñar : enduire
#
# j  définit une occlusive médiopalatale sonore par opposition à c (cf.
# ci-dessus). Elle se démarque par ailleurs de la nasale ñ comme
# on le constate ci-dessous :
#
# j/ñ    jam : piquer            ñam : nourriture
#
# daj : atteindre, toucher     dañ : caracoler
#
# xaajoo : se partager       xaañoo : se briser la tête
# mutuellement
#
# La réalisation de j requiert à la fois le placement de la partie
# médiane de la langue sur le palais et la vibration des cordes vocales.
# ñ  L'identification de comme occlusive nasale a été faite grâce aux
# rapprochements opérés à propos des éléments de la même série
#
# j et c.
#
# Par ailleurs on a déjà marqué le départ entre le phonème qu'il
# représente et la consonne n.
#
# On peut écarter une dernière possibilité de confusion en notant
# l'opposition qui ressort du couple ñ/õ :
#
# n/õ   õar : rugir             ñar : enduire
#
# daõ : tendu            dañ : caracoler
#
# daõal : tendre, rendre tendu  dañal : caracoler
#
# k  est une occlusive sourde et orale. Comme g et õ il introduit à
# une autre série. Le mécanisme articulatoire mis en jeu ici,
# consiste pour l'essentiel à ramener la langue de sorte que la
# partie postérieure de celle-ci entre en étroit contact avec
#
#
# ANALYSE PHONOLOGIQUE            23
#
# l'extrémité du palais. L'avant de la cavité buccale dégagé, la
# langue se masse vers l'intérieur. En expirant, on obtient un type
# d'occlusives dites dorsopalatales.
#
# L'identification de k s'opère à partir des oppositions qui
# suivent :
#
# k/g    kan : qui ?             gan : hôte
#
# k/õ   kar : guetter           õar : rugir
#
# dak : serviteur          daõ : tendu
#
# Par rapport à la série précédente, on peut dégager l'individualité
# de k en l'opposant à l'occlusive sourde c :
#
# k/c    kar : guetter            car : branche
#
# dok : couper            doc : pierre
#
# g   L'identification de k permet de considérer g comme l'occlusive
# dorsopalatale sonore de la série. La distinction g/õ révèle le
# caractère oral de la consonne g:
#
# gabb : piocher           õabb : tenir à bout de bras
#
# daõ : tendu            dag : serviteur
#
# õ  est une dorsopalatale nasale. Ceci ressort de l'opposition õ/g.
# Cette  occlusive  õ se  réalise  en  ajustant  le  mécanisme
# articulatoire tel qu'il a été dit à propos de k. Elle présente
# toutefois la particularité d'astreindre le sujet à expirer l'air par
# le nez tout en produisant un fort voisement des cordes vocales.
#
#
#
# il y a lieu de considérer les situations mises à jour à propos de la
# paire õ/x :
#
# õ/x    õar : rugir             xar : mouton
#
# dan : tendu            dax : beurre
#
# x  révèle le point d'articulation extrême mis en oeuvre par le
# système phonologique. Cette consonne met en action luette
# et voile du palais. Leur rapprochement permet d'obtenir un
# voisement très léger au passage de l'air. x est une fricative
# sourde et orale.
#
# L'identification de x commencée avec le couple õ/x peut être
# complétée grâce aux exemples qui suivent :
#
# x/k    xar : mouton      kar : guetter
#
# lax : fané        lak : tranche médiane de poisson
#
# x/g    xor : caillou       gor : homme libre
#
# dox : marcher     dog : couper
#
#
# 24         GRAMMAIRE DE WOLOF MODERNE
#
# s   ramène à un point d'articulation qui a pour particularité de
# mettre en contact les incisives supérieures et inférieures. Il se
# forme un interstice étroit. On place le rebord de la partie
# latérale correspondante du bout de la langue au niveau de cet
# interstice. L'étroitesse de celui-ci provoque au passage de l'air un
# sifflement assez aigu.
#
# Le phonème est identifié par rapprochement avec l'apicovélaire
# sourde t :
#
# s/t    siit : couler, suinter  tiit : avoir peur
#
# tiis : inquiétude    tiit : peur
#
# fasu : se nouer     fatu : s'abriter, s'enfermer chez soi
# et la labiodentale f :
#
# s/f    saf : être piquant    xaf : coudre deux bandes d'étoffe
#
# tase : se coincer    tafu : s'aplatir contre une paroi
#
# s   qui est une spirante sourde, est très sifflante.
#
#
#
#
# l/n    nal : presser      lal: étendre
#
# fan : où         fal : élire
#
# l/r    fal : élire        far : amant
#
# laf : bande d'étoffe   raf : clignoter, bouger de façon
#
# subreptice
#
# l/t     lal : lit          tal : avoir le temps
#
# fal : élire        fat : ranger
#
# l/d   laaw : prendre dans  daaw : année dernière
# un filet
#
# fal : élire        fad : abriter, ranger
#
# La consonne 1 présente des réalisations sonores ou sourdes selon
# qu'elle est explosive ou implosive.
#
#
# ANALYSE PHONOLOGIQUE            25
#
# r   Il faut relever le rebord de la langue vers le palais tout en
# infléchissant celle-ci légèrement en son centre. Cette partie
# latérale recourbée entre en contact avec le palais. L'air, en
# sortant, lui imprime un mouvement de vibration d'où résulte
# précisément la vibrante r.
#
# — r est un phonème oral :
#
# r/n    rax : mélanger        nax : tromper
#
# far : effacer          fan : où ?
# c'est aussi un phonème sourd :
#
# r/d    raf : clignoter        daf : souder un trou
#
# dar : écorché, usé par   dad : tailler, polir
# frottement
#
# w  Ce phonème se réalise par arrondissement et rapprochement des
# lèvres. On imprime à la langue un léger retrait vers l'intérieur
# tout en relevant la partie médiane de celle-ci. Le déplacement
# d'air dont résulte le son s'accompagne de la vibration des cordes
# vocales. L'identité du mécanisme d'articulation de w et de la
# voyelle u n'est pas parfaite. L'arrondissement des lèvres est plus
# accentué pour u.
#
# w  est attesté à toutes les positions. L'opposition w/f le prouve.
#
# w/f    wal : couler          fal : élire
#
#
# siiwal : publier       siifal : accaparer quelque chose
# pour quelqu'un
#
# ou
#
# w/b    wax : parler          bax : bouillir
#
# daw : courir         dab : rejoindre
#
# et aussi
#
# w/p    wàl : souffler        pàl: élection
#
# daw : courir         dap : rejoindre
#
# y  l'identification de cette unité phonique sera envisagée dans le
# cadre des oppositions :
#
# y/j    yëf : choses        jëf : fait, acte
# fay : abandonner le    faj : soigner
# domicile conjugal
#
# y/l    yëf : choses          lëf : chose
#
# wày : chanter        wàl : moudre
#
#
# 26         GRAMMAIRE DE WOLOF MODERNE
#
# y/ñ    wày : chanter        wañ : tordre
#
# yaw : toi           ñaw : coudre
#
# Lorsqu'on réalise le phonème y, on ramène la langue vers
# l'intérieur de la cavité buccale, la pointe légèrement tournée vers le
# bas. La partie médiane de la langue s'élève vers le palais. Les lèvres
# sont étirées et non arrondies. Le son émis grâce au passage de l'air à
# travers l'étroite ouverture délimitée par la langue rapprochée du
# palais s'accompagne généralement de vibrations des cordes vocales.
#
# Le phonème y définit une consonne.
#
# Ainsi w et y sont des fricatives orales et sonores. On les
# rencontre à toutes les positions.
#
# Physiologiquement, elles nécessitent la mise en oeuvre d'un
# mécanisme articulatoire rappelant sur bien des points ceux que l'on
# connaît  respectivement  pour  u  et  i.  La  différence  essentielle
# résiderait  sur  le  fait  que,  comme  unités  consonantiques,  elles
# requièrent des ouvertures plus étroites pour le passage de l'air et une
# déformation moins accentuée des lèvres.
#
# b) INVENTAIRE DES CONSONNES NASALISÉES.
#
# Le système consonantique wolof possède un certain nombre
# d'éléments  résultant  de  la  nasalisation  d'unités  phoniques
# fondamentales.
#
# Ce processus de nasalisation est assez général. Il affecte la
# majeure partie des séries connues.
#
# Du point de vue de la réalisation, une consonne fondamentale
# nasalisée conserve son point d'articulation initiale. La nouveauté
# résulte de l'utilisation des fosses nasales pour expirer l'air comme à
# propos d'une consonne nasale simple. L'analyse du phénomène révèle
# que la transformation s'effectue comme par combinaison
#
# entre la consonne fondamentale orale et la nasale de même série.
# Théoriquement les consonnes nasalisées sont considérées comme
# phonèmes uniques.
#
# L'identification  des  consonnes  nasalisées  se  fera  par
# commutation. On comparera chacune d'entre elles avec la nasale
# simple et la consonne fondamentale correspondante.
#
#
# ANALYSE PHONOLOGIQUE            27
#
# mp bilabiale, se définit à partir d'oppositions telles que :
#
# mp/p   mpar : espèce de cheval   par : allié
#
# sàmp : planter       sap : chanter (coq)
#
# mp/m  mpar : variété de cheval  mar : avoir soif
#
# xamp : mordre à pleines  xam : savoir
# dents
#
# mb  autre bilabiale, constitue un phonème susceptible d'être mis en
# évidence sur la base de distinctions telles que :
#
# mb/b   mbaal : filet         baal : pardonner
#
# tëmb : flotter        tëb : sauter
#
# m/mb  mbay : diminutif de Babacar  may : donner
#
# xamb : avarié           xam : savoir
#
# nt  consonne apicovelaire est identifiée par des oppositions telles
# que :
#
# nt/t    ntëng : sorte de puits    tëng : femelle d'animal
#
# sant : remercier       sat : battre quelqu'un à
# plusieurs
#
# nt/n   ndab : récipient         dab : rattraper
#
# ban : boue          bant : baton
#
# nd apicovelaire est identifiable grâce aux rapprochements :
#
# nd/d   ndaw : envoyé        naw : souffle
#
# and : sorte de fourneau  an : enlever des ordures
#
# nd/n   Ndar : Saint-Louis     nar : part
#
# an : enlever (ordures)   and : fourneau en argile
#
# nc  consonne médiopalatale, est identifiée grâce à des oppositions
# telles que :
#
# ñc/c    xac : chien          xañc : écorce
#
# ñc/ñ   sañc : bâtir (une ville)    sañ : faire preuve d'audace
#
# excessive, manque de gêne
# à l'initiale l'opposition ñc et c n'est plus pertinente :
#
# car ou ñcar : branche
#
# ñj  consonne  médiopalatale  peut  être  identifiée  grâce  aux
# oppositions :
#
# nj/j    njël : aube          jël : prendre
#
# doñj : boule de couscous  doj : pierre
#
# ñj/ñ   ñjaq : canari         ñaq : sueur
#
#
# 28         GRAMMAIRE DE WOLOF MODERNE
#
# õk  cette consonne dorsopalatale doit être définie par opposition à
#
# k et õ :
#
# õk/k   tak : se poser         taõk : pied
#
# õk/õ   laõk : refuser         laõ : s'exiler plus ou moins
# définitivement
#
# õx  avec cette consonne, la liste des nasalisées est close. Il s'agit
# d'une vélaire. Elle partage avec x un même point d'articulation
# tout en demeurant distincte de cette consonne :
#
# õx/x   tax : calebasse        taõx : puiser
#
# saxal : faire pousser    saõxal : brisures de mil
#
#
#
# c) LA GÉMINATION.
#
# Le phénomène traduit l'utilisation de consonnes fondamentales
# redoublées comme entité phonique distinctive.
#
# Seules trois des 19 consonnes fondamentales du wolof ne
# manifestent pas de formes géminées.
#
# Il s'agit de :
#
# f / r / et s /
#
# On parvient à identifier le fait de gémination par commutation
# à l'intervocalique et à la finale. Les géminées sont mises en évidence
# par opposition à la consonne fondamentale simple.
#
# Ainsi arrive-t-on à faire l'inventaire :
#
# — des bilabiales p, b, m géminées :
#
# p/pp   sop : étourdi         sopp : trouver gentil
#
# b/nn   nëb : pourri         nëbb : cacher
#
# nëbël : pourrir       nëbbël : cacher pour quelqu'un
#
# m/mm  gëm : croire         gëmm : fermer les yeux
#
#
# ANALYSE PHONOLOGIQUE            29
#
# — des épicoalvéolaires t, d, n géminées :
#
# t/tt    fat : ranger          fatt : boucher
#
# fetal : fusil          fettal : faire éclater
#
# d/dd   fad : ranger          fadd : abattre
#
# n/nn   wàn : montrer       wànn : avaler
#
# — des médiopalatales c, j, n géminées :
#
# c/cc    tac : soigner         facc : éclater
#
# j/jj    xaj : chien          xajj : séparer
#
# xajal: faire de la place à   xajjal : frayer un chemin
# quelqu'un           à quelqu'un
#
# n/nn   wàñ : tordre         wàññ : compter
#
# — des dorsopalates k, g et n géminées :
#
# k/kk  tak : se poser      takk : s'enflammer
#
# g/gg    mag: grand         magg: grandir
# dagu: adopter une atti-   dagguu : pourboire
# tude de serviteur vis-à-vis
#
# de quelqu'un
#
# õ/õõ   daõ : tendu          daõõ  : clairement
#
# — la dorsovélaire x se réalise en situation de gémination comme
# occlusive avec fermeture de la cavité buccale par application du dos
# de la langue sur la partie vélaire :
#
# x/q   tax : calebasse      taq : se tâcher
# jëxi : être sur le point de  jeqi : remuer
# s'épuiser
#
# — la latérale l géminée :
#
# wàl : piler          wàll : secours
#
# tali : talus          talli : s'étendre de tout son long
#
# — les consonnes fricatives w et y connaissent des situations de
# géminations, c'est ce qui ressort des exemples ci-dessous :
#
# coy : variété d'oiseau ; coyy : rouge écarlate ; noyyi : respirer
#
# sawu : urinoir ;  sawwu : Est
#
# Jaw ; Diaw : nom de personne ; jaww : atmosphère
#
#
# 30         GRAMMAIRE DE WOLOF MODERNE
#
# REMARQUE :
#
# 1) Distribution complémentaire. La consonne transcrite x
# comporte deux réalisations possibles. Dans le cas où elle est mise en
# oeuvre comme consonne fondamentale simple, elle constitue une
# fricative :
#
# taax : bâtiment
#
# Dans le cadre de la nasalisation et de la gémination, elle se
# réalise comme une occlusive :
#
# taq : se tâcher
#
# taõx : puiser
#
# Mais il s'agit du même phénomène dans tous les cas. La
# différence de réalisation est phonologiquement déterminée par des
# variations de contextes.
#
# 2) L'opposition sourde/sonore n'est pas pertinente lorsqu'il s'agit
# de phonèmes simples à la finale :
#
# p/b  fab — fap : prendre
# t/d  fat — fad : ranger
# c/j  fac — faj : soigner
# k/g  tak — tag : se poser
#
# Toutefois, lorsque  les  unités  qu'ils  concernent  entrent  en
# combinaison, les phonèmes sonores s'imposent à l'exception du cas
# relatif au couple t/d où le phonème t s'impose :
#
# fap — fab : prendre  fabal : prendre pour quelqu'un
# fat — fad : ranger   fatal : ranger pour quelqu'un
# fac — faj : soigner  faji : aller soigner
#
# dek — deg : épine degu àll : épine de brousse
#
#
#
#
# ANALYSE PHONOLOGIQUE            31
#
# TABLEAU RÉCAPITULATIF DU SYSTÈME CONSONANTIQUE.
#
#
# OCCLUSIVE ORALE              p
#
# b
#
# FRICATIVE .........................................  w   f
#
# t   c   k
#
# d   j   g   x
# r
#
# l
#
# s     y
#
# OCCLUSIVE NON ORALE .......................  m         n   ñ   õ
#
#
# PRENASALISÉES               mp
#
# mb
#
# nt  ñc
#
# nd  ñj
#
# õk  õx
# õg
#
# B. — SYSTÈME VOCALIQUE
#
# Dans  l'ensemble  trois  types  d'opposition  constituent  le
# fondement sur lequel repose le système vocalique walaf. Ils relèvent
# de l'analyse de la substance phonique.
#
# a) Opposition relative aux dimensions de la cavité buccale. Elle
# permet de distinguer entre :
#
# —  une cavité maxima déterminée par la position très en retrait de
# la langue vers l'intérieur de la bouche et celle des lèvres
# allongées vers l'avant,
#
# — une cavité minima dans laquelle la pointe de la langue est placé
# très près des lèvres qui, elles-mêmes, restent fortement aplaties
# sur les gencives,
#
# —  une cavité moyenne où les lèvres sont légèrement arrondies et la
# langue quelque peu en retrait.
#
# b) En second lieu, une opposition d'aperture qui porte sur le
# degré d'ouverture de la bouche.
#
#
# 32         GRAMMAIRE DE WOLOF MODERNE
#
# Tous ces deux types d'oppositions renvoient au mécanisme
# articulatoire et permettent de repérer :
#
# —  des voyelles arrondies ou non arrondies selon le contour
# imprimé aux lèvres,
#
# —  des voyelles antérieures ou postérieures selon que la pointe de la
# langue est placée près des dents ou en retrait sur celles-ci,
#
# —  des voyelles de premier, second, troisième ou quatrième degré ;
# ceci par rapport à l'arc, à l'ouverture nécessaire à la cavité
# buccale pour la réalisation du phonème.
#
# c) Enfin, un dernier type d'opposition résulte des variations
# quantitatives connues et attestées par l'ensemble des phonèmes
# vocaliques en dehors de quelques rares exceptions.
#
# En pratique ici, toutes les voyelles arrondies sont postérieures
# et de cavité maxima. Les voyelles non arrondies sont antérieures et
# possèdent des cavités minima ou moyennes.
#
# 1° VOYELLES ARRONDIES POSTÉRIEURES DE CAVITÉ MAXIMA :
#
#
#
# u/uu   tur : nom          tuur : verser
#
# ku : quiconque       kuu : celui-là, que voilà
#
# La voyelle brève u peut encore être définie à partir de
# l'opposition u/i :
#
# u/i    tus : rien           tis : éclabousser
#
#
#
# uu/ii   muur : recouvrir       miir : avoir des vertiges
#
# kuu : célui-là devant    kii : celui-ci
#
#
#
# o/óo    boli : gosier          bóoli : grand plat
#
#
#
# o/i    jog : se soulever       jig : porter bonheur
#
#
# ANALYSE PHONOLOGIQUE            33
#
# La voyelle longue arrondie et fermée óo se démarque par rapport
# à uu et oo :
#
# óo/uu  suup : teindre à l'indigo  sóop : plonger
#
# óo/oo   tóoy : mou          tooy : humide
#
#
#
# o/oo    wor : trahir         woor : jeûner
#
# o et oo sont respectivement plus ouvertes que ó et óo :
#
# gor : noble          goor : s'affaisser
#
# La voyelle brève o se distingue d'autre part de e :
#
# o/e    kor : trahison        ker : ombre
#
# La voyelle longue oo de ee :
#
# oo/ee   noor : saison sèche     neer : mal de mer
#
#
#
# à/o    wàl : souffler        wol : piler
#
# fàr : effacer         far : amant
# jaõg : dent mal plantée   jàõg : étudier
# wàl : souffler        wal : couler
#
# xamb : attiser un feu    xàmb : lieu de culte
#
#
#
#
# i/ii    nit : homme         niit : éclairer
#
# ki : lequel           kii : celui-ci
#
# Comme voyelle brève i s'oppose à e :
#
# i/e    dikk : venir          dékk  :  recueillir dans un
# récipient
#
# gisi : aller voir       gise : se concerter
#
#
# 34         GRAMMAIRE DE WOLOF MODERNE
#
# La voyelle longue i se définit à partir de l'opposition :
#
# i/ée    géer : homme de caste    giir : lignée, descendance
#
#
# é/ée   wér : être guéri       wéer : adosser
#
# Le phonème bref en é se démarque encore de e
# é/e    wét : fibre de coton     wet : côte
#
# Le phonème long ée de ee :
#
# ée/ee   wéer : adosser        weer : lune
#
#
#
# e/ee    xer : berge, rivage      xeer : pierre
#
# La voyelle brève e peut encore être identifiée quand on pose :
#
# e/é    wer : ver de terre      wér : être guéri
#
# e/a    fer : s'évaporer        far : amant
#
# La voyelle longue ee se définit encore par opposition à aa
# ee/aa   xeer : pierre          xaar : attendre
#
#
#
# a/aa   war : monter        waar : étonner
#
# Le phonème long aa peut encore être identifié grâce à
# l'opposition :
#
# aa/oo   jaar : passer par      joor : terrain sablonneux, mais
#
# aussi nom de personne
#
# L'identité du phonème vocalique bref a ressort de l'opposition
# avec la voyelle brève et arrondie o, cf. ci-dessus et aussi de
# l'opposition :
#
# a/à    far : amant         fàr : effacer
#
# tàkk : s'allumer       takk : attacher
#
# jàõg : étudier        jaõg : dent de travers
#
#
# ANALYSE PHONOLOGIQUE            35
#
# 3° VOYELLE NON ARRONDIE DE CAVITÉ MOYENNE :
#
# On recense dans cette rubrique la voyelle ë. Sa réalisation
# implique le retrait de la langue vers l'intérieur et un non
# arrondissement des lèvres. Le type ë ne révèle aucune opposition de
# longueur.
#
# On le définit à partir des oppositions qui suivent :
#
# ë/a    gën : être meilleur        gan : hôte
#
# ëgg : vent             agg : arriver
#
# ë/aa   fër : avoir une dysenterie    faar : côte
# ä/à    fër : avoir une dysenterie    fàr : effacer
#
#
#
# bër : être en vacance       bëër : beurre
#
# Tableau du système vocalique traduit sur le diagramme de
# Jones. On obtient le schéma suivant :
#
# i ii ———————– u uu
#
# é ée —ë ————à— ó óo
#
# e ee ———————– o oo
#
# a aa ———————–
#
# Horizontalement le diagramme exprime pour un même type de
# phonèmes vocaliques, une opposition de longueur ii — i :
#
# Pour deux types différents, il s'agit d'une opposition entre
# voyelles arrondies et non arrondies i — ii, u — uu :
#
# Verticalement, l'opposition porte sur les variations d'aperture.
# Le degré de celle-ci va croissant — ainsi en est-il si on considère les
# types i — ii et a — aa.
#
#
#
# suux  sóox : chair
#
# guux   góox : absorber une forte gorgée
# mais on relève :
#
# suup : teindre        sóop : plonger
#
#
#
#
# 36         GRAMMAIRE DE WOLOF MODERNE
#
# C. — DÉFINITION
#
# ET CLASSEMENT DES PHONÈMES
#
# L'inventaire  auquel  il  a  été  procédé  a  permis  d'identifier
# l'ensemble des phonèmes du système phonologique walaf. Nous
# allons procéder ici à leur mise en ordre.
#
# Les oppositions établies entre les phonèmes ont permis de
# déterminer respectivement l'ensemble des caractéristiques, des traits
# pertinents qui spécifient la singularité de chacun. Ces données vont
# être récapitulées à travers deux tableaux.
#
# LES CONSONNES :
#
# p  sourde p/b; bilabiale p/f ; non nasale p/m
# b  sonore b/p ; bilabiale b/d; non nasale b/m
#
# f   sourde f/b; labiodentale b/j ; non nasale f/m
# m  bilabiale m/n, m/f ; nasale m/b, m/p
#
# d  sonore d/t ; apicoalvéolaire d/b, d/m ; non nasale d/n
# t  sourde t/d ; apicoalvéolaire t/p ; non nasale t/n
#
# n  apicoalvéolaire n/m ; nasale n/d, /n/t
#
# j   médiopalatale j/d ; sonore j/c ; non nasale j/ñ
# c   médiopalatale c/t ; sourde c/j ; non nasale c/n
# ñ  médiopalatale ñ/n ; nasale ñ/c ñ/j
#
# k  dorsopalatale c/k ; sourde k/g ; non nasale k/n
# g  dorsopalatale g/j ; sonore g/k ; non nasale n/g
# õ  dorsopalatale õ/ñ ; nasale õ/k/ñ/g
#
# x  velaire x/k ; non nasale x/õ
#
# r  apicovelaire r/p ; vibrante r/l; orale r/n
# l   apicovelaire l/b; latérale l/r ; orale l/n
#
# s  interdentale s/f ; sifflante s/r ; orale s/n
#
# w  bilabiale w/d ; sonore w/p ; non nasale w/m
# y  médiopalatale y/l ; orale y/n
#
# mp bilabiale mp/nt ; sourde mb/mp ; nasale mp/p
# mb bilabiale mb/nd ; sourde mb/mp ; nasale mp/p
#
# nt  apicoalvéolaire nt/mp ; sourde nt/nd ; nasale nt/t
# nd  apicoalvéolaire nd/mb; sourde nd/nt; nasale nd/d
# ñc  médiopalatale ñc/nt; sourde ñc/ñj ; nasale ñc/c
# ñj  médiopalatale ñj/nd ; sourde ñj/ñc ; nasale ñj/j
# õk  dorsopalatale õk/ñc ; sourde õk/õg ; nasale õg/k
# õg  dorsopalatale õg/nd ; sonore õg/õk ; nasale õg/g
# õx  dorsovelaire õx/nd ; sonore õx/õk ; nasale õx/x
#
#
# LES VOYELLES :
#
# ANALYSE PHONOLOGIQUE            37
#
# Récapitulation et classement des voyelles selon leurs caractéristiques
# phonologiques :
#
#
# D. — DISTRIBUTION DES PHONÈMES
#
# Les phonèmes peuvent occuper au sein des signes une position
# initiale, médiane ou finale. En maintenant le principe de la
# distinction entre phonèmes vocaliques et consonnes, on peut
# considérer successivement la distribution des voyelles et celles des
# consonnes.
#
# 1) DISTRIBUTION DES PHONÈMES VOCALIQUES :
#
# 1/ Initiales vocaliques :
#
# A l'initiale des unités signifiées du walaf, la présence de voyelles
# n'est pas d'un usage très courant, néanmoins pour certains types on
# relève d'assez nombreux exemples :
#
# a) les voyelles antérieures non arrondies fournissent quelques
# données, en particulier sous leur forme de brèves :
#
# i  iñaan : envieux
#
# e  egg : arriver
#
# a  añ : déjeuner
#
#
# ANALYSE PHONOLOGIQUE            39
#
# Seule l'unité vocalique aa manifeste sa présence à l'initiale
# comme voyelle antérieure non arrondie longue.
#
# aa aay : avare
#
# aa aajo : serviabilité
#
# b) Les voyelles postérieures arrondies livrent de ce point de vue
# un tableau plus complet :
#
# u  ub : fermer
#
# o  obali : bailler
#
# o  om : être maigre
#
# A côté de cette utilisation de voyelles brèves, on relève celles de
# voyelles postérieures non arrondies longues :
#
# uu uuf : prendre sur ses genoux
#
# óo  óom : genoux
#
# oo  oos : maigre
#
# L'élément ë connaît aussi l'usage à l'initiale :
#
# ëpp : dépasser les limites, excessif
# 2° Finales vocaliques d'unités signifiées :
#
# Selon la même procédure, on va pouvoir distinguer entre :
#
# a) les voyelles postérieures arrondies, finales et brèves :
#
# u  juddu : naissance
#
# o  ndimo : tissu
#
# ó  lóxó : bras
#
# b) les voyelles postérieures arrondies, finales et longues :
#
# uu kuu : celui-ci, tout près
#
# óo  gisóo : se concerter
#
# oo  woddoo : se couvrir avec
#
# c) Les voyelles non arrondies antérieures finales et brèves :
#
# i  ki : cet, que voici
#
# é  téeré : amulette
# e  tere : interdire
# a  dara : rien
#
# d) Les voyelles non arrondies antérieures finales et longues :
#
# ii  kii : celui-ci
#
# ee  ree : rire
#
# aa  daa : encre
#
#
# 40         GRAMMAIRE DE WOLOF MODERNE
#
# La voyelle ë recensée à l'initiale se retrouve à la finale. Ainsi,
# dans l'exemple :
#
# muumë : muet
# 3° Voyelles médianes :
#
# Pour établir la liste des éléments vocaliques que l'on retrouve
# comme composantes internes de l'unité signifiée, il suffit de renvoyer
# à  l'ensemble  des  situations  étudiées  précèdemment.  Les  unités
# vocaliques sans exception ont manifesté leur présence à cette position
# à  propos des oppositions de commutation.
#
# Aussi bien les voyelles non initiales :
#
# ii  tiis : inquiétude
#
# é  wér : guérir
#
# ée  wéer : adosser
#
# ë  wër : faire le tour
#
# ee  weer : lune
#
# que les voyelles non finales :
#
# ée ci-dessus dans wéer : adosser
#
# ee  »    dans  weer : lune
#
# a  »    dans  jaõg : dent mal plantée
#
# ou encore les entités phoniques minimales qui, dans aucun cas,
# n'assument dans la langue le rôle d'initiale ou de finale :
#
# à  de  wàl : piler
#
# ée de  géer : homme de noble caste
#
# ee de  xeer : pierre
#
# A noter que les voyelles non finales ne sont jamais initiales dans
# la langue. Mais la réciproque n'est pas vraie.
#
# En récapitulant les faits, on peut dresser deux tableaux relatifs
# à l'utilisation du système vocalique à l'initiale et à la finale.
#
# a) Tableau des voyelles initiales :
#
# i   ———————— u uu
#
# ———————— ó óo
#
# ë
#
# e   ———————— o oo
#
# a aa ————————
#
#
# ANALYSE PHONOLOGIQUE            41
#
# b) Tableau des voyelles finales :
#
# i ii ———————— u uu
#
# ———————— ó óo
#
# ë
#
# ee ———————— o oo
#
# a aa ———————— . .
#
#
#
# La prédominance parmi les monèmes d'éléments de type CVC
# et CVCC met en relief l'importance du consonantisme sur les
# positions limites des signes et la très grande fréquence des entités
# vocaliques médianes.
#
# Les lexèmes à initiale ou finale vocalique sont assez rares.
# Néanmoins les éléments dérivés, en particulier, manifestent parfois
# à la finale la présence de voyelles. Dans les combinaisons entre
# phonèmes, surtout lorsqu'il y a une procédure de formation lexicale,
# une fonction d'orientation euphonique est dévolue à la voyelle
# centrale de la forme de base. C'est le principe de l'harmonie
# vocalique. Celle-ci se matérialise par l'agencement des phonèmes à
# partir de choix qui tendent à n'introduire dans une entité phonique
# signifiée que des voyelles ayant des degrés d'aperture assez proches.
#
# La dérivation de ce point de vue présente des faits riches
# d'enseignement.
#
# L'expression  de la notion d'ensemble par exemple impose
# l'utilisation de voyelles postérieures arrondies du 3ᵉ ou 4ᵉ degré
# d'aperture, selon la nature de la voyelle centrale de la forme soumise
# à la procédure de dérivation.
#
# Pour une entité phonique telle que gis voir, l'expression de la
# notion de vision collective imposera l'usage de la voyelle fermée de 2ᵉ
# degré, plus proche par son aperture, de la voyelle i (premier degré)
# d'où :
#
# gis óo : voir ensemble
#
# par contre l'idée de manger collectivement se dira lekkoo avec un oo
# long ouvert de 3ᵉ degré et dont la mise en oeuvre respecte le
# parallélisme avec le phonème e qui constitue une unité d'aperture
# voisine.
#
#
# 42         GRAMMAIRE DE WOLOF MODERNE
#
# En empruntant toujours à la dérivation des exemples types, on
# peut encore remarquer le traitement euphonique de l'unité vocalique
# dans la forme expressive de l'idée de « faire quelque chose au profit
# de quelqu'un ». Ici, l'élément consonantique reste stable et de forme
#
# -l- alors que la voyelle qui précède cet élément dépend au contraire
# très étroitement de la voyelle centrale de la racine à dériver :
#
# baax donne baaxal : rendre bon
#
# tuur donne tuurul : faire une offrande à une divinité.
#
# Le principe ne joue pas seulement à propos de l'aperture. Les
# mêmes ajustements sont opérés pour trouver une certaine adéquation
# euphonique entre voyelles arrondies postérieures et non arrondies
# antérieures.
#
# Ainsi peut-on noter que l'idée d'inachèvement rendue par la
# combinaison de la consonne g et d'une voyelle variable emprunte, sur
# ce plan, des formes différentes selon le contexte vocalique dominant
# d'où :
#
# dem-ag-ul : il n'a pas encore été
#
# seet-eeg-ul : il n'a pas encore été voir
#
# wuut-óog-ul : il ne s'est pas encore substitué à
#
# gis-éeg-ul : il n'a pas encore pris de contacts
#
# 3) DISTRIBUTION DES PHONÈMES CONSONANTIQUES
# AU SEIN DES UNITÉS SIGNIFIÉES.
#
# 1° Initiale consonantique :
#
# A cette position, la totalité des consonnes fondamentales a déjà
# pu être recensée à propos de la procédure d'identification :
#
# p  pàl : élection         t   taf : coller, afficher
#
# t   fal : élire           c   car : branche
#
# k  kër : maison         x  xar : mouton
#
# r   rëbb : chasser         b  bañ : refuser
#
# d  dóor : frapper        j   jëf : acte
#
# g   gëm : croire          l   laaf : aile
#
# w  wày : chanter        m  mën : pouvoir
#
# n  nar : mentir         ñ  ñaaw : vilain
#
# õ  õar : rugir          s   sëf : change
#
# y  yar : éduquer
#
#
# ANALYSE PHONOLOGIQUE            43
#
# Par contre toutes les variétés de consonnes nasalisées ne sont
# pas représentées. Certains usages sont toutefois assez courants ; il
# s'agit surtout de consonnes sonores nasalisées :
#
# mp mpal : élection       mb mbay : culture
#
# nd ndof : folie
#
# ñj  ñjëg : prise
#
# õg  õgëm : croyance
#
# d'autres sont pratiquement inconnues comme initiales, en particulier
# les nasalisées issues de consonnes sourdes :
#
# nt ñc õk õx
#
#   Il serait plus exact de dire que leur emploi lorsque cela se
# trouve a valeur purement dialectale. Ainsi en est-il de nt et de ñc.
#
# Les éléments õk et õx ont perdu toute vie dans la langue ici.
#
# L'initiale nasalisée est un phonème en voie de régression dans
# les villes. Elle tend de plus en plus à constituer une variante
# facultative de la consonne fondamentale correspondante.
#
# 2° Finales consonantiques :
#
# La procédure d'identification a déjà révélé la finale comme la
# position où tous les éléments consonantiques sans exception se
# manifestent :
#
# — Les consonnes fondamentales :
#
# p  fap : prendre         f   taf : coller
#
# t   fat : ranger          b   fab : prendre
#
# d  fad : ranger         m  xam : savoir
#
# n  wàn : montrer        c   fac : soigner
#
# k  tak : se poser         x  taax : bâtiment
#
# s   sas : charge         w  daw : courir
#
# j   faj : soigner         g   tag : se poser
#
# l   taal : allumer        r   far : amant
#
# y  fày : éteindre        ñ  wañ : tordre
#
# õ  laõ : s'exiler
#
# — Les consonnes nasalisées :
#
# mp sàmp : planter       mb lamb : tâter
#
# nt  gént : rêver         nd  and : sorte de fourneau
#
# ñc  lañc : bouchée        ñj  õgëñj : indigo
#
#
# 44         GRAMMAIRE DE WOLOF MODERNE
#
# õk  taõk : pied          õg  taõg : chaud
#
# õx  saõx : il y a un moment
#
# — Les consonnes géminées :
#
# pp  bopp : tête          tt  fatt : boucher
#
# cc  facc : éclater         kk  takk : attacher
#
# q  saq : grenier         ww jaww : atmosphère
#
# bb  gabb : piocher        dd  fadd : abattre
#
# jj  gajj : scarifier        gg  dagg : couper
#
# ll  wall : secours        yy  coyy : rouge écarlate
#
# mm  tamm : avoir pris l'habitude de  nn  tann : choir
#
#
# ññ  wàññ : compter        õõ  wàõõ : avarié
#
# 3° Position interne des consonnes :
#
# En reprenant les mêmes étapes que précédemment, on pourra
# voir successivement :
#
# — Consonnes fondamentales :
#
# b  sabar : tam tam       m  ndemin : façon d'être
#
# f   safara : feu          p  ñappati : s'embourber
#
# t  satala : récipient
#
# c   xaacu             n  ganaar : poulet
#
# d  Idi : nom           j   Kajoor : Prov. du Sénégal
#
# k  Dakaar
#
# ñ  kañaan : envie
# g  sagar : torchon
# õ  laõaay : exil
#
# x  saxaar : fumée train    l   bala : demander pardon
#
# s   xasaw : puer         r   faral : prendre partie pour
#
# w  dawal : conduire      y  aaye : interdire
#
# Un certain nombre de consonnes n'apparaissent ici, le plus
# souvent, qu'après une voyelle longue. Il s'agit en particulier de
# phonèmes tels que p, c, k qui, en position finale présentent la
# particularité d'être comme consonnes fondamentales simples des
# variantes facultatives de phonèmes différents par la sonorité.
#
#
# ANALYSE PHONOLOGIQUE            45
#
# — Consonnes nasalisées :
#
# mp  sempi : déraciner      mb  ñjambaas : rebord
#
# nt  õgenté : baptême      nd  andaar : unité de mesure
#
# ñc  tañcu : se coincer      ñj  xañjar : cuivre
#
#
#
# õx  teõxu : jointure, articulation
#
# — Consonnes géminées :
#
# pp  noppi : se taire       tt  wattu : éviter
#
# cc  tëccu : se pincer       kk  ñakku : être vacciné
#
# q  laqu : se cacher       bb  libbët : être anémié
#
# dd  addu : répondre      jj  dajji : défoncer
#
# gg  jéggi : enjamber       ll  wàllu : secourir
# ww  jaww : atmosphère      yy  noyyi : respirer
# nn  sannar : nom        mm  tammal : habituer
#
# õõ  Daõõar : nom        ññ  saññi : déboucher
#
# E. — SYLLABATION
#
# ET TRAITEMENT CONTEXTUEL DES PHONÈMES
#
#
#
# a) LE GROUPE SYLLABIQUE.
#
# La constitution de la syllabe varie. On peut être en présence
# d'une simple unité vocalique ou d'un groupe de phonèmes
# susceptibles de se combiner de façon différente.
#
# On distinguera par ailleurs entre la syllabe à initiale vocalique
# ou syllabe vocalique et la syllabe consonantique à initiale de
# consonne.
#
#
# 46         GRAMMAIRE DE WOLOF MODERNE
#
# Le groupe initial.
#
# a) Syllabe vocalique :
#
# Comme syllabe vocalique ouverte /V- on rencontre :
#
# i  i-ñaan : jaloux
# a  a-ñaan : jaloux
# aa  aa-ye : interdire
# u  u-rus : or
#
# o  óbbëli : bailler
#
# o  om-meeku : s'essuyer la bouche
#
# uu  uu-fu : se blottir
#
# oo  oo-sal : faire maigrir
#
# ë  ë-ñu : se retrousser les manches
#
# La syllabe vocalique fermée (terminée par une consonne). On
# note que toutes les voyelles brèves initiales sont à même de
# constituer ce type de syllabe :
#
# i  it-te : obligeance      u  ub-bi : ouvrir
#
# a  at-té : séparer, juger     óo  óom : genoux
#
# o  ok-katu : se gratter
#
# ë  ëñ : retrousser
#
# La consonne qui termine la syllabe peut être géminée ou
# nasalisée :
#
# itt : frapper  ëmb : envelopper
#
# app : limite  opp : maladie      ëndi : amener
#
# La syllabe initiale vocalique et fermée n'est, en principe, possible
# qu'avec une voyelle initiale brève.
#
# b) Syllabe consonantique :
#
# La syllabe possède une initiale consonantique. Il s'agit par
# conséquent de toutes les situations où une consonne donnée peut être
# initiale.
#
# Les phonèmes consonantiques à l'exception des nasalisées ñc, nt,
# õk, õx peuvent constituer des initiales de syllabes qui présentent
# alors l'une des combinaisons suivantes :
#
# CV   tis : éclabousser    ndaa : canari
#
# CVC   testën : plante de pied    toskare : connaître un mauvais sort
#
#
# CVCC  bopp : tête       gabbkat : piocheur
#
#
# ANALYSE PHONOLOGIQUE            47
#
# Le groupe final.
#
# Il s'agit d'une syllabe ouverte ou fermée à la finale d'une unité
# signifiée.
#
# a) La syllabe vocalique finale commence sur une voyelle. Dans
# le cas où elle est vocalique et ouverte, elle n'est constituée que par
# une voyelle. On en possède quelques exemples. Ils valent pour des
# régions limitées (parler lebou, etc.) :
#
# i  dee-i : aller mourir     u  ji-u : semence
#
# ree-i : aller rire        o   dee-o : mourir en groupe
#
# Les  exemples  sont  surtout  fournis  par  la  procédure  de
# dérivation. En fait, la coexistence de voyelles successives est rare. Il
# s'opère généralement soit une contraction de voyelles mises en
# contact en une unité phonique longue, soit une insertion des
# phonènes w et y entre celles-ci :
#
# dee-o ÷ deewoo : mourir ensemble
#
# ji-i ÷ jiyi : aller semer
#
# b) La syllabe vocalique finale fermée est une possibilité
# reconnue :
#
# VC   dée-al : mourir pour
#
# dee-al : trouve en deewal un substitut plus courant.
#
# Le type VCC ne semble pas exister.
#
# c) La syllabe consonantique finale :
#
# Elle est plus conforme aux procédés de la syllabation walaf. La
# syllabe fermée ou ouverte comporte à l'initiale une consonne et une
# seule.
#
# — Syllabe consonantique finale et ouverte, type VC :
#
# juu-tu : se renverser         ji-tu : devancer
#
# do-goo : se brouiller définitivement  téeré : livre
#
# dug-go : frayer ensemble       tere : interdire
#
# — Syllabe consonantique fermée et finale, type CVC :
#
# En dehors des monosyllabes, on peut dénombrer toute une
# variété de cas :
#
# ndu-góor : fruit       dawal : faire courir
#
# sa-gar : torchon      libbët : être anémié
#
# On ne rencontre pas d'exemples de syllabe consonantique fermée
# du type CVCC à la finale.
#
#
# 48         GRAMMAIRE DE WOLOF MODERNE
#
# Le groupe interne.
#
# Le groupe interne doit nécessairement appartenir à une unité
# signifiée d'au moins trois syllabes. Il est assez rare de trouver un
# élément lexical de cette envergure en walaf. Les exemples sur lesquels
# porteront  par  conséquent  cette  analyse  relèvent  en  général  de
# situations issues de la dérivation ou de la composition.
#
# a) Syllabes internes vocaliques :
#
# On trouve quelques exemples de :
#
# — syllabe interne vocalique ouverte du type -V- :
#
# ree-aa-le : rire en même temps
#
# de-aa-le : mourir en même temps
#
# Le fait n'est pas très courant du point de vue euphonique. Le
# procédé, quoique vivant, demeure acceptable, néanmoins ces
# rencontres d'unités vocaliques sont généralement évitées par
# l'insertion facultative des consonnes w et y :
#
# ree-waa-le : rire en même temps de, feindre en riant
#
# sa-waa-le : expliquer en même temps
#
# ji-yaa-le : semer en même temps
#
# — On relève aussi des syllabes vocaliques fermées comme groupe
# interne, c'est le cas avec le dérivé :
#
# ree-aat-le : rire encore avec quelqu'un (pour lui)
#
# une syllabe vocalique du type VCC n'existe pas comme groupe
# interne.
#
# b) Syllabe interne consonantique :
#
# Comme syllabe ouverte de ce type CV on possède de très
# nombreux exemples :
#
# o-ba-li : bailler     leqa-li-ku : s'épanouir
#
#
#
# fa-tar-ñi : déboucher
#
# Mais à cette position on ne relève pas non plus de syllabe du
# type CVCC.
#
#
# ANALYSE PHONOLOGIQUE            49
#
# b) TRAITEMENT DES CONSONNES GÉMINÉES ET NASALISÉES.
#
# La question qui se pose intéresse principalement les consonnes
# géminées  dans  l'ensemble  de  leurs  situations  d'emploi  et  les
# nasalisées précédées d'une unité vocalique.
#
# Chaque fois qu'au sein d'un signe, une voyelle précède soit une
# géminée, soit une nasalisée, la réalisation de ces dernières s'opère
# comme si pratiquement l'une et l'autre se décomposaient en deux
# entités consonantiques.
#
# La géminée se présente comme la juxtaposition d'une implosive
# et d'une explosive :
#
# > <              > <
#
# bopp : tête       fatt : boucher
#
# ><                  > <
#
# gabb : piocher        dagg : couper
#
# La consonne nasalisée est réalisée comme la succession d'une
# nasale et de la nasalisée de même série.
#
# > <                  ><
#
# sàmp : plante        gent : déserter
#
# > <               > <
#
# taõk : pied       saõg : recouvrir
#
# Le phénomène qui peut offrir des difficultés d'interprétation
# semble par ailleurs jouer un rôle de différenciation dialectale.
#
# Le wolof de Gambie complète l'entité phonique en créant à
# partir de la consonne explosive finale une nouvelle tranche
# syllabique, à moins que ce ne soit évidemment le wolof du Sénégal
# qui aurait procédé à un amuissement vocalique. L'explication du
# reste n'a valeur que du point de vue diachronique. Toujours est-il
# que de part et d'autre s'est établi le parallélisme suivant :
#
# Wolof sénégalais         Wolof de Gambie
#
# > <                      ><
#
# bopp : tête            boppa : tête
#
# ><                      ><
#
# fatt : boucher           fatta : boucher
#
# > <                     > <
#
# samp : planter          sampa : planter
#
#
# 50         GRAMMAIRE DE WOLOF MODERNE
#
# Du point de vue d'une bonne prononciation, le sujet devrait
# articuler comme si :
#
# pour Fatt   il y avait   fat-t
#
# >  <
#
# et pour samp          samp mp
#
# Cette particularité aide à comprendre qu'à l'intervocalique la
# syllabation agit comme s'il y avait deux consonnes identiques mais
# sériées, l'une jouant le rôle de finale d'une syllabe, l'autre l'initiale
# d'une autre syllabe :
#
# > <                  >    <
#
# samp : planter       sam — mpi
#
# ><                        >    <
#
# fatt : boucher        Fattu : être obstrué
#
#
#
#
# ANALYSE STRUCTURO-SYNTAXIQUE
#
#
#
# L'étude des éléments du discours proposée ici, s'articule sur la
# mise en évidence de formes et de fonctions linguistiques.
#
# Les entités phoniques de la langue, sont des formes qui par les
# relations qu'elles établissent, et les significations qu'elles revêtent
# dans des énoncés acceptables en wolof, assument des fonctions.
#
# Tout énoncé susceptible de revêtir un sens et d'être compris
# dans la langue est nécessairement constitué par une ou plusieurs
# formes qu'il convient toujours de définir d'un point de vue
# fonctionnel.
#
# Pour des raisons de méthode et de commodité, l'analyse
# structuro-syntaxique qui est proposée ici sera menée en deux temps :
#
# —  dans la première partie, on s'attachera à établir une
# systématique des monèmes.
#
#
#
#
#
# PREMIÈRE PARTIE
#
# SYSTÉMATIQUE DES MONÈMES
# ET SYNTAGMES CARACTÉRISTIQUES
#
# La présentation des monèmes se fera dans le cadre des
# combinaisons plus ou moins régulières où on les rencontre
# généralement. Une telle procédure facilite leur analyse comme formes
# assumant nécessairement des fonctions.
#
#
#
# CHAPITRE PREMIER
#
# LES SYNTAGMES LEXICAUX
#
# Le syntagme lexical résulte de la mise en oeuvre d'une base.
# Cette base est caractérisée par un certain nombre de relations
# spécifiques. Sur le plan formel, on verra qu'elle peut être soit un
# simple monème ou lexème, soit un syntagme équivalent (ensemble
# de monèmes assurant la même fonction que le lexème) .
#
# Les éléments qui établissent avec une base lexicale des relations
# de spécification permettent, du fait de la nature même des rapports
# qu'ils introduisent, de distinguer entré deux types de syntagmes
# lexicaux :
#
# — le syntagme nominal d'une part,
#
# — le syntagme verbal d'autre part.
#
# L'ensemble de ces considérations amène à envisager trois
# moments dans l'analyse des syntagmes lexicaux :
#
# I — les formes lexicales,
#
# II — le syntagme nominal,
#
# III — le syntagme verbal.
#
#
# LES SYNTAGMES LEXICAUX           57
#
# SECTION I. - LES FORMES LEXICALES
#
# Les formes lexicales sont repérées et classées à partir de deux
# critères :
#
#
#
# —  selon leur disponibilité à assumer l'une ou l'autre des
# fonctions nominale et verbale ; on les définira comme formes
# monovalentes ou comme formes bivalentes.
#
#
#
# Les lexèmes revêtent ici le plus couramment la forme CVC ou
# CVCC ; on rencontre toutefois des formes telles que CVCV ou
# CVCCV (cette dernière forme est surtout le fait du dialecte gambien).
#
# Par rapport aux fonctions qu'ils peuvent assumer, on distinguera
# entre :
#
# — lexèmes monovalents,
#
# — lexèmes bivalents.
#
#
#
#
# nit : homme
# góor : mâle
# xar : mouton
# nag : boeuf
#
# sabar : tambour
#
# jigéen : femme, etc.
#
#
#
# xeeñ : sentir
#
# dagg : couper
#
# wàcc : abandonner, etc.
#
#
# 58         GRAMMAIRE DE WOLOF MODERNE
#
#
#
# Fonction verbale      Fonction nominale
# dem : partir  dem-na : il part    dem-bi : le départ
# wax     wax-na        wax ji
#
# lox       lox-na           lox-wi
#
# dox       dox-na          dox-bi
#
# dof       dof-na          dof-bi
#
# Sous-section II :
#
# CATÉGORIE DES SYNTAGMES DE FORMATION
#
# C'est une catégorie qui regroupe des formes polymonématiques.
# Ces bases lexicales qui résultent de la combinaison de plusieurs
# monèmes procèdent de la dérivation ou de la composition.
#
# I. — LA DÉRIVATION.
#
#   jiitu : précéder ; fit-al : mettre en tête   ).
#
# La présentation des formes dérivées se fera en allant du simple
# au complexe.
#
# Dans le cas de dérivation simple, il n'y a qu'un seul monème.
# Dans la dérivation complexe, il y a combinaison de plusieurs
# dérivatifs.
#
# LA DÉRIVATION SIMPLE.
#
# Elle concerne deux types de situations qui résultent l'une et
# l'autre de la complexité des formes utilisées simultanément pour sa
# réalisation.
#
#
# LES SYNTAGMES LEXICAUX           59
#
# A) DÉRIVATION SIMPLE AU PREMIER DEGRÉ.
#
# Le dérivatif est exprimé sur le plan formel par une seule
# manifestation localisée en un point unique.
#
#
#
# Les formes relevant de la dérivation simple au premier degré
# sont souvent monovalentes et dans ce cas généralement destinées à
# la fonction nominale.
#
# a) Dérivation par permutation consonantique :
#
# 1° Dérivation par permutation consonantique non nasale :
#
# soxor : méchant         coxor : méchanceté
#
# sëriñ : musulman         cëriñ : islam — l'état de musulman
#
# guy : baobab           buy : fruit du baobab
#
# fas : cheval            pas : petit cheval
#
# far : être allié           par : allié, alliance
#
# wor : trahir            kor : trahison
#
# wàlaf : habitant du Lof     jolof : pays du Lof, pays wolof
#
#
# Waa joor : habitant des régions
# sablonneuse
#
#
#
# Par contre avec :
#
#   far naa : je suis allié  par : alliance
# on possède en far une base polyvalente.
#
#
# 60         GRAMMAIRE DE WOLOF MODERNE
#
# 2° Dérivation par préfixation consonantique :
#
# ajoor : habitant de l'intérieur  Kajoor : région du Sénégal
#
# añaan : jaloux          kañaan : jalousie
#
# aaréen : arachide        kaaréen : petite quantité d'arachide
#
# addu : répondre         kaddu : parole, tonnerre
#
# andaar : instrument de mesure  kandaar : le même instrument
#
# Ces formes dérivées sont toutes monovalentes et à fonction
# nominale.
#
# 3° Dérivation par flexion du prolongement morphologique ¹ :
#
# La même forme revêt des sens différents selon le prolongement
# morphologique qui l'affecte :
#
# néeg bi : la maison
#
# ...
#
# (2) yaa õgi, mi õgi : te voilà, le voilà
#
# Dans tous les cas, on peut ici intervertir l'ordre syntaxique et
# coordonner les formes de structure juxtaposées :
#
# (1) foo jaõge xërëm : où as-tu été initié en sciences occultes
#
# (2) ci Pël yi ag ci Séeréer si, ag ci Ñomiõka yi : chez les Peul, les
# Sérère, etc.
#
# (2) ya õgi te mi õgi : le voilà et le voilà
#
# ¹ Ils ne sont toutefois pas des énoncés alternants car les énoncés alternants ne peuvent
# être coordonnés. Ainsi dans l'ensemble l'impossibilité de coordonner ou d'alterner ici des
# constituants ou formes de structure indique que ces formes sont soit autonomes, soit
# dépendantes.
#
#
# 196         GRAMMAIRE DE WOLOF MODERNE
#
# b) Avec des énoncés prédicatifs quelle que soit la forme de leur
# base :
#
#
#
# nit la, nit õga : il est homme, tu es homme
#
# ci biir la, ci biir a biir la : c'est à l'intérieur, à l'intérieur même
#
#
#
# kookule la kookule taxaw la : c'est celui-là, celui-là debout
#
# kenn la kenn doõõ la : c'est un seul, un seul
#
#
#
# dem naa, dem õga, dem na : j'ai été, tu as été, il a été
#
#
#
# Dans tous les cas où les énoncés sont prédicatifs, la possibilité
# de les coordonner ou de les alterner existe :
#
# dem naa, te dem õga, te dem na : j'ai été et tu as été et lui il a été
# ou encore :
#
# dem õga, te dem na, te dem naa : tu as été et il a été et moi aussi j'ai
# été
#
# noona góor gi dugg, xale yi gis ka, mu toog, ñépp toog : alors l'homme
# entra, les enfants le virent, il s'assit, tous s'assirent
#
# Il est à noter ici que mu toog et ñépp toog établissent des rapports
# de coordination et non góor gi toog et xale yi gis ka qui établissent une
# relation de dépendance, et on ne peut les alterner.
#
# 2° Avec des énoncés complétifs.
#
# La juxtaposition est possible s'il s'agit :
#
# a) d'énoncés complétifs directs :
#
# bëgg naa góor ñi ñëw, xale yi ñëw, jigéen ñi toog : je souhaite que les
# hommes viennent, que les enfants viennent et que les femmes
# s'asseyent
#
# nee waa jii gor la, goor la, jambe la : il dit que ce Monsieur est un
# homme, il est noble, il est brave
#
# defe naa du kookuu, du kookee : je crois que ce n'est pas celui-ci ce n'est
# pas celui-là
#
#
# FONCTIONS ET FORMES D'ÉNONCÉS        197
#
# b) d'énoncés complétifs indirects :
#
# demal : ndax mu ñëw, ndax mu meddi : vas-y pour qu'il vienne, pour
# qu'il ne soit plus fâché
#
# ñëwël ndax xale yi di ay liggéeykat, di ay jambaar : viens pour que les
# enfants soient des travailleurs, soient des braves
#
# demal, ndax mu di, leneen, mu di feneen : vas-y pour que ce soit autre
# chose, que ce soit ailleurs
#
# 3° Avec des énoncés alternants.
#
# Ici la juxtaposition peut concerner :
#
# a) des énoncés alternants simples comme dans les situations qui
# suivent :
#
# Les énoncés sont à prédicat verbal :
#
# õga dem õga bañ dem dana ñëw : il viendra que tu veuilles ou non
# ou encore :
#
# dana ñëw õga bañ dem õga dem
#
# sans prédicat :
#
# tày ci suba, tày ci õgoon ma fiy nekk : ce matin ou ce soir c'est moi qui
# suis ici
#
# ou encore pour un même sens :
#
# maa fiy nekk : tày ci õgoon, tày ci suba
#
# b) des énoncés alternants et complétifs.
#
# Ici, nombre de cas peuvent être envisagés comme par exemple :
#
# avec des énoncés à prédicat :
#
# bëgg në õga ñëw, mu bañ dem su nëjul : je veux que tu viennes, qu'il
# refuse de partir s'il n'y a pas de soleil
#
# ou encore :
#
# bëgg naa õga ñëw mu dem su õgeen noppée : je veux, si vous avez fini,
# que tu viennes et qu'il parte
#
# sans prédicat :
#
# bëgg në õga ñëw ci subë ci juróomi waxtu ci sedd bi : je veux
# que tu viennes le matin à cinq heures dans la fraîcheur
# ou encore pour un même sens :
#
# bëgg naa ci juróomi waxtu, ci subë, õga ñëw
#
# defewoon na, ci subë si, ci bes bi, daa dem : je croyais que tu irais, ce
# matin, ce jour
#
#
# 198         GRAMMAIRE DE WOLOF MODERNE
#
# ou encore pour un même sens :
#
# defewoon na, daa dem, ci bes bi ci subë si
#
# VI. — LA COORDINATION
#
# La relation de coordination établit ici un rapport entre les
# énoncés assurant une même fonction. Ces énoncés peuvent être
# autonomes, complétifs ou alternants. Deux énoncés coordonnés
# doivent pouvoir se substituer à leur position syntaxique respective.
# Sinon, il s'agirait d'énoncé en relation d'expansion. Ainsi la
# forme te peut être un fonctionnel subordinatif ou coordinatif selon
# que les énoncés qu'elle relie peuvent ou non se substituer à leur
#
# position respective.
#
# Dans góor gi bëgg na õga dem te mu ñëw : l'homme veut que tu
# ailles et qu'il vienne
#
# te est un fonctionnel subordinatif car :
#
# góor gi bëgg na mu ñëw te õga dem a un tout autre sens
#
#
#
#
#
# a) avec des énoncés non prédicatifs on peut envisager si :
#
# — la base est nominale comme dans les exemples (2) :
#
# fo jëm : où vas-tu ?
#
# ci Séeréer yi ag Pël yi : chez les Sérère et les Peul
#
# — la base est pronominale :
#
# (1) té jëm ? : où vas-tu ?
#
# (2) ci ñi ak ca nee : chez ceux-ci et ceux-là
#
# b) avec des énoncés prédicatifs on peut envisager si :
#
# — la base est nominale :
#
# nit la te góor õga : c'est un homme de chair et d'os et tu es un homme
#
# — la base est pronominale :
#
# kooku la, te keneen la : c'est celui-là et c'est un autre
#
#
# FONCTIONS ET FORMES D'ÉNONCÉS        199
#
# — la base est verbale :
#
# góor gi dem te xale yi dugg : que l'homme parte et que les enfants
# entrent
#
# dem naa te demuloo : j'ai été et tu n'as pas été
#
# 2° Coordination d'énoncés complétifs.
#
# La coordination est possible ici s'il s'agit d'énoncés complétifs
# directs. Ainsi peut-on envisager :
#
# — avec des énoncés à prédicat verbal :
#
# góor gi bëgg na õga dem te xale yi toog : l'homme souhaite que tu partes
# et que les enfants restent
#
# ne jigéen ji ñëw te mu toog : il demande que la femme vienne et que lui
# il reste
#
# — avec des énoncés à prédicat nominal tels que les exemples (2) :
#
# (2) defewoon naa góor gi mag la te ndaw si nit la : je croyais que
# l'homme était mûr et que la femme était saine d'esprit
#
# — avec des énoncés à prédicat pronominal :
#
# defewoon naa góor gi kenn ki la, te xale bi kooku la : je croyais que
# l'homme c'était cet autre et que l'enfant c'était celui-là
#
# —  avec des énoncés complétifs indirects on peut envisager si
# ceux-ci sont :
#
# — des énoncés à prédicat verbal, des exemples tels que :
#
# demal ndax mu ñëw ndax it mu génn : vas-y afin qu'il vienne et aussi
# afin qu'il sorte
#
#
#
# ñëwël ndax xale yi di mbër te it ñu di ay jambaar : viens pour que les
# enfants soient des lutteurs et aussi qu'ils soient des braves
#
# — des énoncés à prédicat pronominal qui permettent des exemples
# du genre de :
#
# soppi leen ba ñu di ñeñeen te seeni xalaat di leneen : change-les à tel
# point qu'ils soient autres et que leur opinion aussi soit toute autre.
#
#
#
#
# 200         GRAMMAIRE DE WOLOF MODERNE
#
# a) si les énoncés sont alternants et simples :
#
# soo demee ag soo demul itam : dana ñëw : que tu partes ou que tu ne
# partes pas il viendra
#
# ou encore pour le même sens :
#
# dana ñëw soo demul ag soo demee itam
#
# tay ag demb yépp ñëw na : il est venu hier et aujourd'hui
# ou encore :
#
# ñëw na demb yépp ag tay
#
# b) si les énoncés sont alternants et complétifs :
#
# bëgg na soo demee : mu dellusi te góor gi ñëw : il veut, lorsque tu iras
# que lui, il revienne et que l'homme aussi revienne
#
# ou encore :
#
# bëgg na góor gi ñëw te mu dellusi soo demee : il veut que l'homme vienne
# et que lui, il revienne si tu pars
#
# dañu defewoon ni daa dem ci subë ag ci õgoon yépp : on croyait que tu
# allais partir matin et soir
#
# ou encore :
#
# dañu defewoon ci õgoon ag ci suba yépp da dem
#
# 4° Formes de coordinatifs.
#
# Les exemples qui sont fournis ci-dessus permettent d'illustrer la
# situation de quelques formes assumant une fonction de coordinatif.
#
# te : et, ensuite, or, etc...
#
# est une forme qui, dans certains cas,
# doit être considérée comme un coordinatif :
#
# góor ñi dañu tayel te jigéen ñi du ñu deglóo : les hommes sont des
# paresseux et les femmes ne savent pas écouter
#
# xale yi bëgg nañu dikk, te mag ni ñaan nañu õgeen dem : les enfants
# veulent venir et les adultes souhaitent que vous partiez
#
# gis naa góor googu demoon Ndar te õga abaloon ka sa gaal : j'ai vu
# l'homme qui était parti à Saint-Louis et auquel tu prêtas ta pirogue
#
# Le dernier exemple porte sur la coordination de deux énoncés.
#
# L'un est appositif, l'autre direct ¹ :
#
# — googu demoon Ndar
#
# — « googu » (entendu) te õga abaloon ka sa gaal
#
# ¹ En fait cette possibilité de coordonner un énoncé appositif et un énoncé direct du type
# de celui qu'on a ici et qui complete un élément pronominal apposé montre la similitude des
# fonctions assurées par ces deux formes d'expansion.
#
#
# FONCTIONS ET FORMES D'ÉNONCÉS        201
#
# te  est  en  particulier  l'élément  de  coordination  d'énoncés
# appositifs :
#
# gis naa góor gi doon wax te toogoon ci suuf : j'ai vu cet homme qui
# parlait et qui était assis par terre
#
# góor gee dem walla xale yee noppi ? : c'est l'homme qui est parti ou
# bien ce sont les enfants qui se sont tus ?
#
# xale yee ñaan walla mag née bëgg õga dem ? : ce sont les enfants
# qui ont demandé ou les adultes qui ont voulu que tu partes ?
# demal Ndar mu mën ñëw walla mu yonnée : va à Saint-Louis
# pour qu'il puisse venir ou qu'il envoie quelqu'un
#
#
#
# mbaa : ou bien, ou alors, etc...
#
# góor gee dem mba xale yee toog : ou l'homme est parti ou les enfants
# sont assis
#
# sa baay né õga dem mba õga nibbisi : ton père te demande de partir ou
# de rester à la maison
#
# daõgeen di naõgu mbaa du dem : vous acceptez ou il ne part pas
#
# góor gi dem na waaye xale yi demuñu : l'homme est parti mais les
# enfants ne le sont pas
#
#
#
# Par exemple, à propos de deux propositions ayant une même
# forme comme sujet :
#
# sa bay bëggul õgeen di génn ag di wëndéelu : ton père n'aime pas que
# vous sortiez et que vous vous baladiez
#
#
#
#
#
#
# 202         GRAMMAIRE DE WOLOF MODERNE
#
# may na la ndax xale yi beg te it õga ànd ak ñom : il t'a fait un cadeau
# pour que les enfants soient contents et que toi aussi tu les
# accompagnes
#
#
# jëgg day wut fu mu jaar ag itam na mu laqoo : le convoyeur doit
# chercher où passer et aussi comment se cacher
#
# jigéen ji ñaan na ndax xale yi agg te itam seen baay nekk fa : la femme
# pria pour que les enfants arrivent et aussi pour que leur père soit
# dans les lieux
#
# ,
# etc... :
#
# bëgg na sa waajur ñëw te nak ñu fay kà : il veut que tes parents
# viennent et surtout qu'ils le payent
#
# góor gi dem na ndax õgeen ñëw te nak kenn bañ leen foog : l'homme est
# parti pour que vous veniez sans que personne, surtout, ne le
# soupçonne
#
# na õgeen dem ndax gerte gi ñëw te nak ñjaay mi jar benn yoon : allez
# pour que l'arachide arrive et qu'enfin les ventes marchent une fois
# pour toutes
#
#
#
# du bañ boo naõgoo ag it boo yaboo ci liggéey bi : il ne refusera pas si tu
# acceptes et aussi (si tu) t'engages dans le travail
#
# yaakaaroon na ni, mag ñi du ñu ci agg foofu te it xale yi nekkunu fi
# woon : il espérait que les gens d'âge n'en seraient pas arrivés là et
# aussi que les enfants étaient absents
#
#
#
#
# CHAPITRE III
#
# L'INTERROGATION
#
# Il existe quatre procédés pour exprimer l'interrogation dans le
# cadre du discours. Il s'agit :
#
# — de l'intonation,
#
# — de l'usage d'un monème pronominal interrogatif
#
# — de l'emploi d'un déterminatif interrogatif
#
# — de la mise en oeuvre d'un fonctionnel interrogatif.
#
# A) L'intonation. Elle peut affecter n'importe quel type d'énoncé :
#
# a) Avec un énoncé non prédicatif on peut envisager un certain
# nombre de situations telles que :
#
#
#
#
# (2) :
#
# (1) gis naa Samba : j'ai vu Samba
#
# (2) Samba ? : Samba ?
#
# (3) waaw Samba : oui Samba
#
# (1) gis naa ka ci bir : je l'ai vu à l'intérieur
#
# (2) ci bir sax ? : à l'intérieur même ?
#
# (3) waaw ci bir : oui à l'intérieur
#
# 2° cas d'un énoncé pronominal :
#
# (1) xam na kookule : il connaît celui-là
#
# (2) kii ? : celui-ci ?
#
# (3) waw kookule : oui celui-là
#
# (1) gis naa ka fii ! : je l'ai vu par ici !
#
# (2) ci fii ? : par ici ?
#
# (3) waaw ci fii : oui par ici
#
# (2) mi õgi fii ? : il est là ?
#
#
# an :
#
# L'INTERROGATION             205
#
# b) Avec un énoncé prédicatif les exemples sont indiqués par (2) :
# 1° cas d'un énoncé verbal :
#
# (2) gor gi dem ? : l'homme peut-il partir ?
#
# (2) dem õga ? : tu pars ?
#
# 2° avec un énoncé pronominal :
# keneen la ? : c'est un autre ?
# kookule la ? : c'est cet autre-là ?
#
# 3° avec un énoncé nominal :
# Samba la ? : c'est Samba ?
# góor la ? : c'est un homme ?
#
# B) Le pronom interrogatif. Il y a ici deux situations.
#
# La première procède de l'utilisation de monème de forme :
#
# kan dem na ? : qui est parti ?
#
# gis õga kan ? : tu as vu qui ?
#
# yan ñoo réer ? : lesquels se sont égarés ?
#
# ag ñan õga doon xeexal ? : tu te battais avec qui ?
#
# fan õga jëm? : où vas-tu ?
#
# La seconde procède de l'utilisation du monème de forme en u :
#
# ku dem ? : qui est parti ?
#
# koo ¹ jox xaalis ? : à qui as-tu donné de l'argent ?
#
# ñu dikkul ? : lesquels ne sont pas venus ?
#
# fu mu jëm ? : où va-t-il ?
#
# fu mu ? : où est-ce ?
#
# ku mu ? : qui est-ce ? etc...
#
# C) Le déterminatif interrogatif. Il forme syntagme avec une base
#
# nominale ou pronominale et permet d'envisager des situations telles
# que :
#
# góor gan moo dem ? : quel homme est parti ?
# nit ñan õga wax ? : tu parles de quels gens ?
# keneen kan la ? : qui, est-ce d'autres ?
#
# keneen kan õga wax ? : tu parles de qui d'autre ?
#
# ¹ koo est une contraction de ku õga.
#
#
# 206         GRAMMAIRE DE WOLOF MODERNE
#
# D) Les fonctionnels interrogatifs. Il s'agit de formes qui se situent
# avant ou après un énoncé. On en énumère un certain nombre :
# ana mu ? : où est-il ?
#
# ana góor gi ? : où est l'homme ?
#
# ana foo jëm ? : où est-ce que tu vas ?
#
# ndax : est-ce que ?
#
# ndax dem na ? : est-ce qu'il est parti ?
#
# ndax góor gi moo dem ? : est-ce l'homme qui est parti ?
#
# ndax réew mi am na alal ? : est-ce que le pays a des richesses ?
# ou : réew mi am na alal ndax ?
#
# xanaa : est-ce par hasard ?
#
# xanaa doo dem ? : tu ne partiras donc pas ?
#
# xand kenn demul ? : personne n'est donc parti ?
#
# ñaata ? : combien ?
#
# ñaata õgeen ? : combien êtes-vous ?
#
# na? : comment ?
#
# na õgeen def ? : comment allez-vous ?
#
# naka : comment ? de quelle manière ?
#
# naka õga def ? : comment vas-tu ?
#
# naka góor gi tudd ? : comment s'appelle l'homme ?
#
# naka õgeen bëggé góor gi dimëlé leen ? : comment voulez-vous que
# l'homme vous aide ?
#
# mbaa : est-ce que comme je le souhaite...
# est-ce comme je le crains que...
#
# Avec le fonctionnel mbaa, l'interrogation est formulée avec une
# idée de souhait ou de crainte à propos du fait évoqué :
#
# mbaa xale yi yeksi nañu ? : les enfants sont arrivés j'espère ?
#
# mbaa kenn génnul ? : j'espère que nul n'est sorti ?
#
# mbaa móo dem ? : j'espère que c'est lui qui a été ?
#
# Il peut être associé indifféremment aux formes verbales affectées
# ou non de la modalité pronominale.
#
# Par ailleurs, il possède des positions syntaxiques variables :
#
# kenn demul mbaa : (j'espère) que personne n'est parti
# ou :
#
# mbaa kenn demul
#
#
# L'INTERROGATION             207
#
# Des locutions qui sont en réalité des énoncés généralement à
# relation de prédication sont utilisées couramment comme procédés
# interrogatifs :
#
# lu tax ?
#
# lu waral ? : pourquoi ? (qu'est-ce, qui est la cause ?)
#
#
#
# TERMINOLOGIE LINGUISTIQUE
# WOLOF-FRANÇAIS
#
# amees : actuel.
#
# ameef : aoriste.
#
# amoon : inactuel, passé défini.
#
# àndandoo : combinaison.
#
# addu : mbir mu nopp di degg.
#
# addu : son, phonème (waxesna it : « soõ fonem »).
#
# mbóoleem-addu : entité phonique.
#
# addooku : phonétique, science phonétique — « fonetik ».
#
# adducaakoon : phonéticien « fonetikkat ».
#
# araf : addu wuy tabbi ci biir wax te kenn bañ ka mën séddale.
# araf : phonème, lettre.
#
# araf céex — ñaari araf yu niróo te ànd : géminée.
#
# araf céexal : gémination, géminée (araf séexal ou araf wu séex).
# araféef : consonne.
#
# araf raññee : prolongement morphologique, élément de « classé ».
#
# araféef raññee : prolongement morphologique simple.
#
# araf wu ubbéeku : walla araf ubbéeku fricative.
# araf wu tëju walla araf tëju : occlusive.
# araféef wu léer : consonne sonore.
#
# araféef wu tëx : consonne sourde.
#
#
#
# arafu digg : phonème médian.
# arafu ndorte : phonème initial.
# arafu geen : phonème final.
# apiko-dantaal : apico-dental.
# apiko-weller : apicovélaire.
# amees : actuel.
#
# raññe ameef : catégorie de l'actuel.
#
# birël, leeral, génne, wàne : montrer, élucider, mettre en évidence, identifier.
#
# bares : pluriel.
#
# raññe bares : catégorie de pluriel.
#
# bareedi : singulier.
#
#
# --------------------------------------------------

# %% [markdown]
# Let us create the extraction class.

# %%
# %%writefile wolof-translate/wolof_translate/utils/extract_new_sentences.ipynb
from typing import *
import pandas as pd
import pickle
import re
import os

class NewSentenceExtraction:

    def __init__(self, text: Union[str, None] = None, sent_sep: str = ":", corpus_1: str = "french", corpus_2: str = "wolof", save_directory: str = "data/additional_documents/diagne_sentences/", checkpoint_name: str = "new_sentences"):
        
        self.text = text
        
        self.corpus_1 = corpus_1
        
        self.corpus_2 = corpus_2
        
        self.sep = sent_sep
        
        self.groups = []
        
        self.index = 0
        
        self.save_directory = save_directory
        
        self.checkpoint = checkpoint_name
        
        self.extractions = {corpus_1: [], corpus_2: []}
        
    def __save(self):
        
        checkpoints = {
            # 'extractions': self.extractions,
            'index': self.index,
            # 'groups': self.groups
        }
        
        pd.DataFrame({'groups': self.groups}).to_csv(os.path.join(self.save_directory, 'groups.csv'), index=False)
        
        pd.DataFrame(self.extractions).to_csv(os.path.join(self.save_directory, 'extractions.csv'), index=False)
        
        with open(os.path.join(self.save_directory, self.checkpoint), "wb") as f:
            
            pickler = pickle.Pickler(f)
            
            pickler.dump(checkpoints)
    
    def sep_with_mark(self, group: str, mark: Union[str, None] = None):
        
        raise NotImplementedError
    
    def load(self):
        
        with open(os.path.join(self.save_directory, self.checkpoint), "rb") as f:
            
            depickler = pickle.Unpickler(f)
            
            checkpoints = depickler.load()
        
        try:
            
            self.extractions = pd.read_csv(os.path.join(self.save_directory, 'extractions.csv')).to_dict('list')
        
        except Exception:
            
            pass
             
        self.groups = pd.read_csv(os.path.join(self.save_directory, 'groups.csv'))['groups'].to_list()
        
        self.index = checkpoints['index']
    
    def add_groups(self, new_groups: list):
        
        self.groups += new_groups
        
        self.__save()
        
    def get_groups(self, stop_criterions: list = ["  ", "\n"], comparisons: list = []):
        
        assert not self.text is None
        
        i = 0
        
        a = 0
        
        g = 1
        
        while i < len(self.text):
            
            
            letter = self.text[i]
            
            if letter == self.sep:
                
                print(f"Extraction of group number {g}\n")
                
                b = i - 1 # index of letters before the current letter
                
                a = i + 1 # index of letters after the current letter
                
                corpus_1_s = [] # letters of the left sentence
                
                corpus_2_s = [] # letters of the right sentence
                
                stop = False
                
                for stop_cr in stop_criterions:
                    
                    if self.text[b-len(stop_cr)+1:b+1] == stop_cr:
                        
                        stop = True   
                
                while not stop:
                    
                    corpus_1_s.append(self.text[b])
                    
                    b -= 1
                    
                    stop = False
                
                    for stop_cr in stop_criterions:
                        
                        if self.text[b-len(stop_cr)+1:b+1] == stop_cr:
                            
                            stop = True 
                
                stop = False
                
                for stop_cr in stop_criterions:
                    
                    if self.text[a:a+len(stop_cr)] == stop_cr:
                        
                      stop = True   
                
                while not stop:
                    
                    corpus_2_s.append(self.text[a])
                    
                    a += 1
                    
                    stop = False
                
                    for stop_cr in stop_criterions:
                        
                        if self.text[a:a+len(stop_cr)] == stop_cr:
                            
                            stop = True   
                
                # reverse first sentence
                corpus_1_s.reverse()
                
                # add the sentences
                current_sentence = "".join(corpus_1_s).strip() + f" {self.sep} " + "".join(corpus_2_s).strip()
                
                if "".join(corpus_1_s).strip() != "" and "".join(corpus_2_s) != "":
                    
                    # verify if it is not already manually got
                    not_recuperated = True
                
                    for comparison in comparisons:
                        
                        if current_sentence in comparison:
                            
                            not_recuperated = False
                    
                    # verify if it is not already in the extracted groups
                    for group in self.groups:
                        
                        if current_sentence in group:
                            
                            not_recuperated = False
                    
                    if not_recuperated:
                        
                        self.groups.append(current_sentence.strip())
                        # print(current_sentence)
                
                        g += 1
                    
                        print("Successfully extracted !!\n")
                    
                        print("-----------------\n")
                
                        i = a - 1
                    
                        self.__save()
                
            i += 1
                        
        # print("The groups were successfully recuperated !")
    
    def replace_groups(self, 
                      re_match: str,
                      delete_re: Union[str, None] = None,
                      n_replace_max: int = 1,
                      load: bool = True,
                      save: bool = False, 
                      manual_replace: bool = False,
                      csv_file: str = "founded.csv",
                      force_replace: bool = False):
        
        # we load the data
        if load:
            
            self.load()
        
        # find the groups matching the match regex
        founded = [(i, self.groups[i]) for i in range(len(self.groups)) if re.match(re_match, self.groups[i])]
        
        print(f"Found groups matching the regular expression {re_match} are the followings:\n")
        
        [print(f'- {f[1]}') for f in founded]
        
        print("\n----------------------\n")
        
        # if regex for deletion are provided we replace those that will be found with a max number of replace 
        not_replaced = set()
        
        replaced = set()
        
        result = {}
        
        delete_re_ = input("Do you want to change the deletion' regex expression -> provide one if yes or give empty string ('') if not : ")
        
        if delete_re_ != '':
            
            delete_re = delete_re_
        
        if not delete_re is None or manual_replace:
            
            for i in range(len(founded)):
                
                f = founded[i][1]
                
                index = founded[i][0]
                    
                m_replace = 'n'
                
                if not force_replace and manual_replace:
                    
                    print(f"You will modify the following group:\n {f}")
                    
                    m_replace = input(f"\nDo you want to make a manual replacement of the group {f} -> Yes(y) or No(n). If you want to quit, press q!")
                    
                    if m_replace == 'q':
                        
                        break
                    
                    while not m_replace in ['y', 'n']:
                                    
                        replace_r = input(f"You must provide a response between Yes(y), No(n)!")
                
                    if m_replace != 'n':

                        print(f"The manual modification of the group\n {f}\n is done in the following file: {csv_file}\n!If you want to provide multiple new groups please make them in different lines")
                                    
                        finish = 'n'
                        
                        pd.DataFrame({'to_modify':[f]}).to_csv(csv_file, index = False)

                        while finish == 'n':
                            
                            finish = input("Did you finish to replace -> No(n) if you didn't finish yet, click any another key if Yes(y) : ")
                        
                        f = pd.read_csv(csv_file)['to_modify'].to_list()
                        
                    print("\n--------\n")
                                            
                if not delete_re is None and m_replace in ['n', '']:
                    
                    to_replace = set(re.findall(delete_re, f))
                    
                    replace_r = None
                    
                    for r in to_replace:
                        
                        if force_replace:
                            
                            f = f.replace(r, '', n_replace_max)
                            
                            replaced.add(f)
                        
                        else:
                            
                            replace_r = input(f"Do you want to replace the {r} string in the group:\n {f} ? Yes(y) or No(n). If you want to quit, press q!")
                            
                            if m_replace == 'q':
                        
                                break
                            
                            while not replace_r in ['y', 'n']:
                                
                                replace_r = input(f"You must provide a response between Yes(y) and No(n)!")
                            
                            if replace_r == 'y':
                            
                                f = f.replace(r, '', n_replace_max)
                                
                                replaced.add(f)
                            
                            else:       
                                
                                not_replaced.add(f)
                    
                    if not replace_r is None and replace_r == 'q':
                        
                        break
                                                 
                if isinstance(f, str): 
                    
                    f = [f.strip()]
                
                else:
                    
                    f = [f_.strip() for f_ in f]
                    
                try:
                
                    self.groups = self.groups[:index] + f + self.groups[index+1:]
                
                except IndexError:
                    
                    self.groups = self.groups[:index] + f 

                if len(f) > 1 and i != len(founded) - 1:
                    
                    for j in range(i + 1, len(founded)):
                        
                        founded[j] = (founded[j][0] + len(f) - 1, founded[j][1]) 
                    
                result[index] = f
                
            if save:
            
                print("Final result:")
                
                [print(v) for r, v in result.items()]
                
                save_result = input("Do you want to save the result ? Yes(y) or No(n)")
                
                while not save_result in ['y', 'n']:
                                    
                    replace_r = input(f"You must provide a response between Yes(y) or No(n) !")
                
                if save_result == 'y':
                    
                    self.__save()
        
        return {'founded': founded, 'result': result, 'replaced': replaced, 'not_replaced': not_replaced}
    
    def extraction_commands(self, 
                        add_end_mark_cmd: str = "a", 
                        pass_cmd: str = "p",
                        add_end_mark_on_all: str = "l",
                        add_upper_cmd: str = "u",
                        add_upper_on_all: str = "o",
                        sep_cmd: str = "_",
                        quit_cmd: str = "q",
                        ):
                    
        # recuperate the current command
        cm = input(f"Choose one of the following commands: \n- {add_end_mark_cmd}+group_nb1,group_nb2:mark|group_nb3,group_nb4:mark|...(or group_nb1-group_nbn:mark) : To add end mark on specific groups\
                \n- {add_end_mark_on_all}+mark : To add end mark of all groups, \n- {add_upper_cmd}+group_nb1,group_nb2,group_nb3,group_nb4,...(or group_nb1-group_nbn) : To uppercase the first letter of specific groups\
                    \n- {add_upper_on_all} : To uppercase the first letter of all the groups\
                        \n- {pass_cmd} : To accept all of the groups\
                            \n- {quit_cmd} : To stop the process\
                                \n- You can combine all two commands by underscore {sep_cmd} excepted for the two last commands !")
        
        cms = cm.split(sep_cmd)
        
        error = False
        
        if len(cms) == 2: 
            
            p_cm = [cms[0].split("+")[0], cms[1].split("+")[0]]

            if pass_cmd in p_cm or quit_cmd in p_cm or sep_cmd in p_cm:
                
                print(f"You cannot provide {pass_cmd}, {quit_cmd} or {sep_cmd} in combined commands !")
                
                error = True
            
            elif (p_cm[0] in [add_end_mark_cmd, add_end_mark_on_all] and p_cm[1] in [add_upper_cmd, add_upper_on_all]) or (
                p_cm[0] in [add_upper_cmd, add_upper_on_all] and p_cm[1] in [add_upper_cmd, add_upper_on_all]
            ):
                
                print("You cannot combine the same type of command: Type of commands are 'end mark' and 'upper'")
            
        elif len(cms) == 1:
            
            if not cms[0].split('+')[0] in [add_end_mark_cmd, add_end_mark_on_all, add_upper_cmd, add_upper_on_all, pass_cmd, quit_cmd]:
                
                print("You didn't provide a right command ! Please retry")
                
                error = True 
        
        else:
            
            print("You cannot provide more than 2 or 0 commands !")
            
        return cms, error
            
         
    def split_group(self, group: Union[list, str]):
        # we base on the colon critter to split the groups
        
        if isinstance(group, str):
            
            group = [group]
        
        sents = {
            self.corpus_1: [],
            self.corpus_2: []
            }
        
        for g in group:
            
            splits = g.split(':')
                
            middle = len(splits)//2
            
            cp1_corpus = "".join(splits[:middle])
            
            cp2_corpus = "".join(splits[middle:])

            sents[self.corpus_1].append(cp1_corpus.strip())
            
            sents[self.corpus_2].append(cp2_corpus.strip())
        
        return sents

    def add_end_mark(self, batch: dict, command: str):
        
        cm = command
        
        # recuperate the marks with groups and apply the transformations
        tfs = cm.split('|')
        
        for tf in tfs:
            
            if '-' in tf:
                
                groups = tf.split(':')[0].split('-')
                
                groups = list(range(int(groups[0]), int(groups[1]) + 1))
            
            else:
                
                groups = [int(nb) for nb in tf.split(':')[0].split(',')]
            
            mark = tf.split(':')[1]
            
            for nb in groups:
                
                batch[self.corpus_1][nb-1] += mark
                
                batch[self.corpus_2][nb-1] += mark
        
        return batch
    
    def add_upper(self, batch: dict, command: str):
        
        cm = command
        
        # recuperate the marks with groups and apply the transformations
        tfs = cm.split('|')
        
        for tf in tfs:
        
            # recuperate the marks with groups and apply the transformations
            if '-' in tf:
                    
                groups = tf.split('-')
                
                groups = list(range(int(groups[0]), int(groups[1]) + 1))
            
            else:
                
                groups = [int(nb) for nb in tf.split(',')]
        
            for nb in groups:
                
                batch[self.corpus_1][nb-1] = batch[self.corpus_1][nb-1][0].upper() + batch[self.corpus_1][nb-1][1:] 
                
                batch[self.corpus_2][nb-1] = batch[self.corpus_2][nb-1][0].upper() + batch[self.corpus_2][nb-1][1:] 
        
        return batch
    
    def inner_command(self, batch: dict):
        
        cp1_sents = batch[self.corpus_1]
        
        cp2_sents = batch[self.corpus_2]
                
        for i in range(0, len(batch[self.corpus_1])):
            
            cp1_sent = cp1_sents[i]
            
            cp2_sent = cp2_sents[i]
            
            if re.match('.*Mark\[.*\].*', cp2_sent):
                
                mark = re.findall('Mark\[.*\]', cp2_sent)[0]
                
                mark = mark.replace('Mark[', '').replace(']', '')
                
                cp1_sent = cp1_sent + mark
                
                cp2_sent = re.sub('Mark\[.*\]', '', cp2_sent, 1) + mark
                
            if re.match('.*Upper', cp2_sent):
                
                cp1_sent = cp1_sent[0].upper() + cp1_sent[1:]
                
                cp2_sent = cp2_sent[0].upper() + re.sub('Upper', '', cp2_sent, 1)[1:]

            cp1_sents[i] = cp1_sent
            
            cp2_sents[i] = cp2_sent
            
        batch[self.corpus_1] = cp1_sents
        
        batch[self.corpus_2] = cp2_sents

        return batch

    def extract_sentences(self, 
                          group_range: Union[tuple, None] = None, 
                          add_end_mark_cmd: str = "a", 
                          pass_cmd: str = "p",
                          add_end_mark_on_all: str = "l",
                          add_upper_cmd: str = "u",
                          add_upper_on_all: str = "o",
                          sep_cmd: str = "_",
                          quit_cmd: str = "q",
                          batch_size: int = 30,
                          load: bool = True,
                          save: bool = False,
                          csv_file: str = "batch.csv",
                          last_checkpoint: bool = True
                          ):
        
        
        # we load the data
        if load:
            
            self.load()
            
        # the group range is equal to a tuple containing the last saved index and the index of the last element in the list of groups
        # indices if nothing is given
        if last_checkpoint:
            
            if group_range is None: group_range = (self.index, len(self.groups)-1)
        
        else: 
            
            raise ValueError("You must provide a group range if last checkpoint is to False !")
        
        # change the number of displayed lines
        pd.options.display.max_rows = batch_size
        
        groups =  self.groups[group_range[0]:group_range[1]+1]
        
        # initialize the sub corpora
        sub_corpora = {
            self.corpus_1: [],
            self.corpus_2: []
            }
        
        i = 0
        
        # for each batch we will add the groups in a csv file and take a command
        for b in range(0, len(groups), batch_size):
            
            
            # recuperate a batch
            batch_ = groups[b: b + batch_size]
            
            # recuperate the index
            self.index += len(batch_)
            
            # split each group into two sentences and transform the obtained dictionary to a DataFrame
            batch = self.split_group(batch_)

            pd.DataFrame(batch).to_csv(csv_file, index=False)
            
            print(f"Which of the groups of batch number {i+1} do you consider to be complete sentences (see the file {csv_file}) ?")
            
            error = False
            
            cms = []
            
            try:
                
                cms, error = self.extraction_commands(add_end_mark_cmd, pass_cmd, add_end_mark_on_all, add_upper_cmd, add_upper_on_all, sep_cmd, quit_cmd)
            
            except Exception:
                
                print("You didn't provide a right group number !")
                
                error = True
            
            while error:
                
                error = False
                
                try:
                
                    cms, error = self.extraction_commands(add_end_mark_cmd, pass_cmd, add_end_mark_on_all, add_upper_cmd, add_upper_on_all, sep_cmd, quit_cmd)
                
                except IndexError:
                    
                    print("You didn't provide a right group number !")
                    
                    error = True
            
            # recuperate the batch
            batch = pd.read_csv(csv_file).to_dict('list')
            
            # add corrections
            batch = self.inner_command(batch)
            
            cm_type = ""
            
            quit_ = "n"
            
            for cm in cms:
                
                cm_type = cm.split('+')[0]
            
                if cm_type == add_end_mark_cmd:
                    
                    batch = self.add_end_mark(batch, cm.split("+")[1])
                
                elif cm_type == add_end_mark_on_all:
                    
                    mark = cm.split("+")[1]
                    
                    batch = self.add_end_mark(batch, ",".join([str(nb) for nb in range(1, len(batch[self.corpus_1]) + 1)]) + f":{mark}")
                
                elif cm_type == add_upper_cmd:
                    
                    batch = self.add_upper(batch, cm.split("+")[1])
                
                elif cm_type == add_upper_on_all:
                    
                    batch = self.add_upper(batch, ",".join([str(nb) for nb in range(1, len(batch[self.corpus_1]) + 1)]))
                
                elif cm_type == quit_cmd:
                    
                    quit_ = input("Are you sure you want to quit: Yes(y) or No(n)")
                    
                    while not quit_ in ['y', 'n']:
                        
                        quit_ = input("Are you sure you want to quit: Yes(y) or No(n)")

                    if quit_ == 'y':
                        
                        break
                
                print("\nBatch result")
                
                print(pd.DataFrame(batch).head(batch_size))
            
            print("\n--------------------\n\n")
            
            # add the batch to the sub corpora
            sub_corpora[self.corpus_1].extend(batch[self.corpus_1])
            
            sub_corpora[self.corpus_2].extend(batch[self.corpus_2])

            if cm_type == quit_cmd and quit_ == 'y':
                
                break
            
            else:
                
                if save:
                
                    save_ = input("Do you want to save the result ? Yes(y) or No(n)")
                    
                    while not save_ in ['y', 'n']:
                        
                        save_ = input("Do you want to save the result ? Yes(y) or No(n)")
                    
                    if save_ == 'y':
                        
                        self.extractions[self.corpus_1].extend(batch[self.corpus_1])
                        
                        self.extractions[self.corpus_2].extend(batch[self.corpus_2])
                        
                        self.__save()
            
            i += 1
        
        print("Finished !")
        
    def remove_duplicated_sentences(self, save: bool = False):
        
        # we load the data
        self.load()
        
        # use pandas to delete the duplicated rows
        extractions = pd.DataFrame(self.extractions)
        
        extractions.drop_duplicates(inplace=True)
        
        self.extractions = extractions.to_dict('list')
        
        # save the sentences
        if save:
            
            self.__save()

# %% [markdown]
# Let us recuperate the manually the extracted groups.

# %%
with open("data/diagne_manual_recuperation.txt", "r", encoding="utf-8") as f:
    
    comparisons = f.read().strip()

# %%
# print manually extracted groups' text
comparisons
# Out:
# "anal : ramasser des ordures pour quelqu'un   \namal ! : obtenir quelque chose pour quelqu'un  \nwànal : montrer quelque chose (à quelqu'un de la part de quelqu'un d'autre)\ndac : toucher, entrer en contact avec\ndad : user par frottement\nxaañoo : se briser la tête mutuellement\nraf : clignoter, bouger de façon subreptice\nlaaw : prendre dans un filet\ndar : écorché, usé par frottement\nlaw : s'étendre \nlaf : bande d'étoffe grimpante\nsiifal : accaparer quelque chose pour quelqu'un\nfay : abandonner le faj domicile conjugal\nxamp : mordre à pleines dents\nsat : battre quelqu'un à plusieurs\nsañ : faire preuve d'audace excessive, manque de gêne\nlaõ : s'exiler plus ou moins définitivement\nxajal: faire de la place à quelqu'un \nxajjal : frayer un chemin à quelqu'un\ndagu: adopter une attitude de serviteur vis-à-vis de quelqu'un\njëxi : être sur le point de s'épuiser\njoor : terrain sablonneux, mais aussi nom de personne\nmaõkoo : être de connivence  \nweõgalu : pencher d'un côté\nteõxu : jointure, articulation\ntoskare : connaître un mauvais sort pied\nwaa joor : habitant de l'Hinterland\nWaa joor : habitant des régions sablonneuse\ndogal : couper pour quelqu'un, halte, marché de bétail\ndemal : accomplir une démarche pour quelqu'un\nliggéeyaan : louer son travail à l'extérieur\nbokkaan : posséder en commun, copropriété\njam : piquer, émoustiller, stimuler\nmayle: contribuer à un cadeau fait par quelqu'un\ngénnandoo : sortir ensemble, sortie collective\ndendandoo : voisiner, voisin, voisinage\ngaawantu : se dépêcher, empressement\nnobaate : nourrir une petite passion, amourette\nñaanaatu : quémander, mendier, quémande\njéexaatu : fouiller le sol avec insistance\nwaxé : parler avec, parler à partir d'un lieu donné\ngoreel : annoblir, ennoblissement, libération\nñaareel : prendre une seconde femme, deuxième épouse\nwàññeeku : se retourner, retournement\nwaa joor, waajoor : habitants de l'arrière-pays\nwaa kaw, waakaw : habitant de l'intérieur\ncoppeekuwaay : manière de changer\nnaqadil : rendre désagréable\nndogalante : concession mutuelle\nxéewlu : bénéficier d'un sort favorable\ndaõõ-daõõ : de bruits et de mouvement, fracas\nraõõ-raõõ : de bruits et de mouvement, fracas\nkër-kër : de bruits et de mouvement, fracas\nwër wër lu : aller à droite et à gauche\nxarxarlekat : qui simule l'agonie\nñaari goroõi : aller danser le naari goroõ\njambaar du bare wax : (un) homme de courage n'abonde pas (en) paroles\nnit ki ci sama wet ak nit kooku mbokk la ñu : cet homme près de moi et celui là près (de toi) sont parents\nnit ka dem ag nit kooka dee duñu benn : l'homme parti et l'homme décédé ne sont pas les mêmes\nxale yooya daan ñëw ñëwëtuñu : les enfants qui venaient ne viennent plus\nwaaye nit kookii gaddaayoon nag dellusiwul : par contre, cet homme qui s'exila ne revint pas\njigéen joojule mu àndaloon mooy Ngóone : c'est cette femme qu'il accompagnait qui est Ngone\nnit ñooñii génn ay mbër lanu : ces gens qui sont sortis sont des lutteurs\nxammee õga waa joojule : tu reconnais cette personne-là (éloignée du locuteur)\nwaa jii ag waa joojale duñu benn : Cet homme-ci — devant nous — et cet homme-là (éloigné dans le temps) ne sont pas les mêmes\nXam õga xale bii ? : Tu connais cet enfant-ci ?\nXam õga bii xale ? : Tu connais cet enfant-ci ?\nSeet õga néeg buu ? : Tu as regardé dans cette chambre-ci ?\nSeet õga buu néeg ? : Tu as regardé dans cette chambre-ci ?\nXammee õga xale bee ? : Tu reconnais cet enfant-ci ?\nXammee õga bee xale ? : Tu reconnais cet enfant-ci ?\nXale bile ñëwul ? : Cet enfant-ci n'est pas venu ?\nBile xale ñëwul ? : Cet enfant-ci n'est pas venu ?\nXale bule laa wax ? : Je parle de cet enfant-ci ?\nBule xale laa wax ? : Je parle de cet enfant-ci ?\nXale bale laa wax ? : Je parle de cet enfant là-bas ?\nBale xale laa wax ? : Je parle de cet enfant là-bas ?\nGis naa xale booba ? : J'ai vu cet enfant-là ?\nGis naa booba xale ? : J'ai vu cet enfant-là ?\nXar muu duuful ? : Ce mouton n'est pas gras ?\nMuu xar duuful ? : C ...

# %% [markdown]
# Let us separated the groups by the brake line "\n".

# %%
comparisons = comparisons.split("\n")

# %%
# print again
comparisons
# Out:
# ["anal : ramasser des ordures pour quelqu'un   ",
#  "amal ! : obtenir quelque chose pour quelqu'un  ",
#  "wànal : montrer quelque chose (à quelqu'un de la part de quelqu'un d'autre)",
#  'dac : toucher, entrer en contact avec',
#  'dad : user par frottement',
#  'xaañoo : se briser la tête mutuellement',
#  'raf : clignoter, bouger de façon subreptice',
#  'laaw : prendre dans un filet',
#  'dar : écorché, usé par frottement',
#  "law : s'étendre ",
#  "laf : bande d'étoffe grimpante",
#  "siifal : accaparer quelque chose pour quelqu'un",
#  'fay : abandonner le faj domicile conjugal',
#  'xamp : mordre à pleines dents',
#  "sat : battre quelqu'un à plusieurs",
#  "sañ : faire preuve d'audace excessive, manque de gêne",
#  "laõ : s'exiler plus ou moins définitivement",
#  "xajal: faire de la place à quelqu'un ",
#  "xajjal : frayer un chemin à quelqu'un",
#  "dagu: adopter une attitude de serviteur vis-à-vis de quelqu'un",
#  "jëxi : être sur le point de s'épuiser",
#  'joor : terrain sablonneux, mais aussi nom de personne',
#  'maõkoo : être de connivence  ',
#  "weõgalu : pencher d'un côté",
#  'teõxu : jointure, articulation',
#  'toskare : connaître un mauvais sort pied',
#  "waa joor : habitant de l'Hinterland",
#  'Waa joor : habitant des régions sablonneuse',
#  "dogal : couper pour quelqu'un, halte, marché de bétail",
#  "demal : accomplir une démarche pour quelqu'un",
#  "liggéeyaan : louer son travail à l'extérieur",
#  'bokkaan : posséder en commun, copropriété',
#  'jam : piquer, émoustiller, stimuler',
#  "mayle: contribuer à un cadeau fait par quelqu'un",
#  'génnandoo : sortir ensemble, sortie collective',
#  'dendandoo : voisiner, voisin, voisinage',
#  'gaawantu : se dépêcher, empressement',
#  'nobaate : nourrir une petite passion, amourette',
#  'ñaanaatu : quémander, mendier, quémande',
#  'jéexaatu : fouiller le sol avec insistance',
#  "waxé : parler avec, parler à partir d'un lieu donné",
#  'goreel : annoblir, ennoblissement, libération',
#  'ñaareel : prendre une seconde femme, deuxième épouse',
#  'wàññeeku : se retourner, retournement',
#  "waa joor, waajoor : habitants de l'arrière-pays",
#  "waa kaw, waakaw : habitant de l'intérieur",
#  'coppeekuwaay : manière de changer',
#  'naqadil : rendre désagréable',
#  'ndogalante : concession mutuelle',
#  "xéewlu : bénéficier d'un sort favorable",
#  'daõõ-daõõ : de bruits et de mouvement, fracas',
#  'raõõ-raõõ : de bruits et de mouvement, fracas',
#  'kër-kër : de bruits et de mouvement, fracas',
#  'wër wër lu : aller à droite et à gauche',
#  "xarxarlekat : qui simule l'agonie",
#  'ñaari goroõi : aller danser le naari goroõ',
#  "jambaar du bare wax : (un) homme de courage n'abonde pas (en) paroles",
#  'nit ki ci sama wet ak nit kooku mbokk la ñu : cet homme près de moi et celui là près (de toi) sont parents',
#  "nit ka dem ag nit kooka dee duñu benn : l'homme parti et l'homme décédé ne sont pas les mêmes",
#  'xale yooya daan ñëw ñëwëtuñu : les enfants qui venaient ne viennent plus',
#  "waaye nit kookii gaddaayoon nag dellusiwul : par contre, cet homme qui s'exila ne revint pas",
#  "jigéen joojule mu àndaloon mooy Ngóone : c'est cette femme qu'il accompagnait qui est Ngone",
#  'nit ñooñii génn ay mbër lanu : ces gens qui sont sortis sont des lutteurs',
#  'xammee õga waa joojule : tu reconnais cette personne-là (éloignée du locuteur)',
#  'waa jii ag waa joojale duñu benn : Cet homme-ci — devant nous — et cet homme-là (éloigné dans le temps) ne sont pas les mêmes',
#  'Xam õga xale bii ? : Tu connais cet enfant-ci ?',
#  'Xam õga bii xale ? : Tu connais cet enfant-ci ?',
#  'Seet õga néeg buu ? : Tu as regardé dans cette chambre-ci ?',
#  'Seet õga buu néeg ? : Tu as regardé dans cette chambre-ci ?',
#  'Xammee õga xale bee ? : Tu reconnais cet enfant-ci ?',
#  'Xammee õga bee xale ? : Tu reconnais cet enfant-ci ?',
#  "Xale bile ñëwul ? : Cet enfant-ci n'est pas venu ?",
#  "Bile xale ñëwul ? : Cet enfant-ci n'est pas venu ?",
#  'Xale bule laa wax ? : Je parle de cet enfant-ci ?',
#  'Bule xale laa wax ? : Je parle de cet enfant-ci ?',
#  'Xale bale laa wax ? : Je parle de cet enfant là-bas ?',
#  'Bale xale laa wax ? : Je parle de cet enfant là-bas ?',
#  "Gis naa xale booba ? : J'ai vu cet enfant-là ?",
#  "Gis naa booba xale ? : J'ai vu cet enfant-là ?",
#  "Xar muu duuful ? : Ce mouton n'est pas gras ?",
#  "Muu xar duuful ? : Ce mouton n'est pas gras ?",
#  'Waxuma xale yooyale ? : Je ne parle pas de ces enfants ?',
#  'Waxuma yooyale xale ? : Je ne parle pas de ces enfants ?',
#  "Séen naa am xar : J'ai aperçu un mouton",
#  "Séen naa ab néeg : J'ai aperçu une maison",
#  "Séen naa ag guy : J'ai aperçu un baobab (am guy) ",
#  "Séen naa aw fas : J'ai aperçu un cheval",
#  "Séen naa as jigéen : J'ai aperçu une femme",
#  "Séen naa as ndaw : J'ai aperçu une jeune fille",
#  "Séen naa as lëf : J'ai aperçu une chose, une portion",
#  "Séen naa ay xar : J'ai aperçu des moutons",
#  "Séen naa ay fas : J'ai aperçu des chevaux",
#  "Séen naa ay yëf : J'ai aperçu des choses",
#  "Séen naa ay gëléem : J'ai aperçu des chameaux",
#  "Séen naa ay ndaw : J'ai aperçu des messagers",
#  "Séen naa ay jigéen : J'ai aperçu des femmes",
#  'Xar man moo réer ? : Quel moutons est égaré ?',
#  'Man xar moo réer ? : Quel moutons est égaré ?',
#  'Xar yan ñoo ñëw ? : Quels moutons sont arrivés ?',
#  'Yan xar ñoo ñëw ? : Quels moutons sont arrivés ?',
#  'Nit ñan ñoo ñëw ? : Quelles personnes sont venues ?',
#  'Yan nit ñoo ñëw ? : Quelles personnes sont venues ?',
#  "Xar yooyu yan õga moom ? : (les) quels moutons (qui) t'appartiennent ?",
#  'teralal mépp nit : honore tout homme',
#  'teralal bépp nit : honore tout homme',
#  'yeewal bépp xar : attache tout mouton',
#  'yeewal mépp xar : attache tout mouton',
#  'xar mépp man ? : quel mouton ?',
#  'xar mépp man ? : Quel mouton en entier ?',
#  "kenn nit ki ñëw na : l'un des homme (s) est venu ",
#  "nit kenn ki ñëw na : l'un des homme (s) est venu",
#  "benn nit ki ñëw na : l'un des homme (s) est venu",
#  'nit ñenn ñi yegseeguñu : certaines personnes ne sont pas encore arrivées',
#  'ñenn nit ñi yegseeguñu : certaines personnes ne sont pas encore arrivées',
#  'nit ñenn ñooñii laa wax : je parle de ces autres individus',
#  'ñenn nit ñooñii laa wax : je parle de ces autres individus',
#  'yenn xar yooyuu laa wax : je parle des autres moutons (ceux-là) ',
#  'xar yenn yooyu laa wax : je parle des autres moutons (ceux-là) ',
#  "xar menn man õga wax ? : tu parles de quel mouton (l'un) ? > ",
#  "menn xar man õga wax ? : tu parles de quel mouton (l'un) ?",
#  "yeneen fas laa bëgg : c'est d'autres chevaux que je veux",
#  "fas yéenen la bëgg : c'est d'autres chevaux que je veux",
#  "yeneen nit laa gis : c'est d'autres gens que j'ai vus",
#  "nit ñeñeen la gis : c'est d'autres gens que j'ai vus",
#  'gis õga jigéen ñeneen ñooñu ? : as-tu vu ces autres femmes (en question) ?',
#  'yeneen fas yan õga gis ? : quels autres chevaux as-tu vu ?',
#  'fas yeneen yan õga gis ? : quels autres chevaux as-tu vu ?',
#  'gis õga sa yan xarit ? : tu as vu quels amis à toi ?',
#  'gis õga sa xarit yan ? : tu as vu quels amis à toi ?',
#  'gis õga sa yeneen xarit yi : tu as vu les autres amis (eux)',
#  'gis õga sa xarit yeneen yi : tu as vu les autres amis (eux)',
#  "mbëggéelam googee woon a õgi fi ba tay : c'est son amour d'antan qui survit encore",
#  "nit laa : j'ai été quelqu'un ",
#  "nit õga : Tu as été quelqu'un ",
#  "nit la : Il a été quelqu'un ",
#  "nit lanu : Nous avons été quelqu'un ",
#  "nit õgeen : Vous avez été quelqu'un ",
#  "nit lañu : Ils ont été quelqu'un ",
#  "nit lañu : Elles ont été quelqu'un ",
#  'Laobe lë woon : je fus Laobé',
#  'Laobe õga woon : Tu fus Laobé',
#  'Laobe la woon : Il fut Laobé',
#  'Laobe lanu woon : Nous fûmes Laobé',
#  'Laobe õgeen woon : Vous fûtes Laobé',
#  'Laobe lañu woon : Ils furent Laobé',
#  'Laobe lañu woon : elles furent Laobé',
#  "gis naa nagu Tugël : j'ai vu (une) vache d'Europe",
#  "gis naa nagu Tugël : j'ai vu (des) vaches d'Europe",
#  'gisóon õga doomu jigéen joojale jan ? : tu as vu le fils de quelle femme (celle-là) ?',
#  'tann õga doomu benn jigéen jan ? : tu as choisi la fille de quelle femme ?',
#  "jënd naa xaru beneen waa jan? : j'aurais acheté le mouton de quelle autre personne ?",
#  "Amul benn ardow Jéeri boo xamul : il n'est de Ardo du Dieri que tu ne connaisses",
#  'Dem naa : je pars, je suis parti',
#  'Dem õga : Tu pars, Tu es parti',
#  'Dem na : Il part, il est parti',
#  'Dem nañu : Nous partons, nous sommes partis',
#  'Dem õgeen : Vous partez, vous êtes partis',
#  'Dem nañu : Ils partent, elles sont partis',
#  'Dem nañu : Ils partent, ils sont partis',
#  'soo ñëwóon, kon, demkoon naa : si tu étais venu, dans ce cas, je serais parti',
#  'fu mu bëgg ? : où veut-il ',
#  'fu mu bëgg ? : quelle partie ?',
#  'mi õgii di dem : le voilà qui part',
#  'mi õgiiy : le voilà qui part',
#  'diõga dem ? : tu iras ?',
#  'daõga dem ? : tu iras ?',
#  'gor gii di Lawbe Ndar : cet homme (qui) est (un) Laobe de Saint-Louis',
#  "maa di dem : c'est moi qui pars — qui suis en train de partir — qui dois partir — qui vais partir, etc...",
#  "góor gi doon dem : l'homme qui partait, qui devait partir, qui allait partir",
#  "su góor gi dee ñëw : si l'homme vient, si l'homme doit venir — quand l'homme viendra, etc...",
#  'bi õga dee dem : alors que tu partais — au moment où tu partais — du moment que tu pars, etc...',
#  "bi mu dee dem : du moment qu'il part — du fait qu'il doit partir, etc...",
#  "wool góor gi dul Kajgaamu fii : appelle l'homme qui n'est pas (un) Kangame d'ici",
#  'xam naa nit ñi dul Sërin : je connais les gens qui ne sont pas des Sérignes',
#  "bu mu fen bi mu dul ñëw : qu'il ne mente pas du moment qu'il ne vient pas",
#  "góor gi moo dulwoon boroom kër gi : c'est l'homme qui n'était pas le maître de maison",
#  'ñii dañu demul xanaa : ceux-ci ne partent peut-être pas — ne sont peut-être pas partis',
#  "góor gi doon na di nit koo xam ni : il se trouve que l'homme est de ces gens qui...",
#  'na ma : que je....',
#  'naa : que je....',
#  "na mu : qu'il...",
#  "na : qu'il...",
#  'ka : celui ',
#  'ñi : lesquels, auxquels ',
#  'ña : lesquels, auxquels',
#  'ñooña : lesquels, auxquels',
#  'ñu : lesquels, auxquels',
#  'ñooñu : lesquels, auxquels',
#  'yi : lesquels, auxquels ',
#  'ya : lesquels, auxquels',
#  'yooya : lesquels, auxquels',
#  'yu : lesquels, auxquels',
#  'yooyu : lesquels, auxquels',
#  "góor gi bëgg na gis ki demoon : l'homme voudrait voir celui qui était parti",
#  'nagi dëkk bii õga gis, wa ci ëpp sa baay Alfa moo ka moom : des boeufs que tu vois dans cette ville, (celui) le plus gros appartient à ton père Alfa.',
#  "wante woowa ma la yóot it deey bonul : mais celui que (ce boeuf) je t'ai donné n'est pas mauvais non plus",
#  'nuyul më ñépp te maarel ma bu baax ñooña õga dajeeloon : mon salut à tout le monde mais surtout honore de ma part ceux-là que tu rencontras.',
#  "nit ñi õga ma wàn ñépp, kii laa ci wóolu : des gens que tu m'as présentés celui que voici me dispose le plus à la confiance.",
#  'gis õga nag yii yépp, woowuu moo ci gën : des boeufs que tu vois, celui-là (tout près) est le meilleur.',
#  "mii maa ka moom, waaye moomule deey, xawma fu mu bokk : celui-ci (ce mouton) est à moi mais j'ignore d'où provient cet autre-là (près de toi).",
#  'yan fas õga bëggoon ak wan õga japp : quels chevaux voulais-tu et lequel as-tu pris ?',
#  "xëynë xar yi ñëw nañu wante gisaguma wenn : les moutons sont peut-être déjà arrivés, j'en n'ai encore vu aucun",
#  "sa jarbaat yi, jenn gënu kë ci tayel : aucun de tes neveux n'est aussi paresseux que celui-là.",
#  'yan fas õga bëggoon ak wan õga japp : quels chevaux voulais-tu et lequel as-tu pris ?',
#  'lépp jeex na : le tout est épuisé',
#  'gis õga kooku : tu as vu celui-ci ?',
#  'gis õga kookuu kan : tu as vu celui-là lequel ',
#  'gis õga kookale : tu as vu celui-là ?',
#  'gis õga ñooñale ñan : tu as vu ceux-là lesquels ',
#  "gaynde gee lekk moomu mépp : c'est le lion qui a mangé entièrement celui-là",
#  "waxtaan õga ag keneen kookule kan ? : tu aurais conversé avec qui d'autre ? ",
#  'ñenn nit : certaines gens (quelques-uns parmi les hommes) ',
#  'ñennu nit : certaines gens (quelques-uns parmi les hommes) ',
#  'yenniy kaddu : certaines paroles',
#  "taxawaayu kooka sax taxul nëw : la présence de celui-là même ne justifie pas qu'on vienne",
#  'ñéneen ñi sax demewuñu noonu ! : les autres mêmes ne sont pas si fameux !',
#  'ñooñu ñépp woon demuñu : tous ceux-là (dont il fut question) ne sont pas partis',
#  'nile : de cette manière',
#  'nule : de cette manière ci',
#  'nale : de cette manière-là',
#  'loolale : ce fait-là',
#  "népp noo defe baax na : de toute manière, quelle que soit ta façon d'agir c'est bien",
#  "foofu góor gi dem fu rafet la : l'endroit où l'homme est parti est beau, là / l'homme / parti / là / beau / est",
#  'fépp fu mu jëm foofu jàmm dana fa wacc : partout où il ira la paix descendra là, partout où / il descend / là / paix / descendra',
#  "képp ku dem, kooku raggal la : quiconque s'en va, celui-là est un froussard",
#  "kooku dem ku më bëgg la : c'est quelqu'un que j'apprécie, celui qui est parti",
#  'moom daal : lui, aussi',
#  'moom daal léegi addina dafa soppeeku : en fait le monde a changé de nos jours',
#  'mondé ci subë dafa naajoon : mais ce matin il y avait du soleil pourtant',
#  'te dey addina laabiir dafa ci baax : du reste la générosité est une bonne chose dans la vie',
#  "yéen ñi ci bir foofule lawoon : c'est vous-même qui étiez là à l'intérieur.",
#  '(3) ca ñoom : noonule taxaw : vers ceux qui sont debout là-bas',
#  "wax ji yépp, bañ-õga-ñëw la : tout ce verbiage, c'est pour que tu ne viennes pas",
#  'õga bañ ñëw ²÷ rafetul : le fait que tu ne viennes pas est préjudiciable',
#  "di tel-teli doõõ ²÷ taxul sotal dara : s'agiter simplement ne suffit à rien résoudre",
#  "maa õgii gis leen ma ²÷ du jëfu nit ku yiw : « me voici, regardez-moi » n'est pas le fait d'un homme serein",
#  "jigéen ji ag góor gi ²÷ ñjool lañu : la femme et l'homme sont de haute taille",
#  'jigéen ñi ag góor ñi ²÷ ñjóol lañu : les femmes et les hommes sont de haute taille',
#  "góor gi soppul : seen lekku Saalum yooyu : l'homme n'apprécie pas votre cuisine du Saloum",
#  'Amet jaay na : naaru-góoru Daawuda wa woon : Ahmet a vendu le pur-sang que David possédait',
#  'Siré ñaanal na Umar mi taxaw : Cire a prié pour Oumar qui se tient-là',
#  "sëriñ bi ñaan na : mayewoon : alalam ji ba mënkóon yalwaan : le marabout implora qu'il fût dans la situation de quelqu'un qui aurait fait don de sa fortune, pour être en mesure de demander l'aumône",
#  'deõk naa la : boobule woon : je te confie celui-là (dont il fut question au passé).',
#  "góor gi nee na la fi saõx : ci biti : l'homme t'a dit ici il y a un instant : dehors (de sortir)",
#  "góor gi ni : cam : l'homme fit pouah ! (l'homme émis un geste de regret)",
#  "góor gi may na nit dara : l'homme a donné quelque chose à quelqu'un",
#  "góor gi may na dara nit : l'homme a donné quelque chose à quelqu'un",
#  "góor gi wax na xale yi wax ju rafet : l'homme a tenu aux enfants de bons propos",
#  'deõk õga xalel liggéey bu rafetkon : tu confies à un enfant un travail qui eût été beau',
#  "xale bi mayul dara kii : l'enfant n'a rien donné à celui-ci",
#  "xale bi mayul kii dara : l'enfant n'a rien donné à celui-ci",
#  'joxal kenn liggéey bi : donne le travail à un autre',
#  'joxal liggéey bi kenn : donne le travail à un autre',
#  'mayal ñépp benn : donne un à chacun',
#  'mayal benn ñépp : donne un à chacun',
#  "abalal keneen ki demkoonul ki, sama téeré bi : prête à cet autre qui n'eût pas été, mon ouvrage",
#  "waxati ma la koon dara : je ne t'aurais rien répété",
#  'waxati ma la koon dara : je ne te répéterai plus jamais rien',
#  '(2) ci keneen ki : ci buntu kër gi : vers cet autre qui est devant la porte de la maison',
#  'attekat õgeen : ci ban yoon ? : vous êtes des juges en vertu de quel droit ?',
#  "moom mile : ci buntu kër gi la : c'est celui-là même devant le seuil de la maison",
#  'bul yaréediku niki waa jii : ne sois pas aussi impoli que cet individu',
#  'waxtaan õga ag ñépp gannaaw nooñii : tu as discuté avec tous sauf avec ceux-là',
#  "nit ki lekkul dara ak loxoom : l'homme n'a rien mangé avec la main",
#  "góor gi dem na ca tool ya : l'homme est allé aux champs",
#  "góor gi dem na tool ya : l'homme est allé aux champs",
#  "nit ki dóor na nag wi ak bant : l'homme a frappé la vache avec un bâton",
#  "waa ji day noyyee ak bakkan : l'individu respire avec son nez",
#  "waa ji day waxe bakkan : l'individu parle avec son nez ",
#  'yobul na ka õgooñ tool ya : il lui a amené du fourrage au champ',
#  'yobul na ka õgoon ca tool ya : il lui a amené du fourrage au champ',
#  "yobul na góor gi xar kërëm : il a amené à l'homme un mouton chez lui",
#  "yobul na fi xar góor gi : il y amena un mouton pour l'homme ",
#  "noona Gelwar bi : buur bi, daldi ni tekk : alors le roi Guelwar s'immobilisa",
#  'ñëwël ndax Musaa lamaanu réew mi : viens pour Moussa, lamane de ce pays',
#  'jéeg yi ak jaõx yi it dañu ñëw : les femmes mariées et les jeunes filles viendront',
#  "ndaw si ak waa ji itam dañu bëggul déggoo : la femme et l'homme non plus ne désirent s'entendre",
#  'sa xarit yi ag sa mbokk yi danañu ñëw : tes parents et tes amis viendront',
#  "jox na doom ji ak yaayam séen wall : il a donné à l'enfant et à sa mère leur part",
#  "set na ci biir ak ci biti itam : il a cherché à l'intérieur et à l'extérieur aussi",
#  "gis naa la : je t'ai vu",
#  "gis naa la ak moom : je t'ai vu avec lui",
#  "gis naa la yaw ak moom : je t'ai vu avec lui",
#  "gis naa la yaak moom : je t'ai vu avec lui",
#  'nit, gayndé, nag, àndoon nañu fi, ... : homme, lion, boeuf, allaient de concert...',
#  "xale yi set nañu ci biir, ci biti gisuñu dara : les enfants ont cherché à l'intérieur, à l'extérieur, mais n'ont rien trouvé",
#  'nit, gaynde, xar, ak bukki duñu ànd : homme, lion, mouton et hyène, ne vont pas ensemble',
#  'may na ka lëg, doomam ak nopp ya : il lui a donné le lièvre, ses petits et leurs oreilles',
#  "séetal ci bir, ci biti, ci suuf ak ci kaw : regarde à l'intérieur, à l'extérieur, en bas et en haut",
#  "moontin góor gi jambaar la lool ci liggéey bi : et pourtant l'homme est dur à la tâche",
#  "(2) jigéen ñi demuñu Ndar ba tày : les femmes n'ont été à Saint-Louis jusqu'ici",
#  "nit ku baax la : c'est un homme gentil",
#  "nit la ku baax : c'est un homme gentil",
#  "ndaw la : góor gi di wut : c'est un messager que cherche l'homme",
#  "õga dem la : góor gi bëgg : que tu partes, c'est ce que désire l'homme",
#  "(2) ci ki ñëw ba ñu xammee ka : chez celui qui est venu et qu'on a reconnu",
#  "góor gi dem : ba mu ñëw ? : l'homme peut-il partir jusqu'à ce qu'il vienne",
#  "na góor gi dem : ba xale yi yeksi : l'homme doit s'en aller jusqu'à ce que les enfants reviennent",
#  "xale bi ne : õgeen dugg : mu gis leen : l'enfant dit d'entrer pour qu'il vous voie",
#  "li õga wax la : ndaw si taamu : c'est ce que tu as dit que la jeune femme préfère",
#  '(2) bëggóon : õgeen dem rekk : le désir non exaucé de vous voir partir, désir (vous partiez simplement)',
#  "góor gi nee : xale yi demkoon nañu fa : l'homme soutient que les enfants y eussent été",
#  '(3) góor : googule ñëwóon : mi õgi : cet homme qui vint autrefois, le voilà',
#  "jox naa téere bi góor : gi ñëw : j'ai donné le livre à l'homme qui est venu",
#  "abal naa téere bi góor googule gi dem : j'ai prêté le livre à cet homme parti",
#  "lépp : lu baax la góor gii bëgg : c'est tout ce qui est beau qui séduit cet homme",
#  "keneen kooku génn yeksiwul : cet autre qui est sorti n'est pas encore arrivé",
#  "jox na ka keneen ku sawar : il l'a donné à quelqu'un d'autre de très actif",
#  "may naa ka keneen : ku ka gën : je l'ai donné à quelqu'un de meilleur que lui.",
#  "(2) ci kooku : ndax mu wettëliku : avec celui-là, afin qu'il ne soit pas seul",
#  "góor gaa õgoogule : ndax kenn bañ génn : voilà l'homme ainsi nul ne bougera",
#  "ñawoon la : ba bi mu fiy joge : c'était ceux-là même jusqu'à ce qu'il parte",
#  "foofu la : ba ba ñuy gis feneen : c'est là jusqu'au moment où nous trouverons un autre lieu",
#  "ci fii la : ba ba ñuy gis feneen : c'est là jusqu'à ce qu'on trouve un autre endroit",
#  'amal õgor : ba mën nekk nit : aie assez de sérénité pour conserver ta dignité',
#  "Faatim la : soo demee : c'est Fatim, si on va au fond des choses (peut-être)",
#  "soo demee : Faatim la : c'est Fatim, si on va au fond des choses (peut-être)",
#  "gaynde la : ku dem : c'est peut-être un lion",
#  "góor gi la : yaakaar naa : je crois que c'est l'homme",
#  'so demee : mi õgiy wax : il est là, peut-être',
#  'soo bëggul : ci fii kóon : ici alors, si tu refuses',
#  "soo demee : kookule la : c'est celui-là peut-être",
#  "defe naa : keneen kii la : c'est l'autre je crois",
#  "du kii : defe naa : je crois que ce n'est pas celui-ci",
#  "su bëggul : na dem : qu'il parte s'il ne veut pas",
#  "du ñëw : defe naa : je crois qu'il ne viendra pas",
#  "ma defe : góor gi dem na : l'homme est parti je crois",
#  "ma defe : góor gii dem la : c'est l'homme qui part je crois",
#  'dellu biir Ndar soo bëggée : retourne au centre de Saint-Louis si tu veux',
#  'dellu soo bëggée biir Ndar : si tu veux retourne au centre de Saint-Louis',
#  "góor gee ni : mi õgi fi : soo demee : c'est l'homme qui a dit qu'il est là certainement",
#  "soo demee : góor gee ni mi õgi fi : certainement c'est l'homme qui a dit qu'il est là",
#  "góor gee ni : soo demee mi õgi fi : c'est l'homme certainement qui a dit qu'il est là",
#  "góor gee ni nit la soo demee : c'est l'homme qui a soutenu qu'il est sain d'esprit peut-être",
#  "soo demee góor gee ni nit la : peut-être est-ce l'homme qui a dit qu'il est sain d'esprit",
#  "góor gee ni soo demee nit la : l'homme a peut-être soutenu qu'il est sain d'esprit",
#  "góor gee ni kookule la : soo demee : c'est l'homme qui a dit que c'est celui-là peut-être",
#  "soo demee : góor gee ni : kookule la : peut-être l'homme a-t-il dit que c'est celui-là",
#  "góor gee ni : kookule la : soo demee : l'homme a dit que c'est celui-là peut-être",
#  "sa yay nee : soo yeggee dana dellusi : ta mère promet de revenir si tu vas jusqu'au bout",
#  "sa yay nee : dana dellusi soo yeggee : ta mère dit qu'elle reviendra si tu vas jusqu'au bout",
#  '(2) ci Séeréer si, ci Ñoomiõka yi, ci Pël yi : chez les Sérère, les Peul, les Niominka',
#  '(2) ci Pël yi ag ci Séeréer si, ag ci Ñomiõka yi : chez les Peul, les Sérère, etc.',
#  "noona góor gi seet lëf ki, seetat mbir mi : alors l'homme reconsidéra la chose, reconsidéra l'affaire.",
#  "dem õga, te dem na, te dem naa : tu as été et il a été et moi aussi j'ai été",
#  "noona góor gi dugg, xale yi gis ka, mu toog, ñépp toog : alors l'homme entra, les enfants le virent, il s'assit, tous s'assirent",
#  "bëgg naa góor ñi ñëw, xale yi ñëw, jigéen ñi toog : je souhaite que les hommes viennent, que les enfants viennent et que les femmes s'asseyent",
#  'nee waa jii gor la, goor la, jambe la : il dit que ce Monsieur est un homme, il est noble, il est brave',
#  "defe naa du kookuu, du kookee : je crois que ce n'est pas celui-ci ce n'est pas celui-là",
#  "demal : ndax mu ñëw, ndax mu meddi : vas-y pour qu'il vienne, pour qu'il ne soit plus fâché",
#  'ñëwël ndax xale yi di ay liggéeykat, di ay jambaar : viens pour que les enfants soient des travailleurs, soient des braves',
#  'demal, ndax mu di, leneen, mu di feneen : vas-y pour que ce soit autre chose, que ce soit ailleurs',
#  'dana ñëw õga bañ dem õga dem : il viendra que tu veuilles ou non',
#  "tày ci suba, tày ci õgoon ma fiy nekk : ce matin ou ce soir c'est moi qui suis ici",
#  "maa fiy nekk : tày ci õgoon, tày ci suba : ce matin ou ce soir c'est moi qui suis ici",
#  "bëgg në õga ñëw, mu bañ dem su nëjul : je veux que tu viennes, qu'il refuse de partir s'il n'y a pas de soleil",
#  "bëgg naa õga ñëw mu dem su õgeen noppée : je veux, si vous avez fini, que tu viennes et qu'il parte",
#  'bëgg në õga ñëw ci subë ci juróomi waxtu ci sedd bi : je veux que tu viennes le matin à cinq heures dans la fraîcheur',
#  'bëgg naa ci juróomi waxtu, ci subë, õga ñëw : je veux que tu viennes le matin à cinq heures dans la fraîcheur',
#  'defewoon na, ci subë si, ci bes bi, daa dem : je croyais que tu irais, ce matin, ce jour',
#  'defewoon na, daa dem, ci bes bi ci subë si : je croyais que tu irais, ce matin, ce jour',
#  "Dans góor gi bëgg na õga dem te mu ñëw : l'homme veut que tu ailles et qu'il vienne",
#  'dem õga te ñëw na : tu as été et il est venu.',
#  "góor gi dem te xale yi dugg : que l'homme parte et que les enfants entrent",
#  "góor gi bëgg na õga dem te xale yi toog : l'homme souhaite que tu partes et que les enfants restent",
#  'ne jigéen ji ñëw te mu toog : il demande que la femme vienne et que lui il reste',
#  "(2) defewoon naa góor gi mag la te ndaw si nit la : je croyais que l'homme était mûr et que la femme était saine d'esprit",
#  "defewoon naa góor gi kenn ki la, te xale bi kooku la : je croyais que l'homme c'était cet autre et que l'enfant c'était celui-là",
#  "demal ndax mu ñëw ndax it mu génn : vas-y afin qu'il vienne et aussi afin qu'il sorte",
#  'soo demee ag soo demul itam : dana ñëw : que tu partes ou que tu ne partes pas il viendra',
#  'dana ñëw soo demul ag soo demee itam : que tu partes ou que tu ne partes pas il viendra',
#  "ñëw na demb yépp ag tay : il est venu hier et aujourd'hui",
#  "bëgg na soo demee : mu dellusi te góor gi ñëw : il veut, lorsque tu iras que lui, il revienne et que l'homme aussi revienne",
#  "bëgg na góor gi ñëw te mu dellusi soo demee : il veut que l'homme vienne et que lui, il revienne si tu pars",
#  'dañu defewoon ni daa dem ci subë ag ci õgoon yépp : on croyait que tu allais partir matin et soir',
#  'dañu defewoon ci õgoon ag ci suba yépp da dem : on croyait que tu allais partir matin et soir',
#  'góor ñi dañu tayel te jigéen ñi du ñu deglóo : les hommes sont des paresseux et les femmes ne savent pas écouter',
#  'xale yi bëgg nañu dikk, te mag ni ñaan nañu õgeen dem : les enfants veulent venir et les adultes souhaitent que vous partiez',
#  "gis naa góor googu demoon Ndar te õga abaloon ka sa gaal : j'ai vu l'homme qui était parti à Saint-Louis et auquel tu prêtas ta pirogue",
#  "gis naa góor gi doon wax te toogoon ci suuf : j'ai vu cet homme qui parlait et qui était assis par terre",
#  "góor gee dem walla xale yee noppi ? : c'est l'homme qui est parti ou bien ce sont les enfants qui se sont tus ?",
#  'xale yee ñaan walla mag née bëgg õga dem ? : ce sont les enfants qui ont demandé ou les adultes qui ont voulu que tu partes ?',
#  "demal Ndar mu mën ñëw walla mu yonnée : va à Saint-Louis pour qu'il puisse venir ou qu'il envoie quelqu'un",
#  "géew bi day taxaw walla 1 ma dem : le cercle se forme ou je m'en vais",
#  "góor gee dem mba xale yee toog : ou l'homme est parti ou les enfants sont assis",
#  'sa baay né õga dem mba õga nibbisi : ton père te demande de partir ou de rester à la maison',
#  "góor gi dem na waaye xale yi demuñu : l'homme est parti mais les enfants ne le sont pas",
#  "sa bay bëggul õgeen di génn ag di wëndéelu : ton père n'aime pas que vous sortiez et que vous vous baladiez",
#  'bëgg naa õga dem te it õga noppi : je veux que tu partes et aussi que tu te taises',
#  "may na la ndax xale yi beg te it õga ànd ak ñom : il t'a fait un cadeau pour que les enfants soient contents et que toi aussi tu les accompagnes",
#  'jëgg day wut fu mu jaar ag itam na mu laqoo : le convoyeur doit chercher où passer et aussi comment se cacher',
#  'jigéen ji ñaan na ndax xale yi agg te itam seen baay nekk fa : la femme pria pour que les enfants arrivent et aussi pour que leur père soit dans les lieux',
#  "bëgg na sa waajur ñëw te nak ñu fay kà : il veut que tes parents viennent et surtout qu'ils le payent",
#  "góor gi dem na ndax õgeen ñëw te nak kenn bañ leen foog : l'homme est parti pour que vous veniez sans que personne, surtout, ne le soupçonne",
#  "na õgeen dem ndax gerte gi ñëw te nak ñjaay mi jar benn yoon : allez pour que l'arachide arrive et qu'enfin les ventes marchent une fois pour toutes",
#  "du bañ boo naõgoo ag it boo yaboo ci liggéey bi : il ne refusera pas si tu acceptes et aussi (si tu) t'engages dans le travail",
#  "yaakaaroon na ni, mag ñi du ñu ci agg foofu te it xale yi nekkunu fi woon : il espérait que les gens d'âge n'en seraient pas arrivés là et aussi que les enfants étaient absents",
#  'te itam : et aussi, et surtout',
#  'te nak : et, et aussi, et encore, et surtout, et sans que, et enfin',
#  'ag it : et aussi, mais aussi',
#  'jigéen ji bëgg na õgeen am waaye it õgeen di maye : la dame voudrait bien que vous ayez (des richesses) mais aussi que vous donniez.',
#  'mbaa : est-ce comme je le crains que...',
#  "kenn demul mbaa : (j'espère) que personne n'est parti",
#  "mbaa kenn demul : (j'espère) que personne n'est parti",
#  "lu tax ? : pourquoi ? (qu'est-ce, qui est la cause ?)",
#  "lu waral ? : pourquoi ? (qu'est-ce, qui est la cause ?)"]

# %% [markdown]
# Let us initialize the extraction class and extract the group in the book different from those already extracted.

# %%
new_sent_extraction = NewSentenceExtraction(txt_file)

# %%
new_sent_extraction.get_groups(comparisons=comparisons)
# Out:
# Extraction of group number 1
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 3
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 4
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 5
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 6
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 7
#
# Extraction of group number 7
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 8
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 9
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 10
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 11
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 12
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 13
#
# Extraction of group number 13
#
# Extraction of group number 13
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 14
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 15
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 16
#
# Extraction of group number 16
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 17
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 18
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 19
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 20
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 21
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 22
#
# Extraction of group number 22
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 23
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 24
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 25
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 26
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 27
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 28
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 29
#
# Extraction of group number 29
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 30
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 31
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 32
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 33
#
# Extraction of group number 33
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 34
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 35
#
# Extraction of group number 35
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 36
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 37
#
# Extraction of group number 37
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 38
#
# Extraction of group number 38
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 39
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 40
#
# Extraction of group number 40
#
# Extraction of group number 40
#
# Extraction of group number 40
#
# Extraction of group number 40
#
# Extraction of group number 40
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 41
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 42
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 43
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 44
#
# Extraction of group number 44
#
# Extraction of group number 44
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 45
#
# Extraction of group number 45
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 46
#
# Extraction of group number 46
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 47
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 48
#
# Extraction of group number 48
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 49
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 50
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 51
#
# Extraction of group number 51
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 52
#
# Extraction of group number 52
#
# Extraction of group number 52
#
# Extraction of group number 52
#
# Extraction of group number 52
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 53
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 54
#
# Extraction of group number 54
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 55
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 56
#
# Extraction of group number 56
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 57
#
# Extraction of group number 57
#
# Extraction of group number 57
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 58
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 59
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 60
#
# Extraction of group number 60
#
# Extraction of group number 60
#
# Extraction of group number 60
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 61
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 62
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 63
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 64
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 65
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 66
#
# Extraction of group number 66
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 67
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 68
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 69
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 70
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 71
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 72
#
# Extraction of group number 72
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 73
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 74
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 75
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 76
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 77
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 78
#
# Extraction of group number 78
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 79
#
# Extraction of group number 79
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 80
#
# Extraction of group number 80
#
# Extraction of group number 80
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 81
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 82
#
# Extraction of group number 82
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 83
#
# Extraction of group number 83
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 84
#
# Extraction of group number 84
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 85
#
# Extraction of group number 85
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 86
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 87
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 88
#
# Extraction of group number 88
#
# Extraction of group number 88
#
# Extraction of group number 88
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 89
#
# Extraction of group number 89
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 90
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 91
#
# Extraction of group number 91
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 92
#
# Extraction of group number 92
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 93
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 94
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 95
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 96
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 97
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 98
#
# Extraction of group number 98
#
# Extraction of group number 98
#
# Extraction of group number 98
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 99
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 100
#
# Extraction of group number 100
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 101
#
# Extraction of group number 101
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 102
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 103
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 104
#
# Extraction of group number 104
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 105
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 106
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 107
#
# Extraction of group number 107
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 108
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 109
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 110
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 111
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 112
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 113
#
# Extraction of group number 113
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 114
#
# Extraction of group number 114
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 115
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 116
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 117
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 118
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 119
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 120
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 121
#
# Extraction of group number 121
#
# Extraction of group number 121
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 122
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 123
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 124
#
# Extraction of group number 124
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 125
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 126
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 127
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 128
#
# Extraction of group number 128
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 129
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 130
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 131
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 132
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 133
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 134
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 135
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 136
#
# Extraction of group number 136
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 137
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 138
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 139
#
# Extraction of group number 139
#
# Extraction of group number 139
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 140
#
# Extraction of group number 140
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 141
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 142
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 143
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 144
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 145
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 146
#
# Extraction of group number 146
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 147
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 148
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 149
#
# Extraction of group number 149
#
# Extraction of group number 149
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 150
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 151
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 152
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 153
#
# Extraction of group number 153
#
# Extraction of group number 153
#
# Extraction of group number 153
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 154
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 155
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 156
#
# Extraction of group number 156
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 157
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 158
#
# Extraction of group number 158
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 159
#
# Extraction of group number 159
#
# Extraction of group number 159
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 160
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 161
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 162
#
# Extraction of group number 162
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 163
#
# Extraction of group number 163
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 164
#
# Extraction of group number 164
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 165
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 166
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 167
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 168
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 169
#
# Extraction of group number 169
#
# Extraction of group number 169
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 170
#
# Extraction of group number 170
#
# Extraction of group number 170
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 171
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 172
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 173
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 174
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 175
#
# Extraction of group number 175
#
# Extraction of group number 175
#
# Extraction of group number 175
#
# Extraction of group number 175
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 176
#
# Extraction of group number 176
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 177
#
# Extraction of group number 177
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 178
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 179
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 180
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 181
#
# Extraction of group number 181
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 182
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 183
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 184
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 185
#
# Extraction of group number 185
#
# Extraction of group number 185
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 186
#
# Extraction of group number 186
#
# Extraction of group number 186
#
# Extraction of group number 186
#
# Extraction of group number 186
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 187
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 188
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 189
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 190
#
# Extraction of group number 190
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 191
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 192
#
# Extraction of group number 192
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 193
#
# Extraction of group number 193
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 194
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 195
#
# Extraction of group number 195
#
# Extraction of group number 195
#
# Extraction of group number 195
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 196
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 197
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 198
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 199
#
# Extraction of group number 199
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 200
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 201
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 202
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 203
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 204
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 205
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 206
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 207
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 208
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 209
#
# Extraction of group number 209
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 210
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 211
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 212
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 213
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 214
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 215
#
# Extraction of group number 215
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 216
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 217
#
# Extraction of group number 217
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 218
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 219
#
# Extraction of group number 219
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 220
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 221
#
# Extraction of group number 221
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 222
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 223
#
# Extraction of group number 223
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 224
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 225
#
# Extraction of group number 225
#
# Extraction of group number 225
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 226
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 227
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 228
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 229
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 230
#
# Extraction of group number 230
#
# Extraction of group number 230
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 231
#
# Extraction of group number 231
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 232
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 233
#
# Extraction of group number 233
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 234
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 235
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 236
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 237
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 238
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 239
#
# Extraction of group number 239
#
# Extraction of group number 239
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 240
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 241
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 242
#
# Extraction of group number 242
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 243
#
# Extraction of group number 243
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 244
#
# Extraction of group number 244
#
# Extraction of group number 244
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 245
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 246
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 247
#
# Extraction of group number 247
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 248
#
# Extraction of group number 248
#
# Extraction of group number 248
#
# Extraction of group number 248
#
# Extraction of group number 248
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 249
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 250
#
# Extraction of group number 250
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 251
#
# Extraction of group number 251
#
# Extraction of group number 251
#
# Extraction of group number 251
#
# Extraction of group number 251
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 252
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 253
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 254
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 255
#
# Extraction of group number 255
#
# Extraction of group number 255
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 256
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 257
#
# Extraction of group number 257
#
# Extraction of group number 257
#
# Extraction of group number 257
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 258
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Extraction of group number 259
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 260
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 261
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 262
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 263
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 264
#
# Extraction of group number 264
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 265
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 266
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 267
#
# Extraction of group number 267
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 268
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 269
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 270
#
# Extraction of group number 270
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 271
#
# Extraction of group number 271
#
# Extraction of group number 271
#
# Extraction of group number 271
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 272
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 273
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 274
#
# Extraction of group number 274
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 275
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 276
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 277
#
# Extraction of group number 277
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 278
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 279
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 280
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 281
#
# Extraction of group number 281
#
# Extraction of group number 281
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 282
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 283
#
# Extraction of group number 283
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 284
#
# Extraction of group number 284
#
# Extraction of group number 284
#
# Extraction of group number 284
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 285
#
# Extraction of group number 285
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 286
#
# Extraction of group number 286
#
# Extraction of group number 286
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 287
#
# Extraction of group number 287
#
# Extraction of group number 287
#
# Extraction of group number 287
#
# Extraction of group number 287
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 288
#
# Extraction of group number 288
#
# Extraction of group number 288
#
# Extraction of group number 288
#
# Extraction of group number 288
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 289
#
# Extraction of group number 289
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 290
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 291
#
# Extraction of group number 291
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 292
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 293
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 294
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 295
#
# Extraction of group number 295
#
# Extraction of group number 295
#
# Extraction of group number 295
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 296
#
# Extraction of group number 296
#
# Extraction of group number 296
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 297
#
# Extraction of group number 297
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 298
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 299
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 300
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 301
#
# Extraction of group number 301
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 302
#
# Extraction of group number 302
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 303
#
# Extraction of group number 303
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 304
#
# Extraction of group number 304
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 305
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 306
#
# Extraction of group number 306
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 307
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 308
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 309
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 310
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Extraction of group number 311
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 312
#
# Extraction of group number 312
#
# Extraction of group number 312
#
# Extraction of group number 312
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 313
#
# Extraction of group number 313
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 314
#
# Extraction of group number 314
#
# Extraction of group number 314
#
# Extraction of group number 314
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 315
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 316
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 317
#
# Extraction of group number 317
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 318
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 319
#
# Extraction of group number 319
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 320
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 321
#
# Extraction of group number 321
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 322
#
# Extraction of group number 322
#
# Extraction of group number 322
#
# Extraction of group number 322
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 323
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 324
#
# Extraction of group number 324
#
# Extraction of group number 324
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 325
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 326
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 327
#
# Extraction of group number 327
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 328
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 329
#
# Extraction of group number 329
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 330
#
# Extraction of group number 330
#
# Extraction of group number 330
#
# Extraction of group number 330
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 331
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 332
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 333
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 334
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 335
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 336
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 337
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 338
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 339
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 340
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 341
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 342
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 343
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 344
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 345
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 346
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 347
#
# Extraction of group number 347
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 348
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 349
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 350
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 351
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 352
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 353
#
# Extraction of group number 353
#
# Extraction of group number 353
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 354
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 355
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 356
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 357
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 358
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 359
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 360
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 361
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 362
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 363
#
# Extraction of group number 363
#
# Extraction of group number 363
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 364
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 365
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 366
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 367
#
# Extraction of group number 367
#
# Extraction of group number 367
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 368
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 369
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 370
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 371
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 372
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 373
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 374
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 375
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 376
#
# Extraction of group number 376
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 377
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 378
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 379
#
# Extraction of group number 379
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 380
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 381
#
# Extraction of group number 381
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 382
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 383
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 384
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 385
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 386
#
# Extraction of group number 386
#
# Extraction of group number 386
#
# Extraction of group number 386
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 387
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 388
#
# Extraction of group number 388
#
# Extraction of group number 388
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 389
#
# Extraction of group number 389
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 390
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 391
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 392
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 393
#
# Extraction of group number 393
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 394
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 395
#
# Extraction of group number 395
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 396
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 397
#
# Extraction of group number 397
#
# Extraction of group number 397
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 398
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 399
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 400
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 401
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 402
#
# Extraction of group number 402
#
# Extraction of group number 402
#
# Extraction of group number 402
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 403
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 404
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 405
#
# Extraction of group number 405
#
# Extraction of group number 405
#
# Extraction of group number 405
#
# Extraction of group number 405
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 406
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 407
#
# Extraction of group number 407
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 408
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 409
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 410
#
# Extraction of group number 410
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 411
#
# Extraction of group number 411
#
# Extraction of group number 411
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 412
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 413
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 414
#
# Extraction of group number 414
#
# Extraction of group number 414
#
# Extraction of group number 414
#
# Extraction of group number 414
#
# Extraction of group number 414
#
# Extraction of group number 414
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 415
#
# Extraction of group number 415
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 416
#
# Extraction of group number 416
#
# Extraction of group number 416
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 417
#
# Extraction of group number 417
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 418
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 419
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 420
#
# Extraction of group number 420
#
# Extraction of group number 420
#
# Extraction of group number 420
#
# Extraction of group number 420
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 421
#
# Extraction of group number 421
#
# Extraction of group number 421
#
# Extraction of group number 421
#
# Extraction of group number 421
#
# Extraction of group number 421
#
# Extraction of group number 421
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 422
#
# Extraction of group number 422
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 423
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 424
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 425
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 426
#
# Extraction of group number 426
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 427
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 428
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 429
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 430
#
# Extraction of group number 430
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 431
#
# Extraction of group number 431
#
# Extraction of group number 431
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 432
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 433
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 434
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 435
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 436
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 437
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 438
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 439
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 440
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 441
#
# Extraction of group number 441
#
# Extraction of group number 441
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 442
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 443
#
# Extraction of group number 443
#
# Extraction of group number 443
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 444
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 445
#
# Extraction of group number 445
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 446
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 447
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 448
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 449
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 450
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 451
#
# Extraction of group number 451
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 452
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 453
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 454
#
# Extraction of group number 454
#
# Extraction of group number 454
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 455
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 456
#
# Extraction of group number 456
#
# Extraction of group number 456
#
# Extraction of group number 456
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 457
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 458
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 459
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 460
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 461
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 462
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 463
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 464
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 465
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 466
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 467
#
# Extraction of group number 467
#
# Extraction of group number 467
#
# Extraction of group number 467
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 468
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 469
#
# Extraction of group number 469
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 470
#
# Extraction of group number 470
#
# Extraction of group number 470
#
# Extraction of group number 470
#
# Extraction of group number 470
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 471
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 472
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 473
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 474
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 475
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 476
#
# Extraction of group number 476
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 477
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 478
#
# Extraction of group number 478
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 479
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 480
#
# Extraction of group number 480
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 481
#
# Extraction of group number 481
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 482
#
# Extraction of group number 482
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 483
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 484
#
# Extraction of group number 484
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 485
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 486
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 487
#
# Extraction of group number 487
#
# Extraction of group number 487
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 488
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 489
#
# Extraction of group number 489
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 490
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 491
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 492
#
# Extraction of group number 492
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 493
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 494
#
# ...
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1887
#
# Extraction of group number 1887
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1888
#
# Extraction of group number 1888
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1889
#
# Extraction of group number 1889
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1890
#
# Extraction of group number 1890
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1891
#
# Extraction of group number 1891
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1892
#
# Extraction of group number 1892
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1893
#
# Extraction of group number 1893
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1894
#
# Extraction of group number 1894
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1895
#
# Extraction of group number 1895
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1896
#
# Extraction of group number 1896
#
# Extraction of group number 1896
#
# Extraction of group number 1896
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1897
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1898
#
# Extraction of group number 1898
#
# Extraction of group number 1898
#
# Extraction of group number 1898
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1899
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Extraction of group number 1900
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1901
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1902
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1903
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1904
#
# Extraction of group number 1904
#
# Extraction of group number 1904
#
# Extraction of group number 1904
#
# Extraction of group number 1904
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1905
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1906
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1907
#
# Extraction of group number 1907
#
# Extraction of group number 1907
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1908
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1909
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1910
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1911
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1912
#
# Extraction of group number 1912
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1913
#
# Extraction of group number 1913
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1914
#
# Extraction of group number 1914
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1915
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1916
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1917
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1918
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1919
#
# Extraction of group number 1919
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Extraction of group number 1920
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Extraction of group number 1921
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1922
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1923
#
# Extraction of group number 1923
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1924
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1925
#
# Extraction of group number 1925
#
# Extraction of group number 1925
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1926
#
# Extraction of group number 1926
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1927
#
# Extraction of group number 1927
#
# Extraction of group number 1927
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Extraction of group number 1928
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1929
#
# Extraction of group number 1929
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1930
#
# Extraction of group number 1930
#
# Extraction of group number 1930
#
# Extraction of group number 1930
#
# Extraction of group number 1930
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Extraction of group number 1931
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Extraction of group number 1932
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1933
#
# Extraction of group number 1933
#
# Extraction of group number 1933
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Extraction of group number 1934
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1935
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1936
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1937
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1938
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1939
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1940
#
# Extraction of group number 1940
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1941
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1942
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1943
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1944
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1945
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1946
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1947
#
# Extraction of group number 1947
#
# Extraction of group number 1947
#
# Extraction of group number 1947
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1948
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1949
#
# Extraction of group number 1949
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1950
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1951
#
# Extraction of group number 1951
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1952
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1953
#
# Extraction of group number 1953
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1954
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1955
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1956
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1957
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1958
#
# Extraction of group number 1958
#
# Extraction of group number 1958
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1959
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1960
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1961
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1962
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1963
#
# Extraction of group number 1963
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1964
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1965
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1966
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1967
#
# Extraction of group number 1967
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1968
#
# Extraction of group number 1968
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1969
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1970
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1971
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1972
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1973
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1974
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1975
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1976
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1977
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1978
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1979
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1980
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1981
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1982
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1983
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1984
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1985
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1986
#
# Extraction of group number 1986
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1987
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1988
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1989
#
# Extraction of group number 1989
#
# Extraction of group number 1989
#
# Extraction of group number 1989
#
# Extraction of group number 1989
#
# Extraction of group number 1989
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1990
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1991
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1992
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1993
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1994
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1995
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1996
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1997
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1998
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 1999
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2000
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2001
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2002
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2003
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2004
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2005
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2006
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2007
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2008
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2009
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2010
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2011
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2012
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2013
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2014
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2015
#
# Extraction of group number 2015
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2016
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2017
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2018
#
# Successfully extracted !!
#
# -----------------
#
# Extraction of group number 2019
#
# Successfully extracted !!
#
# -----------------

# %% [markdown]
# Let us print some of the groups.

# %%
# new_sent_extraction.groups[-1000:]

# %% [markdown]
# Let us add the manually extract groups in the already extracted groups.

# %%
new_sent_extraction.add_groups(comparisons)

# %% [markdown]
# #### Modify the groups

# %% [markdown]
# It is time to add modification on the groups. We will make modification using the regular expressions. We will investigate the groups containing the following expression or marks:
#
# 1. groups beginning with a number surrounded by parentheses: re = \(\d+\).\*
# 2. groups with anti-slashes: re = .\*\\.\*
# 3. groups with comma: re = .\*,.\*
# 4. groups containing number: re = .\*\d+.\*
# 5. groups containing the "²÷" sign: re = .\*²÷.\*
# 6. groups containing the "²" or "¹" footnote numbers (we have already removed the number three): re = .\*[²¹]+.\*
# 7. groups containing the semicolons: re = .\*;.\*
# 8. groups containing the "÷" sign: re = .\*÷.\*
# 9. groups containing ems: re = .\*—.\*
# 10. groups containing more than one colon: re = .\*:.\*:.\*
# 11. groups containing parentheses: re = .\*(.\*).\*

# %% [markdown]
# **Regex 1** -->

# %%
result = new_sent_extraction.replace_groups("(\(\d+\)).*", force_replace=True, save=True)
# Out:
# Found groups matching the regular expression (\(\d+\)).* are the followings:
#
# - (1) nit ku góor la : c'est un homme
# - (2) nit ku baax la : c'est un homme généreux
# - (1) dem õga ? : tu as été ?
# - (2) déedéed ! : non !
# - (2) xanaa ! : bien sur !
# - (2) xëyna ! : peut-être ! etc...
# - (1) Loo gis ci biti : qu'as-tu vu dehors ?
# - (2) nit : (un) homme
# - (1) kooy waxal ? : à qui parles-tu ?
# - (2) buur : (au) roi
# - (2) Ndar : à Saint-Louis
# - (1) ki kan la ? : qui est-ce celui-ci ?
# - (2) jaambur : un quidam
# - (1) loo bëgg def ? : que veux-tu faire ?
# - (2) dem : partir
# - (1) looy ñaan ? : tu pries pour quoi ?
# - (2) rafet : (pour la) beauté
# - (1) ku ñëw ? : qui est venu ?
# - (2) kenn : personne
# - (1) ku wax ? : qui a parlé ?
# - (2) kookuu : celui-là
# - (1) neex na ? : c'est bon ?
# - (2) cam ! : pouah !
# - (1) baax na ? : c'est bon ?
# - (2) ex ! etc... : oh !
# - (1) ana góor gi ? : où est le Monsieur ?
# - (2) dem : na : il est parti
# - (1) xoolal gii garab : regarde cet arbre
# - (2) guy : la : c'est un boabab
# - (1) ana boroom kër gi ? : où est le maître de maison ?
# - (2) kile : la : c'est celui-là
# - (1) foo jëm ? : où vas-tu ?
# - (2) ci : biir : à l'intérieur
# - (1) ana õgoor ? : où est NGor ?
# - (2) õgoor : dem : (mais) NGor est parti
# - (1) koo gis ? : qui as-tu vu ?
# - (2) Musaa : Moussa
# - (1) loo jënd ? : qu'as-tu acheté ?
# - (2) mbubb : (un) boubou
# - (2) ci biir : à l'intérieur
# - (1) koo gis ? : qu'as-tu vu ?
# - (2) ci biir : vers celui-ci
# - (1) lu muy jooy ? : que pleure-t-il ?
# - (2) rafet : de (n')être pas belle
# - (2) nit la : c'est un homme
# - (3) nit la ci lu wér : c'est vraiment un homme
# - (3) nit la ku baax : c'est un homme gentil
# - (1) loo gis ? : qui as-tu vu ?
# - (2) nit : un homme
# - (3) nit : ki ñëw : l'homme qui est venu
# - (1) ko gis ? : qui as-tu vu ?
# - (2) kooku : celui-là
# - (3) kooku ci biir : celui-là à l'intérieur
# - (1) koo wax : de qui parles-tu ?
# - (2) keneen ki : de l'autre
# - (3) keneen kookule muy woo : de cet autre qu'on appelle
# - (2) ca ñoom : vers eux
# - (3) mi õgi foofule ci biir : il est là à l'intérieur
# - (2) dama bëgg : dem : c'est que je veux partir
# - (1) gis õga lan ? : tu as vu quoi ?
# - (2) aw gaynde : ci biir néeg bi : un lion dans la chambre
# - (2) wax na : ba mi õgi : il a tant parlé que le voilà
# - (2) laajal : ndax mi õgi fi : demande s'il est là
# - (2) sindax bi : ci foofuu : un lézard par là
# - (1) kañ õga ka gis? : quand l'as-tu vu ?
# - (2) tay : ci õgoon : aujourd'hui dans la soirée
# - (1) bëgg õga lan ? : tu veux quoi ?
# - (2) tuuti xaalis : ci yaw : un peu d'argent de toi
# - (1) kañ ñgay dem ? : quand pars-tu ?
# - (2) tay : ci subë : aujourd'hui, le matin
# - (1) àna õga ? : où es-tu ?
# - (2) maa õgi : ci biti : me voilà à l'extérieur
# - (2) maa õgi : ci bir kär gi : je suis dans la maison
# - (1) kooy set ? : qui cherches-tu ?
# - (2) kenn ki : ci kaw : celui qui est en haut
# - (1) loo bëgg ? : que veux-tu ?
# - (2) demoon : ba Ndar : avoir pu aller jusqu'à Saint-Louis
# - (2) dem naa : ba Ndar : j'ai été jusqu'à Saint-Louis
# - (2) woo naa ka ba mi õgi : je l'ai appelé, aussi est-il là
# - (1) là bëggóon ? : que souhaitais-tu ?
# - (2) demoon : fôfu : y avoir été
# - (2) tukki ëlëk : voyager demain
# - (2) demna saõx : il est parti il y a un instant
# - (2) Musaa rekk : Moussa seulement
# - (2) ci biir doõõ : à l'intérieur tout simplement
# - (2) yaa õgoogu rekk : te voilà tout simplement (te voilà, quoi)
# - (1) loolu laa bëgg : c'est là ce que je veux
# - (2) loolu doõõ : cela simplement
# - (2) Ibraayima : Ibrahima
# - (1) dem : partir
# - (1) ana õga ? : où es-tu ?
# - (2) maa õgii : me voici
# - (1) kooy waxal ? : a qui parles-tu ?
# - (2) Musaa ! : A Moussa !
# - (2) xalel õga ! : tu es jeune !
# - (2) demõga ? : tu pars ?
# - (3) yaw la ?, etc... : c'est toi ?
# - (2) góor googule mi õgii ! : cet homme le voilà !
# - (1) koo gis? : qui vois-tu ?
# - (2) nit kookule woon : cet homme dont il était question
# - (2) ci biir fiy leer : là où il y a de la lumière
# - (2) ci biir kër googule : à l'intérieur de cette maison
# - (1) ku def lii : qui a fait ceci ?
# - (2) góor gi ! : le Monsieur !
# - (2) ana góor gi ? : où est le Monsieur ?
# - (2) yaw mile mi fii : à toi qui es-là
# - (2) ci fii : par ici
# - (2) ci keneen : ki ñëw : chez l'autre qui est arrivé
# - (2) yéena õgoogule foofu ci biir : vous voilà là à l'intérieur
# - (2) mi õgi foofule : il est par-là
# - (2) góor gi dem ci biir kër gi ? : l'homme peut-il aller dans la maison ?
# - (2) demumawoon fenn tày ci suba : je n'avais été nulle part ce matin
# - (1) Aminta ñëw ? : Aminata peut-elle venir ?
# - (2) su bëggée kañ : si elle veut, bien sûr
# - (2) mi õgii dem na : le voilà, il est parti
# - (2) na dem ca Laamin Ngom : qu'il aille chez Lamine NGom
# - (2) Samba : mi ñëw ? ¹ : Samba : qui est venu ?
# - (2) góor gi : ñëw ? : l'homme qui est venu ?
# - (2) góor gi : xale bi woo : l'homme que l'enfant a appelé
# - (2) ci bir : foofu di leer : à l'intérieur : où il fait clair
# - (2) ana waa ji : muy wax ? : où est celui dont il parle ?
# - (1) koo woowul ? : qui n'as-tu pas appelé ?
# - (2) góor gi : mu àndi ² : l'homme qu'il a amené
# - (2) googu góor : mu àndal : cet homme qui l'accompagne
# - (2) kookule : õgay waxal : celui-là avec qui tu parles
# - (2) keneen : ki ñëw : l'autre, celui qui est arrivé
# - (2) ci foofu : õga jëm : là où tu vas
# - (2) ci foofu : ba õgeen dellusi : là-bas jusqu'à ce que vous reveniez
# - (2) keneen la : ku yeksi ? : c'est un autre qui est venu ?
# - (1) waaw : oui
# - (2) yooyu la : góor gi bëgg : c'est là ceux que l'homme désire
# - (2) yaw la : ndaw si sopp : c'est toi qui aimes la jeune femme
# - (1) kooy seet ? : qui cherches-tu ?
# - (2) góor gi : waa ji wax : l'homme dont parle cet individu
# - (2) ci kër gi : waa ji wax : dans la maison dont parle le Monsieur
# - (2) góor gi : kenn xamu ko : cet homme nul ne le connaît
# - (2) ci biir foofu : mu bënn : là, où il a fait un trou.
# - (2) ci ki : mu wax : chez celui qu'il a indiqué
# - (1) baax na ? : c'est bien ?
# - (2) ba fi : mu tollu : jusqu'ici c'est bon
# - (1) looy def ? : que fais-tu ?
# - (2) li : waa ji wax ¹ : ce que : cet homme a dit
# - (2) ci foofu : õga taxaw : là où tu es
# - (2) góor gi niwul : mi õgi fi : l'homme ne dit pas qu'il est là
# - (1) lan la ? : qu'est-ce qu'il y a ?
# - (2) bëgg na : góor gi dellusi : il veut (que) l'homme revienne
# - (2) góor gi nee : ñépp dem : l'homme demande à tous de partir
# - (1) loo gis ? : qu'as-tu vu ?
# - (2) nit : ku baax : quelqu'un de bien
# - (1) foo kay def ? : où le mets-tu ?
# - (2) ci teen : boobu bënn : dans ce puits qui coule
# - (2) keneen : ki ñëwulwoon kookee : cet autre qui n'était pas venu
# - (1) foo wax ? : où dis-tu ?
# - (1) ma seetal la lan ? : je veille sur quoi ?
# - (2) liggéey bii : ba mu sotti : sur le travail, jusqu'à ce qu'il soit fait
# - (2) ci biir : ndax mu dugg : à l'intérieur ! pour qu'il entre
# - (2) ci fii : ba ma ñëw : ici, jusqu'à ce qu'il vienne !
# - (1) ma toog fan ? : où puis-je m'asseoir ?
# - (1) ma def lan ? : que dois-je faire ?
# - (1) yan bes õga fa demoon ? : tu y as été quels jours
# - (2) tay, demb, bërki demb : hier, aujourd'hui, avant-hier
# - (1) foo jaõge xerëm ? : où t'es-tu initié en sciences occultes
# - (1) ci ñan õga jëm ? : tu vas vers qui ?
# - (2) ci kii, ci kuu, ci kee : vers, celui que voilà celui-ci, vers celui-là,
# - (1) ma may ñan ? : je donne à qui ?
# - (2) ñii, ñee, ñooñu : à ceux-ci, ceux-là, à ceux qui sont là-bas
# - (2) yaa õgi, mi õgi : te voilà, le voilà
# - (1) foo jaõge xërëm : où as-tu été initié en sciences occultes
# - (2) ya õgi te mi õgi : le voilà et le voilà
# - (1) té jëm ? : où vas-tu ?
# - (2) ci ñi ak ca nee : chez ceux-ci et ceux-là
# - (1) gis naa Samba : j'ai vu Samba
# - (2) Samba ? : Samba ?
# - (3) waaw Samba : oui Samba
# - (1) gis naa ka ci bir : je l'ai vu à l'intérieur
# - (2) ci bir sax ? : à l'intérieur même ?
# - (3) waaw ci bir : oui à l'intérieur
# - (1) xam na kookule : il connaît celui-là
# - (2) kii ? : celui-ci ?
# - (3) waw kookule : oui celui-là
# - (1) gis naa ka fii ! : je l'ai vu par ici !
# - (2) ci fii ? : par ici ?
# - (3) waaw ci fii : oui par ici
# - (2) mi õgi fii ? : il est là ?
# - (2) gor gi dem ? : l'homme peut-il partir ?
# - (2) dem õga ? : tu pars ?
# - (3) ca ñoom : noonule taxaw : vers ceux qui sont debout là-bas
# - (2) ci keneen ki : ci buntu kër gi : vers cet autre qui est devant la porte de la maison
# - (2) jigéen ñi demuñu Ndar ba tày : les femmes n'ont été à Saint-Louis jusqu'ici
# - (2) ci ki ñëw ba ñu xammee ka : chez celui qui est venu et qu'on a reconnu
# - (2) bëggóon : õgeen dem rekk : le désir non exaucé de vous voir partir, désir (vous partiez simplement)
# - (3) góor : googule ñëwóon : mi õgi : cet homme qui vint autrefois, le voilà
# - (2) ci kooku : ndax mu wettëliku : avec celui-là, afin qu'il ne soit pas seul
# - (2) ci Séeréer si, ci Ñoomiõka yi, ci Pël yi : chez les Sérère, les Peul, les Niominka
# - (2) ci Pël yi ag ci Séeréer si, ag ci Ñomiõka yi : chez les Peul, les Sérère, etc.
# - (2) defewoon naa góor gi mag la te ndaw si nit la : je croyais que l'homme était mûr et que la femme était saine d'esprit
#
# ----------------------
#
# Final result:
# ["nit ku góor la : c'est un homme"]
# ["nit ku baax la : c'est un homme généreux"]
# ['dem õga ? : tu as été ?']
# ['déedéed ! : non !']
# ['xanaa ! : bien sur !']
# ['xëyna ! : peut-être ! etc...']
# ["Loo gis ci biti : qu'as-tu vu dehors ?"]
# ['nit : (un) homme']
# ['kooy waxal ? : à qui parles-tu ?']
# ['buur : (au) roi']
# ['Ndar : à Saint-Louis']
# ['ki kan la ? : qui est-ce celui-ci ?']
# ['jaambur : un quidam']
# ['loo bëgg def ? : que veux-tu faire ?']
# ['dem : partir']
# ['looy ñaan ? : tu pries pour quoi ?']
# ['rafet : (pour la) beauté']
# ['ku ñëw ? : qui est venu ?']
# ['kenn : personne']
# ['ku wax ? : qui a parlé ?']
# ['kookuu : celui-là']
# ["neex na ? : c'est bon ?"]
# ['cam ! : pouah !']
# ["baax na ? : c'est bon ?"]
# ['ex ! etc... : oh !']
# ['ana góor gi ? : où est le Monsieur ?']
# ['dem : na : il est parti']
# ['xoolal gii garab : regarde cet arbre']
# ["guy : la : c'est un boabab"]
# ['ana boroom kër gi ? : où est le maître de maison ?']
# ["kile : la : c'est celui-là"]
# ['foo jëm ? : où vas-tu ?']
# ["ci : biir : à l'intérieur"]
# ['ana õgoor ? : où est NGor ?']
# ['õgoor : dem : (mais) NGor est parti']
# ['koo gis ? : qui as-tu vu ?']
# ['Musaa : Moussa']
# ["loo jënd ? : qu'as-tu acheté ?"]
# ['mbubb : (un) boubou']
# ["ci biir : à l'intérieur"]
# ["koo gis ? : qu'as-tu vu ?"]
# ['ci biir : vers celui-ci']
# ['lu muy jooy ? : que pleure-t-il ?']
# ["rafet : de (n')être pas belle"]
# ["nit la : c'est un homme"]
# ["nit la ci lu wér : c'est vraiment un homme"]
# ["nit la ku baax : c'est un homme gentil"]
# ['loo gis ? : qui as-tu vu ?']
# ['nit : un homme']
# ["nit : ki ñëw : l'homme qui est venu"]
# ['ko gis ? : qui as-tu vu ?']
# ['kooku : celui-là']
# ["kooku ci biir : celui-là à l'intérieur"]
# ['koo wax : de qui parles-tu ?']
# ["keneen ki : de l'autre"]
# ["keneen kookule muy woo : de cet autre qu'on appelle"]
# ['ca ñoom : vers eux']
# ["mi õgi foofule ci biir : il est là à l'intérieur"]
# ["dama bëgg : dem : c'est que je veux partir"]
# ['gis õga lan ? : tu as vu quoi ?']
# ['aw gaynde : ci biir néeg bi : un lion dans la chambre']
# ['wax na : ba mi õgi : il a tant parlé que le voilà']
# ["laajal : ndax mi õgi fi : demande s'il est là"]
# ['sindax bi : ci foofuu : un lézard par là']
# ["kañ õga ka gis? : quand l'as-tu vu ?"]
# ["tay : ci õgoon : aujourd'hui dans la soirée"]
# ['bëgg õga lan ? : tu veux quoi ?']
# ["tuuti xaalis : ci yaw : un peu d'argent de toi"]
# ['kañ ñgay dem ? : quand pars-tu ?']
# ["tay : ci subë : aujourd'hui, le matin"]
# ['àna õga ? : où es-tu ?']
# ["maa õgi : ci biti : me voilà à l'extérieur"]
# ['maa õgi : ci bir kär gi : je suis dans la maison']
# ['kooy set ? : qui cherches-tu ?']
# ['kenn ki : ci kaw : celui qui est en haut']
# ['loo bëgg ? : que veux-tu ?']
# ["demoon : ba Ndar : avoir pu aller jusqu'à Saint-Louis"]
# ["dem naa : ba Ndar : j'ai été jusqu'à Saint-Louis"]
# ["woo naa ka ba mi õgi : je l'ai appelé, aussi est-il là"]
# ['là bëggóon ? : que souhaitais-tu ?']
# ['demoon : fôfu : y avoir été']
# ['tukki ëlëk : voyager demain']
# ['demna saõx : il est parti il y a un instant']
# ['Musaa rekk : Moussa seulement']
# ["ci biir doõõ : à l'intérieur tout simplement"]
# ['yaa õgoogu rekk : te voilà tout simplement (te voilà, quoi)']
# ["loolu laa bëgg : c'est là ce que je veux"]
# ['loolu doõõ : cela simplement']
# ['Ibraayima : Ibrahima']
# ['dem : partir']
# ['ana õga ? : où es-tu ?']
# ['maa õgii : me voici']
# ['kooy waxal ? : a qui parles-tu ?']
# ['Musaa ! : A Moussa !']
# ['xalel õga ! : tu es jeune !']
# ['demõga ? : tu pars ?']
# ["yaw la ?, etc... : c'est toi ?"]
# ['góor googule mi õgii ! : cet homme le voilà !']
# ['koo gis? : qui vois-tu ?']
# ['nit kookule woon : cet homme dont il était question']
# ['ci biir fiy leer : là où il y a de la lumière']
# ["ci biir kër googule : à l'intérieur de cette maison"]
# ['ku def lii : qui a fait ceci ?']
# ['góor gi ! : le Monsieur !']
# ['ana góor gi ? : où est le Monsieur ?']
# ['yaw mile mi fii : à toi qui es-là']
# ['ci fii : par ici']
# ["ci keneen : ki ñëw : chez l'autre qui est arrivé"]
# ["yéena õgoogule foofu ci biir : vous voilà là à l'intérieur"]
# ['mi õgi foofule : il est par-là']
# ["góor gi dem ci biir kër gi ? : l'homme peut-il aller dans la maison ?"]
# ["demumawoon fenn tày ci suba : je n'avais été nulle part ce matin"]
# ['Aminta ñëw ? : Aminata peut-elle venir ?']
# ['su bëggée kañ : si elle veut, bien sûr']
# ['mi õgii dem na : le voilà, il est parti']
# ["na dem ca Laamin Ngom : qu'il aille chez Lamine NGom"]
# ['Samba : mi ñëw ? ¹ : Samba : qui est venu ?']
# ["góor gi : ñëw ? : l'homme qui est venu ?"]
# ["góor gi : xale bi woo : l'homme que l'enfant a appelé"]
# ["ci bir : foofu di leer : à l'intérieur : où il fait clair"]
# ['ana waa ji : muy wax ? : où est celui dont il parle ?']
# ["koo woowul ? : qui n'as-tu pas appelé ?"]
# ["góor gi : mu àndi ² : l'homme qu'il a amené"]
# ["googu góor : mu àndal : cet homme qui l'accompagne"]
# ['kookule : õgay waxal : celui-là avec qui tu parles']
# ["keneen : ki ñëw : l'autre, celui qui est arrivé"]
# ['ci foofu : õga jëm : là où tu vas']
# ["ci foofu : ba õgeen dellusi : là-bas jusqu'à ce que vous reveniez"]
# ["keneen la : ku yeksi ? : c'est un autre qui est venu ?"]
# ['waaw : oui']
# ["yooyu la : góor gi bëgg : c'est là ceux que l'homme désire"]
# ["yaw la : ndaw si sopp : c'est toi qui aimes la jeune femme"]
# ['kooy seet ? : qui cherches-tu ?']
# ["góor gi : waa ji wax : l'homme dont parle cet individu"]
# ['ci kër gi : waa ji wax : dans la maison dont parle le Monsieur']
# ['góor gi : kenn xamu ko : cet homme nul ne le connaît']
# ['ci biir foofu : mu bënn : là, où il a fait un trou.']
# ["ci ki : mu wax : chez celui qu'il a indiqué"]
# ["baax na ? : c'est bien ?"]
# ["ba fi : mu tollu : jusqu'ici c'est bon"]
# ['looy def ? : que fais-tu ?']
# ['li : waa ji wax ¹ : ce que : cet homme a dit']
# ['ci foofu : õga taxaw : là où tu es']
# ["góor gi niwul : mi õgi fi : l'homme ne dit pas qu'il est là"]
# ["lan la ? : qu'est-ce qu'il y a ?"]
# ["bëgg na : góor gi dellusi : il veut (que) l'homme revienne"]
# ["góor gi nee : ñépp dem : l'homme demande à tous de partir"]
# ["loo gis ? : qu'as-tu vu ?"]
# ["nit : ku baax : quelqu'un de bien"]
# ['foo kay def ? : où le mets-tu ?']
# ['ci teen : boobu bënn : dans ce puits qui coule']
# ["keneen : ki ñëwulwoon kookee : cet autre qui n'était pas venu"]
# ['foo wax ? : où dis-tu ?']
# ['ma seetal la lan ? : je veille sur quoi ?']
# ["liggéey bii : ba mu sotti : sur le travail, jusqu'à ce qu'il soit fait"]
# ["ci biir : ndax mu dugg : à l'intérieur ! pour qu'il entre"]
# ["ci fii : ba ma ñëw : ici, jusqu'à ce qu'il vienne !"]
# ["ma toog fan ? : où puis-je m'asseoir ?"]
# ['ma def lan ? : que dois-je faire ?']
# ['yan bes õga fa demoon ? : tu y as été quels jours']
# ["tay, demb, bërki demb : hier, aujourd'hui, avant-hier"]
# ["foo jaõge xerëm ? : où t'es-tu initié en sciences occultes"]
# ['ci ñan õga jëm ? : tu vas vers qui ?']
# ['ci kii, ci kuu, ci kee : vers, celui que voilà celui-ci, vers celui-là,']
# ['ma may ñan ? : je donne à qui ?']
# ['ñii, ñee, ñooñu : à ceux-ci, ceux-là, à ceux qui sont là-bas']
# ['yaa õgi, mi õgi : te voilà, le voilà']
# ['foo jaõge xërëm : où as-tu été initié en sciences occultes']
# ['ya õgi te mi õgi : le voilà et le voilà']
# ['té jëm ? : où vas-tu ?']
# ['ci ñi ak ca nee : chez ceux-ci et ceux-là']
# ["gis naa Samba : j'ai vu Samba"]
# ['Samba ? : Samba ?']
# ['waaw Samba : oui Samba']
# ["gis naa ka ci bir : je l'ai vu à l'intérieur"]
# ["ci bir sax ? : à l'intérieur même ?"]
# ["waaw ci bir : oui à l'intérieur"]
# ['xam na kookule : il connaît celui-là']
# ['kii ? : celui-ci ?']
# ['waw kookule : oui celui-là']
# ["gis naa ka fii ! : je l'ai vu par ici !"]
# ['ci fii ? : par ici ?']
# ['waaw ci fii : oui par ici']
# ['mi õgi fii ? : il est là ?']
# ["gor gi dem ? : l'homme peut-il partir ?"]
# ['dem õga ? : tu pars ?']
# ['ca ñoom : noonule taxaw : vers ceux qui sont debout là-bas']
# ['ci keneen ki : ci buntu kër gi : vers cet autre qui est devant la porte de la maison']
# ["jigéen ñi demuñu Ndar ba tày : les femmes n'ont été à Saint-Louis jusqu'ici"]
# ["ci ki ñëw ba ñu xammee ka : chez celui qui est venu et qu'on a reconnu"]
# ['bëggóon : õgeen dem rekk : le désir non exaucé de vous voir partir, désir (vous partiez simplement)']
# ['góor : googule ñëwóon : mi õgi : cet homme qui vint autrefois, le voilà']
# ["ci kooku : ndax mu wettëliku : avec celui-là, afin qu'il ne soit pas seul"]
# ['ci Séeréer si, ci Ñoomiõka yi, ci Pël yi : chez les Sérère, les Peul, les Niominka']
# ['ci Pël yi ag ci Séeréer si, ag ci Ñomiõka yi : chez les Peul, les Sérère, etc.']
# ["defewoon naa góor gi mag la te ndaw si nit la : je croyais que l'homme était mûr et que la femme était saine d'esprit"]

# %% [markdown]
# **Regex 2** -->

# %%
result = new_sent_extraction.replace_groups(".*/.*", save=True, manual_replace=True, csv_file="founded.csv", load=False)
# Out:
# Found groups matching the regular expression .*/.* are the followings:
#
# - na woon : de la manière dont ce fut, / manière / fuut
# - leneen loolee woon : cet autre fait-là, chose autre / celle-là / fut
# - moo di loola : quel démon ! / lui / être / cela
# - dafa di leneen : c'est qu'il s'agit d'autre chose, c'est / autre chose
# - góor : gi dem : l'homme qui est parti (l'homme / lequel / s'en alla)
# - kookule la : soo demee : c'est celui-là / peut-être
# - keneen ki la : defe naa : c'est l'autre / je crois
# - foofu góor gi dem fu rafet la : l'endroit où l'homme est parti est beau, là / l'homme / parti / là / beau / est
# - fépp fu mu jëm foofu jàmm dana fa wacc : partout où il ira la paix descendra là, partout où / il descend / là / paix / descendra
#
# ----------------------
#
# You will modify the following group:
#  na woon : de la manière dont ce fut, / manière / fuut
# The manual modification of the group
#  na woon : de la manière dont ce fut, / manière / fuut
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  leneen loolee woon : cet autre fait-là, chose autre / celle-là / fut
# The manual modification of the group
#  leneen loolee woon : cet autre fait-là, chose autre / celle-là / fut
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  moo di loola : quel démon ! / lui / être / cela
# The manual modification of the group
#  moo di loola : quel démon ! / lui / être / cela
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dafa di leneen : c'est qu'il s'agit d'autre chose, c'est / autre chose
# The manual modification of the group
#  dafa di leneen : c'est qu'il s'agit d'autre chose, c'est / autre chose
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor : gi dem : l'homme qui est parti (l'homme / lequel / s'en alla)
# The manual modification of the group
#  góor : gi dem : l'homme qui est parti (l'homme / lequel / s'en alla)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kookule la : soo demee : c'est celui-là / peut-être
# The manual modification of the group
#  kookule la : soo demee : c'est celui-là / peut-être
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  keneen ki la : defe naa : c'est l'autre / je crois
# The manual modification of the group
#  keneen ki la : defe naa : c'est l'autre / je crois
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  foofu góor gi dem fu rafet la : l'endroit où l'homme est parti est beau, là / l'homme / parti / là / beau / est
# The manual modification of the group
#  foofu góor gi dem fu rafet la : l'endroit où l'homme est parti est beau, là / l'homme / parti / là / beau / est
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fépp fu mu jëm foofu jàmm dana fa wacc : partout où il ira la paix descendra là, partout où / il descend / là / paix / descendra
# The manual modification of the group
#  fépp fu mu jëm foofu jàmm dana fa wacc : partout où il ira la paix descendra là, partout où / il descend / là / paix / descendra
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# Final result:
# ['na woon : de la manière dont ce fut']
# ['leneen loolee woon : cet autre fait-là', 'leneen loolee woon : cet autre chose qui fut']
# ['moo di loola : quel démon !', 'moo di loola : quel être !']
# ["dafa di leneen : c'est qu'il s'agit d'autre chose", "dafa di leneen : c'est que c'est autre chose", "dafa di leneen : c'est autre chose"]
# ["góor gi dem : l'homme qui est parti", "góor gi dem : l'homme qui s'en alla"]
# ["kookule la soo demee : c'est celui-là, peut-être", "kookule la soo demee : c'est peut-être celui-là", "soo demee kookule la : c'est peut-être celui-là", "soo demee kookule la : c'est celui-là, peut-être"]
# ["keneen ki la, defe naa : c'est l'autre, je crois", "defe naa ni keneen ki la : je crois que c'est l'autre", "keneen ki la, defe naa : je crois que c'est l'autre"]
# ["foofu góor gi dem fu rafet la : l'endroit où l'homme est parti est beau", "foofu góor gi dem fu rafet la : là où l'homme est parti est beau"]
# ['fépp fu mu jëm foofu jàmm dana fa wacc : partout où il ira la paix descendra là', 'fépp fu mu jëm foofu jàmm dana fa wacc : partout où il descend, là paix descendra']

# %% [markdown]
# **Regex 3** -->

# %%
result = new_sent_extraction.replace_groups(".*,.*", save=True, manual_replace=True, csv_file="founded.csv")
# Out:
# Found groups matching the regular expression .*,.* are the followings:
#
# - daj : atteindre, toucher
# - daõal : tendre, rendre tendu
# - siit : couler, suinter
# - fatu : s'abriter, s'enfermer chez soi
# - fad : abriter, ranger
# - dad : tailler, polir
# - jëf : fait, acte
# - kuu : celui-là, que voilà
# - giir : lignée, descendance
# - xer : berge, rivage
# - ëpp : dépasser les limites, excessif
# - uu kuu : celui-ci, tout près
# - ki : cet, que voici
# - taf : coller, afficher
# - at-té : séparer, juger
# - ree-waa-le : rire en même temps de, feindre en riant
# - jigéen : femme, etc.
# - wàcc : abandonner, etc.
# - par : allié, alliance
# - jolof : pays du Lof, pays wolof
# - kaddu : parole, tonnerre
# - ndem : le fait de partir, départ
# - safaay : l'acidité, le piquant
# - demin : manière d'aller, l'état
# - waxin : façon de parler, accent
# - waxkat : bavard, locuteur
# - sëgg : se courber, attendre
# - xamadi : ignorer, ignorance, insolence
# - goreedi : manquer de noblesse, indignité
# - mosal : faire goûter, pourboire
# - gistal : faire voir, exhibitionnisme
# - mooy : manquer un but, dévier
# - moyaal : détournement, quemande
# - wày : chanter, louer
# - wàyaan : louer, quémander
# - reetaan : se moquer, ricaner,
# - waxtaan : causer, causerie
# - seet : regarder, sonder
# - jamaale : concurrencer, concurrent
# - waxaale : marchander, marchandage
# - demaale : accompagner, compagnon
# - nawle : pair, un égal
# - àndandoo : aller en groupe, cohorte
# - bëggante : s'aimer, amour
# - duggonte : se lier, s'acquoquiner
# - fo : jouer, jeu
# - fontu : jouer, manquer de sérieux
# - daggat : découper, morceau
# - xottat : déchiqueter, morceau
# - maggat : vieux, vieillesse, vieillir
# - soppaate : estimer,
# - jógé : venir de, se redresser grâce à
# - gisé : voir (avec ses yeux), entrevue
# - soppe : ami, estimer à cause de...
# - suuf : sol, le bas
# - déeyóo : se concerter, confidence
# - wàñoo : se disputer, déchirement
# - seetu : se mirer, miroir
# - dindéeku : se détacher, lâcher
# - nit : homme,
# - waa jur, waajur : parents
# - waa réew, waaréw : nationaux
# - waa Lof, wàlaf : habitant du Lof (wolof)
# - waa Ndar, waandar : Saint-Louisien
# - waa Raw, waaraw : habitant de Rao
# - daay : endroit déserté, brûlé,
# - gad-daay : émigrer, émigration
# - sax : verre, pousse
# - rucci : honorer, « relever d'une honte »
# - taggi : dénicher,
# - ceetu : le fait de se mirer, etc...
# - komre : maigreur, etc...
# - jam : piquer, emporter un enjeu ; jamaale : concurrent ;
# - dog : arrêter ; dogal ; aji dogal : juge, qui peut décider
# - def : faire ; defar : arranger, aji-defar : esprit constructif
# - def ; defar : arranger ; defarkat : agent, constructeur
# - soppi : changer ; coppeeku : changement ; coppalin, coppeekuwaay :
# - jiitalante : succession, série
# - sax-sax : jeune pousse, chef de province
# - jigéenu wérul : femme qui ne se porte pas bien, femme enceinte
# - waru gar : prestation obligatoire, dot
# - naaru góor : littéralement maure mâle, cheval pur sang arabe
# - ñaari goroõ : deux rythmes, figures de danse
# - moom-sa-réew : rentrer en possession de son pays, indépendance
# - na jaay : qu'il vende, oncle
# - jarabibaat : qu'on ne peut plus aliéner, femme qui épouse son oncle
# - gis õga nit kookale : tu sais, cet homme (en question)...
# - gis õga nit kookee : tu sais, cet homme là...
# - monématiques représentées par des éléments vocaliques : i, u, a.
# - wax jépp : tout ce discours, tout le propos
# - gisoon naa xar yi yépp : j'ai vu tous ces moutons-ci, etc...
# - Selon le contexte, on peut avoir comme sens : aucun, un seul,
# - gis õga xale bii woon : tu vois, ce garçon-là (au passé)
# - xammee õga sa far, woowee woon : tu reconnais ton amour d'autrefois
# - soo dee góor : si tu es (un) homme, etc...
# - dil nitu nit ñi : sois l'homme de tout le monde, etc...
# - su waxee më ñëw : s'il parle, je viens
# - génnéel : fais sortir, etc...
# - yéen dem õgeen : vous, vous avez été
# - yéen bëgg õgeen : vous, vous voulez
# - góor gi demul : l'homme n'a pas été, ne part pas
# - góor gi bëggul : l'homme ne veut pas, n'a pas voulu
# - demuma : je n'ai pas été, je n'irai pas
# - su góor gi nëwée lépp baax : si l'homme vient, tout ira
# - bu nu demee lépp baax : quand on ira, tout ira
# - góor gii bëggóon : cet homme qui aimait (qui avait voulu, etc. )
# - man demuma : moi je n'ai pas été, je n'irai pas
# - góor gaa õgi dikkul : l'homme est là, il ne vint pas
# - waa ja di raam, di raam : waa jay raam, di raam, etc...
# - gor gi dafa demul ? : l'homme, il n'est pas parti ?
# - Samba : yaw : yaa dem : Samba, toi, tu as été
# - yaa ka gis moom Samba : c'est toi qui l'as vu, lui, Samba
# - waxu la yaw : il ne te parle pas, à toi
# - ñoonu ñu õgii : ceux-là les voilà (eux, ils, ici)
# - góor gi mi õgi ¹ : l'homme, le voilà
# - góor gaa õgi : l'homme, le voilà
# - noonu man më dem : sur ces entrefaites moi, je quittais
# - yaa õgi, dem õga : te voila, tu as été
# - noonu ma dem : sur ces entrefaites, je partis
# - na mu ÷ na : qu'il..., etc.
# - ku : lequel, quiconque
# - mu : lequel, quiconque
# - gu : lequel, quiconque
# - kooku : lequel, quiconque
# - moomu : lequel, quiconque
# - googu : lequel, quiconque
# - kii : celui-ci, lequel ; kuu : celui-ci tout près ; mee : celui-là (là-bas)
# - mii : celui-là, lequel ; muu : celle-ci ; muu celleci
# - mile : celui-là, lequel ; mule : celle-ci ; mule : celle-ci
# - yooyale deey bëggu leen : ceux-là, il ne les apprécie guère
# - ñan et yan : qui, lequel, etc.
# - yan ñoo yeksi ? : lesquels sont arrivés ?, etc...
# - képp, mépp, lépp, wépp, sépp, bépp, gépp, jépp : (le tout), tout, chaque
# - ñépp et yépp : (tous, la totalité).
# - un fait de détermination et dans le sens de : tout, chaque : béppu nit :
# - ñooñu, ñépp dañuy dem : tous ceux-là doivent partir
# - mépp mu rëcc : n'importe lequel, qui s'échappe.. (mouton)
# - fi : là où, alors que, dès que ¹
# - foofa : là, alors, à ce moment
# - fu : ici, où, ou ?
# - foofu : là, alors à ce moment
# - ci : à l'intérieur, dedans, parmi, sur, etc...
# - cu : à l'intérieur, etc...
# - ca : à l'intérieur, à cet endroit-là, sur, etc...
# - li : ce que, ce qui
# - looli : ceci, le fait que
# - lu : ce que, qu'est-ce qui ?
# - loola : cela, ce fait-là
# - fee : là-bas ; foofee ou fale ou foofale : là-bas, à ce moment-là
# - nii : comme ci, ainsi ; noonii : comme ça, ainsi ; nile : de cette
# - nuu : comme ci ; noonuu : comme ça, ainsi ; nule : de cette manière
# - nee : comme cela, de cette manière-là ; noonee : comme cela ; nale : de
# - le : cela là-bas ; loolee : cela ; lale : cela, là-bas, de fait-là ; loolale : ce
# - fan ou naan ? : comment, de quelle manière ?
# - fenn : en un lieu, nulle part, etc.
# - nenn : en aucune manière, une façon, etc.
# - demuloo feneen : tu ne vas pas ailleurs, un autre lieu
# - xolal fépp : fouille tout endroit, (en tout lieu, toute la place, etc. )
# - foofu õga dem fu : là-même où tu as été, là où tu as été là
# - ni õga def noonu : cela que tu as fait, cela même
# - leneen li : l'autre, l'autre partie
# - lenn lale : l'un là-bas, l'une des parties qui est là-bas
# - naka : du moment que, comme dès que
# - gannaaw : derrière, après que, du moment que, après
# - ba : après que, jusqu'au moment où
# - bi : lorsque, au moment où
# - bu : lorsque, quand (subjonctif prohibitif)
# - su : si, lorsque
# - te : sans que, alors que, mais
# - ndax : afin que, est-ce que
# - ba itam : à moins que, ou alors que
# - kon nag : dans ce cas, alors
# - ci : dans, parmi
# - ak : avec, en compagnie de, grâce à
# - balaa : avant que, etc...
# - te : et, et aussi
# - walla : ou, ou bien
# - wante : toutefois, cependant, mais
# - ag itam : et aussi, et encore
# - walla nak : ou alors, ou enfin, etc...
# - te et noona nak : alors, de ce fait, sur ce
# - ndeke ou waaye : mais, cependant, toutefois
# - moontin : et pourtant, cependant, quoi qu'il en soit, en fait
# - kon nag (variante du précédent) : dans ce cas, s'il en est ainsi
# - kon nag dàwul ! : dans ce cas, fuis !
# - kon nag dey buleen dem : alors, ne partez pas
# - waaye : mais, cependant, malheureusement
# - waaye sax : par contre, d'ailleurs, du reste
# - waaye nag : d'ailleurs, toutefois, malheureusement
# - wante itam : mais aussi, mais non plus
# - waaw : oui, alors, et puis
# - waaw : waaw ndax dem na ? : eh bien, est-ce qu'il est parti ?
# - ba nag : ainsi donc, de sorte que
# - te kat na õga ma nég ! : et surtout, attends-moi !
# - foofu : là, alors, en cet endroit, en ce moment :
# - foofu nak : alors, à ce moment :
# - noonu : alors, ainsi :
# - noonu itam : alors, mais aussi sur ces entrefaites :
# - noonu itam ma noppi : sur ces entrefaites, je me tus
# - góor gaa õgi ²÷ nitu Ndar la : l'homme le voici, il est Saint-Louisien
# - mi õgi ²÷ benn la ci ndàyam : le voilà, il est unique en son genre
# - yaakaar ²÷ nax sa bopp doõõ la : espérer, c'est se nourrir d'illusion
# - dem ²÷ rafetoon na : avoir été, eût été bon
# - maa õgii gis leen ma ²÷ du jëfu nit ku yiw : « me voici, regar-
# - tay : ci subë : aujourd'hui, le matin
# - woo naa ka ba mi õgi : je l'ai appelé, aussi est-il là
# - ndax : à cause de, grâce à, etc...
# - õgir : à cause de, grâce à...
# - bayyi ma õgir yalla : laisse-moi de grâce, au nom de Dieu
# - gannaaw : sauf, excepté, etc...
# - ci : dans, parmi, au sujet
# - ca : à, parmi, ce qui est éloigné dans le temps ou dans l'espace
# - ba : jusqu'à, à
# - ak : grâce à, par, avec
# - góor gi dem fee ana mu : l'homme qui a été là-bas, où est-il ?
# - yaa õgoogu rekk : te voilà tout simplement (te voilà, quoi)
# - góor gi : moom demul : l'homme, lui, ne s'en alla pas
# - jigéen ji : moom waxatul : la vieille, elle, ne parla plus
# - gis na ka : moom : Musâ : il l'a vu, lui, Moussa
# - kookule : moom du naõgu : celui-là, lui, il refusera
# - yaw : yaa õgi : toi, tu es là
# - kooka ak kile, bokkuñu : celui-là et celui-ci n'ont rien de commun
# - yaw walla moom am na ci ku dem : toi ou lui, il en est un qui est parti
# - bëggulóo xaalis walla alal : tu ne veux ni argent, ni fortune
# - jënd na xar, bëy, ganaar : il a acheté moutons, chèvres, poulets
# - yaw la ?, etc... : c'est toi ?
# - su bëggée kañ : si elle veut, bien sûr
# - mi õgii dem na : le voilà, il est parti
# - waaye man sax dama dul ñëw : mais, moi, je n'ai pas été
# - te bul ñëw jaõgu ba de, etc. : et ne viens surtout pas à l'école
# - ba yaa õgii di dem ! : ainsi, tu vas t'en aller !
# - keneen : ki ñëw : l'autre, celui qui est arrivé
# - ci biir foofu : mu bënn : là, où il a fait un trou.
# - toogal ci fépp : fu leer : mets-toi n'importe où, où il fait clair
# - toogal fépp : fu leer : mets-toi n'importe où, où il fait clair
# - liggéey bii : ba mu sotti : sur le travail, jusqu'à ce qu'il soit fait
# - ci fii : ba ma ñëw : ici, jusqu'à ce qu'il vienne !
# - loolu : ba mu sotti : cela, jusqu'à ce que ce soit terminé
# - soo bëggul, ci biir : si tu ne veux pas à l'intérieur
# - mi õgi fi : soo demee : il est là, peut-être
# - cii fii kon : soo bëggul : ici alors, si tu refuses
# - kookule la soo demee : c'est celui-là, peut-être
# - soo demee kookule la : c'est celui-là, peut-être
# - keneen ki la, defe naa : c'est l'autre, je crois
# - keneen ki la, defe naa : je crois que c'est l'autre
# - tay, demb, bërki demb : hier, aujourd'hui, avant-hier
# - ci kii, ci kuu, ci kee : vers, celui que voilà celui-ci, vers celui-là,
# - ñii, ñee, ñooñu : à ceux-ci, ceux-là, à ceux qui sont là-bas
# - yaa õgi, mi õgi : te voilà, le voilà
# - nit la, nit õga : il est homme, tu es homme
# - ci biir la, ci biir a biir la : c'est à l'intérieur, à l'intérieur même
# - kookule la kookule taxaw la : c'est celui-là, celui-là debout
# - kenn la kenn doõõ la : c'est un seul, un seul
# - dem naa, dem õga, dem na : j'ai été, tu as été, il a été
# - dem naa, te dem õga, te dem na : j'ai été et tu as été et lui il a été
# - kooku la, te keneen la : c'est celui-là et c'est un autre
# - te : et, ensuite, or, etc...
# - mbaa : ou bien, ou alors, etc...
# - keneen kan la ? : qui, est-ce d'autres ?
# - amoon : inactuel, passé défini.
# - addu : son, phonème (waxesna it : « soõ fonem »).
# - addooku : phonétique, science phonétique — « fonetik ».
# - araf : phonème, lettre.
# - araf céexal : gémination, géminée (araf séexal ou araf wu séex).
# - araf raññee : prolongement morphologique, élément de « classé ».
# - arafal : bole ay araf yóo xam ni tabbalnañu aw maas syllabe, syllabation.
# - birël, leeral, génne, wàne : montrer, élucider, mettre en évidence, identifier.
# - dac : toucher, entrer en contact avec
# - raf : clignoter, bouger de façon subreptice
# - dar : écorché, usé par frottement
# - sañ : faire preuve d'audace excessive, manque de gêne
# - joor : terrain sablonneux, mais aussi nom de personne
# - teõxu : jointure, articulation
# - dogal : couper pour quelqu'un, halte, marché de bétail
# - bokkaan : posséder en commun, copropriété
# - jam : piquer, émoustiller, stimuler
# - génnandoo : sortir ensemble, sortie collective
# - dendandoo : voisiner, voisin, voisinage
# - gaawantu : se dépêcher, empressement
# - nobaate : nourrir une petite passion, amourette
# - ñaanaatu : quémander, mendier, quémande
# - waxé : parler avec, parler à partir d'un lieu donné
# - goreel : annoblir, ennoblissement, libération
# - ñaareel : prendre une seconde femme, deuxième épouse
# - wàññeeku : se retourner, retournement
# - waa joor, waajoor : habitants de l'arrière-pays
# - waa kaw, waakaw : habitant de l'intérieur
# - daõõ-daõõ : de bruits et de mouvement, fracas
# - raõõ-raõõ : de bruits et de mouvement, fracas
# - kër-kër : de bruits et de mouvement, fracas
# - waaye nit kookii gaddaayoon nag dellusiwul : par contre, cet homme qui s'exila ne revint pas
# - Séen naa as lëf : J'ai aperçu une chose, une portion
# - Dem naa : je pars, je suis parti
# - Dem õga : Tu pars, Tu es parti
# - Dem na : Il part, il est parti
# - Dem nañu : Nous partons, nous sommes partis
# - Dem õgeen : Vous partez, vous êtes partis
# - Dem nañu : Ils partent, elles sont partis
# - Dem nañu : Ils partent, ils sont partis
# - soo ñëwóon, kon, demkoon naa : si tu étais venu, dans ce cas, je serais parti
# - maa di dem : c'est moi qui pars — qui suis en train de partir — qui dois partir — qui vais partir, etc...
# - góor gi doon dem : l'homme qui partait, qui devait partir, qui allait partir
# - su góor gi dee ñëw : si l'homme vient, si l'homme doit venir — quand l'homme viendra, etc...
# - bi õga dee dem : alors que tu partais — au moment où tu partais — du moment que tu pars, etc...
# - bi mu dee dem : du moment qu'il part — du fait qu'il doit partir, etc...
# - ñi : lesquels, auxquels
# - ña : lesquels, auxquels
# - ñooña : lesquels, auxquels
# - ñu : lesquels, auxquels
# - ñooñu : lesquels, auxquels
# - yi : lesquels, auxquels
# - ya : lesquels, auxquels
# - yooya : lesquels, auxquels
# - yu : lesquels, auxquels
# - yooyu : lesquels, auxquels
# - nagi dëkk bii õga gis, wa ci ëpp sa baay Alfa moo ka moom : des boeufs que tu vois dans cette ville, (celui) le plus gros appartient à ton père Alfa.
# - nit ñi õga ma wàn ñépp, kii laa ci wóolu : des gens que tu m'as présentés celui que voici me dispose le plus à la confiance.
# - gis õga nag yii yépp, woowuu moo ci gën : des boeufs que tu vois, celui-là (tout près) est le meilleur.
# - mii maa ka moom, waaye moomule deey, xawma fu mu bokk : celui-ci (ce mouton) est à moi mais j'ignore d'où provient cet autre-là (près de toi).
# - xëynë xar yi ñëw nañu wante gisaguma wenn : les moutons sont peut-être déjà arrivés, j'en n'ai encore vu aucun
# - sa jarbaat yi, jenn gënu kë ci tayel : aucun de tes neveux n'est aussi paresseux que celui-là.
# - népp noo defe baax na : de toute manière, quelle que soit ta façon d'agir c'est bien
# - fépp fu mu jëm foofu jàmm dana fa wacc : partout où il descend, là paix descendra
# - képp ku dem, kooku raggal la : quiconque s'en va, celui-là est un froussard
# - kooku dem ku më bëgg la : c'est quelqu'un que j'apprécie, celui qui est parti
# - moom daal : lui, aussi
# - wax ji yépp, bañ-õga-ñëw la : tout ce verbiage, c'est pour que tu ne viennes pas
# - maa õgii gis leen ma ²÷ du jëfu nit ku yiw : « me voici, regardez-moi » n'est pas le fait d'un homme serein
# - sëriñ bi ñaan na : mayewoon : alalam ji ba mënkóon yalwaan : le marabout implora qu'il fût dans la situation de quelqu'un qui aurait fait don de sa fortune, pour être en mesure de demander l'aumône
# - abalal keneen ki demkoonul ki, sama téeré bi : prête à cet autre qui n'eût pas été, mon ouvrage
# - noona Gelwar bi : buur bi, daldi ni tekk : alors le roi Guelwar s'immobilisa
# - ñëwël ndax Musaa lamaanu réew mi : viens pour Moussa, lamane de ce pays
# - nit, gayndé, nag, àndoon nañu fi, ... : homme, lion, boeuf, allaient de concert...
# - xale yi set nañu ci biir, ci biti gisuñu dara : les enfants ont cherché à l'intérieur, à l'extérieur, mais n'ont rien trouvé
# - nit, gaynde, xar, ak bukki duñu ànd : homme, lion, mouton et hyène, ne vont pas ensemble
# - may na ka lëg, doomam ak nopp ya : il lui a donné le lièvre, ses petits et leurs oreilles
# - séetal ci bir, ci biti, ci suuf ak ci kaw : regarde à l'intérieur, à l'extérieur, en bas et en haut
# - õga dem la : góor gi bëgg : que tu partes, c'est ce que désire l'homme
# - bëggóon : õgeen dem rekk : le désir non exaucé de vous voir partir, désir (vous partiez simplement)
# - góor : googule ñëwóon : mi õgi : cet homme qui vint autrefois, le voilà
# - ci kooku : ndax mu wettëliku : avec celui-là, afin qu'il ne soit pas seul
# - Faatim la : soo demee : c'est Fatim, si on va au fond des choses (peut-être)
# - soo demee : Faatim la : c'est Fatim, si on va au fond des choses (peut-être)
# - so demee : mi õgiy wax : il est là, peut-être
# - soo bëggul : ci fii kóon : ici alors, si tu refuses
# - ci Séeréer si, ci Ñoomiõka yi, ci Pël yi : chez les Sérère, les Peul, les Niominka
# - ci Pël yi ag ci Séeréer si, ag ci Ñomiõka yi : chez les Peul, les Sérère, etc.
# - noona góor gi seet lëf ki, seetat mbir mi : alors l'homme reconsidéra la chose, reconsidéra l'affaire.
# - dem õga, te dem na, te dem naa : tu as été et il a été et moi aussi j'ai été
# - noona góor gi dugg, xale yi gis ka, mu toog, ñépp toog : alors l'homme entra, les enfants le virent, il s'assit, tous s'assirent
# - bëgg naa góor ñi ñëw, xale yi ñëw, jigéen ñi toog : je souhaite que les hommes viennent, que les enfants viennent et que les femmes s'asseyent
# - nee waa jii gor la, goor la, jambe la : il dit que ce Monsieur est un homme, il est noble, il est brave
# - defe naa du kookuu, du kookee : je crois que ce n'est pas celui-ci ce n'est pas celui-là
# - demal : ndax mu ñëw, ndax mu meddi : vas-y pour qu'il vienne, pour qu'il ne soit plus fâché
# - ñëwël ndax xale yi di ay liggéeykat, di ay jambaar : viens pour que les enfants soient des travailleurs, soient des braves
# - demal, ndax mu di, leneen, mu di feneen : vas-y pour que ce soit autre chose, que ce soit ailleurs
# - tày ci suba, tày ci õgoon ma fiy nekk : ce matin ou ce soir c'est moi qui suis ici
# - maa fiy nekk : tày ci õgoon, tày ci suba : ce matin ou ce soir c'est moi qui suis ici
# - bëgg në õga ñëw, mu bañ dem su nëjul : je veux que tu viennes, qu'il refuse de partir s'il n'y a pas de soleil
# - bëgg naa õga ñëw mu dem su õgeen noppée : je veux, si vous avez fini, que tu viennes et qu'il parte
# - bëgg naa ci juróomi waxtu, ci subë, õga ñëw : je veux que tu viennes le matin à cinq heures dans la fraîcheur
# - defewoon na, ci subë si, ci bes bi, daa dem : je croyais que tu irais, ce matin, ce jour
# - defewoon na, daa dem, ci bes bi ci subë si : je croyais que tu irais, ce matin, ce jour
# - defewoon naa góor gi kenn ki la, te xale bi kooku la : je croyais que l'homme c'était cet autre et que l'enfant c'était celui-là
# - bëgg na soo demee : mu dellusi te góor gi ñëw : il veut, lorsque tu iras que lui, il revienne et que l'homme aussi revienne
# - bëgg na góor gi ñëw te mu dellusi soo demee : il veut que l'homme vienne et que lui, il revienne si tu pars
# - xale yi bëgg nañu dikk, te mag ni ñaan nañu õgeen dem : les enfants veulent venir et les adultes souhaitent que vous partiez
# - góor gi dem na ndax õgeen ñëw te nak kenn bañ leen foog : l'homme est parti pour que vous veniez sans que personne, surtout, ne le soupçonne
# - yaakaaroon na ni, mag ñi du ñu ci agg foofu te it xale yi nekkunu fi woon : il espérait que les gens d'âge n'en seraient pas arrivés là et aussi que les enfants étaient absents
# - te itam : et aussi, et surtout
# - te nak : et, et aussi, et encore, et surtout, et sans que, et enfin
# - ag it : et aussi, mais aussi
# - lu tax ? : pourquoi ? (qu'est-ce, qui est la cause ?)
# - lu waral ? : pourquoi ? (qu'est-ce, qui est la cause ?)
#
# ----------------------
#
# You will modify the following group:
#  daj : atteindre, toucher
# The manual modification of the group
#  daj : atteindre, toucher
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  daõal : tendre, rendre tendu
# The manual modification of the group
#  daõal : tendre, rendre tendu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  siit : couler, suinter
# The manual modification of the group
#  siit : couler, suinter
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fatu : s'abriter, s'enfermer chez soi
# The manual modification of the group
#  fatu : s'abriter, s'enfermer chez soi
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fad : abriter, ranger
# The manual modification of the group
#  fad : abriter, ranger
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dad : tailler, polir
# The manual modification of the group
#  dad : tailler, polir
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jëf : fait, acte
# The manual modification of the group
#  jëf : fait, acte
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kuu : celui-là, que voilà
# The manual modification of the group
#  kuu : celui-là, que voilà
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  giir : lignée, descendance
# The manual modification of the group
#  giir : lignée, descendance
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xer : berge, rivage
# The manual modification of the group
#  xer : berge, rivage
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ëpp : dépasser les limites, excessif
# The manual modification of the group
#  ëpp : dépasser les limites, excessif
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  uu kuu : celui-ci, tout près
# The manual modification of the group
#  uu kuu : celui-ci, tout près
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ki : cet, que voici
# The manual modification of the group
#  ki : cet, que voici
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  taf : coller, afficher
# The manual modification of the group
#  taf : coller, afficher
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  at-té : séparer, juger
# The manual modification of the group
#  at-té : séparer, juger
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ree-waa-le : rire en même temps de, feindre en riant
# The manual modification of the group
#  ree-waa-le : rire en même temps de, feindre en riant
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jigéen : femme, etc.
# The manual modification of the group
#  jigéen : femme, etc.
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wàcc : abandonner, etc.
# The manual modification of the group
#  wàcc : abandonner, etc.
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  par : allié, alliance
# The manual modification of the group
#  par : allié, alliance
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jolof : pays du Lof, pays wolof
# The manual modification of the group
#  jolof : pays du Lof, pays wolof
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kaddu : parole, tonnerre
# The manual modification of the group
#  kaddu : parole, tonnerre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ndem : le fait de partir, départ
# The manual modification of the group
#  ndem : le fait de partir, départ
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  safaay : l'acidité, le piquant
# The manual modification of the group
#  safaay : l'acidité, le piquant
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  demin : manière d'aller, l'état
# The manual modification of the group
#  demin : manière d'aller, l'état
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waxin : façon de parler, accent
# The manual modification of the group
#  waxin : façon de parler, accent
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waxkat : bavard, locuteur
# The manual modification of the group
#  waxkat : bavard, locuteur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sëgg : se courber, attendre
# The manual modification of the group
#  sëgg : se courber, attendre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xamadi : ignorer, ignorance, insolence
# The manual modification of the group
#  xamadi : ignorer, ignorance, insolence
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  goreedi : manquer de noblesse, indignité
# The manual modification of the group
#  goreedi : manquer de noblesse, indignité
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mosal : faire goûter, pourboire
# The manual modification of the group
#  mosal : faire goûter, pourboire
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gistal : faire voir, exhibitionnisme
# The manual modification of the group
#  gistal : faire voir, exhibitionnisme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mooy : manquer un but, dévier
# The manual modification of the group
#  mooy : manquer un but, dévier
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  moyaal : détournement, quemande
# The manual modification of the group
#  moyaal : détournement, quemande
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wày : chanter, louer
# The manual modification of the group
#  wày : chanter, louer
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wàyaan : louer, quémander
# The manual modification of the group
#  wàyaan : louer, quémander
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  reetaan : se moquer, ricaner,
# The manual modification of the group
#  reetaan : se moquer, ricaner,
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waxtaan : causer, causerie
# The manual modification of the group
#  waxtaan : causer, causerie
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  seet : regarder, sonder
# The manual modification of the group
#  seet : regarder, sonder
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jamaale : concurrencer, concurrent
# The manual modification of the group
#  jamaale : concurrencer, concurrent
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waxaale : marchander, marchandage
# The manual modification of the group
#  waxaale : marchander, marchandage
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  demaale : accompagner, compagnon
# The manual modification of the group
#  demaale : accompagner, compagnon
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nawle : pair, un égal
# The manual modification of the group
#  nawle : pair, un égal
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  àndandoo : aller en groupe, cohorte
# The manual modification of the group
#  àndandoo : aller en groupe, cohorte
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  bëggante : s'aimer, amour
# The manual modification of the group
#  bëggante : s'aimer, amour
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  duggonte : se lier, s'acquoquiner
# The manual modification of the group
#  duggonte : se lier, s'acquoquiner
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fo : jouer, jeu
# The manual modification of the group
#  fo : jouer, jeu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fontu : jouer, manquer de sérieux
# The manual modification of the group
#  fontu : jouer, manquer de sérieux
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  daggat : découper, morceau
# The manual modification of the group
#  daggat : découper, morceau
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xottat : déchiqueter, morceau
# The manual modification of the group
#  xottat : déchiqueter, morceau
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  maggat : vieux, vieillesse, vieillir
# The manual modification of the group
#  maggat : vieux, vieillesse, vieillir
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soppaate : estimer,
# The manual modification of the group
#  soppaate : estimer,
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jógé : venir de, se redresser grâce à
# The manual modification of the group
#  jógé : venir de, se redresser grâce à
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gisé : voir (avec ses yeux), entrevue
# The manual modification of the group
#  gisé : voir (avec ses yeux), entrevue
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soppe : ami, estimer à cause de...
# The manual modification of the group
#  soppe : ami, estimer à cause de...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  suuf : sol, le bas
# The manual modification of the group
#  suuf : sol, le bas
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  déeyóo : se concerter, confidence
# The manual modification of the group
#  déeyóo : se concerter, confidence
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wàñoo : se disputer, déchirement
# The manual modification of the group
#  wàñoo : se disputer, déchirement
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  seetu : se mirer, miroir
# The manual modification of the group
#  seetu : se mirer, miroir
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dindéeku : se détacher, lâcher
# The manual modification of the group
#  dindéeku : se détacher, lâcher
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit : homme,
# The manual modification of the group
#  nit : homme,
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa jur, waajur : parents
# The manual modification of the group
#  waa jur, waajur : parents
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa réew, waaréw : nationaux
# The manual modification of the group
#  waa réew, waaréw : nationaux
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa Lof, wàlaf : habitant du Lof (wolof)
# The manual modification of the group
#  waa Lof, wàlaf : habitant du Lof (wolof)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa Ndar, waandar : Saint-Louisien
# The manual modification of the group
#  waa Ndar, waandar : Saint-Louisien
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa Raw, waaraw : habitant de Rao
# The manual modification of the group
#  waa Raw, waaraw : habitant de Rao
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  daay : endroit déserté, brûlé,
# The manual modification of the group
#  daay : endroit déserté, brûlé,
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gad-daay : émigrer, émigration
# The manual modification of the group
#  gad-daay : émigrer, émigration
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sax : verre, pousse
# The manual modification of the group
#  sax : verre, pousse
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  rucci : honorer, « relever d'une honte »
# The manual modification of the group
#  rucci : honorer, « relever d'une honte »
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  taggi : dénicher,
# The manual modification of the group
#  taggi : dénicher,
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ceetu : le fait de se mirer, etc...
# The manual modification of the group
#  ceetu : le fait de se mirer, etc...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  komre : maigreur, etc...
# The manual modification of the group
#  komre : maigreur, etc...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jam : piquer, emporter un enjeu ; jamaale : concurrent ;
# The manual modification of the group
#  jam : piquer, emporter un enjeu ; jamaale : concurrent ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dog : arrêter ; dogal ; aji dogal : juge, qui peut décider
# The manual modification of the group
#  dog : arrêter ; dogal ; aji dogal : juge, qui peut décider
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  def : faire ; defar : arranger, aji-defar : esprit constructif
# The manual modification of the group
#  def : faire ; defar : arranger, aji-defar : esprit constructif
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  def ; defar : arranger ; defarkat : agent, constructeur
# The manual modification of the group
#  def ; defar : arranger ; defarkat : agent, constructeur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soppi : changer ; coppeeku : changement ; coppalin, coppeekuwaay :
# The manual modification of the group
#  soppi : changer ; coppeeku : changement ; coppalin, coppeekuwaay :
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jiitalante : succession, série
# The manual modification of the group
#  jiitalante : succession, série
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sax-sax : jeune pousse, chef de province
# The manual modification of the group
#  sax-sax : jeune pousse, chef de province
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jigéenu wérul : femme qui ne se porte pas bien, femme enceinte
# The manual modification of the group
#  jigéenu wérul : femme qui ne se porte pas bien, femme enceinte
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waru gar : prestation obligatoire, dot
# The manual modification of the group
#  waru gar : prestation obligatoire, dot
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  naaru góor : littéralement maure mâle, cheval pur sang arabe
# The manual modification of the group
#  naaru góor : littéralement maure mâle, cheval pur sang arabe
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñaari goroõ : deux rythmes, figures de danse
# The manual modification of the group
#  ñaari goroõ : deux rythmes, figures de danse
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  moom-sa-réew : rentrer en possession de son pays, indépendance
# The manual modification of the group
#  moom-sa-réew : rentrer en possession de son pays, indépendance
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  na jaay : qu'il vende, oncle
# The manual modification of the group
#  na jaay : qu'il vende, oncle
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jarabibaat : qu'on ne peut plus aliéner, femme qui épouse son oncle
# The manual modification of the group
#  jarabibaat : qu'on ne peut plus aliéner, femme qui épouse son oncle
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga nit kookale : tu sais, cet homme (en question)...
# The manual modification of the group
#  gis õga nit kookale : tu sais, cet homme (en question)...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga nit kookee : tu sais, cet homme là...
# The manual modification of the group
#  gis õga nit kookee : tu sais, cet homme là...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  monématiques représentées par des éléments vocaliques : i, u, a.
# The manual modification of the group
#  monématiques représentées par des éléments vocaliques : i, u, a.
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wax jépp : tout ce discours, tout le propos
# The manual modification of the group
#  wax jépp : tout ce discours, tout le propos
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gisoon naa xar yi yépp : j'ai vu tous ces moutons-ci, etc...
# The manual modification of the group
#  gisoon naa xar yi yépp : j'ai vu tous ces moutons-ci, etc...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Selon le contexte, on peut avoir comme sens : aucun, un seul,
# The manual modification of the group
#  Selon le contexte, on peut avoir comme sens : aucun, un seul,
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga xale bii woon : tu vois, ce garçon-là (au passé)
# The manual modification of the group
#  gis õga xale bii woon : tu vois, ce garçon-là (au passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xammee õga sa far, woowee woon : tu reconnais ton amour d'autrefois
# The manual modification of the group
#  xammee õga sa far, woowee woon : tu reconnais ton amour d'autrefois
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soo dee góor : si tu es (un) homme, etc...
# The manual modification of the group
#  soo dee góor : si tu es (un) homme, etc...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dil nitu nit ñi : sois l'homme de tout le monde, etc...
# The manual modification of the group
#  dil nitu nit ñi : sois l'homme de tout le monde, etc...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  su waxee më ñëw : s'il parle, je viens
# The manual modification of the group
#  su waxee më ñëw : s'il parle, je viens
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  génnéel : fais sortir, etc...
# The manual modification of the group
#  génnéel : fais sortir, etc...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yéen dem õgeen : vous, vous avez été
# The manual modification of the group
#  yéen dem õgeen : vous, vous avez été
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yéen bëgg õgeen : vous, vous voulez
# ...
# ['naka : comme dès que', 'naka : du moment que']
# ['gannaaw : derrière', 'gannaaw : après que', 'gannaaw : du moment que', 'gannaaw : après']
# ['ba : après que', "ba : jusqu'au moment où"]
# ['bi : lorsque', 'bi : au moment où']
# ['bu : lorsque', 'bu : quand']
# ['su : lorsque', 'su : si']
# ['te : sans que', 'te : alors que', 'te : mais']
# ['ndax : afin que', 'ndax : est-ce que']
# ['ba itam : à moins que', 'ba itam : ou alors que']
# ['kon nag : dans ce cas', 'kon nag : alors']
# ['ci : parmi', 'ci : dans']
# ['ak : avec', 'ak : en compagnie de', 'ak : grâce à']
# ['balaa : avant que']
# ['te : et', 'te : et aussi']
# ['walla : ou', 'walla : ou bien']
# ['wante : toutefois', 'wante : cependant', 'wante : mais']
# ['ag itam : et aussi', 'ag itam : et encore']
# ['walla nak : ou alors', 'walla nak : ou enfin']
# ['te et noona nak : alors', 'te et noona nak : de ce fait', 'te et noona nak : sur ce']
# ['ndeke : mais', 'ndeke : cependant', 'ndeke : toutefois', 'waaye : mais', 'waaye : cependant', 'waaye : toutefois']
# ['moontin : et pourtant', 'moontin : cependant', "moontin : quoi qu'il en soit", 'moontin : en fait']
# ['kon nag : dans ce cas', "kon nag : s'il en est ainsi"]
# ['kon nag dàwul ! : dans ce cas, fuis !']
# ['kon nag dey buleen dem : alors, ne partez pas']
# ['waaye : mais', 'waaye : cependant', 'waaye : malheureusement']
# ['waaye sax : par contre', "waaye sax : d'ailleurs", 'waaye sax : du reste']
# ["waaye nag : d'ailleurs", 'waaye nag : toutefois', 'waaye nag : malheureusement']
# ['wante itam : mais aussi', 'wante itam : mais non plus']
# ['waaw : oui', 'waaw : alors', 'waaw : et puis']
# ["waaw, waaw ndax dem na ? : eh bien, est-ce qu'il est parti ?"]
# ['ba nag : de sorte que', 'ba nag : ainsi donc']
# ['te kat na õga ma nég ! : et surtout, attends-moi !']
# ['foofu : là', 'foofu : alors', 'foofu : en cet endroit', 'foofu : en ce moment']
# ['foofu nak : à ce moment', 'foofu nak : alors']
# ['noonu : alors', 'noonu : ainsi']
# ['noonu itam : alors', 'noonu itam : mais aussi sur ces entrefaites']
# ['noonu itam ma noppi : sur ces entrefaites, je me tus']
# ["góor gaa õgi, nitu Ndar la : l'homme le voici, il est Saint-Louisien"]
# ['mi õgi, benn la ci ndàyam : le voilà, il est unique en son genre']
# ["yaakaar, nax sa bopp doõõ la : espérer, c'est se nourrir d'illusion"]
# ['dem, rafetoon na : avoir été, eût été bon']
# ['maa õgii gis leen ma ²÷ du jëfu nit ku yiw : « me voici, regar-']
# ["tay, ci subë : aujourd'hui, le matin", "tay ci subë : aujourd'hui, le matin"]
# ["woo naa ka ba mi õgi : je l'ai appelé, aussi est-il là"]
# ['ndax : à cause de', 'ndax : grâce à']
# ['õgir : à cause de', 'õgir : grâce à']
# ['bayyi ma õgir yalla : laisse-moi de grâce, au nom de Dieu']
# ['gannaaw : sauf', 'gannaaw : excepté']
# ['ci : dans', 'ci : parmi', 'ci : au sujet']
# ['ca : à', 'ca : parmi']
# ['ba : à', "ba : jusqu'à"]
# ['ak : grâce à', 'ak : par', 'ak : avec']
# ["góor gi dem fee ana mu : l'homme qui a été là-bas, où est-il ?"]
# ['yaa õgoogu rekk : te voilà tout simplement', 'yaa õgoogu rekk : te voilà, quoi']
# ["góor gi, moom demul : l'homme, lui, ne s'en alla pas"]
# ['jigéen ji, moom waxatul : la vieille, elle, ne parla plus']
# ["gis na ka, moom, Musâ : il l'a vu, lui, Moussa"]
# ['kookule, moom du naõgu : celui-là, lui, il refusera']
# ['yaw, yaa õgi : toi, tu es là']
# ["kooka ak kile, bokkuñu : celui-là et celui-ci n'ont rien de commun", 'kooka ak kile, bokkuñu : celui-là et celui-ci ne se ressemble pas', 'kooka ak kile, bokkuñu : celui-là et celui-ci ne se ressemble en rien']
# ['yaw walla moom am na ci ku dem : toi ou lui, il en est un qui est parti']
# ['bëggulóo xaalis walla alal : tu ne veux ni argent, ni fortune']
# ['jënd na xar, bëy, ganaar : il a acheté moutons, chèvres, poulets']
# ["yaw la ? : c'est toi ?"]
# ['su bëggée kañ : si elle veut, bien sûr']
# ['mi õgii dem na : le voilà, il est parti']
# ["waaye man sax dama dul ñëw : mais, moi, je n'ai pas été", "waaye man sax dama dul ñëw : mais, même moi, je n'ai pas été", 'waaye man sax dama dul ñëw : mais, même moi, je ne viendrai pas']
# ["te bul ñëw jaõgu ba de : et ne viens surtout pas à l'école"]
# ["ba yaa õgii di dem ! : ainsi, tu vas t'en aller !"]
# ["keneen, ki ñëw : l'autre, celui qui est arrivé"]
# ['ci biir foofu, mu bënn : là, où il a fait un trou.']
# ["toogal ci fépp, fu leer : mets-toi n'importe où, où il fait clair"]
# ["toogal fépp, fu leer : mets-toi n'importe où, où il fait clair"]
# ["liggéey bii, ba mu sotti : sur le travail, jusqu'à ce qu'il soit fait"]
# ["ci fii, ba ma ñëw : ici, jusqu'à ce qu'il vienne !"]
# ["loolu, ba mu sotti : cela, jusqu'à ce que ce soit terminé"]
# ["soo bëggul, ci biir : si tu ne veux pas, à l'intérieur"]
# ['mi õgi fi, soo demee : il est là, peut-être']
# ['cii fii kon, soo bëggul : ici alors, si tu refuses']
# ["kookule la soo demee : c'est celui-là, peut-être"]
# ["soo demee, kookule la : c'est celui-là, peut-être"]
# ["keneen ki la, defe naa : c'est l'autre, je crois"]
# ["keneen ki la, defe naa : je crois que c'est l'autre"]
# ["tay, demb, bërki demb : hier, aujourd'hui, avant-hier"]
# ['ci kii, ci kuu, ci kee : vers celui que voilà, vers celui-ci, vers celui-là']
# ['ñii, ñee, ñooñu : à ceux-ci, ceux-là, à ceux qui sont là-bas']
# ['yaa õgi, mi õgi : te voilà, le voilà']
# ['nit la, nit õga : il est homme, tu es homme']
# ["ci biir la, ci biir a biir la : c'est à l'intérieur, à l'intérieur même"]
# ["kookule la kookule taxaw la : c'est celui-là, celui-là debout"]
# ["kenn la kenn doõõ la : c'est un seul, un seul"]
# ["dem naa, dem õga, dem na : j'ai été, tu as été, il a été"]
# ["dem naa, te dem õga, te dem na : j'ai été et tu as été et lui il a été"]
# ["kooku la, te keneen la : c'est celui-là et c'est un autre"]
# ['te : et', 'te : ensuite', 'te : or']
# ['mbaa : ou bien', 'mbaa : ou alors']
# ["keneen kan la ? : qui, est-ce d'autres ?"]
# ['amoon : inactuel', 'amoon : passé défini']
# ['addu : son', 'addu : phonème']
# ['addooku : phonétique', 'addooku : science phonétique']
# ['araf : phonème', 'araf : lettre']
# ['araf céexal : gémination', 'araf céexal : géminée', 'araf séexal : gémination', 'araf séexal : géminée', 'araf wu séex : gémination', 'araf wu séex : géminée']
# ['araf raññee : prolongement morphologique', 'araf raññee : élément de « classé »']
# ['arafal : bole ay araf yóo xam ni tabbalnañu aw maas syllabe, syllabation.']
# ['birël, leeral, génne, wàne : montrer, élucider, mettre en évidence, identifier']
# ['dac : toucher', 'dac : entrer en contact avec']
# ['raf : clignoter', 'raf : bouger de façon subreptice']
# ['dar : écorché', 'dar : usé par frottement']
# ['sañ : manque de gêne', "sañ : faire preuve d'audace excessive"]
# ['joor : terrain sablonneux']
# ['teõxu : jointure', 'teõxu : articulation']
# ["dogal : couper pour quelqu'un", 'dogal : halte', 'dogal : marché de bétail']
# ['bokkaan : copropriété', 'bokkaan : posséder en commun']
# ['jam : piquer', 'jam : émoustiller', 'jam : stimuler']
# ['génnandoo : sortir ensemble', 'génnandoo : sortie collective']
# ['dendandoo : voisiner', 'dendandoo : voisin', 'dendandoo : voisinage']
# ['gaawantu : se dépêcher', 'gaawantu : empressement']
# ['nobaate : amourette', 'nobaate : nourrir une petite passion']
# ['ñaanaatu : quémander', 'ñaanaatu : mendier', 'ñaanaatu : quémande']
# ['waxé : parler avec', "waxé : parler à partir d'un lieu donné"]
# ['goreel : annoblir', 'goreel : ennoblissement', 'goreel : libération']
# ['ñaareel : deuxième épouse', 'ñaareel : prendre une seconde femme']
# ['wàññeeku : retournement', 'wàññeeku : se retourner']
# ["waa joor : habitants de l'arrière-pays", "waajoor : habitants de l'arrière-pays"]
# ["waa kaw : habitant de l'intérieur", "waakaw : habitant de l'intérieur"]
# ['daõõ-daõõ : fracas', 'daõõ-daõõ : de bruits et de mouvement']
# ['raõõ-raõõ : fracas', 'raõõ-raõõ : de bruits et de mouvement']
# ['kër-kër : de bruits et de mouvement', 'kër-kër : fracas']
# ["waaye nit kookii gaddaayoon nag dellusiwul : par contre, cet homme qui s'exila ne revint pas"]
# ["Séen naa as lëf : J'ai aperçu une chose, une portion"]
# ['Dem naa : je pars', 'Dem naa : je suis parti']
# ['Dem õga : Tu pars', 'Dem õga : Tu es parti']
# ['Dem na : Il part', 'Dem na : Il est parti']
# ['Dem nañu : Nous sommes partis', 'Dem nañu : Nous partons']
# ['Dem õgeen : vous êtes partis', 'Dem õgeen : Vous partez']
# ['Dem nañu : Ils partent', 'Dem nañu : Elles sont partis']
# ['Dem nañu : Ils partent', 'Dem nañu : Ils sont partis']
# ['soo ñëwóon, kon, demkoon naa : si tu étais venu, dans ce cas, je serais parti']
# ["maa di dem : c'est moi qui pars", "maa di dem : c'est moi qui suis en train de partir", "maa di dem : c'est moi qui dois partir", "maa di dem : c'est moi qui vais partir"]
# ["góor gi doon dem : l'homme qui partait", "góor gi doon dem : l'homme qui devait partir", "góor gi doon dem : l'homme qui allait partir"]
# ["su góor gi dee ñëw : si l'homme vient", "su góor gi dee ñëw : si l'homme doit venir", "su góor gi dee ñëw : quand l'homme viendra"]
# ['bi õga dee dem : alors que tu partais', 'bi õga dee dem : au moment où tu partais', 'bi õga dee dem : du moment que tu pars']
# ["bi mu dee dem : du moment qu'il part", "bi mu dee dem : du fait qu'il doit partir"]
# ['ñi : lesquels', 'ñi : auxquels']
# ['ña : lesquels', 'ña : auxquels']
# ['ñooña : lesquels', 'ñooña : auxquels']
# ['ñu : lesquels', 'ñu : auxquels']
# ['ñooñu : lesquels', 'ñooñu : auxquels']
# ['yi : lesquels', 'yi : auxquels']
# ['ya : lesquels', 'ya : auxquels']
# ['yooya : lesquels', 'yooya : auxquels']
# ['yu : lesquels', 'yu : auxquels']
# ['yooyu : lesquels', 'yooyu : auxquels']
# ['nagi dëkk bii õga gis, wa ci ëpp sa baay Alfa moo ka moom : des boeufs que tu vois dans cette ville, le plus gros appartient à ton père Alfa.', 'nagi dëkk bii õga gis, wa ci ëpp sa baay Alfa moo ka moom : des boeufs que tu vois dans cette ville, celui le plus gros appartient à ton père Alfa.']
# ["nit ñi õga ma wàn ñépp, kii laa ci wóolu : des gens que tu m'as présentés celui que voici me dispose le plus à la confiance."]
# ['gis õga nag yii yépp, woowuu moo ci gën : des boeufs que tu vois, celui-là est le meilleur.', 'gis õga nag yii yépp, woowuu moo ci gën : des boeufs que tu vois, celui-là tout près est le meilleur.']
# ["mii maa ka moom, waaye moomule deey, xawma fu mu bokk : celui-ci est à moi mais j'ignore d'où provient cet autre-là.", "mii maa ka moom, waaye moomule deey, xawma fu mu bokk : celui-ci est à moi mais j'ignore d'où provient cet autre-là près de toi."]
# ["xëynë xar yi ñëw nañu wante gisaguma wenn : les moutons sont peut-être déjà arrivés, j'en n'ai encore vu aucun"]
# ["sa jarbaat yi, jenn gënu kë ci tayel : aucun de tes neveux n'est aussi paresseux que celui-là."]
# ["népp noo defe baax na : de toute manière, quelle que soit ta façon d'agir c'est bien"]
# ['fépp fu mu jëm foofu jàmm dana fa wacc : partout où il descend, là paix descendra']
# ["képp ku dem, kooku raggal la : quiconque s'en va, celui-là est un froussard"]
# ["kooku dem ku më bëgg la : c'est quelqu'un que j'apprécie, celui qui est parti", "kooku dem ku më bëgg la : celui qui est parti, c'est quelqu'un que j'apprécie"]
# ['moom daal : lui, aussi']
# ["wax ji yépp, bañ-õga-ñëw la : tout ce verbiage, c'est pour que tu ne viennes pas", "wax ji yépp, bañ-õga-ñëw la : tout ce bavardage, c'est pour que tu ne viennes pas"]
# ["maa õgii gis leen ma, du jëfu nit ku yiw : « me voici, regardez-moi » n'est pas le fait d'un homme serein"]
# ["sëriñ bi ñaan na mayewoon alalam ji ba mënkóon yalwaan : le marabout implora qu'il fût dans la situation de quelqu'un qui aurait fait don de sa fortune, pour être en mesure de demander l'aumône"]
# ["abalal keneen ki demkoonul ki, sama téeré bi : prête à cet autre qui n'eût pas été, mon ouvrage"]
# ["noona Gelwar bi, buur bi, daldi ni tekk : alors le roi Guelwar s'immobilisa"]
# ['ñëwël ndax Musaa lamaanu réew mi : viens pour Moussa, lamane de ce pays']
# ['nit, gayndé, nag, àndoon nañu fi : homme, lion, boeuf, allaient de concert']
# ["xale yi set nañu ci biir, ci biti gisuñu dara : les enfants ont cherché à l'intérieur, à l'extérieur, mais n'ont rien trouvé"]
# ['nit, gaynde, xar, ak bukki duñu ànd : homme, lion, mouton et hyène, ne vont pas ensemble']
# ['may na ka lëg, doomam ak nopp ya : il lui a donné le lièvre, ses petits et leurs oreilles']
# ["séetal ci bir, ci biti, ci suuf ak ci kaw : regarde à l'intérieur, à l'extérieur, en bas et en haut"]
# ["õga dem la, góor gi bëgg : que tu partes, c'est ce que désire l'homme"]
# ['bëggóon õgeen dem rekk : le désir non exaucé de vous voir partir']
# ['góor googule ñëwóon, mi õgi : cet homme qui vint autrefois, le voilà']
# ["ci kooku, ndax mu wettëliku : avec celui-là, afin qu'il ne soit pas seul"]
# ["Faatim la soo demee : c'est Fatim, si on va au fond des choses", "Faatim la soo demee : c'est Fatim, peut-être", "Faatim la soo demee : c'est peut-être Fatim"]
# ["soo demee, Faatim la : si on va au fond des choses, c'est Fatim", "soo demee, Faatim la : c'est Fatim, si on va au fond des choses", "soo demee, Faatim la : c'est peut-être Fatim"]
# ['so demee, mi õgiy wax : il est entrain de parler, peut-être', 'so demee, mi õgiy wax : il est peut-être entrain de parler']
# ['soo bëggul, ci fii kóon : ici alors, si tu refuses']
# ['ci Séeréer si, ci Ñoomiõka yi, ci Pël yi : chez les Sérère, les Peul, les Niominka']
# ['ci Pël yi ag ci Séeréer si, ag ci Ñomiõka yi : chez les Peul, les Sérère, et les les Niominka']
# ["noona góor gi seet lëf ki, seetat mbir mi : alors l'homme reconsidéra la chose, reconsidéra l'affaire."]
# ["dem õga, te dem na, te dem naa : tu as été et il a été et moi aussi j'ai été"]
# ["noona góor gi dugg, xale yi gis ka, mu toog, ñépp toog : alors l'homme entra, les enfants le virent, il s'assit, tous s'assirent"]
# ["bëgg naa góor ñi ñëw, xale yi ñëw, jigéen ñi toog : je souhaite que les hommes viennent, que les enfants viennent et que les femmes s'asseyent"]
# ['nee waa jii gor la, goor la, jambe la : il dit que ce Monsieur est un homme, il est noble, il est brave']
# ["defe naa du kookuu, du kookee : je crois que ce n'est pas celui-ci ce n'est pas celui-là"]
# ["demal ndax mu ñëw, ndax mu meddi : vas-y pour qu'il vienne, pour qu'il ne soit plus fâché"]
# ['ñëwël ndax xale yi di ay liggéeykat, di ay jambaar : viens pour que les enfants soient des travailleurs, soient des braves']
# ['demal, ndax mu di, leneen, mu di feneen : vas-y pour que ce soit autre chose, que ce soit ailleurs']
# ["tày ci suba, tày ci õgoon ma fiy nekk : ce matin ou ce soir c'est moi qui suis ici"]
# ["maa fiy nekk tày ci õgoon, tày ci suba : ce matin ou ce soir c'est moi qui suis ici"]
# ["bëgg në õga ñëw, mu bañ dem su nëjul : je veux que tu viennes, qu'il refuse de partir s'il n'y a pas de soleil"]
# ["bëgg naa õga ñëw mu dem su õgeen noppée : je veux, si vous avez fini, que tu viennes et qu'il parte"]
# ['bëgg naa ci juróomi waxtu, ci subë, õga ñëw : je veux que tu viennes le matin à cinq heures dans la fraîcheur']
# ['defewoon na, ci subë si, ci bes bi, daa dem : je croyais que tu irais, ce matin, ce jour']
# ['defewoon na, daa dem, ci bes bi ci subë si : je croyais que tu irais, ce matin, ce jour']
# ["defewoon naa góor gi kenn ki la, te xale bi kooku la : je croyais que l'homme c'était cet autre et que l'enfant c'était celui-là"]
# ["bëgg na soo demee, mu dellusi te góor gi ñëw : il veut, lorsque tu iras que lui, il revienne et que l'homme aussi revienne"]
# ["bëgg na góor gi ñëw te mu dellusi soo demee : il veut que l'homme vienne et que lui, il revienne si tu pars"]
# ['xale yi bëgg nañu dikk, te mag ni ñaan nañu õgeen dem : les enfants veulent venir et les adultes souhaitent que vous partiez']
# ["góor gi dem na ndax õgeen ñëw te nak kenn bañ leen foog : l'homme est parti pour que vous veniez sans que personne, surtout, ne le soupçonne"]
# ["yaakaaroon na ni, mag ñi du ñu ci agg foofu te it xale yi nekkunu fi woon : il espérait que les gens d'âge n'en seraient pas arrivés là et aussi que les enfants étaient absents"]
# ['te itam : et aussi', 'te itam : et surtout']
# ['te nak : et', 'te nak : et aussi', 'te nak : et encore', 'te nak : et surtout', 'te nak : et sans que', 'te nak : et enfin']
# ['ag it : mais aussi', 'ag it : et aussi']
# ['lu tax ? : pourquoi ?', "lu tax ? : qu'est-ce qui est la cause ?"]
# ['lu waral ? : pourquoi ?', "lu waral ? : qu'est-ce, qui est la cause ?"]

# %% [markdown]
# **Regex 4** -->

# %%
result = new_sent_extraction.replace_groups(".*\d+.*", save=True, csv_file="founded.csv")
# Out:
# Found groups matching the regular expression .*\d+.* are the followings:
#
# - géew bi day taxaw walla 1 ma dem : le cercle se forme ou je m'en vais
#
# ----------------------
#
# Final result:
# ["géew bi day taxaw walla  ma dem : le cercle se forme ou je m'en vais"]

# %% [markdown]
# **Regex 5** -->

# %%
result = new_sent_extraction.replace_groups(".*²÷.*", save=True, csv_file="founded.csv", force_replace=True)
# Out:
# Found groups matching the regular expression .*²÷.* are the followings:
#
# - ku ²÷ dem : qui est parti ?
# - góor gu ²÷ dem : quel homme est parti ?
# - moo ²÷ dem : c'est lui qui est parti ?
# - góor gi ²÷ nit la : l'homme est sain d'esprit
# - góor gi ²÷ nitu Ndar la : l'homme est un Saint-Louisien
# - góor gi ²÷ di xel doõõ : cet homme n'est qu'intelligence
# - berëb yi ²÷ berëb yu yaa lañu : ces lieux sont de vastes étendues
# - góor gi ²÷ kenn la : l'homme est unique
# - kooku ²÷ keneen la : celui-là c'est un autre
# - berëb bi ²÷ du foofu : l'endroit ce n'est pas par-là
# - ndaje mi ²÷ ci biir la : la réunion c'est à l'intérieur
# - ndaje mi ²÷ du gannaaw ëlëk ? : la réunion ce n'est pas après-
# - góor gi ²÷ dem : le Monsieur est parti
# - mu ²÷ dem : (mais) il est parti
# - ma ngii ²÷ dem : voilà qu'il est parti
# - góor ñi ²÷ deekoon nanu : les gens en eussent été morts
# - maa ²÷ demulkoon : c'est moi qui n'aurais pas été
# - góor ²÷ demul : (un) homme n'a été (nul n'a été)
# - góor gi ²÷ demul : l'homme n'a pas été
# - xar yu ñuul ²÷ dinañu feeñ : les moutons noirs seront retrouvés.
# - góor gi moo ²÷ demulwoon : c'est l'homme qui n'a pas été
# - sarxe ²÷ baaxkoon na : l'aumône eut été une bonne chose
# - man ²÷ dem në : moi j'ai été
# - man mii ²÷ demuma : moi-même je n'ai pas été
# - kooku ²÷ du nit : celui-là n'est pas sain d'esprit
# - maa ²÷ demoon : c'est moi qui ai été
# - më õgile ²÷ demkoon : voilà que j'aurais été
# - kenn ²÷ demul : nul n'a été
# - yéen ²÷ dem õgeen : vous avez été
# - ku ²÷ dem ? : qui a été ?
# - ñooñii ²÷ dunu demi : ceux-là n'iront pas
# - wóoy ! ²÷ taxul mu yabbi : Aïe ! ne suffit pas pour qu'il lâche
# - dem naa ²÷ doyunu : « j'ai été » ne nous suffit pas
# - demkoon ²÷ doon na ma fi war : j'ai failli être dans l'obligation d'y
# - bëgguma ²÷ du yar : je ne veux pas est une forme impolie
# - góor ²÷ dem na : un homme est parti
# - góor ñi ²÷ dem nañu : les hommes sont partis
# - seen gaynde gi ²÷ xar la : leur lion c'est un mouton
# - seni gaynde yi ²÷ ay xar lañu : leurs lions c'est des moutons
# - nit ag gaynde ²÷ duñu dëkkóo : homme et lion ne cohabitent
# - Liggéeykat yi ²÷ man ag yaw la : les travailleurs c'est toi et moi
# - liggéeykat yi ²÷ ñun la : les travailleurs c'est nous
# - liggéeykat ya ²÷ xale ya la woon : les travailleurs c'était les enfants
# - nit : ki ²÷ ñëw la : c'est l'homme qui est venu
# - õga bañ ñëw ²÷ rafetul : le fait que tu ne viennes pas est préjudiciable
# - di tel-teli doõõ ²÷ taxul sotal dara : s'agiter simplement ne suffit à rien résoudre
# - jigéen ji ag góor gi ²÷ ñjool lañu : la femme et l'homme sont de haute taille
# - jigéen ñi ag góor ñi ²÷ ñjóol lañu : les femmes et les hommes sont de haute taille
#
# ----------------------
#
# Final result:
# ['ku dem : qui est parti ?']
# ['góor gu dem : quel homme est parti ?']
# ["moo dem : c'est lui qui est parti ?"]
# ["góor gi nit la : l'homme est sain d'esprit"]
# ["góor gi nitu Ndar la : l'homme est un Saint-Louisien"]
# ["góor gi di xel doõõ : cet homme n'est qu'intelligence"]
# ['berëb yi berëb yu yaa lañu : ces lieux sont de vastes étendues']
# ["góor gi kenn la : l'homme est unique"]
# ["kooku keneen la : celui-là c'est un autre"]
# ["berëb bi du foofu : l'endroit ce n'est pas par-là"]
# ["ndaje mi ci biir la : la réunion c'est à l'intérieur"]
# ["ndaje mi du gannaaw ëlëk ? : la réunion ce n'est pas après-"]
# ['góor gi dem : le Monsieur est parti']
# ['mu dem : (mais) il est parti']
# ["ma ngii dem : voilà qu'il est parti"]
# ['góor ñi deekoon nanu : les gens en eussent été morts']
# ["maa demulkoon : c'est moi qui n'aurais pas été"]
# ["góor demul : (un) homme n'a été (nul n'a été)"]
# ["góor gi demul : l'homme n'a pas été"]
# ['xar yu ñuul dinañu feeñ : les moutons noirs seront retrouvés.']
# ["góor gi moo demulwoon : c'est l'homme qui n'a pas été"]
# ["sarxe baaxkoon na : l'aumône eut été une bonne chose"]
# ["man dem në : moi j'ai été"]
# ["man mii demuma : moi-même je n'ai pas été"]
# ["kooku du nit : celui-là n'est pas sain d'esprit"]
# ["maa demoon : c'est moi qui ai été"]
# ["më õgile demkoon : voilà que j'aurais été"]
# ["kenn demul : nul n'a été"]
# ['yéen dem õgeen : vous avez été']
# ['ku dem ? : qui a été ?']
# ["ñooñii dunu demi : ceux-là n'iront pas"]
# ["wóoy ! taxul mu yabbi : Aïe ! ne suffit pas pour qu'il lâche"]
# ["dem naa doyunu : « j'ai été » ne nous suffit pas"]
# ["demkoon doon na ma fi war : j'ai failli être dans l'obligation d'y"]
# ['bëgguma du yar : je ne veux pas est une forme impolie']
# ['góor dem na : un homme est parti']
# ['góor ñi dem nañu : les hommes sont partis']
# ["seen gaynde gi xar la : leur lion c'est un mouton"]
# ["seni gaynde yi ay xar lañu : leurs lions c'est des moutons"]
# ['nit ag gaynde duñu dëkkóo : homme et lion ne cohabitent']
# ["Liggéeykat yi man ag yaw la : les travailleurs c'est toi et moi"]
# ["liggéeykat yi ñun la : les travailleurs c'est nous"]
# ["liggéeykat ya xale ya la woon : les travailleurs c'était les enfants"]
# ["nit : ki ñëw la : c'est l'homme qui est venu"]
# ['õga bañ ñëw rafetul : le fait que tu ne viennes pas est préjudiciable']
# ["di tel-teli doõõ taxul sotal dara : s'agiter simplement ne suffit à rien résoudre"]
# ["jigéen ji ag góor gi ñjool lañu : la femme et l'homme sont de haute taille"]
# ['jigéen ñi ag góor ñi ñjóol lañu : les femmes et les hommes sont de haute taille']

# %% [markdown]
# **Regex 6** -->

# %%
result = new_sent_extraction.replace_groups(".*¹+.*", save=True, csv_file="founded.csv", force_replace=True)
# Out:
# Found groups matching the regular expression .*¹+.* are the followings:
#
# - Séen naa ak nit : J'ai aperçu un homme (aw nit) ¹
# - lëf lenn réerul ¹ : rien ne s'est égaré
# - seneen ¹ ndaw laa bëgg : c'est une autre jeune fille que je veux
# - góor gi dana demi ¹ : l'homme ira
# - dafa di ¹ nitu tay : c'est un homme de son époque
# - góor gi nee mi õgi fi : l'homme affirme qu'il est là ¹
# - õga dem la ñooñu bëgg ¹ : que tu partes c'est ce que ceux-là veulent
# - Samba : mi ñëw ? ¹ : Samba : qui est venu ?
# - li : waa ji wax ¹ : ce que : cet homme a dit
# - man ¹ : õga woo : c'est moi (que) tu appelles
# - koo ¹ jox xaalis ? : à qui as-tu donné de l'argent ?
#
# ----------------------
#
# Final result:
# ["Séen naa ak nit : J'ai aperçu un homme (aw nit)"]
# ["lëf lenn réerul : rien ne s'est égaré"]
# ["seneen ndaw laa bëgg : c'est une autre jeune fille que je veux"]
# ["góor gi dana demi : l'homme ira"]
# ["dafa di nitu tay : c'est un homme de son époque"]
# ["góor gi nee mi õgi fi : l'homme affirme qu'il est là"]
# ["õga dem la ñooñu bëgg : que tu partes c'est ce que ceux-là veulent"]
# ['Samba : mi ñëw ? : Samba : qui est venu ?']
# ['li : waa ji wax : ce que : cet homme a dit']
# ["man : õga woo : c'est moi (que) tu appelles"]
# ["koo jox xaalis ? : à qui as-tu donné de l'argent ?"]

# %%
result = new_sent_extraction.replace_groups(".*².*", save=True, csv_file="founded.csv", force_replace=True)
# Out:
# Found groups matching the regular expression .*².* are the followings:
#
# - góor gi : mu àndi ² : l'homme qu'il a amené
# - Samba ² : õga woo : c'est Samba que tu appelles
# - ci biir ² : õga wax : c'est à l'intérieur que tu dis
# - yaw la : bëgg ² : c'est toi (qu')elle veut
#
# ----------------------
#
# Final result:
# ["góor gi : mu àndi : l'homme qu'il a amené"]
# ["Samba : õga woo : c'est Samba que tu appelles"]
# ["ci biir : õga wax : c'est à l'intérieur que tu dis"]
# ["yaw la : bëgg : c'est toi (qu')elle veut"]

# %% [markdown]
# **Regex 7** -->

# %%
result = new_sent_extraction.replace_groups(".*;.*", save=True, csv_file="founded.csv", manual_replace=True)
# Out:
# Found groups matching the regular expression .*;.* are the followings:
#
# - coy : variété d'oiseau ; coyy : rouge écarlate ; noyyi : respirer
# - sawu : urinoir ;
# - Jaw ; Diaw : nom de personne ; jaww : atmosphère
# - jiitu : précéder ; fit-al : mettre en tête
# - samp : planter ; cemp : variété d'herbe aromatique ;
# - def : faire ; jëf : acte ; jëfkat : homme d'action
# - boot : porter sur le dos ; bootaay : manière de porter sur le dos ;
# - dog : couper ; dogal : pourboire ; ndogal : destin
# - sopp : estimer ; soppal : estimer à cause de quelqu'un ;
# - wax : dire ; weddi : nier ; weddikat : qui nie
# - neex : agréable ; naqadi : désagréable ; naqadil : rendre
# - dog : couper ; dogalante : se faire de petits cadeaux ; ndogalante : concession mutuelle
# - jiitu : précéder ; jiital : mettre en tête ; jiitëlante : se mettre en rang ;
# - wax : parler ; waxaale : marchander ; waxaalelu : faire marchander ;
# - jéem : essayer ; jëmentu : s'exercer ; jëmentalukaay : terrain d'essai
# - jiit qui donne : jiitu : être en tête ; jiital : mettre en tête...
# - wuut qui donne : wuutu : se substituer ; wuutal : substituer
# - xéew qui donne : xéewal : bonne fortune ; xéewlu : bénéficier d'un sort
# - ñuul : noir ; biir : ventre ; donne ñuulbiir : méchant; méchanceté
# - jaam : esclave ; buur : roi ; donne jaambur : homme libre
# - wër : faire le tour ; sëg : cimetière ; donne wërsëg : chance
# - bax : bon ; donne baxbax-lu : faire semblant d'être gentil
# - góor : mâle ; donne góorgóor-lu : se conduire en homme
# - wër : faire le tour ; wër-wër : va et vient ; wër wër lu : aller à droite et
# - xam : savoir ; xam-xam : science ; xam xam lu : jouer au savant
# - xar : fendre ; xar-xar : fente ; xar xar le : simuler l'agonie
# - daõ-daõ : trépidation ; daõ daõ : trépigner ; daõ daõ lu : trépigner
# - raõ-raõ : fracas ; raõ raõ lu : faire du vacarme
# - jaambur : homme libre ; jaambur-jaambur : habitant du Diambour ;
# - xar xar : fente ; xarxarle : agoniser ; xarxarlekat : qui simule
# - wër sëg : chance ; wërsëglóo : bénéficier de quelque chose
# - daõ daõ : trépidation ; daõdaõluji : aller s'exciter quelque part
# - bëkknéeg : courtisan ; bëkknéegu : se conduire en courtisan
# - warugar : dot ; warugarloo : considérer comme une obligation
# - ñaari goroõ : figure de danse ; ñaari goroõi : aller danser le naari
# - yaw doõõ laa wax : je ne parle que de toi ; je parle de toi seul
# - kile : celle-ci ; kule : celle-ci ; male : celle-ci
# - kookii : celui-ci (près de toi) ; kookuu : celle-ci (près de toi) ;
# - moomile : celui-ci ; moomule : celle-ci ; moomale : celle-ci
# - nii : ceux-ci ; nuu : ceux-ci (près de toi) ; ñooñee : ceux-là (passé)
# - yi : celles-ci ; yuu : celles-ci ; joyee : celles-là
# - ñooñii : celles-ci ; ñooñuu : celles-ci ; ñooñale : celles-là
# - yooyii : celles-ci ; yooyuu : celles-ci ; yooyale : celles-là
# - ndax kan dem ? : afin que parte qui ? ; afin que (qui) parte ?
# - lépp tuuru na : le tout s'est renversé ; lépp jeex na : le tout est
# - kooku la : c'est celui-là ; celui-là (c'est)
# - keneen õga : tu es un autre ; autre (tu es)
# - ñeñeen lañu : il s'agit d'autres ; autres (ils sont)
# - menn la : il est unique ; un (il est)
# - ñeneen lañu : il s'agit d'autres ; autres (ils sont)
# - ñan la : qui sont-ce ; qui est-ce
# - fii : ici ; foofii ou file ou foofile : là a cet endroit
# - fuu : ici ; foofuu ou fule ou foofale : là tout près de toi (alors)
# - lii : ceci ; loolii : ceci ; lile : ceci ; loolule : ce fait
# - luu : ceci ; looluu : ceci ; lule : ceci ; loolule : ce fait-ci
# - foofee fan ? : où ; là-bas où
#
# ----------------------
#
# You will modify the following group:
#  coy : variété d'oiseau ; coyy : rouge écarlate ; noyyi : respirer
# The manual modification of the group
#  coy : variété d'oiseau ; coyy : rouge écarlate ; noyyi : respirer
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sawu : urinoir ;
# The manual modification of the group
#  sawu : urinoir ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Jaw ; Diaw : nom de personne ; jaww : atmosphère
# The manual modification of the group
#  Jaw ; Diaw : nom de personne ; jaww : atmosphère
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jiitu : précéder ; fit-al : mettre en tête
# The manual modification of the group
#  jiitu : précéder ; fit-al : mettre en tête
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  samp : planter ; cemp : variété d'herbe aromatique ;
# The manual modification of the group
#  samp : planter ; cemp : variété d'herbe aromatique ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  def : faire ; jëf : acte ; jëfkat : homme d'action
# The manual modification of the group
#  def : faire ; jëf : acte ; jëfkat : homme d'action
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  boot : porter sur le dos ; bootaay : manière de porter sur le dos ;
# The manual modification of the group
#  boot : porter sur le dos ; bootaay : manière de porter sur le dos ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dog : couper ; dogal : pourboire ; ndogal : destin
# The manual modification of the group
#  dog : couper ; dogal : pourboire ; ndogal : destin
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sopp : estimer ; soppal : estimer à cause de quelqu'un ;
# The manual modification of the group
#  sopp : estimer ; soppal : estimer à cause de quelqu'un ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wax : dire ; weddi : nier ; weddikat : qui nie
# The manual modification of the group
#  wax : dire ; weddi : nier ; weddikat : qui nie
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  neex : agréable ; naqadi : désagréable ; naqadil : rendre
# The manual modification of the group
#  neex : agréable ; naqadi : désagréable ; naqadil : rendre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dog : couper ; dogalante : se faire de petits cadeaux ; ndogalante : concession mutuelle
# The manual modification of the group
#  dog : couper ; dogalante : se faire de petits cadeaux ; ndogalante : concession mutuelle
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jiitu : précéder ; jiital : mettre en tête ; jiitëlante : se mettre en rang ;
# The manual modification of the group
#  jiitu : précéder ; jiital : mettre en tête ; jiitëlante : se mettre en rang ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wax : parler ; waxaale : marchander ; waxaalelu : faire marchander ;
# The manual modification of the group
#  wax : parler ; waxaale : marchander ; waxaalelu : faire marchander ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jéem : essayer ; jëmentu : s'exercer ; jëmentalukaay : terrain d'essai
# The manual modification of the group
#  jéem : essayer ; jëmentu : s'exercer ; jëmentalukaay : terrain d'essai
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jiit qui donne : jiitu : être en tête ; jiital : mettre en tête...
# The manual modification of the group
#  jiit qui donne : jiitu : être en tête ; jiital : mettre en tête...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wuut qui donne : wuutu : se substituer ; wuutal : substituer
# The manual modification of the group
#  wuut qui donne : wuutu : se substituer ; wuutal : substituer
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xéew qui donne : xéewal : bonne fortune ; xéewlu : bénéficier d'un sort
# The manual modification of the group
#  xéew qui donne : xéewal : bonne fortune ; xéewlu : bénéficier d'un sort
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñuul : noir ; biir : ventre ; donne ñuulbiir : méchant; méchanceté
# The manual modification of the group
#  ñuul : noir ; biir : ventre ; donne ñuulbiir : méchant; méchanceté
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jaam : esclave ; buur : roi ; donne jaambur : homme libre
# The manual modification of the group
#  jaam : esclave ; buur : roi ; donne jaambur : homme libre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wër : faire le tour ; sëg : cimetière ; donne wërsëg : chance
# The manual modification of the group
#  wër : faire le tour ; sëg : cimetière ; donne wërsëg : chance
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  bax : bon ; donne baxbax-lu : faire semblant d'être gentil
# The manual modification of the group
#  bax : bon ; donne baxbax-lu : faire semblant d'être gentil
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor : mâle ; donne góorgóor-lu : se conduire en homme
# The manual modification of the group
#  góor : mâle ; donne góorgóor-lu : se conduire en homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wër : faire le tour ; wër-wër : va et vient ; wër wër lu : aller à droite et
# The manual modification of the group
#  wër : faire le tour ; wër-wër : va et vient ; wër wër lu : aller à droite et
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xam : savoir ; xam-xam : science ; xam xam lu : jouer au savant
# The manual modification of the group
#  xam : savoir ; xam-xam : science ; xam xam lu : jouer au savant
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xar : fendre ; xar-xar : fente ; xar xar le : simuler l'agonie
# The manual modification of the group
#  xar : fendre ; xar-xar : fente ; xar xar le : simuler l'agonie
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  daõ-daõ : trépidation ; daõ daõ : trépigner ; daõ daõ lu : trépigner
# The manual modification of the group
#  daõ-daõ : trépidation ; daõ daõ : trépigner ; daõ daõ lu : trépigner
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  raõ-raõ : fracas ; raõ raõ lu : faire du vacarme
# The manual modification of the group
#  raõ-raõ : fracas ; raõ raõ lu : faire du vacarme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jaambur : homme libre ; jaambur-jaambur : habitant du Diambour ;
# The manual modification of the group
#  jaambur : homme libre ; jaambur-jaambur : habitant du Diambour ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xar xar : fente ; xarxarle : agoniser ; xarxarlekat : qui simule
# The manual modification of the group
#  xar xar : fente ; xarxarle : agoniser ; xarxarlekat : qui simule
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wër sëg : chance ; wërsëglóo : bénéficier de quelque chose
# The manual modification of the group
#  wër sëg : chance ; wërsëglóo : bénéficier de quelque chose
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  daõ daõ : trépidation ; daõdaõluji : aller s'exciter quelque part
# The manual modification of the group
#  daõ daõ : trépidation ; daõdaõluji : aller s'exciter quelque part
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  bëkknéeg : courtisan ; bëkknéegu : se conduire en courtisan
# The manual modification of the group
#  bëkknéeg : courtisan ; bëkknéegu : se conduire en courtisan
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  warugar : dot ; warugarloo : considérer comme une obligation
# The manual modification of the group
#  warugar : dot ; warugarloo : considérer comme une obligation
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñaari goroõ : figure de danse ; ñaari goroõi : aller danser le naari
# The manual modification of the group
#  ñaari goroõ : figure de danse ; ñaari goroõi : aller danser le naari
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yaw doõõ laa wax : je ne parle que de toi ; je parle de toi seul
# The manual modification of the group
#  yaw doõõ laa wax : je ne parle que de toi ; je parle de toi seul
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kile : celle-ci ; kule : celle-ci ; male : celle-ci
# The manual modification of the group
#  kile : celle-ci ; kule : celle-ci ; male : celle-ci
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kookii : celui-ci (près de toi) ; kookuu : celle-ci (près de toi) ;
# The manual modification of the group
#  kookii : celui-ci (près de toi) ; kookuu : celle-ci (près de toi) ;
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  moomile : celui-ci ; moomule : celle-ci ; moomale : celle-ci
# The manual modification of the group
#  moomile : celui-ci ; moomule : celle-ci ; moomale : celle-ci
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nii : ceux-ci ; nuu : ceux-ci (près de toi) ; ñooñee : ceux-là (passé)
# The manual modification of the group
#  nii : ceux-ci ; nuu : ceux-ci (près de toi) ; ñooñee : ceux-là (passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yi : celles-ci ; yuu : celles-ci ; joyee : celles-là
# The manual modification of the group
#  yi : celles-ci ; yuu : celles-ci ; joyee : celles-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñooñii : celles-ci ; ñooñuu : celles-ci ; ñooñale : celles-là
# The manual modification of the group
#  ñooñii : celles-ci ; ñooñuu : celles-ci ; ñooñale : celles-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yooyii : celles-ci ; yooyuu : celles-ci ; yooyale : celles-là
# The manual modification of the group
#  yooyii : celles-ci ; yooyuu : celles-ci ; yooyale : celles-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ndax kan dem ? : afin que parte qui ? ; afin que (qui) parte ?
# The manual modification of the group
#  ndax kan dem ? : afin que parte qui ? ; afin que (qui) parte ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  lépp tuuru na : le tout s'est renversé ; lépp jeex na : le tout est
# The manual modification of the group
#  lépp tuuru na : le tout s'est renversé ; lépp jeex na : le tout est
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kooku la : c'est celui-là ; celui-là (c'est)
# The manual modification of the group
#  kooku la : c'est celui-là ; celui-là (c'est)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  keneen õga : tu es un autre ; autre (tu es)
# The manual modification of the group
#  keneen õga : tu es un autre ; autre (tu es)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñeñeen lañu : il s'agit d'autres ; autres (ils sont)
# The manual modification of the group
#  ñeñeen lañu : il s'agit d'autres ; autres (ils sont)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  menn la : il est unique ; un (il est)
# The manual modification of the group
#  menn la : il est unique ; un (il est)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñeneen lañu : il s'agit d'autres ; autres (ils sont)
# The manual modification of the group
#  ñeneen lañu : il s'agit d'autres ; autres (ils sont)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñan la : qui sont-ce ; qui est-ce
# The manual modification of the group
#  ñan la : qui sont-ce ; qui est-ce
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fii : ici ; foofii ou file ou foofile : là a cet endroit
# The manual modification of the group
#  fii : ici ; foofii ou file ou foofile : là a cet endroit
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fuu : ici ; foofuu ou fule ou foofale : là tout près de toi (alors)
# The manual modification of the group
#  fuu : ici ; foofuu ou fule ou foofale : là tout près de toi (alors)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  lii : ceci ; loolii : ceci ; lile : ceci ; loolule : ce fait
# The manual modification of the group
#  lii : ceci ; loolii : ceci ; lile : ceci ; loolule : ce fait
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  luu : ceci ; looluu : ceci ; lule : ceci ; loolule : ce fait-ci
# The manual modification of the group
#  luu : ceci ; looluu : ceci ; lule : ceci ; loolule : ce fait-ci
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  foofee fan ? : où ; là-bas où
# The manual modification of the group
#  foofee fan ? : où ; là-bas où
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# Final result:
# ["coy : variété d'oiseau", 'coyy : rouge écarlate', 'noyyi : respirer']
# ['sawu : urinoir']
# ['jaww : atmosphère']
# ['jiitu : précéder', 'fit-al : mettre en tête']
# ['samp : planter', "cemp : variété d'herbe aromatique"]
# ['def : faire', 'jëf : acte', "jëfkat : homme d'action"]
# ['boot : porter sur le dos', 'bootaay : manière de porter sur le dos']
# ['dog : couper', 'dogal : pourboire', 'ndogal : destin']
# ['sopp : estimer', "soppal : estimer à cause de quelqu'un"]
# ['wax : dire', 'weddi : nier', 'weddikat : qui nie']
# ['neex : agréable', 'naqadi : désagréable', 'naqadil : rendre']
# ['dog : couper', 'dogalante : se faire de petits cadeaux', 'ndogalante : concession mutuelle']
# ['jiitu : précéder', 'jiital : mettre en tête', 'jiitëlante : se mettre en rang']
# ['wax : parler', 'waxaale : marchander', 'waxaalelu : faire marchander']
# ['jéem : essayer', "jëmentu : s'exercer", "jëmentalukaay : terrain d'essai"]
# ['jiit : qui donne', 'jiitu : être en tête', 'jiital : mettre en tête']
# ['wuut : qui donne', 'wuutu : se substituer', 'wuutal : substituer']
# ['xéewal : bonne fortune', "xéewlu : bénéficier d'un sort"]
# ['ñuul : noir', 'biir : ventre', 'ñuulbiir : méchant', 'ñuulbiir : méchanceté']
# ['jaam : esclave', 'buur : roi', 'jaambur : homme libre']
# ['wër : faire le tour', 'sëg : cimetière', 'wërsëg : chance']
# ['bax : bon', "baxbax-lu : faire semblant d'être gentil"]
# ['góor : mâle', 'góorgóor-lu : se conduire en homme']
# ['wër : faire le tour', 'wër-wër : va et vient', 'wër wër lu : aller à droite et à gauche']
# ['xam : savoir', 'xam-xam : science', 'xam xam lu : jouer au savant']
# ['xar : fendre', 'xar-xar : fente', "xar xar le : simuler l'agonie"]
# ['daõ-daõ : trépidation', 'daõ daõ : trépigner', 'daõ daõ lu : trépigner']
# ['raõ-raõ : fracas', 'raõ raõ lu : faire du vacarme']
# ['jaambur : homme libre', 'jaambur-jaambur : habitant du Diambour']
# ['xar xar : fente', 'xarxarle : agoniser', "xarxarlekat : qui simule l'agonie"]
# ['wër sëg : chance', 'wërsëglóo : bénéficier de quelque chose']
# ['daõ daõ : trépidation', "daõdaõluji : aller s'exciter quelque part"]
# ['bëkknéeg : courtisan', 'bëkknéegu : se conduire en courtisan']
# ['warugar : dot', 'warugarloo : considérer comme une obligation']
# ['ñaari goroõ : figure de danse', 'ñaari goroõi : aller danser le naari']
# ['yaw doõõ laa wax : je ne parle que de toi', 'yaw doõõ laa wax : je parle de toi seul']
# ['kile : celle-ci', 'kule : celle-ci', 'male : celle-ci']
# ['kookii : celui-ci', 'kookii : celui-ci près de toi', 'kookuu : celle-ci', 'kookuu : celle-ci près de toi']
# ['moomile : celui-ci', 'moomule : celle-ci', 'moomale : celle-ci']
# ['nii : ceux-ci', 'nuu : ceux-ci', 'nuu : ceux-ci près de toi', 'ñooñee : ceux-là']
# ['yi : celles-ci', 'yuu : celles-ci', 'joyee : celles-là']
# ['ñooñii : celles-ci', 'ñooñuu : celles-ci', 'ñooñale : celles-là']
# ['yooyii : celles-ci', 'yooyuu : celles-ci', 'yooyale : celles-là']
# ['ndax kan dem ? : afin que parte qui ?', 'ndax kan dem ? : afin que parte ?', 'ndax kan dem ? : afin que qui parte ?']
# ["lépp tuuru na : le tout s'est renversé", 'lépp jeex na : le tout est épuisé']
# ["kooku la : c'est celui-là", 'kooku la : celui-là', "kooku la : celui-là c'est"]
# ['keneen õga : tu es un autre', 'keneen õga : autre', 'keneen õga : autre tu es']
# ["ñeñeen lañu : il s'agit d'autres", 'ñeñeen lañu : autres', 'ñeñeen lañu : autres ils sont']
# ['menn la : il est unique', 'menn la : un', 'menn la : un il est']
# ["ñeneen lañu : il s'agit d'autres", 'ñeneen lañu : autres', 'ñeneen lañu : autres ils sont']
# ['ñan la : qui sont-ce', 'ñan la : qui est-ce']
# ['fii : ici', 'foofii : là a cet endroit', 'file : là a cet endroit', 'foofile : là a cet endroit']
# ['fuu : ici', 'foofuu : là tout près de toi', 'foofuu : là tout près de toi alors', 'fule : là tout près de toi', 'fule : là tout près de toi alors', 'foofale : là tout près de toi', 'foofale : là tout près de toi alors']
# ['lii : ceci', 'loolii : ceci', 'lile : ceci', 'loolule : ce fait']
# ['luu : ceci', 'looluu : ceci', 'lule : ceci', 'loolule : ce fait-ci']
# ['foofee fan ? : où ?', 'foofee fan ? : là-bas où ?']

# %% [markdown]
# **Regex 8** -->

# %%
result = new_sent_extraction.replace_groups(".*÷.*", save=True, csv_file="founded.csv", manual_replace=True)
# Out:
# Found groups matching the regular expression .*÷.* are the followings:
#
# - dee-o ÷ deewoo : mourir ensemble
# - ji-i ÷ jiyi : aller semer
# - jambuur : homme libre ÷ jambuur-jambuur : habitant de la région des
# - kërbët : pas de cheval ÷ kërbët kërbët : galop de cheval
# - na ma ÷ naa : que je....
#
# ----------------------
#
# You will modify the following group:
#  dee-o ÷ deewoo : mourir ensemble
# The manual modification of the group
#  dee-o ÷ deewoo : mourir ensemble
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ji-i ÷ jiyi : aller semer
# The manual modification of the group
#  ji-i ÷ jiyi : aller semer
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jambuur : homme libre ÷ jambuur-jambuur : habitant de la région des
# The manual modification of the group
#  jambuur : homme libre ÷ jambuur-jambuur : habitant de la région des
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kërbët : pas de cheval ÷ kërbët kërbët : galop de cheval
# The manual modification of the group
#  kërbët : pas de cheval ÷ kërbët kërbët : galop de cheval
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  na ma ÷ naa : que je....
# The manual modification of the group
#  na ma ÷ naa : que je....
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# Final result:
# ['dee-o : mourir ensemble', 'deewoo : mourir ensemble']
# ['ji-i : aller semer', 'jiyi : aller semer']
# ['jambuur : homme libre', 'jambuur-jambuur : habitant de la région des hommes libres']
# ['kërbët : pas de cheval', 'kërbët kërbët : galop de cheval']
# ['na ma : que je', 'naa : que je']

# %% [markdown]
# **Regex 9** -->

# %%
result = new_sent_extraction.replace_groups(".*—.*", save=True, csv_file="founded.csv", manual_replace=True)
# Out:
# Found groups matching the regular expression .*—.* are the followings:
#
# - fab — fap : prendre
# - fat — fad : ranger
# - fac — faj : soigner
# - tak — tag : se poser
# - fap — fab : prendre
# - dek — deg : épine degu àll : épine de brousse
# - cëriñ : islam — l'état de musulman
# - nit dem na : (un) homme est parti — quelqu'un est parti
# - su dee dem : alors qu'il sera en train de partir — s'il part
# - su demee : s'il est parti — une fois là-bas — s'il part
# - su dee dem : quand il partira — une fois en chemin
# - kenn — u nit : un seul homme
# - ñenn — u nit : certaines gens (quelques-uns parmi les hommes) yenn
# - araf céex — ñaari araf yu niróo te ànd : géminée.
# - waa jii ag waa joojale duñu benn : Cet homme-ci — devant nous — et cet homme-là (éloigné dans le temps) ne sont pas les mêmes
# - ñii dañu demul xanaa : ceux-ci ne partent peut-être pas — ne sont peut-être pas partis
#
# ----------------------
#
# You will modify the following group:
#  fab — fap : prendre
# The manual modification of the group
#  fab — fap : prendre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fat — fad : ranger
# The manual modification of the group
#  fat — fad : ranger
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fac — faj : soigner
# The manual modification of the group
#  fac — faj : soigner
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  tak — tag : se poser
# The manual modification of the group
#  tak — tag : se poser
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fap — fab : prendre
# The manual modification of the group
#  fap — fab : prendre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dek — deg : épine degu àll : épine de brousse
# The manual modification of the group
#  dek — deg : épine degu àll : épine de brousse
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  cëriñ : islam — l'état de musulman
# The manual modification of the group
#  cëriñ : islam — l'état de musulman
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit dem na : (un) homme est parti — quelqu'un est parti
# The manual modification of the group
#  nit dem na : (un) homme est parti — quelqu'un est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  su dee dem : alors qu'il sera en train de partir — s'il part
# The manual modification of the group
#  su dee dem : alors qu'il sera en train de partir — s'il part
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  su demee : s'il est parti — une fois là-bas — s'il part
# The manual modification of the group
#  su demee : s'il est parti — une fois là-bas — s'il part
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  su dee dem : quand il partira — une fois en chemin
# The manual modification of the group
#  su dee dem : quand il partira — une fois en chemin
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kenn — u nit : un seul homme
# The manual modification of the group
#  kenn — u nit : un seul homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñenn — u nit : certaines gens (quelques-uns parmi les hommes) yenn
# The manual modification of the group
#  ñenn — u nit : certaines gens (quelques-uns parmi les hommes) yenn
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  araf céex — ñaari araf yu niróo te ànd : géminée.
# The manual modification of the group
#  araf céex — ñaari araf yu niróo te ànd : géminée.
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa jii ag waa joojale duñu benn : Cet homme-ci — devant nous — et cet homme-là (éloigné dans le temps) ne sont pas les mêmes
# The manual modification of the group
#  waa jii ag waa joojale duñu benn : Cet homme-ci — devant nous — et cet homme-là (éloigné dans le temps) ne sont pas les mêmes
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñii dañu demul xanaa : ceux-ci ne partent peut-être pas — ne sont peut-être pas partis
# The manual modification of the group
#  ñii dañu demul xanaa : ceux-ci ne partent peut-être pas — ne sont peut-être pas partis
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# Final result:
# ['fab : prendre', 'fap : prendre']
# ['fat : ranger', 'fad : ranger']
# ['faj : soigner', 'fac : soigner']
# ['tag : se poser', 'tak : se poser']
# ['fab : prendre', 'fap : prendre']
# ['dek : épine', 'deg : épine', 'degu àll : épine de brousse']
# ["cëriñ : l'état de musulman", 'cëriñ : islam']
# ["nit dem na : quelqu'un est parti", 'nit dem na : homme est parti', 'nit dem na : un homme est parti']
# ["su dee dem : alors qu'il sera en train de partir", "su dee dem : s'il part"]
# ["su demee : s'il est parti", 'su demee : une fois là-bas', "su demee : s'il part"]
# ['su dee dem : une fois en chemin', 'su dee dem : quand il partira']
# ['kenn : un seul homme', 'kennu nit : un seul homme']
# ['ñenn : quelques-uns parmi les hommes', 'yenn : quelques-uns parmi les hommes', 'ñenn : certaines gens', 'yenn : certaines gens', 'ñenn nit : quelques-uns parmi les hommes', 'yenn nit : quelques-uns parmi les hommes', 'ñenn nit : certaines gens', 'yenn nit : certaines gens', 'ñennu nit : certaines gens', 'yennu nit : certaines gens', 'ñennu nit : quelques-uns parmi les hommes', 'yennu nit : quelques-uns parmi les hommes']
# ['araf céex : géminée', 'ñaari araf yu niróo te ànd : géminée']
# ['waa jii ag waa joojale duñu benn : Cet homme-ci et cet homme-là ne sont pas les mêmes', 'waa jii ag waa joojale duñu benn : Cet homme-ci, devant nous, et cet homme-là ne sont pas les mêmes']
# ['ñii dañu demul xanaa : ceux-ci ne partent peut-être pas', 'ñii dañu demul xanaa : ceux-ci ne sont peut-être pas partis']

# %% [markdown]
# **Regex 10** -->

# %%
result = new_sent_extraction.replace_groups(".*:.*:.*", save=True, csv_file="founded.csv", manual_replace=True)
# Out:
# Found groups matching the regular expression .*:.*:.* are the followings:
#
# - samay xarit : des amis à moi : mes amis
# - nit ku góor : être humain (lequel) (mâle) : un homme
# - nit ñu góor : être humain (lesquels) (mâles) : hommes
# - kaay : viens kaay : est une forme qui n'apparaît dans aucun autre
# - dem : na : il est parti
# - guy : la : c'est un boabab
# - kile : la : c'est celui-là
# - ci : biir : à l'intérieur
# - õgoor : dem : (mais) NGor est parti
# - nit : ki ñëw : l'homme qui est venu
# - dem na : ci biir : il est allé à l'intérieur
# - bëgg na : õga dem : il veut que tu viennes
# - dama bëgg : dem : c'est que je veux partir
# - dafa bëgg : xaalis : c'est qu'il veut de l'argent
# - dafa bañ : rewande : c'est qu'il déteste l'impolitesse
# - bëgg na : gëléem : il aime le chameau
# - gis na : ndaw : il a vu un messager
# - góor gi gisul : xale boobale woon : l'homme n'a pas vu cet enfant-là
# - négël : xale bu rafet bi : attends la belle jeune fille
# - sërin bi bëgg na : mayewoon alalam ji ba mënkoon yalwaan tay :
# - góor gi ragal na : juubuwoon : l'homme craint d'avoir interrompu son
# - ndaw si réccu na : amoon : la femme regrette d'avoir eu une fortune.
# - ragal naa : joxoon ka doom bi : je crains de lui avoir donné la clé
# - góor gi bëgg na : kii : l'homme aime celui-là
# - góor gi gis na : kookale : l'homme a vu cet autre-là
# - góor gi nee na ma : ci biti : l'homme m'a dit : dehors
# - nil : wóoy : dis : « woy » ! (crie)
# - góor gi ni : dawleen : l'homme de dire : fuyez
# - jox na : nit ki dara : il a donné à la personne quelque chose
# - aw gaynde : ci biir néeg bi : un lion dans la chambre
# - wax na : ba mi õgi : il a tant parlé que le voilà
# - laajal : ndax mi õgi fi : demande s'il est là
# - sindax bi : ci foofuu : un lézard par là
# - tay : ci õgoon : aujourd'hui dans la soirée
# - tuuti xaalis : ci yaw : un peu d'argent de toi
# - maa õgi : ci biti : me voilà à l'extérieur
# - maa õgi : ci bir kär gi : je suis dans la maison
# - kenn ki : ci kaw : celui qui est en haut
# - nit la : ci lan ? : c'est un homme pour quelles raisons ?
# - mag la : ndax iy atam : c'est un homme âgé de par ses années
# - dóor na ka : ba mi õgi : il l'a battu à telle enseigne qu'il est là
# - kookule la : ci biir : c'est celui-là à l'intérieur
# - kookule la : ci biti : c'est celui-là qui est dehors
# - demoon : ba Ndar : avoir pu aller jusqu'à Saint-Louis
# - dem naa : ba Ndar : j'ai été jusqu'à Saint-Louis
# - waa ji gor la : fi : l'homme y est magnifique
# - xale ya mbër lañu : fa woon : les gosses y furent formidables
# - mi õgi : fi : il y est
# - ma õgoogule : foofu : il est là (le voilà là)
# - demoon : fôfu : y avoir été
# - tay : danaa dem : j'irai aujourd'hui
# - góor gi : Musaa dem na : Monsieur Moussa est parti
# - gis naa góor gi : Musaa : j'ai vu Monsieur Moussa
# - wooyil Musaa : moom mi di dem : rappelle Moussa qui s'en va
# - góor gi : mi õgi : voila l'homme
# - moom : Musaa dem na : lui Moussa est parti
# - demal ça moom : góor gi : va voir l'homme lui-même
# - kii : moom dafa naqadi deret : celui-là a mauvais caractère
# - ci keneen : ki ñëw : chez l'autre qui est arrivé
# - Samba : mi ñëw ? : Samba : qui est venu ?
# - góor gi : ñëw ? : l'homme qui est venu ?
# - góor gi : xale bi woo : l'homme que l'enfant a appelé
# - ci bir : foofu di leer : à l'intérieur : où il fait clair
# - ana waa ji : muy wax ? : où est celui dont il parle ?
# - góor gi : mu àndi : l'homme qu'il a amené
# - googu góor : mu àndal : cet homme qui l'accompagne
# - kookule : õgay waxal : celui-là avec qui tu parles
# - ci foofu : õga jëm : là où tu vas
# - ci foofu : ba õgeen dellusi : là-bas jusqu'à ce que vous reveniez
# - keneen la : ku yeksi ? : c'est un autre qui est venu ?
# - yooyu la : góor gi bëgg : c'est là ceux que l'homme désire
# - yaw la : ndaw si sopp : c'est toi qui aimes la jeune femme
# - bëgg naa : góor gi ñëw : je veux que l'homme vienne
# - xale bi ne : õgeen dugg : l'enfant dit d'entrer
# - góor gi : waa ji wax : l'homme dont parle cet individu
# - ci kër gi : waa ji wax : dans la maison dont parle le Monsieur
# - góor gi : kenn xamu ko : cet homme nul ne le connaît
# - ci ki : mu wax : chez celui qu'il a indiqué
# - ba fi : mu tollu : jusqu'ici c'est bon
# - li : waa ji wax : ce que : cet homme a dit
# - ci foofu : õga taxaw : là où tu es
# - góor gi niwul : mi õgi fi : l'homme ne dit pas qu'il est là
# - góor gii la : xale yi wax : c'est de l'homme que parlent les enfants
# - Samba : õga woo : c'est Samba que tu appelles
# - soo demée : mu ñëw : si tu pars il vient
# - ci biir : õga wax : c'est à l'intérieur que tu dis
# - ci biir la : ñu jëm : nous allons à l'intérieur
# - ci biir la : góor gi dugg : c'est à l'intérieur (qu')est entré l'homme
# - ci biir : õgeen jëm : c'est à l'intérieur (que) vous allez
# - ana góor gi : mu wax : où est l'homme (dont) il parle
# - kooku la : xale yiy wax : c'est de celui-là (que) parlent les enfants
# - feneen fi la : góor gi dëkk : c'est de l'autre côté (qu')habite l'homme
# - man la : góor gi woo : c'est moi (que) l'homme appelle
# - keneen ki la : ñu xam : c'est l'autre (que) nous connaissons
# - man : õga woo : c'est moi (que) tu appelles
# - yaw la : bëgg : c'est toi (qu')elle veut
# - defe naa : mi õgiy ñëw : je crois qu'il vient
# - bëgg na : góor gi dellusi : il veut (que) l'homme revienne
# - wax naa ko : mu ñibbi : je lui ai dit de rentrer
# - góor gi nee : ñépp dem : l'homme demande à tous de partir
# - soo demee : mu ñëw : si tu pars il vient
# - demal : góor gi gis la : va que l'homme te voie
# - góor gi bëgg na : õga ñëw : l'homme veut que tu viennes
# - nit : ki ñëw la : c'est l'homme qui est venu
# - nit : ku baax : quelqu'un de bien
# - ci teen : boobu bënn : dans ce puits qui coule
# - nit : ki ñëw la : c'est l'homme qui est venu
# - góor : gu baax réer na : un homme vertueux a disparu
# - góor googule : ga nëwoon dellu na : l'homme qui vint s'en est allé
# - gis naa góor : gi ñëw : j'ai vu l'homme qui est venu
# - gis naa googii gan : gi doon wax : j'ai vu cet homme qui parlait
# - dem naa ci kër : gu yaa : j'ai été dans une maison spacieuse
# - keneen : ki ñëwulwoon kookee : cet autre qui n'était pas venu
# - feneen : fi bëttóon foofu : cet autre endroit où il y avait une fuite
# - kenn : kooku yeksi lawoon : c'est cet autre qui était venu
# - gis naa kenn : ki ñëw : j'ai vu l'autre qui est venu
# - dem na feneen : fu rafet : il a été dans un autre bel endroit
# - dem naa ci keneen : ku baax : j'ai été chez un autre qui est gentil
# - ci biir : ndax mu dugg : à l'intérieur ! pour qu'il entre
# - jambaar la : ba mu dooy : c'est un brave à n'en pas douter
# - Maa õgi fi : ba mu ñëw : je reste ici jusqu'à ce qu'il vienne
# - demal : ba ñëw : va et reviens
# - dana dem : ba õgeen beg : il ira afin que vous soyez heureux
# - ni ka : bu mu ñëw : dis-lui qu'il ne vienne pas
# - nil waa ji : na ñëw : dis à la personne qu'elle vienne
# - tay jii : góor gi dana dem : aujourd'hui l'homme partira
# - góor gi dana dem : tay ji : l'homme partira aujourd'hui
# - tay jii : bul dem : aujourd'hui ne sors pas
# - bul dem : tay jii : ne sors pas aujourd'hui
# - ci biir : soo bëggul : à l'intérieur si tu ne veux pas
# - tay : Faatim la : aujourd'hui c'est Fatim
# - Faatim la : tay : c'est Fatim aujourd'hui
# - Faatim la : mu ni : c'est Fatim dit-il
# - mu ni : Faatim la : il dit que c'est Fatim
# - ku dem : gaynde la : c'est peut-être un lion
# - yaakaar naa : góor gi la : je crois que c'est l'homme
# - defe na : du kii : je crois que ce n'est pas celui-ci
# - na dem : su bëggul : qu'il parte s'il ne veut pas
# - defe naa : du ñëw : je crois qu'il ne viendra pas
# - góor gi dem na : ma defe : l'homme est parti je crois
# - góor gi dem la : ma defe : c'est l'homme qui part je crois
# - defe naa : tày dana ñëw : je croie qu'aujourd'hui il viendra
# - defe naa : dana ñëw tày : je crois qu'il viendra aujourd'hui
# - sa yay nee : dana ñëw ci õgoon : ta mère dit qu'elle viendra ce soir
# - sa yay nee : ci õgoon dana ñëw : ta mère dit qu'elle viendra ce soir
# - góor gi nee : soo demee mi õgi fi : l'homme dit qu'il serait peut-être là
# - góor gi née : mi õgi fi soo demee : l'homme dit qu'il serait peut-être là
# - ca ñoom : noonule taxaw : vers ceux qui sont debout là-bas
# - góor gi soppul : seen lekku Saalum yooyu : l'homme n'apprécie pas votre cuisine du Saloum
# - Amet jaay na : naaru-góoru Daawuda wa woon : Ahmet a vendu le pur-sang que David possédait
# - deõk naa la : boobule woon : je te confie celui-là (dont il fut question au passé).
# - góor gi nee na la fi saõx : ci biti : l'homme t'a dit ici il y a un instant : dehors (de sortir)
# - góor gi ni : cam : l'homme fit pouah ! (l'homme émis un geste de regret)
# - ci keneen ki : ci buntu kër gi : vers cet autre qui est devant la porte de la maison
# - attekat õgeen : ci ban yoon ? : vous êtes des juges en vertu de quel droit ?
# - moom mile : ci buntu kër gi la : c'est celui-là même devant le seuil de la maison
# - ndaw la : góor gi di wut : c'est un messager que cherche l'homme
# - góor gi dem : ba mu ñëw ? : l'homme peut-il partir jusqu'à ce qu'il vienne
# - na góor gi dem : ba xale yi yeksi : l'homme doit s'en aller jusqu'à ce que les enfants reviennent
# - xale bi ne : õgeen dugg : mu gis leen : l'enfant dit d'entrer pour qu'il vous voie
# - li õga wax la : ndaw si taamu : c'est ce que tu as dit que la jeune femme préfère
# - góor gi nee : xale yi demkoon nañu fa : l'homme soutient que les enfants y eussent été
# - jox naa téere bi góor : gi ñëw : j'ai donné le livre à l'homme qui est venu
# - lépp : lu baax la góor gii bëgg : c'est tout ce qui est beau qui séduit cet homme
# - may naa ka keneen : ku ka gën : je l'ai donné à quelqu'un de meilleur que lui.
# - góor gaa õgoogule : ndax kenn bañ génn : voilà l'homme ainsi nul ne bougera
# - ñawoon la : ba bi mu fiy joge : c'était ceux-là même jusqu'à ce qu'il parte
# - foofu la : ba ba ñuy gis feneen : c'est là jusqu'au moment où nous trouverons un autre lieu
# - ci fii la : ba ba ñuy gis feneen : c'est là jusqu'à ce qu'on trouve un autre endroit
# - amal õgor : ba mën nekk nit : aie assez de sérénité pour conserver ta dignité
# - gaynde la : ku dem : c'est peut-être un lion
# - góor gi la : yaakaar naa : je crois que c'est l'homme
# - soo demee : kookule la : c'est celui-là peut-être
# - defe naa : keneen kii la : c'est l'autre je crois
# - du kii : defe naa : je crois que ce n'est pas celui-ci
# - su bëggul : na dem : qu'il parte s'il ne veut pas
# - du ñëw : defe naa : je crois qu'il ne viendra pas
# - ma defe : góor gi dem na : l'homme est parti je crois
# - ma defe : góor gii dem la : c'est l'homme qui part je crois
# - góor gee ni : mi õgi fi : soo demee : c'est l'homme qui a dit qu'il est là certainement
# - soo demee : góor gee ni mi õgi fi : certainement c'est l'homme qui a dit qu'il est là
# - góor gee ni : soo demee mi õgi fi : c'est l'homme certainement qui a dit qu'il est là
# - góor gee ni kookule la : soo demee : c'est l'homme qui a dit que c'est celui-là peut-être
# - soo demee : góor gee ni : kookule la : peut-être l'homme a-t-il dit que c'est celui-là
# - góor gee ni : kookule la : soo demee : l'homme a dit que c'est celui-là peut-être
# - sa yay nee : soo yeggee dana dellusi : ta mère promet de revenir si tu vas jusqu'au bout
# - sa yay nee : dana dellusi soo yeggee : ta mère dit qu'elle reviendra si tu vas jusqu'au bout
# - soo demee ag soo demul itam : dana ñëw : que tu partes ou que tu ne partes pas il viendra
#
# ----------------------
#
# You will modify the following group:
#  samay xarit : des amis à moi : mes amis
# The manual modification of the group
#  samay xarit : des amis à moi : mes amis
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit ku góor : être humain (lequel) (mâle) : un homme
# The manual modification of the group
#  nit ku góor : être humain (lequel) (mâle) : un homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit ñu góor : être humain (lesquels) (mâles) : hommes
# The manual modification of the group
#  nit ñu góor : être humain (lesquels) (mâles) : hommes
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kaay : viens kaay : est une forme qui n'apparaît dans aucun autre
# The manual modification of the group
#  kaay : viens kaay : est une forme qui n'apparaît dans aucun autre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dem : na : il est parti
# The manual modification of the group
#  dem : na : il est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  guy : la : c'est un boabab
# The manual modification of the group
#  guy : la : c'est un boabab
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kile : la : c'est celui-là
# The manual modification of the group
#  kile : la : c'est celui-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci : biir : à l'intérieur
# The manual modification of the group
#  ci : biir : à l'intérieur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  õgoor : dem : (mais) NGor est parti
# The manual modification of the group
#  õgoor : dem : (mais) NGor est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit : ki ñëw : l'homme qui est venu
# The manual modification of the group
#  nit : ki ñëw : l'homme qui est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dem na : ci biir : il est allé à l'intérieur
# The manual modification of the group
#  dem na : ci biir : il est allé à l'intérieur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  bëgg na : õga dem : il veut que tu viennes
# The manual modification of the group
#  bëgg na : õga dem : il veut que tu viennes
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dama bëgg : dem : c'est que je veux partir
# The manual modification of the group
#  dama bëgg : dem : c'est que je veux partir
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dafa bëgg : xaalis : c'est qu'il veut de l'argent
# The manual modification of the group
#  dafa bëgg : xaalis : c'est qu'il veut de l'argent
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dafa bañ : rewande : c'est qu'il déteste l'impolitesse
# The manual modification of the group
#  dafa bañ : rewande : c'est qu'il déteste l'impolitesse
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  bëgg na : gëléem : il aime le chameau
# The manual modification of the group
#  bëgg na : gëléem : il aime le chameau
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis na : ndaw : il a vu un messager
# The manual modification of the group
#  gis na : ndaw : il a vu un messager
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi gisul : xale boobale woon : l'homme n'a pas vu cet enfant-là
# The manual modification of the group
#  góor gi gisul : xale boobale woon : l'homme n'a pas vu cet enfant-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  négël : xale bu rafet bi : attends la belle jeune fille
# The manual modification of the group
#  négël : xale bu rafet bi : attends la belle jeune fille
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sërin bi bëgg na : mayewoon alalam ji ba mënkoon yalwaan tay :
# The manual modification of the group
#  sërin bi bëgg na : mayewoon alalam ji ba mënkoon yalwaan tay :
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi ragal na : juubuwoon : l'homme craint d'avoir interrompu son
# The manual modification of the group
#  góor gi ragal na : juubuwoon : l'homme craint d'avoir interrompu son
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ndaw si réccu na : amoon : la femme regrette d'avoir eu une fortune.
# The manual modification of the group
#  ndaw si réccu na : amoon : la femme regrette d'avoir eu une fortune.
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ragal naa : joxoon ka doom bi : je crains de lui avoir donné la clé
# The manual modification of the group
#  ragal naa : joxoon ka doom bi : je crains de lui avoir donné la clé
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi bëgg na : kii : l'homme aime celui-là
# The manual modification of the group
#  góor gi bëgg na : kii : l'homme aime celui-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi gis na : kookale : l'homme a vu cet autre-là
# The manual modification of the group
#  góor gi gis na : kookale : l'homme a vu cet autre-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi nee na ma : ci biti : l'homme m'a dit : dehors
# The manual modification of the group
#  góor gi nee na ma : ci biti : l'homme m'a dit : dehors
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nil : wóoy : dis : « woy » ! (crie)
# The manual modification of the group
#  nil : wóoy : dis : « woy » ! (crie)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi ni : dawleen : l'homme de dire : fuyez
# The manual modification of the group
#  góor gi ni : dawleen : l'homme de dire : fuyez
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jox na : nit ki dara : il a donné à la personne quelque chose
# The manual modification of the group
#  jox na : nit ki dara : il a donné à la personne quelque chose
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  aw gaynde : ci biir néeg bi : un lion dans la chambre
# The manual modification of the group
#  aw gaynde : ci biir néeg bi : un lion dans la chambre
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wax na : ba mi õgi : il a tant parlé que le voilà
# The manual modification of the group
#  wax na : ba mi õgi : il a tant parlé que le voilà
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  laajal : ndax mi õgi fi : demande s'il est là
# The manual modification of the group
#  laajal : ndax mi õgi fi : demande s'il est là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sindax bi : ci foofuu : un lézard par là
# The manual modification of the group
#  sindax bi : ci foofuu : un lézard par là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  tay : ci õgoon : aujourd'hui dans la soirée
# The manual modification of the group
#  tay : ci õgoon : aujourd'hui dans la soirée
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  tuuti xaalis : ci yaw : un peu d'argent de toi
# The manual modification of the group
#  tuuti xaalis : ci yaw : un peu d'argent de toi
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  maa õgi : ci biti : me voilà à l'extérieur
# The manual modification of the group
#  maa õgi : ci biti : me voilà à l'extérieur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  maa õgi : ci bir kär gi : je suis dans la maison
# The manual modification of the group
#  maa õgi : ci bir kär gi : je suis dans la maison
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kenn ki : ci kaw : celui qui est en haut
# The manual modification of the group
#  kenn ki : ci kaw : celui qui est en haut
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit la : ci lan ? : c'est un homme pour quelles raisons ?
# The manual modification of the group
#  nit la : ci lan ? : c'est un homme pour quelles raisons ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mag la : ndax iy atam : c'est un homme âgé de par ses années
# The manual modification of the group
#  mag la : ndax iy atam : c'est un homme âgé de par ses années
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dóor na ka : ba mi õgi : il l'a battu à telle enseigne qu'il est là
# The manual modification of the group
#  dóor na ka : ba mi õgi : il l'a battu à telle enseigne qu'il est là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kookule la : ci biir : c'est celui-là à l'intérieur
# The manual modification of the group
#  kookule la : ci biir : c'est celui-là à l'intérieur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kookule la : ci biti : c'est celui-là qui est dehors
# The manual modification of the group
#  kookule la : ci biti : c'est celui-là qui est dehors
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  demoon : ba Ndar : avoir pu aller jusqu'à Saint-Louis
# The manual modification of the group
#  demoon : ba Ndar : avoir pu aller jusqu'à Saint-Louis
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dem naa : ba Ndar : j'ai été jusqu'à Saint-Louis
# The manual modification of the group
#  dem naa : ba Ndar : j'ai été jusqu'à Saint-Louis
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa ji gor la : fi : l'homme y est magnifique
# The manual modification of the group
#  waa ji gor la : fi : l'homme y est magnifique
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xale ya mbër lañu : fa woon : les gosses y furent formidables
# The manual modification of the group
#  xale ya mbër lañu : fa woon : les gosses y furent formidables
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mi õgi : fi : il y est
# The manual modification of the group
#  mi õgi : fi : il y est
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ma õgoogule : foofu : il est là (le voilà là)
# The manual modification of the group
#  ma õgoogule : foofu : il est là (le voilà là)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  demoon : fôfu : y avoir été
# The manual modification of the group
#  demoon : fôfu : y avoir été
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  tay : danaa dem : j'irai aujourd'hui
# The manual modification of the group
#  tay : danaa dem : j'irai aujourd'hui
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi : Musaa dem na : Monsieur Moussa est parti
# The manual modification of the group
#  góor gi : Musaa dem na : Monsieur Moussa est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa góor gi : Musaa : j'ai vu Monsieur Moussa
# The manual modification of the group
#  gis naa góor gi : Musaa : j'ai vu Monsieur Moussa
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wooyil Musaa : moom mi di dem : rappelle Moussa qui s'en va
# The manual modification of the group
#  wooyil Musaa : moom mi di dem : rappelle Moussa qui s'en va
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi : mi õgi : voila l'homme
# The manual modification of the group
#  góor gi : mi õgi : voila l'homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  moom : Musaa dem na : lui Moussa est parti
# The manual modification of the group
#  moom : Musaa dem na : lui Moussa est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  demal ça moom : góor gi : va voir l'homme lui-même
# The manual modification of the group
#  demal ça moom : góor gi : va voir l'homme lui-même
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kii : moom dafa naqadi deret : celui-là a mauvais caractère
# The manual modification of the group
#  kii : moom dafa naqadi deret : celui-là a mauvais caractère
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci keneen : ki ñëw : chez l'autre qui est arrivé
# The manual modification of the group
#  ci keneen : ki ñëw : chez l'autre qui est arrivé
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Samba : mi ñëw ? : Samba : qui est venu ?
# The manual modification of the group
#  Samba : mi ñëw ? : Samba : qui est venu ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi : ñëw ? : l'homme qui est venu ?
# The manual modification of the group
#  góor gi : ñëw ? : l'homme qui est venu ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi : xale bi woo : l'homme que l'enfant a appelé
# The manual modification of the group
#  góor gi : xale bi woo : l'homme que l'enfant a appelé
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci bir : foofu di leer : à l'intérieur : où il fait clair
# The manual modification of the group
#  ci bir : foofu di leer : à l'intérieur : où il fait clair
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ana waa ji : muy wax ? : où est celui dont il parle ?
# The manual modification of the group
#  ana waa ji : muy wax ? : où est celui dont il parle ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi : mu àndi : l'homme qu'il a amené
# The manual modification of the group
#  góor gi : mu àndi : l'homme qu'il a amené
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  googu góor : mu àndal : cet homme qui l'accompagne
# The manual modification of the group
#  googu góor : mu àndal : cet homme qui l'accompagne
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kookule : õgay waxal : celui-là avec qui tu parles
# The manual modification of the group
#  kookule : õgay waxal : celui-là avec qui tu parles
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci foofu : õga jëm : là où tu vas
# The manual modification of the group
#  ci foofu : õga jëm : là où tu vas
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci foofu : ba õgeen dellusi : là-bas jusqu'à ce que vous reveniez
# The manual modification of the group
#  ci foofu : ba õgeen dellusi : là-bas jusqu'à ce que vous reveniez
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  keneen la : ku yeksi ? : c'est un autre qui est venu ?
# The manual modification of the group
#  keneen la : ku yeksi ? : c'est un autre qui est venu ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yooyu la : góor gi bëgg : c'est là ceux que l'homme désire
# The manual modification of the group
#  yooyu la : góor gi bëgg : c'est là ceux que l'homme désire
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yaw la : ndaw si sopp : c'est toi qui aimes la jeune femme
# The manual modification of the group
#  yaw la : ndaw si sopp : c'est toi qui aimes la jeune femme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  bëgg naa : góor gi ñëw : je veux que l'homme vienne
# The manual modification of the group
#  bëgg naa : góor gi ñëw : je veux que l'homme vienne
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xale bi ne : õgeen dugg : l'enfant dit d'entrer
# The manual modification of the group
#  xale bi ne : õgeen dugg : l'enfant dit d'entrer
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi : waa ji wax : l'homme dont parle cet individu
# The manual modification of the group
#  góor gi : waa ji wax : l'homme dont parle cet individu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci kër gi : waa ji wax : dans la maison dont parle le Monsieur
# The manual modification of the group
#  ci kër gi : waa ji wax : dans la maison dont parle le Monsieur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi : kenn xamu ko : cet homme nul ne le connaît
# The manual modification of the group
#  góor gi : kenn xamu ko : cet homme nul ne le connaît
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci ki : mu wax : chez celui qu'il a indiqué
# The manual modification of the group
#  ci ki : mu wax : chez celui qu'il a indiqué
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ba fi : mu tollu : jusqu'ici c'est bon
# The manual modification of the group
#  ba fi : mu tollu : jusqu'ici c'est bon
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  li : waa ji wax : ce que : cet homme a dit
# The manual modification of the group
#  li : waa ji wax : ce que : cet homme a dit
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci foofu : õga taxaw : là où tu es
# The manual modification of the group
#  ci foofu : õga taxaw : là où tu es
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi niwul : mi õgi fi : l'homme ne dit pas qu'il est là
# The manual modification of the group
#  góor gi niwul : mi õgi fi : l'homme ne dit pas qu'il est là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gii la : xale yi wax : c'est de l'homme que parlent les enfants
# The manual modification of the group
#  góor gii la : xale yi wax : c'est de l'homme que parlent les enfants
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Samba : õga woo : c'est Samba que tu appelles
# The manual modification of the group
#  Samba : õga woo : c'est Samba que tu appelles
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soo demée : mu ñëw : si tu pars il vient
# The manual modification of the group
#  soo demée : mu ñëw : si tu pars il vient
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci biir : õga wax : c'est à l'intérieur que tu dis
# The manual modification of the group
#  ci biir : õga wax : c'est à l'intérieur que tu dis
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci biir la : ñu jëm : nous allons à l'intérieur
# The manual modification of the group
#  ci biir la : ñu jëm : nous allons à l'intérieur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci biir la : góor gi dugg : c'est à l'intérieur (qu')est entré l'homme
# The manual modification of the group
#  ci biir la : góor gi dugg : c'est à l'intérieur (qu')est entré l'homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci biir : õgeen jëm : c'est à l'intérieur (que) vous allez
# The manual modification of the group
#  ci biir : õgeen jëm : c'est à l'intérieur (que) vous allez
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ana góor gi : mu wax : où est l'homme (dont) il parle
# The manual modification of the group
#  ana góor gi : mu wax : où est l'homme (dont) il parle
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kooku la : xale yiy wax : c'est de celui-là (que) parlent les enfants
# The manual modification of the group
#  kooku la : xale yiy wax : c'est de celui-là (que) parlent les enfants
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  feneen fi la : góor gi dëkk : c'est de l'autre côté (qu')habite l'homme
# The manual modification of the group
#  feneen fi la : góor gi dëkk : c'est de l'autre côté (qu')habite l'homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  man la : góor gi woo : c'est moi (que) l'homme appelle
# The manual modification of the group
#  man la : góor gi woo : c'est moi (que) l'homme appelle
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  keneen ki la : ñu xam : c'est l'autre (que) nous connaissons
# The manual modification of the group
#  keneen ki la : ñu xam : c'est l'autre (que) nous connaissons
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  man : õga woo : c'est moi (que) tu appelles
# The manual modification of the group
#  man : õga woo : c'est moi (que) tu appelles
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yaw la : bëgg : c'est toi (qu')elle veut
# The manual modification of the group
#  yaw la : bëgg : c'est toi (qu')elle veut
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  defe naa : mi õgiy ñëw : je crois qu'il vient
# The manual modification of the group
#  defe naa : mi õgiy ñëw : je crois qu'il vient
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  bëgg na : góor gi dellusi : il veut (que) l'homme revienne
# The manual modification of the group
#  bëgg na : góor gi dellusi : il veut (que) l'homme revienne
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wax naa ko : mu ñibbi : je lui ai dit de rentrer
# The manual modification of the group
#  wax naa ko : mu ñibbi : je lui ai dit de rentrer
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi nee : ñépp dem : l'homme demande à tous de partir
# The manual modification of the group
#  góor gi nee : ñépp dem : l'homme demande à tous de partir
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soo demee : mu ñëw : si tu pars il vient
# The manual modification of the group
#  soo demee : mu ñëw : si tu pars il vient
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  demal : góor gi gis la : va que l'homme te voie
# The manual modification of the group
#  demal : góor gi gis la : va que l'homme te voie
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi bëgg na : õga ñëw : l'homme veut que tu viennes
# The manual modification of the group
#  góor gi bëgg na : õga ñëw : l'homme veut que tu viennes
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit : ki ñëw la : c'est l'homme qui est venu
# The manual modification of the group
#  nit : ki ñëw la : c'est l'homme qui est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit : ku baax : quelqu'un de bien
# The manual modification of the group
#  nit : ku baax : quelqu'un de bien
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ci teen : boobu bënn : dans ce puits qui coule
# The manual modification of the group
#  ci teen : boobu bënn : dans ce puits qui coule
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit : ki ñëw la : c'est l'homme qui est venu
# The manual modification of the group
#  nit : ki ñëw la : c'est l'homme qui est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor : gu baax réer na : un homme vertueux a disparu
# The manual modification of the group
#  góor : gu baax réer na : un homme vertueux a disparu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor googule : ga nëwoon dellu na : l'homme qui vint s'en est allé
# The manual modification of the group
#  góor googule : ga nëwoon dellu na : l'homme qui vint s'en est allé
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa góor : gi ñëw : j'ai vu l'homme qui est venu
# The manual modification of the group
#  gis naa góor : gi ñëw : j'ai vu l'homme qui est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa googii gan : gi doon wax : j'ai vu cet homme qui parlait
# The manual modification of the group
#  gis naa googii gan : gi doon wax : j'ai vu cet homme qui parlait
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dem naa ci kër : gu yaa : j'ai été dans une maison spacieuse
# The manual modification of the group
#  dem naa ci kër : gu yaa : j'ai été dans une maison spacieuse
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  keneen : ki ñëwulwoon kookee : cet autre qui n'était pas venu
# The manual modification of the group
#  keneen : ki ñëwulwoon kookee : cet autre qui n'était pas venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  feneen : fi bëttóon foofu : cet autre endroit où il y avait une fuite
# The manual modification of the group
#  feneen : fi bëttóon foofu : cet autre endroit où il y avait une fuite
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kenn : kooku yeksi lawoon : c'est cet autre qui était venu
# The manual modification of the group
#  kenn : kooku yeksi lawoon : c'est cet autre qui était venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa kenn : ki ñëw : j'ai vu l'autre qui est venu
# The manual modification of the group
#  gis naa kenn : ki ñëw : j'ai vu l'autre qui est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dem na feneen : fu rafet : il a été dans un autre bel endroit
# The manual modification of the group
#  dem na feneen : fu rafet : il a été dans un autre bel endroit
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dem naa ci keneen : ku baax : j'ai été chez un autre qui est gentil
# The manual modification of the group
#  dem naa ci keneen : ku baax : j'ai été chez un autre qui est gentil
#  is done in the following file: founded.csv
# ...
#
# --------
#
# You will modify the following group:
#  du ñëw : defe naa : je crois qu'il ne viendra pas
# The manual modification of the group
#  du ñëw : defe naa : je crois qu'il ne viendra pas
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ma defe : góor gi dem na : l'homme est parti je crois
# The manual modification of the group
#  ma defe : góor gi dem na : l'homme est parti je crois
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ma defe : góor gii dem la : c'est l'homme qui part je crois
# The manual modification of the group
#  ma defe : góor gii dem la : c'est l'homme qui part je crois
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gee ni : mi õgi fi : soo demee : c'est l'homme qui a dit qu'il est là certainement
# The manual modification of the group
#  góor gee ni : mi õgi fi : soo demee : c'est l'homme qui a dit qu'il est là certainement
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soo demee : góor gee ni mi õgi fi : certainement c'est l'homme qui a dit qu'il est là
# The manual modification of the group
#  soo demee : góor gee ni mi õgi fi : certainement c'est l'homme qui a dit qu'il est là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gee ni : soo demee mi õgi fi : c'est l'homme certainement qui a dit qu'il est là
# The manual modification of the group
#  góor gee ni : soo demee mi õgi fi : c'est l'homme certainement qui a dit qu'il est là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gee ni kookule la : soo demee : c'est l'homme qui a dit que c'est celui-là peut-être
# The manual modification of the group
#  góor gee ni kookule la : soo demee : c'est l'homme qui a dit que c'est celui-là peut-être
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soo demee : góor gee ni : kookule la : peut-être l'homme a-t-il dit que c'est celui-là
# The manual modification of the group
#  soo demee : góor gee ni : kookule la : peut-être l'homme a-t-il dit que c'est celui-là
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gee ni : kookule la : soo demee : l'homme a dit que c'est celui-là peut-être
# The manual modification of the group
#  góor gee ni : kookule la : soo demee : l'homme a dit que c'est celui-là peut-être
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sa yay nee : soo yeggee dana dellusi : ta mère promet de revenir si tu vas jusqu'au bout
# The manual modification of the group
#  sa yay nee : soo yeggee dana dellusi : ta mère promet de revenir si tu vas jusqu'au bout
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sa yay nee : dana dellusi soo yeggee : ta mère dit qu'elle reviendra si tu vas jusqu'au bout
# The manual modification of the group
#  sa yay nee : dana dellusi soo yeggee : ta mère dit qu'elle reviendra si tu vas jusqu'au bout
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  soo demee ag soo demul itam : dana ñëw : que tu partes ou que tu ne partes pas il viendra
# The manual modification of the group
#  soo demee ag soo demul itam : dana ñëw : que tu partes ou que tu ne partes pas il viendra
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# Final result:
# ['samay xarit : des amis à moi', 'samay xarit : mes amis']
# ['nit ku góor : être humain', 'nit ku góor : un homme']
# ['nit ñu góor : hommes', 'nit ñu góor : êtres humains de sexe masculin']
# ['kaay : viens']
# ['dem na : il est parti']
# ["guy la : c'est un boabab"]
# ["kile la : c'est celui-là"]
# ["ci biir : à l'intérieur"]
# ['õgoor dem : NGor est parti', 'õgoor dem : mais NGor est parti']
# ["nit ki ñëw : l'homme qui est venu"]
# ["dem na ci biir : il est allé à l'intérieur"]
# ['bëgg na õga dem : il veut que tu viennes']
# ["dama bëgg dem : c'est que je veux partir"]
# ["dafa bëgg xaalis : c'est qu'il veut de l'argent"]
# ["dafa bañ rewande : c'est qu'il déteste l'impolitesse"]
# ['bëgg na gëléem : il aime le chameau']
# ['gis na ndaw : il a vu un messager']
# ["góor gi gisul xale boobale woon : l'homme n'a pas vu cet enfant-là"]
# ['négël xale bu rafet bi : attends la belle jeune fille']
# ["sërin bi bëgg na mayewoon alalam ji ba mënkoon yalwaan tay. : le maître souhaiterait avoir donné toute sa fortune pour pouvoir demander aujourd'hui l'aumône."]
# ["góor gi ragal na juubuwoon : l'homme craint d'avoir interrompu son jeûne par inadvertance."]
# ["ndaw si réccu na amoon. : la femme regrette d'avoir eu une fortune."]
# ['ragal naa joxoon ka doom bi : je crains de lui avoir donné la clé']
# ["góor gi bëgg na kii : l'homme aime celui-là"]
# ["góor gi gis na kookale : l'homme a vu cet autre-là"]
# ["góor gi nee na ma : ci biti : l'homme m'a dit : dehors"]
# ['nil : wóoy : dis : « woy » !', 'nil : wóoy ! : crie !']
# ["góor gi ni : dawleen : l'homme de dire : fuyez"]
# ['jox na nit ki dara : il a donné à la personne quelque chose']
# ['aw gaynde ci biir néeg bi : un lion dans la chambre']
# ['wax na ba mi õgi : il a tant parlé que le voilà']
# ["laajal ndax mi õgi fi : demande s'il est là"]
# ['sindax bi ci foofuu : un lézard par là']
# ["tay ci õgoon : aujourd'hui dans la soirée"]
# ["tuuti xaalis ci yaw : un peu d'argent de toi"]
# ["maa õgi ci biti : me voilà à l'extérieur"]
# ['maa õgi ci bir kär gi : je suis dans la maison']
# ['kenn ki ci kaw : celui qui est en haut']
# ["nit la ci lan ? : c'est un homme pour quelles raisons ?"]
# ["mag la ndax iy atam : c'est un homme âgé de par ses années"]
# ["dóor na ka ba mi õgi : il l'a battu à telle enseigne qu'il est là", "dóor na ka ba mi õgi : il l'a battu à tel point qu'il est là"]
# ["kookule la ci biir : c'est celui-là à l'intérieur"]
# ["kookule la ci biti : c'est celui-là qui est dehors"]
# ["demoon ba Ndar : avoir pu aller jusqu'à Saint-Louis"]
# ["dem naa ba Ndar : j'ai été jusqu'à Saint-Louis"]
# ["waa ji gor la fi : l'homme y est magnifique"]
# ['xale ya mbër lañu fa woon : les gosses y furent formidables']
# ['mi õgi fi : il y est']
# ['ma õgoogule foofu : il est là', 'ma õgoogule foofu : le voilà là']
# ['demoon fôfu : y avoir été']
# ["tay danaa dem : j'irai aujourd'hui"]
# ['góor gi Musaa dem na : Monsieur Moussa est parti']
# ["gis naa góor gi Musaa : j'ai vu Monsieur Moussa"]
# ["wooyil Musaa moom mi di dem : rappelle Moussa qui s'en va"]
# ["góor gi mi õgi : voila l'homme"]
# ['moom Musaa dem na : lui Moussa est parti']
# ["demal ça moom góor gi : va voir l'homme lui-même"]
# ['kii moom dafa naqadi deret : celui-là a mauvais caractère']
# ["ci keneen ki ñëw : chez l'autre qui est arrivé"]
# ['Samba : mi ñëw ? : Samba : qui est venu ?']
# ["góor gi ñëw ? : l'homme qui est venu ?"]
# ["góor gi xale bi woo : l'homme que l'enfant a appelé"]
# ["ci bir : foofu di leer : à l'intérieur : où il fait clair"]
# ['ana waa ji muy wax ? : où est celui dont il parle ?']
# ["góor gi mu àndi : l'homme qu'il a amené"]
# ["googu góor mu àndal : cet homme qui l'accompagne"]
# ['kookule õgay waxal : celui-là avec qui tu parles']
# ['ci foofu õga jëm : là où tu vas']
# ["ci foofu ba õgeen dellusi : là-bas jusqu'à ce que vous reveniez"]
# ["keneen la ku yeksi ? : c'est un autre qui est venu ?"]
# ["yooyu la góor gi bëgg : c'est ceux-là que l'homme désire"]
# ["yaw la ndaw si sopp : c'est toi qui aimes la jeune femme"]
# ["bëgg naa góor gi ñëw : je veux que l'homme vienne"]
# ["xale bi ne õgeen dugg : l'enfant dit d'entrer"]
# ["góor gi waa ji wax : l'homme dont parle cet individu"]
# ['ci kër gi waa ji wax : dans la maison dont parle le Monsieur']
# ['góor gi kenn xamu ko : cet homme nul ne le connaît']
# ["ci ki mu wax : chez celui qu'il a indiqué"]
# ["ba fi mu tollu : jusqu'ici c'est bon"]
# ['li waa ji wax : ce que cet homme a dit']
# ['ci foofu õga taxaw : là où tu es']
# ["góor gi niwul mi õgi fi : l'homme ne dit pas qu'il est là"]
# ["góor gii la xale yi wax : c'est de l'homme que parlent les enfants"]
# ["Samba õga woo ? : c'est Samba que tu appelles ?"]
# ['soo demée, mu ñëw : si tu pars, il vient']
# ["ci biir õga wax : c'est à l'intérieur que tu dis"]
# ["ci biir la ñu jëm : nous allons à l'intérieur"]
# ["ci biir la góor gi dugg : c'est à l'intérieur qu'est entré l'homme"]
# ["ci biir õgeen jëm : c'est à l'intérieur que vous allez"]
# ["ana góor gi mu wax ? : où est l'homme dont il parle ?"]
# ["kooku la xale yiy wax : c'est de celui-là que parlent les enfants"]
# ["feneen fi la góor gi dëkk : c'est de l'autre côté qu'habite l'homme"]
# ["man la góor gi woo : c'est moi que l'homme appelle"]
# ["keneen ki la ñu xam : c'est l'autre que nous connaissons"]
# ["man õga woo : c'est moi que tu appelles"]
# ["yaw la bëgg : c'est toi qu'elle veut"]
# ["defe naa mi õgiy ñëw : je crois qu'il vient"]
# ["bëgg na góor gi dellusi : il veut que l'homme revienne"]
# ['wax naa ko mu ñibbi : je lui ai dit de rentrer']
# ["góor gi nee ñépp dem : l'homme demande à tous de partir"]
# ['soo demee, mu ñëw : si tu pars, il vient']
# ["demal góor gi gis la : va que l'homme te voie"]
# ["góor gi bëgg na õga ñëw : l'homme veut que tu viennes"]
# ["nit ki ñëw la : c'est l'homme qui est venu"]
# ["nit ku baax : quelqu'un de bien"]
# ['ci teen boobu bënn : dans ce puits qui coule']
# ["nit ki ñëw la : c'est l'homme qui est venu"]
# ['góor gu baax réer na : un homme vertueux a disparu']
# ["góor googule ga nëwoon dellu na : l'homme qui vint s'en est allé"]
# ["gis naa góor gi ñëw : j'ai vu l'homme qui est venu"]
# ["gis naa googii gan gi doon wax : j'ai vu cet homme qui parlait", "gis naa googii gan gi doon wax : j'ai vu ce visiteur qui parlait"]
# ["dem naa ci kër gu yaa : j'ai été dans une maison spacieuse"]
# ["keneen ki ñëwulwoon kookee : cet autre qui n'était pas venu"]
# ['feneen fi bëttóon foofu : cet autre endroit où il y avait une fuite']
# ["kenn kooku yeksi lawoon : c'est cet autre qui était venu"]
# ["gis naa kenn ki ñëw : j'ai vu l'autre qui est venu"]
# ['dem na feneen fu rafet : il a été dans un autre bel endroit']
# ["dem naa ci keneen ku baax : j'ai été chez un autre qui est gentil"]
# ["ci biir ! ndax mu dugg : à l'intérieur ! pour qu'il entre"]
# ["jambaar la ba mu dooy : c'est un brave à n'en pas douter"]
# ["Maa õgi fi ba mu ñëw : je reste ici jusqu'à ce qu'il vienne"]
# ['demal ba ñëw : va et reviens']
# ['dana dem ba õgeen beg : il ira afin que vous soyez heureux']
# ["ni ka bu mu ñëw : dis-lui qu'il ne vienne pas"]
# ["nil waa ji na ñëw : dis à la personne qu'elle vienne"]
# ["tay jii góor gi dana dem : aujourd'hui l'homme partira"]
# ["góor gi dana dem tay ji : l'homme partira aujourd'hui"]
# ["tay jii bul dem : aujourd'hui ne sors pas"]
# ["bul dem tay jii : ne sors pas aujourd'hui"]
# ["ci biir soo bëggul : à l'intérieur si tu ne veux pas"]
# ["tay Faatim la : aujourd'hui c'est Fatim"]
# ["Faatim la tay : c'est Fatim aujourd'hui"]
# ["Faatim la mu ni : c'est Fatim dit-il"]
# ["mu ni Faatim la : il dit que c'est Fatim"]
# ["ku dem, gaynde la : c'est peut-être un lion"]
# ["yaakaar naa góor gi la : je crois que c'est l'homme"]
# ["defe naa du kii : je crois que ce n'est pas celui-ci"]
# ["na dem su bëggul : qu'il parte s'il ne veut pas"]
# ["defe naa du ñëw : je crois qu'il ne viendra pas"]
# ["góor gi dem na, ma defe : l'homme est parti, je crois"]
# ["góor gi dem la, ma defe : c'est l'homme qui part, je crois"]
# ["defe naa tày dana ñëw : je croie qu'aujourd'hui il viendra"]
# ["defe naa dana ñëw tày : je crois qu'il viendra aujourd'hui"]
# ["sa yay nee dana ñëw ci õgoon : ta mère dit qu'elle viendra ce soir"]
# ["sa yay nee na ci õgoon dana ñëw : ta mère dit qu'elle viendra ce soir"]
# ["góor gi nee na soo demee mi õgi fi : l'homme dit qu'il serait peut-être là"]
# ["góor gi née na mi õgi fi soo demee : l'homme dit qu'il serait peut-être là"]
# ['ca ñoom noonule taxaw : vers ceux qui sont debout là-bas']
# ["góor gi soppul seen lekku Saalum yooyu : l'homme n'apprécie pas votre cuisine du Saloum"]
# ['Amet jaay na naaru-góoru Daawuda wa woon : Ahmet a vendu le pur-sang que David possédait']
# ['deõk naa la boobule woon : je te confie celui-là.', 'deõk naa la boobule woon : je te confie celui-là dont il fut question au passé.']
# ["góor gi nee na la fi saõx : ci biti : l'homme t'a dit ici il y a un instant : dehors", "góor gi nee na la fi saõx, õga dem ci biti : l'homme t'a dit ici il y a un instant de sortir"]
# ["góor gi ni : cam : l'homme fit : pouah !"]
# ['ci keneen ki ci buntu kër gi : vers cet autre qui est devant la porte de la maison']
# ['attekat õgeen ci ban yoon ? : vous êtes des juges en vertu de quel droit ?']
# ["moom mile ci buntu kër gi la : c'est celui-là même devant le seuil de la maison"]
# ["ndaw la góor gi di wut : c'est un messager que cherche l'homme"]
# ["góor gi dem ba mu ñëw ? : l'homme peut-il partir jusqu'à ce qu'il vienne ?"]
# ["na góor gi dem ba xale yi yeksi : l'homme doit s'en aller jusqu'à ce que les enfants reviennent"]
# ["xale bi ne õgeen dugg mu gis leen : l'enfant dit d'entrer pour qu'il vous voie"]
# ["li õga wax la ndaw si taamu : c'est ce que tu as dit que la jeune femme préfère"]
# ["góor gi nee xale yi demkoon nañu fa : l'homme soutient que les enfants y eussent été"]
# ["jox naa téere bi góor gi ñëw : j'ai donné le livre à l'homme qui est venu"]
# ["lépp lu baax la góor gii bëgg : c'est tout ce qui est beau qui séduit cet homme"]
# ["may naa ka keneen ku ka gën : je l'ai donné à quelqu'un de meilleur que lui."]
# ["góor gaa õgoogule ndax kenn bañ génn : voilà l'homme ainsi nul ne bougera"]
# ["ñawoon la ba bi mu fiy joge : c'était ceux-là même jusqu'à ce qu'il parte"]
# ["foofu la ba ba ñuy gis feneen : c'est là jusqu'au moment où nous trouverons un autre lieu"]
# ["ci fii la ba ba ñuy gis feneen : c'est là jusqu'à ce qu'on trouve un autre endroit"]
# ['amal õgor ba mën nekk nit : aie assez de sérénité pour conserver ta dignité']
# ["gaynde la, ku dem : c'est peut-être un lion"]
# ["góor gi la, yaakaar naa : je crois que c'est l'homme"]
# ["soo demee, kookule la : c'est celui-là peut-être"]
# ["defe naa, keneen kii la : c'est l'autre je crois"]
# ["du kii, defe naa : je crois que ce n'est pas celui-ci"]
# ["su bëggul, na dem : qu'il parte s'il ne veut pas"]
# ["du ñëw, defe naa : je crois qu'il ne viendra pas"]
# ["ma defe góor gi dem na : l'homme est parti je crois"]
# ["ma defe góor gii dem la : c'est l'homme qui part je crois"]
# ["góor gee ni mi õgi fi soo demee : c'est l'homme qui a dit qu'il est là certainement"]
# ["soo demee góor gee ni mi õgi fi : certainement c'est l'homme qui a dit qu'il est là"]
# ["góor gee ni soo demee mi õgi fi : c'est l'homme certainement qui a dit qu'il est là"]
# ["góor gee ni kookule la, soo demee : c'est l'homme qui a dit que c'est celui-là, peut-être"]
# ["soo demee góor gee ni kookule la : peut-être l'homme a-t-il dit que c'est celui-là"]
# ["góor gee ni kookule la, soo demee : l'homme a dit que c'est celui-là, peut-être"]
# ["sa yay nee soo yeggee dana dellusi : ta mère promet de revenir si tu vas jusqu'au bout"]
# ["sa yay nee dana dellusi soo yeggee : ta mère dit qu'elle reviendra si tu vas jusqu'au bout"]
# ['soo demee ag soo demul itam, dana ñëw : que tu partes ou que tu ne partes pas, il viendra']

# %% [markdown]
# **Regex 11** -->

# %%
result = new_sent_extraction.replace_groups(".*\(.*\).*", save=True, csv_file="founded.csv", manual_replace=True)
# Out:
# Found groups matching the regular expression .*\(.*\).* are the followings:
#
# - wàtal : traîner (pour quelqu'un)
# - sap : chanter (coq)
# - an : enlever (ordures)
# - sañc : bâtir (une ville)
# - ree-aat-le : rire encore avec quelqu'un (pour lui)
# - saf : piquant (goût)
# - Ndar : Saint-Louis (ville)
# - nit bonul : (l')homme n'est pas mauvais
# - gis naa gaynde : j'ai vu (un) lion
# - nit la : c'est (un) homme
# - xoolal mbër mu : regarde ce (semblant de) lutteur
# - gis õga nit ka : tu as vu l'homme (au passé)
# - Séen naa ak nit : J'ai aperçu un homme (aw nit)
# - Xar moomu man õga wax ? : tu parles de (ce) quel mouton ?
# - Xar mii man ? : (le) quel mouton ?
# - Xar yii yan õga jënd ? : Quels moutons (ceux-là) avais-tu achetés ?
# - Xar yile yan ? : Quels (ceux-là) moutons ?
# - Ma japp nag yee yan ? : Que j'attrape quelles vaches (celles-là) ?
# - Mu japp nag yooyu yan ? : Qu'il attrappe quelles vaches (celles-là) ?
# - Boobu néeg ban õga wax ? : Tu parles de quelle maison (là) ?
# - Bii néeg ban õga wax ? : Tu parles de quelle maison (ici) ?
# - Jile jigéen jan õgeen wax ? : Vous parlez de quelle dame (ici) ?
# - Woowale fas wan õga bëgg ? : Quel cheval (au passé) veux-tu ? Yooyale
# - xarit yan ño ñëw ? : Quels amis (ceux-là) sont arrivés ?
# - nag woowa wépp : ce boeuf-là (au passé) en totalité
# - xar woowalé wépp : toute cette partie (au passé)
# - gisoon naa nit ñooña ñépp : j'ai vu tous ces gens (d'alors au passé)
# - jënd ñaa menn xar mi : j'ai acheté le mouton (l'un)
# - keneen nit kooka la wax : il parle de l'autre homme (passé)
# - gis naa sama xarit yee : j'ai vu mes amis (ceux de là-bas)
# - gis õga samay xarit yan ? : tu as vu (mes) quels amis à moi ?
# - gis na sama xarit yeneen yooyuu : j'ai vu mes autres amis (ceux-là)
# - yaral xar : élève (des) mouton(s)
# - gis õga nit ki woon : tu as vu l'homme (dont il fut question)
# - xammee õga jabaram joojuwoon : tu as reconnu sa femme (d'autrefois)
# - gis õga coroom la woon : tu te rappelles son amour (d'autrefois)
# - jigéen lanu : c'est (des) femmes
# - nit lawoon : ce fut un homme (un vrai)
# - nit õga : tu es (un) homme
# - lawbe la : c'est (un) bûcheron
# - seen lawbe ba woon la : c'est votre bûcheron (d'autrefois)
# - dil nit : sois (un) être de raison
# - ya di ban jaõgkat ? : tu es quel (genre d') étudiant ?
# - dil nitu réew mi : sois (un) homme de ce pays
# - xammee naa nagi Tugël : je reconnais (les) vaches d'Europe
# - gis naa kër xaritam : j'ai vu la maison (de) son ami
# - dëkku Séeréer bii la : c'est (la) ville de ce Sérère
# - gis naa xar mu góor ma : j'ai vu l'ovin mâle (mouton)
# - nit doõõ õga : tu es (un) homme simplement
# - maa õgii demoon : voila (que) j'ai été...
# - li mu waxoon la : c'est ce qu'il a dit (qui est vrai)
# - fu mu bëgg ? : où veut-il... (quelle partie ?)
# - waa ji demkoon na : l'individu serait parti (devait partir)
# - maa di dem : c'est moi qui pars (qui dois...)
# - góor gi di bày : (mais) l'homme cultive
# - yaa õgi demuloo : toi (que voilà) tu n'as pas été
# - loolu di guy : cela (c'est un) baobab
# - góor gi di dem : l'homme (partant) qui part
# - mu doon Lebu Yoff : il était Lebou de Yoff (c'était un Lebou)
# - wool kee dul dem : appelle celui-là qui ne part pas (ne partira pas)
# - su ñëwul dana xam : s'il ne vient pas (eh bien) il verra !
# - doo nitu jamm : tu n'es pas (un) homme de paix
# - kii dafa demkoon : celui-ci serait parti (allait partir)
# - dafa di dem : c'est lui qui part (il doit partir)
# - dama dem : c'est que j'ai été (effectivement)
# - gis na ma man mi : il m'a vu moi-même (que voilà)
# - yéen ñan la wax : il parle de vous (qui) (lesquels)
# - kookee : celle-ci (passé)
# - góor gi gisul meneen : l'homme n'en a pas vu un autre (mouton)
# - benn bi rëcc laay seet : je cherche celui (celui l'un) qui s'est échappé
# - benn boobule laa la may : c'est celui-là (celui-là l'un) que je te donne
# - seetal ma ñenn ñuu : surveille-moi ceux-là (les-uns que voilà)
# - benn ban õga gisul ? : lequel (l'un lequel) n'as-tu pas vu ?
# - fabal benn bii bépp : prends l'un (en entier)
# - waxtaan ak kenn kan ? : converser avec lequel ? (l'un lequel ?)
# - ñépp ñan õga gis ? : lesquels as-tu vus ? (tous) (tous lesquels)
# - gis naa kooku woon : j'ai vu celui-là (au passé révolu)
# - gis naa ñooñale woon : j'ai vu ceux-là (au passé révolu)
# - gis naa ki woon : j'ai vu celui en question (au passé)
# - gis naa ka woon : j'ai vu celui-là (celui dont il fut question)
# - kenn ki woon dem na : l'un (dont il fut question) est parti
# - gis na keneen ki woon : j'ai vu l'autre (dont il fut question)
# - ya di kan ? : tu es qui ? (pour qui te prends-tu ?)
# - fa : là où (envisagé au passé)
# - jëlël lépp : prends tout (la totalité)
# - waaye de : mais (avec menace)
# - nit : (un) homme
# - buur : (au) roi
# - rafet : (pour la) beauté
# - mbubb : (un) boubou
# - rafet : de (n')être pas belle
# - mu dem : (mais) il est parti
# - góor demul : (un) homme n'a été (nul n'a été)
# - deõkël lëf li kenn ki : confie la chose à l'un (d'eux)
# - àndal ak yar : sois poli (sois (avec) politesse)
# - ba õga ñëw rekk : que tu approches (comminatoire)
# - na dugg ci biir su bëggée : qu'il entre (à l'intérieur s'il veut)
# - na dugg su bëggée ci biir : s'il veut qu'il entre (à l'intérieur)
# - wànal : montrer quelque chose (à quelqu'un de la part de quelqu'un d'autre)
# - jambaar du bare wax : (un) homme de courage n'abonde pas (en) paroles
# - nit ki ci sama wet ak nit kooku mbokk la ñu : cet homme près de moi et celui là près (de toi) sont parents
# - xammee õga waa joojule : tu reconnais cette personne-là (éloignée du locuteur)
# - Séen naa ag guy : J'ai aperçu un baobab (am guy)
# - Xar yooyu yan õga moom ? : (les) quels moutons (qui) t'appartiennent ?
# - kenn nit ki ñëw na : l'un des homme (s) est venu
# - nit kenn ki ñëw na : l'un des homme (s) est venu
# - benn nit ki ñëw na : l'un des homme (s) est venu
# - yenn xar yooyuu laa wax : je parle des autres moutons (ceux-là)
# - xar yenn yooyu laa wax : je parle des autres moutons (ceux-là)
# - xar menn man õga wax ? : tu parles de quel mouton (l'un) ? >
# - menn xar man õga wax ? : tu parles de quel mouton (l'un) ?
# - gis õga jigéen ñeneen ñooñu ? : as-tu vu ces autres femmes (en question) ?
# - gis õga sa yeneen xarit yi : tu as vu les autres amis (eux)
# - gis õga sa xarit yeneen yi : tu as vu les autres amis (eux)
# - gis naa nagu Tugël : j'ai vu (une) vache d'Europe
# - gis naa nagu Tugël : j'ai vu (des) vaches d'Europe
# - gisóon õga doomu jigéen joojale jan ? : tu as vu le fils de quelle femme (celle-là) ?
# - gor gii di Lawbe Ndar : cet homme (qui) est (un) Laobe de Saint-Louis
# - wool góor gi dul Kajgaamu fii : appelle l'homme qui n'est pas (un) Kangame d'ici
# - wante woowa ma la yóot it deey bonul : mais celui que (ce boeuf) je t'ai donné n'est pas mauvais non plus
# - ñenn nit : certaines gens (quelques-uns parmi les hommes)
# - ñennu nit : certaines gens (quelques-uns parmi les hommes)
# - ñooñu ñépp woon demuñu : tous ceux-là (dont il fut question) ne sont pas partis
# - du bañ boo naõgoo ag it boo yaboo ci liggéey bi : il ne refusera pas si tu acceptes et aussi (si tu) t'engages dans le travail
# - jigéen ji bëgg na õgeen am waaye it õgeen di maye : la dame voudrait bien que vous ayez (des richesses) mais aussi que vous donniez.
# - kenn demul mbaa : (j'espère) que personne n'est parti
# - mbaa kenn demul : (j'espère) que personne n'est parti
#
# ----------------------
#
# You will modify the following group:
#  wàtal : traîner (pour quelqu'un)
# The manual modification of the group
#  wàtal : traîner (pour quelqu'un)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sap : chanter (coq)
# The manual modification of the group
#  sap : chanter (coq)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  an : enlever (ordures)
# The manual modification of the group
#  an : enlever (ordures)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  sañc : bâtir (une ville)
# The manual modification of the group
#  sañc : bâtir (une ville)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ree-aat-le : rire encore avec quelqu'un (pour lui)
# The manual modification of the group
#  ree-aat-le : rire encore avec quelqu'un (pour lui)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  saf : piquant (goût)
# The manual modification of the group
#  saf : piquant (goût)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Ndar : Saint-Louis (ville)
# The manual modification of the group
#  Ndar : Saint-Louis (ville)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit bonul : (l')homme n'est pas mauvais
# The manual modification of the group
#  nit bonul : (l')homme n'est pas mauvais
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa gaynde : j'ai vu (un) lion
# The manual modification of the group
#  gis naa gaynde : j'ai vu (un) lion
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit la : c'est (un) homme
# The manual modification of the group
#  nit la : c'est (un) homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xoolal mbër mu : regarde ce (semblant de) lutteur
# The manual modification of the group
#  xoolal mbër mu : regarde ce (semblant de) lutteur
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga nit ka : tu as vu l'homme (au passé)
# The manual modification of the group
#  gis õga nit ka : tu as vu l'homme (au passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Séen naa ak nit : J'ai aperçu un homme (aw nit)
# The manual modification of the group
#  Séen naa ak nit : J'ai aperçu un homme (aw nit)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Xar moomu man õga wax ? : tu parles de (ce) quel mouton ?
# The manual modification of the group
#  Xar moomu man õga wax ? : tu parles de (ce) quel mouton ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Xar mii man ? : (le) quel mouton ?
# The manual modification of the group
#  Xar mii man ? : (le) quel mouton ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Xar yii yan õga jënd ? : Quels moutons (ceux-là) avais-tu achetés ?
# The manual modification of the group
#  Xar yii yan õga jënd ? : Quels moutons (ceux-là) avais-tu achetés ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Xar yile yan ? : Quels (ceux-là) moutons ?
# The manual modification of the group
#  Xar yile yan ? : Quels (ceux-là) moutons ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Ma japp nag yee yan ? : Que j'attrape quelles vaches (celles-là) ?
# The manual modification of the group
#  Ma japp nag yee yan ? : Que j'attrape quelles vaches (celles-là) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Mu japp nag yooyu yan ? : Qu'il attrappe quelles vaches (celles-là) ?
# The manual modification of the group
#  Mu japp nag yooyu yan ? : Qu'il attrappe quelles vaches (celles-là) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Boobu néeg ban õga wax ? : Tu parles de quelle maison (là) ?
# The manual modification of the group
#  Boobu néeg ban õga wax ? : Tu parles de quelle maison (là) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Bii néeg ban õga wax ? : Tu parles de quelle maison (ici) ?
# The manual modification of the group
#  Bii néeg ban õga wax ? : Tu parles de quelle maison (ici) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Jile jigéen jan õgeen wax ? : Vous parlez de quelle dame (ici) ?
# The manual modification of the group
#  Jile jigéen jan õgeen wax ? : Vous parlez de quelle dame (ici) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Woowale fas wan õga bëgg ? : Quel cheval (au passé) veux-tu ? Yooyale
# The manual modification of the group
#  Woowale fas wan õga bëgg ? : Quel cheval (au passé) veux-tu ? Yooyale
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xarit yan ño ñëw ? : Quels amis (ceux-là) sont arrivés ?
# The manual modification of the group
#  xarit yan ño ñëw ? : Quels amis (ceux-là) sont arrivés ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nag woowa wépp : ce boeuf-là (au passé) en totalité
# The manual modification of the group
#  nag woowa wépp : ce boeuf-là (au passé) en totalité
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xar woowalé wépp : toute cette partie (au passé)
# The manual modification of the group
#  xar woowalé wépp : toute cette partie (au passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gisoon naa nit ñooña ñépp : j'ai vu tous ces gens (d'alors au passé)
# The manual modification of the group
#  gisoon naa nit ñooña ñépp : j'ai vu tous ces gens (d'alors au passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jënd ñaa menn xar mi : j'ai acheté le mouton (l'un)
# The manual modification of the group
#  jënd ñaa menn xar mi : j'ai acheté le mouton (l'un)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  keneen nit kooka la wax : il parle de l'autre homme (passé)
# The manual modification of the group
#  keneen nit kooka la wax : il parle de l'autre homme (passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa sama xarit yee : j'ai vu mes amis (ceux de là-bas)
# The manual modification of the group
#  gis naa sama xarit yee : j'ai vu mes amis (ceux de là-bas)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga samay xarit yan ? : tu as vu (mes) quels amis à moi ?
# The manual modification of the group
#  gis õga samay xarit yan ? : tu as vu (mes) quels amis à moi ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis na sama xarit yeneen yooyuu : j'ai vu mes autres amis (ceux-là)
# The manual modification of the group
#  gis na sama xarit yeneen yooyuu : j'ai vu mes autres amis (ceux-là)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yaral xar : élève (des) mouton(s)
# The manual modification of the group
#  yaral xar : élève (des) mouton(s)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga nit ki woon : tu as vu l'homme (dont il fut question)
# The manual modification of the group
#  gis õga nit ki woon : tu as vu l'homme (dont il fut question)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xammee õga jabaram joojuwoon : tu as reconnu sa femme (d'autrefois)
# The manual modification of the group
#  xammee õga jabaram joojuwoon : tu as reconnu sa femme (d'autrefois)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga coroom la woon : tu te rappelles son amour (d'autrefois)
# The manual modification of the group
#  gis õga coroom la woon : tu te rappelles son amour (d'autrefois)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jigéen lanu : c'est (des) femmes
# The manual modification of the group
#  jigéen lanu : c'est (des) femmes
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit lawoon : ce fut un homme (un vrai)
# The manual modification of the group
#  nit lawoon : ce fut un homme (un vrai)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit õga : tu es (un) homme
# The manual modification of the group
#  nit õga : tu es (un) homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  lawbe la : c'est (un) bûcheron
# The manual modification of the group
#  lawbe la : c'est (un) bûcheron
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  seen lawbe ba woon la : c'est votre bûcheron (d'autrefois)
# The manual modification of the group
#  seen lawbe ba woon la : c'est votre bûcheron (d'autrefois)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dil nit : sois (un) être de raison
# The manual modification of the group
#  dil nit : sois (un) être de raison
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ya di ban jaõgkat ? : tu es quel (genre d') étudiant ?
# The manual modification of the group
#  ya di ban jaõgkat ? : tu es quel (genre d') étudiant ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dil nitu réew mi : sois (un) homme de ce pays
# The manual modification of the group
#  dil nitu réew mi : sois (un) homme de ce pays
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xammee naa nagi Tugël : je reconnais (les) vaches d'Europe
# The manual modification of the group
#  xammee naa nagi Tugël : je reconnais (les) vaches d'Europe
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa kër xaritam : j'ai vu la maison (de) son ami
# The manual modification of the group
#  gis naa kër xaritam : j'ai vu la maison (de) son ami
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dëkku Séeréer bii la : c'est (la) ville de ce Sérère
# The manual modification of the group
#  dëkku Séeréer bii la : c'est (la) ville de ce Sérère
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa xar mu góor ma : j'ai vu l'ovin mâle (mouton)
# The manual modification of the group
#  gis naa xar mu góor ma : j'ai vu l'ovin mâle (mouton)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit doõõ õga : tu es (un) homme simplement
# The manual modification of the group
#  nit doõõ õga : tu es (un) homme simplement
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  maa õgii demoon : voila (que) j'ai été...
# The manual modification of the group
#  maa õgii demoon : voila (que) j'ai été...
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  li mu waxoon la : c'est ce qu'il a dit (qui est vrai)
# The manual modification of the group
#  li mu waxoon la : c'est ce qu'il a dit (qui est vrai)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fu mu bëgg ? : où veut-il... (quelle partie ?)
# The manual modification of the group
#  fu mu bëgg ? : où veut-il... (quelle partie ?)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waa ji demkoon na : l'individu serait parti (devait partir)
# The manual modification of the group
#  waa ji demkoon na : l'individu serait parti (devait partir)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  maa di dem : c'est moi qui pars (qui dois...)
# The manual modification of the group
#  maa di dem : c'est moi qui pars (qui dois...)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi di bày : (mais) l'homme cultive
# The manual modification of the group
#  góor gi di bày : (mais) l'homme cultive
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yaa õgi demuloo : toi (que voilà) tu n'as pas été
# The manual modification of the group
#  yaa õgi demuloo : toi (que voilà) tu n'as pas été
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  loolu di guy : cela (c'est un) baobab
# The manual modification of the group
#  loolu di guy : cela (c'est un) baobab
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi di dem : l'homme (partant) qui part
# The manual modification of the group
#  góor gi di dem : l'homme (partant) qui part
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mu doon Lebu Yoff : il était Lebou de Yoff (c'était un Lebou)
# The manual modification of the group
#  mu doon Lebu Yoff : il était Lebou de Yoff (c'était un Lebou)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wool kee dul dem : appelle celui-là qui ne part pas (ne partira pas)
# The manual modification of the group
#  wool kee dul dem : appelle celui-là qui ne part pas (ne partira pas)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  su ñëwul dana xam : s'il ne vient pas (eh bien) il verra !
# The manual modification of the group
#  su ñëwul dana xam : s'il ne vient pas (eh bien) il verra !
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  doo nitu jamm : tu n'es pas (un) homme de paix
# The manual modification of the group
#  doo nitu jamm : tu n'es pas (un) homme de paix
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kii dafa demkoon : celui-ci serait parti (allait partir)
# The manual modification of the group
#  kii dafa demkoon : celui-ci serait parti (allait partir)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dafa di dem : c'est lui qui part (il doit partir)
# The manual modification of the group
#  dafa di dem : c'est lui qui part (il doit partir)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  dama dem : c'est que j'ai été (effectivement)
# The manual modification of the group
#  dama dem : c'est que j'ai été (effectivement)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis na ma man mi : il m'a vu moi-même (que voilà)
# The manual modification of the group
#  gis na ma man mi : il m'a vu moi-même (que voilà)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yéen ñan la wax : il parle de vous (qui) (lesquels)
# The manual modification of the group
#  yéen ñan la wax : il parle de vous (qui) (lesquels)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kookee : celle-ci (passé)
# The manual modification of the group
#  kookee : celle-ci (passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor gi gisul meneen : l'homme n'en a pas vu un autre (mouton)
# The manual modification of the group
#  góor gi gisul meneen : l'homme n'en a pas vu un autre (mouton)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  benn bi rëcc laay seet : je cherche celui (celui l'un) qui s'est échappé
# The manual modification of the group
#  benn bi rëcc laay seet : je cherche celui (celui l'un) qui s'est échappé
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  benn boobule laa la may : c'est celui-là (celui-là l'un) que je te donne
# The manual modification of the group
#  benn boobule laa la may : c'est celui-là (celui-là l'un) que je te donne
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  seetal ma ñenn ñuu : surveille-moi ceux-là (les-uns que voilà)
# The manual modification of the group
#  seetal ma ñenn ñuu : surveille-moi ceux-là (les-uns que voilà)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  benn ban õga gisul ? : lequel (l'un lequel) n'as-tu pas vu ?
# The manual modification of the group
#  benn ban õga gisul ? : lequel (l'un lequel) n'as-tu pas vu ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fabal benn bii bépp : prends l'un (en entier)
# The manual modification of the group
#  fabal benn bii bépp : prends l'un (en entier)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waxtaan ak kenn kan ? : converser avec lequel ? (l'un lequel ?)
# The manual modification of the group
#  waxtaan ak kenn kan ? : converser avec lequel ? (l'un lequel ?)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñépp ñan õga gis ? : lesquels as-tu vus ? (tous) (tous lesquels)
# The manual modification of the group
#  ñépp ñan õga gis ? : lesquels as-tu vus ? (tous) (tous lesquels)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa kooku woon : j'ai vu celui-là (au passé révolu)
# The manual modification of the group
#  gis naa kooku woon : j'ai vu celui-là (au passé révolu)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa ñooñale woon : j'ai vu ceux-là (au passé révolu)
# The manual modification of the group
#  gis naa ñooñale woon : j'ai vu ceux-là (au passé révolu)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa ki woon : j'ai vu celui en question (au passé)
# The manual modification of the group
#  gis naa ki woon : j'ai vu celui en question (au passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa ka woon : j'ai vu celui-là (celui dont il fut question)
# The manual modification of the group
#  gis naa ka woon : j'ai vu celui-là (celui dont il fut question)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kenn ki woon dem na : l'un (dont il fut question) est parti
# The manual modification of the group
#  kenn ki woon dem na : l'un (dont il fut question) est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis na keneen ki woon : j'ai vu l'autre (dont il fut question)
# The manual modification of the group
#  gis na keneen ki woon : j'ai vu l'autre (dont il fut question)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ya di kan ? : tu es qui ? (pour qui te prends-tu ?)
# The manual modification of the group
#  ya di kan ? : tu es qui ? (pour qui te prends-tu ?)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  fa : là où (envisagé au passé)
# The manual modification of the group
#  fa : là où (envisagé au passé)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jëlël lépp : prends tout (la totalité)
# The manual modification of the group
#  jëlël lépp : prends tout (la totalité)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  waaye de : mais (avec menace)
# The manual modification of the group
#  waaye de : mais (avec menace)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit : (un) homme
# The manual modification of the group
#  nit : (un) homme
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  buur : (au) roi
# The manual modification of the group
#  buur : (au) roi
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  rafet : (pour la) beauté
# The manual modification of the group
#  rafet : (pour la) beauté
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mbubb : (un) boubou
# The manual modification of the group
#  mbubb : (un) boubou
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  rafet : de (n')être pas belle
# The manual modification of the group
#  rafet : de (n')être pas belle
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mu dem : (mais) il est parti
# The manual modification of the group
#  mu dem : (mais) il est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  góor demul : (un) homme n'a été (nul n'a été)
# The manual modification of the group
#  góor demul : (un) homme n'a été (nul n'a été)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  deõkël lëf li kenn ki : confie la chose à l'un (d'eux)
# The manual modification of the group
#  deõkël lëf li kenn ki : confie la chose à l'un (d'eux)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  àndal ak yar : sois poli (sois (avec) politesse)
# The manual modification of the group
#  àndal ak yar : sois poli (sois (avec) politesse)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ba õga ñëw rekk : que tu approches (comminatoire)
# The manual modification of the group
#  ba õga ñëw rekk : que tu approches (comminatoire)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  na dugg ci biir su bëggée : qu'il entre (à l'intérieur s'il veut)
# The manual modification of the group
#  na dugg ci biir su bëggée : qu'il entre (à l'intérieur s'il veut)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  na dugg su bëggée ci biir : s'il veut qu'il entre (à l'intérieur)
# The manual modification of the group
#  na dugg su bëggée ci biir : s'il veut qu'il entre (à l'intérieur)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wànal : montrer quelque chose (à quelqu'un de la part de quelqu'un d'autre)
# The manual modification of the group
#  wànal : montrer quelque chose (à quelqu'un de la part de quelqu'un d'autre)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jambaar du bare wax : (un) homme de courage n'abonde pas (en) paroles
# The manual modification of the group
#  jambaar du bare wax : (un) homme de courage n'abonde pas (en) paroles
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit ki ci sama wet ak nit kooku mbokk la ñu : cet homme près de moi et celui là près (de toi) sont parents
# The manual modification of the group
#  nit ki ci sama wet ak nit kooku mbokk la ñu : cet homme près de moi et celui là près (de toi) sont parents
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xammee õga waa joojule : tu reconnais cette personne-là (éloignée du locuteur)
# The manual modification of the group
#  xammee õga waa joojule : tu reconnais cette personne-là (éloignée du locuteur)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Séen naa ag guy : J'ai aperçu un baobab (am guy)
# The manual modification of the group
#  Séen naa ag guy : J'ai aperçu un baobab (am guy)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  Xar yooyu yan õga moom ? : (les) quels moutons (qui) t'appartiennent ?
# The manual modification of the group
#  Xar yooyu yan õga moom ? : (les) quels moutons (qui) t'appartiennent ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kenn nit ki ñëw na : l'un des homme (s) est venu
# The manual modification of the group
#  kenn nit ki ñëw na : l'un des homme (s) est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  nit kenn ki ñëw na : l'un des homme (s) est venu
# The manual modification of the group
#  nit kenn ki ñëw na : l'un des homme (s) est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  benn nit ki ñëw na : l'un des homme (s) est venu
# The manual modification of the group
#  benn nit ki ñëw na : l'un des homme (s) est venu
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  yenn xar yooyuu laa wax : je parle des autres moutons (ceux-là)
# The manual modification of the group
#  yenn xar yooyuu laa wax : je parle des autres moutons (ceux-là)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xar yenn yooyu laa wax : je parle des autres moutons (ceux-là)
# The manual modification of the group
#  xar yenn yooyu laa wax : je parle des autres moutons (ceux-là)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  xar menn man õga wax ? : tu parles de quel mouton (l'un) ? >
# The manual modification of the group
#  xar menn man õga wax ? : tu parles de quel mouton (l'un) ? >
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  menn xar man õga wax ? : tu parles de quel mouton (l'un) ?
# The manual modification of the group
#  menn xar man õga wax ? : tu parles de quel mouton (l'un) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga jigéen ñeneen ñooñu ? : as-tu vu ces autres femmes (en question) ?
# The manual modification of the group
#  gis õga jigéen ñeneen ñooñu ? : as-tu vu ces autres femmes (en question) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga sa yeneen xarit yi : tu as vu les autres amis (eux)
# The manual modification of the group
#  gis õga sa yeneen xarit yi : tu as vu les autres amis (eux)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis õga sa xarit yeneen yi : tu as vu les autres amis (eux)
# The manual modification of the group
#  gis õga sa xarit yeneen yi : tu as vu les autres amis (eux)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa nagu Tugël : j'ai vu (une) vache d'Europe
# The manual modification of the group
#  gis naa nagu Tugël : j'ai vu (une) vache d'Europe
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gis naa nagu Tugël : j'ai vu (des) vaches d'Europe
# The manual modification of the group
#  gis naa nagu Tugël : j'ai vu (des) vaches d'Europe
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gisóon õga doomu jigéen joojale jan ? : tu as vu le fils de quelle femme (celle-là) ?
# The manual modification of the group
#  gisóon õga doomu jigéen joojale jan ? : tu as vu le fils de quelle femme (celle-là) ?
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  gor gii di Lawbe Ndar : cet homme (qui) est (un) Laobe de Saint-Louis
# The manual modification of the group
#  gor gii di Lawbe Ndar : cet homme (qui) est (un) Laobe de Saint-Louis
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wool góor gi dul Kajgaamu fii : appelle l'homme qui n'est pas (un) Kangame d'ici
# The manual modification of the group
#  wool góor gi dul Kajgaamu fii : appelle l'homme qui n'est pas (un) Kangame d'ici
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  wante woowa ma la yóot it deey bonul : mais celui que (ce boeuf) je t'ai donné n'est pas mauvais non plus
# The manual modification of the group
#  wante woowa ma la yóot it deey bonul : mais celui que (ce boeuf) je t'ai donné n'est pas mauvais non plus
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñenn nit : certaines gens (quelques-uns parmi les hommes)
# The manual modification of the group
#  ñenn nit : certaines gens (quelques-uns parmi les hommes)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñennu nit : certaines gens (quelques-uns parmi les hommes)
# The manual modification of the group
#  ñennu nit : certaines gens (quelques-uns parmi les hommes)
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  ñooñu ñépp woon demuñu : tous ceux-là (dont il fut question) ne sont pas partis
# The manual modification of the group
#  ñooñu ñépp woon demuñu : tous ceux-là (dont il fut question) ne sont pas partis
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  du bañ boo naõgoo ag it boo yaboo ci liggéey bi : il ne refusera pas si tu acceptes et aussi (si tu) t'engages dans le travail
# The manual modification of the group
#  du bañ boo naõgoo ag it boo yaboo ci liggéey bi : il ne refusera pas si tu acceptes et aussi (si tu) t'engages dans le travail
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  jigéen ji bëgg na õgeen am waaye it õgeen di maye : la dame voudrait bien que vous ayez (des richesses) mais aussi que vous donniez.
# The manual modification of the group
#  jigéen ji bëgg na õgeen am waaye it õgeen di maye : la dame voudrait bien que vous ayez (des richesses) mais aussi que vous donniez.
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  kenn demul mbaa : (j'espère) que personne n'est parti
# The manual modification of the group
#  kenn demul mbaa : (j'espère) que personne n'est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# You will modify the following group:
#  mbaa kenn demul : (j'espère) que personne n'est parti
# The manual modification of the group
#  mbaa kenn demul : (j'espère) que personne n'est parti
#  is done in the following file: founded.csv
# !If you want to provide multiple new groups please make them in different lines
#
# --------
#
# Final result:
# ['wàtal : traîner', "wàtal : traîner pour quelqu'un"]
# ['sap : chanter (coq)']
# ['an : enlever', 'an : enlever des ordures']
# ['sañc : bâtir', 'sañc : bâtir une ville']
# ["ree-aat-le : rire encore avec quelqu'un"]
# ['saf : piquant', 'saf : goût piquant']
# ['Ndar : Saint-Louis']
# ["nit bonul : homme n'est pas mauvais", "nit bonul : l'homme n'est pas mauvais"]
# ["gis naa gaynde : j'ai vu lion", "gis naa gaynde : j'ai vu un lion"]
# ["nit la : c'est un homme"]
# ['xoolal mbër mu : regarde ce lutteur', 'xoolal mbër mu : regarde ce semblant de lutteur']
# ["gis õga nit ka : tu as vu l'homme", "gis õga nit ka : tu as vu, auparavant, l'homme"]
# ["Séen naa ak nit : J'ai aperçu un homme", "Séen naa aw nit : J'ai aperçu un homme"]
# ['Xar moomu man õga wax ? : Tu parles de quel mouton ?', 'Xar moomu man õga wax ? : Tu parles de ce mouton ?']
# ['Xar mii man ? : quel mouton ?']
# ['Xar yii yan õga jënd ? : Quels moutons avais-tu achetés ?', "Xar yii yan õga jënd ? : C'est ces moutons que tu avais achetés ?"]
# ['Xar yile yan ? : Quels moutons ?']
# ["Ma japp nag yee yan ? : Que j'attrape quelles vaches ?"]
# ["Mu japp nag yooyu yan ? : Qu'il attrappe quelles vaches ?"]
# ['Boobu néeg ban õga wax ? : Tu parles de quelle maison ?']
# ['Bii néeg ban õga wax ? : Tu parles de quelle maison ?', 'Bii néeg ban õga wax ? : Tu parles de quelle maison (ici) ?']
# ['Jile jigéen jan õgeen wax ? : Vous parlez de quelle dame ?', 'Jile jigéen jan õgeen wax ? : Vous parlez de quelle dame (ici) ?']
# ['Woowale fas wan õga bëgg ? : Quel cheval veux-tu ?', 'Yooyale fas wan õga bëgg ? : Quel cheval veux-tu ?']
# ['xarit yan ño ñëw ? : Quels amis sont arrivés ?']
# ['nag woowa wépp : ce boeuf-là, en totalité']
# ['xar woowalé wépp : toute cette partie']
# ["gisoon naa nit ñooña ñépp : j'ai vu tous ces gens", "gisoon naa nit ñooña ñépp : j'ai vu tous ces gens auparavant"]
# ["jënd ñaa menn xar mi : j'ai acheté le mouton", "jënd ñaa menn xar mi : j'ai acheté ce seul mouton", "jënd ñaa menn xar mi : j'ai acheté cette unique mouton"]
# ["keneen nit kooka la wax : il parle de l'autre homme"]
# ["gis naa sama xarit yee : j'ai vu mes amis"]
# ['gis õga samay xarit yan ? : tu as vu quels amis à moi ?', 'gis õga samay xarit yan ? : tu as vu lesquels de mes amis ?']
# ["gis na sama xarit yeneen yooyuu : j'ai vu mes autres amis"]
# ['yaral xar : élève un mouton', 'yaral xar : élève des moutons']
# ["gis õga nit ki woon : tu as vu l'homme", "gis õga nit ki woon : tu as vu l'homme dont il fut question"]
# ['xammee õga jabaram joojuwoon : tu as reconnu sa femme', "xammee õga jabaram joojuwoon : tu as reconnu sa femme d'autrefois"]
# ['gis õga coroom la woon : tu te rappelles son amour', "gis õga coroom la woon : tu te rappelles son amour d'autrefois"]
# ["jigéen lanu : c'est des femmes"]
# ['nit lawoon : ce fut un homme', 'nit lawoon : ce fut un homme, un vrai']
# ['nit õga : tu es un homme']
# ["lawbe la : c'est un bûcheron"]
# ["seen lawbe ba woon la : c'est votre bûcheron d'autrefois"]
# ['dil nit : sois un être de raison']
# ['ya di ban jaõgkat ? : tu es quel étudiant ?', "ya di ban jaõgkat ? : tu es quel genre d'étudiant ?"]
# ['dil nitu réew mi : sois homme de ce pays', 'dil nitu réew mi : sois un homme de ce pays']
# ["xammee naa nagi Tugël : je reconnais les vaches d'Europe"]
# ["gis naa kër xaritam : j'ai vu la maison de son ami"]
# ["dëkku Séeréer bii la : c'est la ville de ce Sérère"]
# ["gis naa xar mu góor ma : j'ai vu l'ovin mâle", "gis naa xar mu góor ma : j'ai vu le mouton mâle"]
# ['nit doõõ õga : tu es un homme simplement', 'nit doõõ õga : tu es uniquement un homme']
# ["maa õgii demoon : voila que j'ai été..."]
# ["li mu waxoon la : c'est ce qu'il a dit", "li mu waxoon la : c'est ce qu'il a dit qui est vrai"]
# ['fu mu bëgg : où veut-il...', 'fu mu bëgg : quelle partie veut-il...']
# ["waa ji demkoon na : l'individu serait parti", "waa ji demkoon na : l'individu devait partir"]
# ["maa di dem : c'est moi qui pars", "maa di dem : c'est moi qui dois partir"]
# ["góor gi di bày : l'homme cultive", "góor gi di bày : mais l'homme cultive"]
# ["yaa õgi demuloo : toi, tu n'as pas été", "yaa õgi demuloo : toi que voilà, tu n'as pas été"]
# ["loolu di guy : cela c'est un baobab"]
# ["góor gi di dem : l'homme qui part", "góor gi di dem : l'homme partant"]
# ['mu doon Lebu Yoff : il était Lebou de Yoff', "mu doon Lebu Yoff : c'était un Lebou"]
# ['wool kee dul dem : appelle celui-là qui ne part pas', 'wool kee dul dem : appelle celui-là qui ne partira pas']
# ["su ñëwul dana xam : s'il ne vient pas, il verra !", "su ñëwul dana xam ! : s'il ne vient pas, eh bien, il verra !"]
# ["doo nitu jamm : tu n'es pas homme de paix", "doo nitu jamm : tu n'es pas un homme de paix"]
# ['kii dafa demkoon : celui-ci serait parti', 'kii dafa demkoon : celui-ci allait partir']
# ["dafa di dem : c'est lui qui part", 'dafa di dem : il doit partir']
# ["dama dem : c'est que j'ai été", "dama dem : c'est que j'ai effectivement été"]
# ["gis na ma man mi : il m'a vu moi-même", "gis na ma man mi : il m'a vu moi-même que voilà"]
# ['yéen ñan la wax : il parle de vous', 'yéen ñan la wax : il parle de qui de vous', 'yéen ñan la wax : il parle desquels de vous', 'yéen ñan la wax : il parle desquelles de vous']
# ['kookee : celle-ci']
# ["góor gi gisul meneen : l'homme n'en a pas vu un autre"]
# ["benn bi rëcc laay seet : je cherche celui qui s'est échappé", "benn bi rëcc laay seet : je cherche celui l'un qui s'est échappé"]
# ["benn boobule laa la may : c'est celui-là que je te donne", "benn boobule laa la may : c'est celui-là celui-là l'un que je te donne"]
# ['seetal ma ñenn ñuu : surveille-moi ceux-là', 'seetal ma ñenn ñuu : surveille-moi les-uns que voilà']
# ["benn ban õga gisul ? : lequel n'as-tu pas vu ?", "benn ban õga gisul ? : l'un lequel n'as-tu pas vu ?"]
# ["fabal benn bii bépp : prends l'un", "fabal benn bii bépp : prends l'un en entier"]
# ['waxtaan ak kenn kan ? : converser avec lequel ?', "waxtaan ak kenn kan ? : converser avec l'un lequel ?"]
# ['ñépp ñan õga gis ? : lesquels as-tu vus ?', 'ñépp ñan õga gis ? : Tous lesquels as-tu vus ?']
# ["gis naa kooku woon : j'ai vu celui-là", "gis naa kooku woon : j'ai vu celui-là, auparavant"]
# ["gis naa ñooñale woon : j'ai vu ceux-là", "gis naa ñooñale woon : j'ai vu ceux-là, auparavant"]
# ["gis naa ki woon : j'ai vu celui en question", "gis naa ki woon : j'ai vu celui en question, auparavant"]
# ["gis naa ka woon : j'ai vu celui-là", "gis naa ka woon : j'ai vu celui dont il fut question"]
# ["kenn ki woon dem na : l'un est parti", "kenn ki woon dem na : l'un, dont il fut question, est parti"]
# ["gis na keneen ki woon : j'ai vu l'autre", "gis na keneen ki woon : j'ai vu l'autre, dont il fut question"]
# ['ya di kan ? : tu es qui ?', 'ya di kan ? : pour qui te prends-tu ?']
# ['fa : là où']
# ['jëlël lépp : prends tout', 'jëlël lépp : prends la totalité']
# ['waaye de : mais (avec menace)']
# ['nit : homme', 'nit : un homme']
# ['buur : roi', 'buur : au roi']
# ['rafet : beauté', 'rafet : pour la beauté']
# ['mbubb : boubou', 'mbubb : un boubou']
# ["rafet : de n'être pas belle"]
# ['mu dem : il est parti', 'mu dem : mais il est parti']
# ["góor demul : homme n'a été", "góor demul : un homme n'a été", "góor demul : nul n'a été"]
# ["deõkël lëf li kenn ki : confie la chose à l'un", "deõkël lëf li kenn ki : confie la chose à l'un d'eux", "deõkël lëf li kenn ki : confie la chose à l'un d'entre eux"]
# ['àndal ak yar : sois poli', 'àndal ak yar : sois politesse', 'àndal ak yar : sois avec politesse']
# ['ba õga ñëw rekk : que tu approches']
# ["na dugg ci biir su bëggée : qu'il entre", "na dugg ci biir su bëggée : qu'il entre à l'intérieur s'il veut"]
# ["na dugg su bëggée ci biir : s'il veut qu'il entre", "na dugg su bëggée ci biir : s'il veut qu'il entre à l'intérieur"]
# ['wànal : montrer quelque chose', "wànal : montrer quelque chose à quelqu'un de la part de quelqu'un d'autre"]
# ["jambaar du bare wax : homme de courage n'abonde pas paroles", "jambaar du bare wax : homme de courage n'abonde pas en paroles", "jambaar du bare wax : un homme de courage n'abonde pas paroles", "jambaar du bare wax : un homme de courage n'abonde pas en paroles"]
# ['nit ki ci sama wet ak nit kooku mbokk la ñu : cet homme près de moi et celui là près de toi sont parents']
# ['xammee õga waa joojule : tu reconnais cette personne-là']
# ["Séen naa ag guy : J'ai aperçu un baobab", "Séen naa am guy : J'ai aperçu un baobab"]
# ["Xar yooyu yan õga moom ? : quels moutons t'appartiennent ?", "Xar yooyu yan õga moom ? : les quels moutons qui t'appartiennent ?", "Xar yooyu yan õga moom ? : les quels moutons t'appartiennent ?", "Xar yooyu yan õga moom ? : quels moutons qui t'appartiennent ?"]
# ["kenn nit ki ñëw na : l'un des hommes est venu"]
# ["nit kenn ki ñëw na : l'un des hommes est venu"]
# ["benn nit ki ñëw na : l'un des hommes est venu"]
# ['yenn xar yooyuu laa wax : je parle des autres moutons', 'yenn xar yooyuu laa wax : je parle de ceux-là']
# ['xar yenn yooyu laa wax : je parle des autres moutons', 'xar yenn yooyu laa wax : je parle des autres ceux-là']
# ['xar menn man õga wax ? : tu parles de quel mouton ?']
# ['menn xar man õga wax ? : tu parles de quel mouton ?']
# ['gis õga jigéen ñeneen ñooñu ? : as-tu vu ces autres femmes ?', 'gis õga jigéen ñeneen ñooñu ? : as-tu vu ces autres femmes en question ?']
# ['gis õga sa yeneen xarit yi : tu as vu les autres amis']
# ['gis õga sa xarit yeneen yi : tu as vu tes autres amis']
# ["gis naa nagu Tugël : j'ai vu vache d'Europe", "gis naa nagu Tugël : j'ai vu une vache d'Europe"]
# ["gis naa nagu Tugël : j'ai vu vaches d'Europe", "gis naa nagu Tugël : j'ai vu des vaches d'Europe"]
# ['gisóon õga doomu jigéen joojale jan ? : tu as vu le fils de quelle femme ?']
# ['gor gii di Lawbe Ndar : cet homme est Laobe de Saint-Louis', 'gor gii di Lawbe Ndar : cet homme qui est Laobe de Saint-Louis', 'gor gii di Lawbe Ndar : cet homme est un Laobe de Saint-Louis', 'gor gii di Lawbe Ndar : cet homme qui est un Laobe de Saint-Louis']
# ["wool góor gi dul Kajgaamu fii : appelle l'homme qui n'est pas Kangame d'ici", "wool góor gi dul Kajgaamu fii : appelle l'homme qui n'est pas un Kangame d'ici"]
# ["wante woowa ma la yóot it deey bonul : mais celui que je t'ai donné n'est pas mauvais non plus"]
# ['ñenn nit : certaines gens', 'ñenn nit : quelques-uns parmi les hommes']
# ['ñennu nit : certaines gens', 'ñennu nit : quelques-uns parmi les hommes']
# ['ñooñu ñépp woon demuñu : tous ceux-là ne sont pas partis', 'ñooñu ñépp woon demuñu : tous ceux-là, dont il fut question, ne sont pas partis']
# ["du bañ boo naõgoo ag it boo yaboo ci liggéey bi : il ne refusera pas si tu acceptes et aussi t'engages dans le travail", "du bañ boo naõgoo ag it boo yaboo ci liggéey bi : il ne refusera pas si tu acceptes et aussi si tu t'engages dans le travail"]
# ['jigéen ji bëgg na õgeen am waaye it õgeen di maye : la dame voudrait bien que vous ayez mais aussi que vous donniez.', 'jigéen ji bëgg na õgeen am waaye it õgeen di maye : la dame voudrait bien que vous ayez des richesses mais aussi que vous donniez.']
# ["kenn demul mbaa : que personne n'est parti", "kenn demul mbaa : j'espère que personne n'est parti"]
# ["mbaa kenn demul : que personne n'est parti", "mbaa kenn demul : j'espère que personne n'est parti"]

# %% [markdown]
# #### Extract sentences

# %% [markdown]
# It is time to extract the sentences. We will recuperate the sentences considering batches to add additional modifications if necessary, like the following:
# - Add end marks.
# - Modify the first letter of groups to upper case.
# - Modify the sentences directly from a CSV file.
#
# We can save a result from a batch, stop the process, and continue another when no index is indicated. The index will automatically be saved.

# %%
new_sent_extraction.extract_sentences(group_range=(0, 1000), save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#     french                        wolof
# 0      paq      coiffure de jeune fille
# 1      baq                 terre humide
# 2     matt            bois de chauffage
# 3     patt                       borgne
# 4       up                       fermer
# 5       um             porter malchance
# 6     bokk            posséder ensemble
# 7     mokk               être pulvérisé
# 8      lam                     bracelet
# 9      lap                     se noyer
# 10    amal        trouver quelque chose
# 11    abal                       prêter
# 12    natt                      mesurer
# 13     gëm                       croire
# 14     gën                être meilleur
# 15     fac                      soigner
# 16     pac                         soin
# 17    suuf                        sable
# 18    suup                      teindre
# 19     daf                       souder
# 20     dap                    rejoindre
# 21     tef                     chevreau
# 22     def                        faire
# 23    topp                       suivre
# 24    nopp                      oreille
# 25     wàt                      traîner
# 26     wàn                      montrer
# 27   wàtal                      traîner
# 28   wàtal       traîner pour quelqu'un
# 29    nëbb                       cacher
# 30    dëbb                       piller
# 31     fad                       ranger
# 32     fan                           où
# 33    cëgg                       grappe
# 34    dëgg                     piétiner
# 35     nar                       mentir
# 36     ñar                      enduire
# 37     wàñ                       tordre
# 38     car                      branche
# 39     jar               se vendre bien
# 40     ñam                   nourriture
# 41     daj                    atteindre
# 42     daj                      toucher
# 43     dañ                    caracoler
# 44  xaajoo                  se partager
# 45     õar                        rugir
# 46     daõ                        tendu
# 47   daõal                       tendre
# 48   daõal                 rendre tendu
# 49   dañal                    caracoler
# 50     kan                          qui
# 51     gan                         hôte
# 52     kar                      guetter
# 53     dak                    serviteur
# 54     dok                       couper
# 55     doc                       pierre
# 56    gabb                      piocher
# 57    õabb         tenir à bout de bras
# 58     dag                    serviteur
# 59     xar                       mouton
# 60     dan                        tendu
# 61     dax                       beurre
# 62     lax                         fané
# 63     lak   tranche médiane de poisson
# 64     xor                      caillou
# 65     gor                  homme libre
# 66     dox                      marcher
# 67     dog                       couper
# 68    siit                       couler
# 69    siit                      suinter
# 70    tiit                   avoir peur
# 71    tiis                   inquiétude
# 72    tiit                         peur
# 73    fasu                     se nouer
# 74    fatu                    s'abriter
# 75    fatu          s'enfermer chez soi
# 76     saf                 être piquant
# 77     xaf  coudre deux bandes d'étoffe
# 78    tase                   se coincer
# 79    tafu   s'aplatir contre une paroi
# 80     nal                      presser
# 81     lal                      étendre
# 82     fal                        élire
# 83     far                        amant
# 84     lal                          lit
# 85     tal               avoir le temps
# 86     fat                       ranger
# 87    daaw               année dernière
# 88     fad                      abriter
# 89     fad                       ranger
# 90     rax                     mélanger
# 91     nax                      tromper
# 92     far                      effacer
# 93     daf               souder un trou
# 94     dad                      tailler
# 95     dad                        polir
# 96     wal                       couler
# 97  siiwal                      publier
# 98     wax                       parler
# 99     bax                     bouillir
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#     french                       wolof
# 0      daw                      courir
# 1      dab                   rejoindre
# 2      wàl                    souffler
# 3      pàl                    élection
# 4      yëf                      choses
# 5      jëf                        fait
# 6      jëf                        acte
# 7      faj                     soigner
# 8      lëf                       chose
# 9      wày                     chanter
# 10     wàl                      moudre
# 11     wañ                      tordre
# 12     yaw                         toi
# 13     ñaw                      coudre
# 14    mpar            espèce de cheval
# 15     par                       allié
# 16    sàmp                     planter
# 17     sap               chanter (coq)
# 18    mpar           variété de cheval
# 19     mar                  avoir soif
# 20     xam                      savoir
# 21   mbaal                       filet
# 22    baal                   pardonner
# 23    tëmb                     flotter
# 24     tëb                      sauter
# 25    mbay        diminutif de Babacar
# 26     may                      donner
# 27    xamb                      avarié
# 28   ntëng              sorte de puits
# 29    tëng            femelle d'animal
# 30    sant                   remercier
# 31    ndab                   récipient
# 32     dab                   rattraper
# 33     ban                        boue
# 34    bant                       baton
# 35    ndaw                      envoyé
# 36     naw                     souffle
# 37     and           sorte de fourneau
# 38      an         enlever des ordures
# 39    Ndar                 Saint-Louis
# 40     nar                        part
# 41      an                     enlever
# 42      an         enlever des ordures
# 43     and          fourneau en argile
# 44     xac                       chien
# 45    xañc                      écorce
# 46    sañc                       bâtir
# 47    sañc             bâtir une ville
# 48     car                     branche
# 49    ñcar                     branche
# 50    njël                        aube
# 51     jël                     prendre
# 52    doñj           boule de couscous
# 53     doj                      pierre
# 54    ñjaq                      canari
# 55     ñaq                       sueur
# 56     tak                    se poser
# 57    taõk                        pied
# 58    laõk                     refuser
# 59     tax                   calebasse
# 60    taõx                      puiser
# 61   saxal               faire pousser
# 62  saõxal             brisures de mil
# 63     sop                     étourdi
# 64    sopp              trouver gentil
# 65     nëb                      pourri
# 66   nëbël                     pourrir
# 67  nëbbël       cacher pour quelqu'un
# 68    gëmm             fermer les yeux
# 69    fatt                     boucher
# 70   fetal                       fusil
# 71  fettal               faire éclater
# 72    fadd                     abattre
# 73    wànn                      avaler
# 74     tac                     soigner
# 75    facc                     éclater
# 76     xaj                       chien
# 77    xajj                     séparer
# 78   xajal         faire de la place à
# 79    wàññ                     compter
# 80    takk                 s'enflammer
# 81     mag                       grand
# 82    magg                     grandir
# 83  dagguu                   pourboire
# 84     taq                   se tâcher
# 85    jeqi                      remuer
# 86     wàl                       piler
# 87    wàll                     secours
# 88    tali                       talus
# 89   talli  s'étendre de tout son long
# 90     coy            variété d'oiseau
# 91    coyy              rouge écarlate
# 92   noyyi                    respirer
# 93    sawu                     urinoir
# 94   sawwu                         Est
# 95    jaww                  atmosphère
# 96    taax                    bâtiment
# 97     fab                     prendre
# 98     fap                     prendre
# 99     fat                      ranger
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#       french                      wolof
# 0        fad                     ranger
# 1        faj                    soigner
# 2        fac                    soigner
# 3        tag                   se poser
# 4        tak                   se poser
# 5        fab                    prendre
# 6        fap                    prendre
# 7      fabal     prendre pour quelqu'un
# 8      fatal      ranger pour quelqu'un
# 9       faji              aller soigner
# 10       dek                      épine
# 11       deg                      épine
# 12  degu àll           épine de brousse
# 13       tur                        nom
# 14      tuur                     verser
# 15        ku                  quiconque
# 16       kuu                   celui-là
# 17       kuu                  que voilà
# 18       tus                       rien
# 19       tis                éclabousser
# 20      muur                  recouvrir
# 21      miir         avoir des vertiges
# 22       kuu            celui-là devant
# 23       kii                   celui-ci
# 24      boli                     gosier
# 25     bóoli                 grand plat
# 26       jog                se soulever
# 27       jig             porter bonheur
# 28      suup         teindre à l'indigo
# 29      sóop                    plonger
# 30      tóoy                        mou
# 31      tooy                     humide
# 32       wor                     trahir
# 33      woor                     jeûner
# 34       gor                      noble
# 35      goor                s'affaisser
# 36       kor                   trahison
# 37       ker                      ombre
# 38      noor               saison sèche
# 39      neer                 mal de mer
# 40       wol                      piler
# 41       fàr                    effacer
# 42      jaõg           dent mal plantée
# 43      jàõg                    étudier
# 44      xamb             attiser un feu
# 45      xàmb              lieu de culte
# 46       nit                      homme
# 47      niit                   éclairer
# 48        ki                     lequel
# 49      dikk                      venir
# 50      gisi                 aller voir
# 51      gise               se concerter
# 52      géer             homme de caste
# 53      giir                     lignée
# 54      giir                descendance
# 55       wér                 être guéri
# 56      wéer                    adosser
# 57       wét             fibre de coton
# 58       wet                       côte
# 59      weer                       lune
# 60       xer                      berge
# 61       xer                     rivage
# 62      xeer                     pierre
# 63       wer               ver de terre
# 64       fer                 s'évaporer
# 65      xaar                   attendre
# 66       war                     monter
# 67      waar                    étonner
# 68      jaar                 passer par
# 69      tàkk                  s'allumer
# 70      takk                   attacher
# 71      jaõg            dent de travers
# 72       ëgg                       vent
# 73       agg                    arriver
# 74       fër       avoir une dysenterie
# 75      faar                       côte
# 76       bër            être en vacance
# 77      bëër                     beurre
# 78      sóox                      chair
# 79      góox  absorber une forte gorgée
# 80     iñaan                    envieux
# 81       egg                    arriver
# 82        añ                   déjeuner
# 83       aay                      avare
# 84      aajo               serviabilité
# 85        ub                     fermer
# 86     obali                    bailler
# 87        om                être maigre
# 88       uuf     prendre sur ses genoux
# 89       óom                     genoux
# 90       oos                     maigre
# 91       ëpp       dépasser les limites
# 92       ëpp                   excessif
# 93     juddu                  naissance
# 94     ndimo                      tissu
# 95      lóxó                       bras
# 96       kuu                   celui-ci
# 97       kuu                  tout près
# 98     gisóo               se concerter
# 99    woddoo            se couvrir avec
#
# --------------------
#
#
# Which of the groups of batch number 4 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#        french                               wolof
# 0          ki                                 cet
# 1          ki                           que voici
# 2       téeré                            amulette
# 3        tere                           interdire
# 4        dara                                rien
# 5         ree                                rire
# 6         daa                               encre
# 7       muumë                                muet
# 8         wér                              guérir
# 9         wër                       faire le tour
# 10       wéer                             adosser
# 11       géer                homme de noble caste
# 12      gisóo                       voir ensemble
# 13     baaxal                          rendre bon
# 14     tuurul   faire une offrande à une divinité
# 15    Demagul               Il n'a pas encore été
# 16  Seeteegul          Il n'a pas encore été voir
# 17  Wuutóogul  Il ne s'est pas encore substitué à
# 18   Giséegul  Il n'a pas encore pris de contacts
# 19        taf                              coller
# 20        taf                            afficher
# 21        kër                              maison
# 22       rëbb                             chasser
# 23        bañ                             refuser
# 24       dóor                             frapper
# 25        jëf                                acte
# 26       laaf                                aile
# 27        mën                             pouvoir
# 28       ñaaw                              vilain
# 29        sëf                              change
# 30        yar                             éduquer
# 31       mpal                            élection
# 32       mbay                             culture
# 33       ndof                               folie
# 34       ñjëg                               prise
# 35       õgëm                            croyance
# 36        sas                              charge
# 37       taal                             allumer
# 38        fày                            éteindre
# 39       sàmp                             planter
# 40       lamb                               tâter
# 41       gént                               rêver
# 42       lañc                             bouchée
# 43      õgëñj                              indigo
# 44       taõg                               chaud
# 45       saõx                    il y a un moment
# 46       bopp                                tête
# 47        saq                             grenier
# 48    ww jaww                          atmosphère
# 49       gajj                           scarifier
# 50       dagg                              couper
# 51       wall                             secours
# 52       tamm            avoir pris l'habitude de
# 53       tann                               choir
# 54       wàõõ                              avarié
# 55      sabar                             tam tam
# 56     ndemin                        façon d'être
# 57     safara                                 feu
# 58    ñappati                         s'embourber
# 59     satala                           récipient
# 60     ganaar                              poulet
# 61        Idi                                 nom
# 62     Kajoor                               Cayor
# 63     kañaan                               envie
# 64      sagar                             torchon
# 65     laõaay                                exil
# 66     saxaar                         fumée train
# 67       bala                     demander pardon
# 68      xasaw                                puer
# 69      faral                 prendre partie pour
# 70      dawal                            conduire
# 71       aaye                           interdire
# 72      sempi                           déraciner
# 73   ñjambaas                              rebord
# 74     õgenté                             baptême
# 75     andaar                     unité de mesure
# 76      tañcu                          se coincer
# 77     xañjar                              cuivre
# 78      noppi                            se taire
# 79      wattu                              éviter
# 80      tëccu                           se pincer
# 81      ñakku                        être vacciné
# 82       laqu                           se cacher
# 83     libbët                         être anémié
# 84       addu                            répondre
# 85      dajji                            défoncer
# 86      jéggi                            enjamber
# 87      wàllu                            secourir
# 88     sannar                                 nom
# 89     tammal                            habituer
# 90     Daõõar                                 nom
# 91      saññi                           déboucher
# 92      iñaan                              jaloux
# 93      añaan                              jaloux
# 94       aaye                           interdire
# 95       urus                                  or
# 96     óbbëli                             bailler
# 97    ommeeku                 s'essuyer la bouche
# 98       uufu                          se blottir
# 99      oosal                       faire maigrir
#
# --------------------
#
#
# Which of the groups of batch number 5 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %%
new_sent_extraction.extract_sentences(group_range=(300, 1000), save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#        french                               wolof
# 0          ki                                 cet
# 1          ki                           que voici
# 2       téeré                            amulette
# 3        tere                           interdire
# 4        dara                                rien
# 5         ree                                rire
# 6         daa                               encre
# 7       muumë                                muet
# 8         wér                              guérir
# 9         wër                       faire le tour
# 10       wéer                             adosser
# 11       géer                homme de noble caste
# 12      gisóo                       voir ensemble
# 13     baaxal                          rendre bon
# 14     tuurul  faire une offrande à une divinité.
# 15    Demagul               Il n'a pas encore été
# 16  Seeteegul          Il n'a pas encore été voir
# 17  Wuutóogul  Il ne s'est pas encore substitué à
# 18   Giséegul  Il n'a pas encore pris de contacts
# 19        taf                              coller
# 20        taf                            afficher
# 21        kër                              maison
# 22       rëbb                             chasser
# 23        bañ                             refuser
# 24       dóor                             frapper
# 25        jëf                                acte
# 26       laaf                                aile
# 27        mën                             pouvoir
# 28       ñaaw                              vilain
# 29        sëf                              change
# 30        yar                             éduquer
# 31       mpal                            élection
# 32       mbay                             culture
# 33       ndof                               folie
# 34       ñjëg                               prise
# 35       õgëm                            croyance
# 36        sas                              charge
# 37       taal                             allumer
# 38        fày                            éteindre
# 39       sàmp                             planter
# 40       lamb                               tâter
# 41       gént                               rêver
# 42       lañc                             bouchée
# 43      õgëñj                              indigo
# 44       taõg                               chaud
# 45       saõx                    il y a un moment
# 46       bopp                                tête
# 47        saq                             grenier
# 48       jaww                          atmosphère
# 49       gajj                           scarifier
# 50       dagg                              couper
# 51       wall                             secours
# 52       tamm            avoir pris l'habitude de
# 53       tann                               choir
# 54       wàõõ                              avarié
# 55      sabar                             tam tam
# 56     ndemin                        façon d'être
# 57     safara                                 feu
# 58    ñappati                         s'embourber
# 59     satala                           récipient
# 60     ganaar                              poulet
# 61        Idi                                 nom
# 62     Kajoor                 Province du Sénégal
# 63     kañaan                               envie
# 64      sagar                             torchon
# 65     laõaay                                exil
# 66     saxaar                         fumée train
# 67       bala                     demander pardon
# 68      xasaw                                puer
# 69      faral                 prendre partie pour
# 70      dawal                            conduire
# 71       aaye                           interdire
# 72      sempi                           déraciner
# 73   ñjambaas                              rebord
# 74     õgenté                             baptême
# 75     andaar                     unité de mesure
# 76      tañcu                          se coincer
# 77     xañjar                              cuivre
# 78      noppi                            se taire
# 79      wattu                              éviter
# 80      tëccu                           se pincer
# 81      ñakku                        être vacciné
# 82       laqu                           se cacher
# 83     libbët                         être anémié
# 84       addu                            répondre
# 85      dajji                            défoncer
# 86      jéggi                            enjamber
# 87      wàllu                            secourir
# 88     sannar                                 nom
# 89     tammal                            habituer
# 90     Daõõar                                 nom
# 91      saññi                           déboucher
# 92      iñaan                              jaloux
# 93      añaan                              jaloux
# 94       aaye                           interdire
# 95       urus                                  or
# 96     óbbëli                             bailler
# 97    ommeeku                 s'essuyer la bouche
# 98       uufu                          se blottir
# 99      oosal                       faire maigrir
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#       french                        wolof
# 0        ëñu    se retrousser les manches
# 1       itte                   obligeance
# 2       ubbi                       ouvrir
# 3       atté                      séparer
# 4       atté                        juger
# 5     okkatu                   se gratter
# 6         ëñ                   retrousser
# 7        itt                      frapper
# 8        ëmb                   envelopper
# 9        app                       limite
# 10       opp                      maladie
# 11      ëndi                       amener
# 12      ndaa                       canari
# 13    testën               plante de pied
# 14   gabbkat                     piocheur
# 15      deei                 aller mourir
# 16       jiu                      semence
# 17      reei                   aller rire
# 18      deeo             mourir en groupe
# 19      deeo              mourir ensemble
# 20    deewoo              mourir ensemble
# 21       jii                  aller semer
# 22      jiyi                  aller semer
# 23     déeal                 mourir pour
# 24     deeal                 mourir pour
# 25     juutu                 se renverser
# 26      jitu                     devancer
# 27     dogoo  se brouiller définitivement
# 28     téeré                        livre
# 29     duggo              frayer ensemble
# 30   ndugóor                        fruit
# 31     dawal                 faire courir
# 32     sagar                      torchon
# 33   reeaale           rire en même temps
# 34    deaale         mourir en même temps
# 35  reewaale             feindre en riant
# 36  reewaale        rire en même temps de
# 37   sawaale      expliquer en même temps
# 38   jiyaale          semer en même temps
# 39  reeaatle   rire encore avec quelqu'un
# 40     obali                      bailler
# 41  leqaliku                   s'épanouir
# 42   fatarñi                    déboucher
# 43      gent                     déserter
# 44      saõg                    recouvrir
# 45     boppa                         tête
# 46     fatta                      boucher
# 47      samp                      planter
# 48     sampa                      planter
# 49     Fattu                 être obstrué
# 50      góor                         mâle
# 51       nag                        boeuf
# 52     sabar                      tambour
# 53    jigéen                        femme
# 54    jigéen                      femelle
# 55      xeeñ                       sentir
# 56      wàcc                   abandonner
# 57      wàcc               laisser tomber
# 58       dem                       partir
# 59    dem-na                      il part
# 60    dem-bi                    le départ
# 61     jiitu                     précéder
# 62     fital               mettre en tête
# 63     soxor                      méchant
# 64     coxor                   méchanceté
# 65     sëriñ                     musulman
# 66     cëriñ           l'état de musulman
# 67     cëriñ                        islam
# 68       guy                       baobab
# 69       buy              fruit du baobab
# 70       fas                       cheval
# 71       pas                 petit cheval
# 72       far                   être allié
# 73       par                        allié
# 74       par                     alliance
# 75     wàlaf              habitant du Lof
# 76     jolof                  pays du Lof
# 77     jolof                   pays wolof
# 78   far naa                je suis allié
# 79       par                     alliance
# 80     ajoor      habitant de l'intérieur
# 81    Kajoor                        Cayor
# 82     añaan                       jaloux
# 83    kañaan                     jalousie
# 84    aaréen                     arachide
# 85   kaaréen   petite quantité d'arachide
# 86     kaddu                       parole
# 87     kaddu                     tonnerre
# 88    andaar         instrument de mesure
# 89   kandaar           le même instrument
# 90   néeg bi                    la maison
# 91   néeg si             la petite maison
# 92      ndem            le fait de partir
# 93      ndem                       départ
# 94      bëgg                      désirer
# 95     mbëgg                        désir
# 96      géew            faire une réunion
# 97     ngéew                    assemblée
# 98      góor                        homme
# 99     ngóor                     bravoure
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#           french                            wolof
# 0        baadolo                           manant
# 1       mbaadolo                   état de manant
# 2           baax                         être bon
# 3          mbaax                            bonté
# 4            far                            allié
# 5           mpar                         alliance
# 6           nkor                         trahison
# 7           boot                porter sur le dos
# 8        bootaay  la manière de porter sur le dos
# 9           ñaaw                             laid
# 10       ñaawaay                       la laideur
# 11           saf                          piquant
# 12        safaay                        l'acidité
# 13        safaay                       le piquant
# 14          xuyy                        illuminer
# 15          lakk                           brûler
# 16           dem                            aller
# 17         demin                  manière d'aller
# 18         demin                           l'état
# 19         waxin                  façon de parler
# 20         waxin                           accent
# 21         mënin                         capacité
# 22         wecci                          changer
# 23        weccit                   petite monnaie
# 24        daggit                          morceau
# 25           des             constituer un résidu
# 26         desit                          résidus
# 27       liggéey                          travail
# 28    liggéeykat                      travailleur
# 29        waxkat                           bavard
# 30        waxkat                         locuteur
# 31          ratt                           traire
# 32       rattkat                  celui qui trait
# 33           law                        s'épandre
# 34        lawtan        toute plante proliférante
# 35           wex                             amer
# 36        wextan                             bile
# 37          sëgg                       se courber
# 38          sëgg                         attendre
# 39      sëggtéef              héritier du pouvoir
# 40      ñaawtéef                          vilenie
# 41          toog                        s'asseoir
# 42     toogukaay                            siège
# 43          lekk                           manger
# 44     lekkukaay                             plat
# 45        xamadi                          ignorer
# 46        xamadi                        ignorance
# 47        xamadi                        insolence
# 48       lekkadi  abstinence devant la nourriture
# 49       goreedi              manquer de noblesse
# 50       goreedi                        indignité
# 51           mos                           goûter
# 52         mosal                     faire goûter
# 53         mosal                        pourboire
# 54           gis                             voir
# 55        gistal                       faire voir
# 56        gistal                  exhibitionnisme
# 57          mooy                   manquer un but
# 58          mooy                           dévier
# 59        moyaal                     détournement
# 60        moyaal                         quemande
# 61       liggéey                       travailler
# 62          bokk                détenir en commun
# 63           wày                          chanter
# 64           wày                            louer
# 65        wàyaan                            louer
# 66        wàyaan                        quémander
# 67       reetaan                        se moquer
# 68       reetaan                          ricaner
# 69       reetaan                       ricanement
# 70           wax                           causer
# 71       waxtaan                           causer
# 72       waxtaan                         causerie
# 73          seet                         regarder
# 74          seet                           sonder
# 75       seetaan                        spectacle
# 76       jamaale                     concurrencer
# 77       jamaale                       concurrent
# 78       waxaale                       marchander
# 79       waxaale                      marchandage
# 80       demaale                      accompagner
# 81       demaale                        compagnon
# 82         mayle      contribuer à un cadeau fait
# 83           naw                estimer hautement
# 84         nawle                             pair
# 85         nawle                          un égal
# 86          génn                           sortir
# 87          dend                         voisiner
# 88           ànd                   aller ensemble
# 89      àndandoo                  aller en groupe
# 90      àndandoo                          cohorte
# 91          reew                      être impoli
# 92      reewande                      impolitesse
# 93      ñaawande                          laideur
# 94      toogandi                          attente
# 95           muñ                        patienter
# 96       muñandi                         patience
# 97     fattaliku                      se rappeler
# 98  fattalikondi           ne pouvoir se rappeler
# 99          xool                         regarder
#
# --------------------
#
#
# Which of the groups of batch number 4 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %%
new_sent_extraction.extract_sentences(group_range=(500, 1000), save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#           french                                      wolof
# 0        baadolo                                     manant
# 1       mbaadolo                             état de manant
# 2           baax                                   être bon
# 3          mbaax                                      bonté
# 4            far                                      allié
# 5           mpar                                   alliance
# 6           nkor                                   trahison
# 7           boot                          porter sur le dos
# 8        bootaay            la manière de porter sur le dos
# 9           ñaaw                                       laid
# 10       ñaawaay                                 la laideur
# 11           saf                                    piquant
# 12        safaay                                  l'acidité
# 13        safaay                                 le piquant
# 14          xuyy                                  illuminer
# 15          lakk                                     brûler
# 16           dem                                      aller
# 17         demin                            manière d'aller
# 18         demin                                     l'état
# 19         waxin                            façon de parler
# 20         waxin                                     accent
# 21         mënin                                   capacité
# 22         wecci                                    changer
# 23        weccit                             petite monnaie
# 24        daggit                                    morceau
# 25           des                       constituer un résidu
# 26         desit                                    résidus
# 27       liggéey                                    travail
# 28    liggéeykat                                travailleur
# 29        waxkat                                     bavard
# 30        waxkat                                   locuteur
# 31          ratt                                     traire
# 32       rattkat                            celui qui trait
# 33           law                                  s'épandre
# 34        lawtan                  toute plante proliférante
# 35           wex                                       amer
# 36        wextan                                       bile
# 37          sëgg                                 se courber
# 38          sëgg                                   attendre
# 39      sëggtéef                        héritier du pouvoir
# 40      ñaawtéef                                    vilenie
# 41          toog                                  s'asseoir
# 42     toogukaay                                      siège
# 43          lekk                                     manger
# 44     lekkukaay                                       plat
# 45        xamadi                                    ignorer
# 46        xamadi                                  ignorance
# 47        xamadi                                  insolence
# 48       lekkadi            abstinence devant la nourriture
# 49       goreedi                        manquer de noblesse
# 50       goreedi                                  indignité
# 51           mos                                     goûter
# 52         mosal                               faire goûter
# 53         mosal                                  pourboire
# 54           gis                                       voir
# 55        gistal                                 faire voir
# 56        gistal                            exhibitionnisme
# 57          mooy                             manquer un but
# 58          mooy                                     dévier
# 59        moyaal                               détournement
# 60        moyaal                                   quemande
# 61       liggéey                                 travailler
# 62          bokk                          détenir en commun
# 63           wày                                    chanter
# 64           wày                                      louer
# 65        wàyaan                                      louer
# 66        wàyaan                                  quémander
# 67       reetaan                                  se moquer
# 68       reetaan                                    ricaner
# 69       reetaan                                 ricanement
# 70           wax                                     causer
# 71       waxtaan                                     causer
# 72       waxtaan                                   causerie
# 73          seet                                   regarder
# 74          seet                                     sonder
# 75       seetaan                                  spectacle
# 76       jamaale                               concurrencer
# 77       jamaale                                 concurrent
# 78       waxaale                                 marchander
# 79       waxaale                                marchandage
# 80       demaale                                accompagner
# 81       demaale                                  compagnon
# 82         mayle  contribuer à un cadeau fait par quelqu'un
# 83           naw                          estimer hautement
# 84         nawle                                       pair
# 85         nawle                                    un égal
# 86          génn                                     sortir
# 87          dend                                   voisiner
# 88           ànd                             aller ensemble
# 89      àndandoo                            aller en groupe
# 90      àndandoo                                    cohorte
# 91          reew                                être impoli
# 92      reewande                                impolitesse
# 93      ñaawande                                    laideur
# 94      toogandi                                    attente
# 95           muñ                                  patienter
# 96       muñandi                                   patience
# 97     fattaliku                                se rappeler
# 98  fattalikondi                     ne pouvoir se rappeler
# 99          xool                                   regarder
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#       french                       wolof
# 0   xoolante                 se regarder
# 1       bëgg                       aimer
# 2   bëggante                     s'aimer
# 3   bëggante                       amour
# 4       nuyu                      saluer
# 5    nuyonte                   se saluer
# 6      duggu       s'imposer à quelqu'un
# 7   duggonte                     se lier
# 8   duggonte               s'acquoquiner
# 9   lekkantu    faire semblant de manger
# 10      gaaw                      rapide
# 11  gëmmentu               avoir sommeil
# 12        fo                       jouer
# 13        fo                         jeu
# 14     fontu                       jouer
# 15     fontu          manquer de sérieux
# 16  fattarñi                   déboucher
# 17       fot           avaler de travers
# 18  fottarñi                    arracher
# 19    daggat                    découper
# 20    daggat                     morceau
# 21      xott                     morceau
# 22    xottat                 déchiqueter
# 23    xottat                     morceau
# 24    maggat                       vieux
# 25    maggat                  vieillesse
# 26    maggat                    vieillir
# 27      macc                       sucer
# 28   maccaat                     suçoter
# 29      segg                     filtrer
# 30   seggaat     filtrer une fois encore
# 31       nob                       aimer
# 32      sopp                     estimer
# 33  soppaate                     estimer
# 34      ñaan                    demander
# 35      jéex        fouiller dans le sol
# 36  maccaatu                      lécher
# 37      demi                devoir aller
# 38      waxi                  aller dire
# 39    adduji  devoir répondre à l'avenir
# 40     defar                    arranger
# 41      gaññ        se crisper le visage
# 42    gaññar        crispation du visage
# 43     lekke                 manger avec
# 44       jóg                  se dresser
# 45      jógé                    venir de
# 46      jógé        se redresser grâce à
# 47      gisé                        voir
# 48      gisé                    entrevue
# 49     soppe                         ami
# 50     soppe          estimer à cause de
# 51    bañeel                      ennemi
# 52      suuf                         sol
# 53      suuf                      le bas
# 54   suuféel                   rabaisser
# 55      ñaar                        deux
# 56      déey                     confier
# 57    déeyóo                se concerter
# 58    déeyóo                  confidence
# 59     wàñoo                 se disputer
# 60     wàñoo                 déchirement
# 61     dogoo                     rupture
# 62     toogu                       siège
# 63     seetu                    se mirer
# 64     seetu                      miroir
# 65       lem                       plier
# 66      lemu                    se plier
# 67     waxtu                   se parler
# 68     jabar            jouer les devins
# 69   jabartu               charlatanisme
# 70     wàññi                   retourner
# 71     dindi                     enlever
# 72  dindéeku                 se détacher
# 73  dindéeku                      lâcher
# 74   dindiku                 se détacher
# 75   waññiku                se retourner
# 76       nit                       homme
# 77       nit                 être humain
# 78    as nit             un bout d'homme
# 79       war                      mouton
# 80    as xar             un petit mouton
# 81   as gane             un petit poulet
# 82     géwél                       griot
# 83  as géwél              un petit griot
# 84       jur            donner naissance
# 85   waa jur                     parents
# 86    waajur                     parents
# 87      réew                        pays
# 88    waaréw                   nationaux
# 89  waa réew                   nationaux
# 90      joor                arrière-pays
# 91       kaw                        haut
# 92       Lof           région du Sénégal
# 93   waa Lof             habitant du Lof
# 94     wàlaf             habitant du Lof
# 95      Ndar                 Saint-Louis
# 96  waa Ndar              Saint-Louisien
# 97   waandar              Saint-Louisien
# 98       Raw          village sénégalais
# 99   waa Raw             habitant de Rao
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %%
new_sent_extraction.extract_sentences(group_range=(600, 1000), save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#       french                       wolof
# 0   xoolante                 se regarder
# 1       bëgg                       aimer
# 2   bëggante                     s'aimer
# 3   bëggante                       amour
# 4       nuyu                      saluer
# 5    nuyonte                   se saluer
# 6      duggu       s'imposer à quelqu'un
# 7   duggonte                     se lier
# 8   duggonte               s'acquoquiner
# 9   lekkantu    faire semblant de manger
# 10      gaaw                      rapide
# 11  gëmmentu               avoir sommeil
# 12        fo                       jouer
# 13        fo                         jeu
# 14        po                         jeu
# 15     fontu                       jouer
# 16     fontu          manquer de sérieux
# 17  fattarñi                   déboucher
# 18       fot           avaler de travers
# 19  fottarñi                    arracher
# 20    daggat                    découper
# 21    daggat                     morceau
# 22      xott                     morceau
# 23    xottat                 déchiqueter
# 24    xottat                     morceau
# 25    maggat                       vieux
# 26    maggat                  vieillesse
# 27    maggat                    vieillir
# 28      macc                       sucer
# 29   maccaat                     suçoter
# 30      segg                     filtrer
# 31   seggaat     filtrer une fois encore
# 32       nob                       aimer
# 33      sopp                     estimer
# 34  soppaate                     estimer
# 35      ñaan                    demander
# 36      jéex        fouiller dans le sol
# 37  maccaatu                      lécher
# 38      demi                devoir aller
# 39      waxi                  aller dire
# 40    adduji  devoir répondre à l'avenir
# 41     defar                    arranger
# 42      gaññ        se crisper le visage
# 43    gaññar        crispation du visage
# 44     lekke                 manger avec
# 45       jóg                  se dresser
# 46      jógé                    venir de
# 47      jógé        se redresser grâce à
# 48      gisé                        voir
# 49      gisé                    entrevue
# 50     soppe                         ami
# 51     soppe          estimer à cause de
# 52    bañeel                      ennemi
# 53      suuf                         sol
# 54      suuf                      le bas
# 55   suuféel                   rabaisser
# 56      ñaar                        deux
# 57      déey                     confier
# 58    déeyóo                se concerter
# 59    déeyóo                  confidence
# 60     wàñoo                 se disputer
# 61     wàñoo                 déchirement
# 62     dogoo                     rupture
# 63     toogu                       siège
# 64     seetu                    se mirer
# 65     seetu                      miroir
# 66       lem                       plier
# 67      lemu                    se plier
# 68     waxtu                   se parler
# 69     jabar            jouer les devins
# 70   jabartu               charlatanisme
# 71     wàññi                   retourner
# 72     dindi                     enlever
# 73  dindéeku                 se détacher
# 74  dindéeku                      lâcher
# 75   dindiku                 se détacher
# 76   waññiku                se retourner
# 77       nit                       homme
# 78       nit                 être humain
# 79    as nit             un bout d'homme
# 80       war                      mouton
# 81    as xar             un petit mouton
# 82   as gane             un petit poulet
# 83     géwél                       griot
# 84  as géwél              un petit griot
# 85       jur            donner naissance
# 86   waa jur                     parents
# 87    waajur                     parents
# 88      réew                        pays
# 89    waaréw                   nationaux
# 90  waa réew                   nationaux
# 91      joor                arrière-pays
# 92       kaw                        haut
# 93       Lof           région du Sénégal
# 94   waa Lof             habitant du Lof
# 95     wàlaf             habitant du Lof
# 96      Ndar                 Saint-Louis
# 97  waa Ndar              Saint-Louisien
# 98   waandar              Saint-Louisien
# 99       Raw          village sénégalais
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#            french                         wolof
# 0          waaraw               habitant de Rao
# 1          ngawar                    équitation
# 2            daay                         brûlé
# 3            daay               endroit déserté
# 4         gaddaay                       émigrer
# 5         gaddaay                    émigration
# 6             sax                         verre
# 7             sax                        pousse
# 8           gasax                  ver de terre
# 9            neex                 être agréable
# 10        banneex                       plaisir
# 11            rus                   avoir honte
# 12          rucci                       honorer
# 13          rucci           relever d'une honte
# 14           yeew                      attacher
# 15          yewwi                      détacher
# 16            wex                          salé
# 17           weqi                      dessaler
# 18          weddi                          nier
# 19           neex                      agréable
# 20         naqadi                   désagréable
# 21          taggi                      dénicher
# 22            sop                     turbulent
# 23          copte                    turbulence
# 24          coppe                           ami
# 25           yéem                       étonner
# 26       kéemtaan                     merveille
# 27        ceetaan                     spectacle
# 28            saf                    être acide
# 29          cafka                       acidité
# 30          ceetu           le fait de se mirer
# 31          ceetu    se regarder dans le miroir
# 32         kubéer                     couvercle
# 33            odd                     recouvrir
# 34         kodday         manière de s'habiller
# 35            and                vase en argile
# 36         kandar       vase qui sert à mesurer
# 37             om                        maigre
# 38          komre                      maigreur
# 39           samp                       planter
# 40           cemp    variété d'herbe aromatique
# 41         cempit              portion extraite
# 42            def                         faire
# 43            jëf                          acte
# 44         jëfkat                homme d'action
# 45           boot             porter sur le dos
# 46        bootaay  manière de porter sur le dos
# 47       mbootaay                   association
# 48            dog                        couper
# 49          dogal                     pourboire
# 50         ndogal                        destin
# 51            jam                        piquer
# 52            jam             emporter un enjeu
# 53        jamaale                    concurrent
# 54       njamaale                   concurrence
# 55            dog                       arrêter
# 56      aji dogal                          juge
# 57      aji dogal              qui peut décider
# 58            def                         faire
# 59          defar                      arranger
# 60      aji-defar            esprit constructif
# 61            def                         faire
# 62          defar                      arranger
# 63       defarkat                         agent
# 64       defarkat                  constructeur
# 65           sopp                       estimer
# 66         soppal  estimer à cause de quelqu'un
# 67     soppalante       s'épauler dans l'estime
# 68          soppi                       changer
# 69       coppeeku                    changement
# 70       coppalin            manière de changer
# 71   coppeekuwaay            manière de changer
# 72            wax                          dire
# 73          weddi                          nier
# 74       weddikat                       qui nie
# 75           neex                      agréable
# 76         naqadi                   désagréable
# 77        naqadil                        rendre
# 78            dog                        couper
# 79      dogalante    se faire de petits cadeaux
# 80     ndogalante           concession mutuelle
# 81          jiitu                      précéder
# 82         jiital                mettre en tête
# 83     jiitëlante             se mettre en rang
# 84     jiitalante                         série
# 85     jiitalante                    succession
# 86            wax                        parler
# 87        waxaale                    marchander
# 88      waxaalelu              faire marchander
# 89    waxalelukat           qui fait marchander
# 90           jéem                       essayer
# 91        jëmentu                     s'exercer
# 92  jëmentalukaay               terrain d'essai
# 93          jiitu                  être en tête
# 94         jiital                mettre en tête
# 95          wuutu                 se substituer
# 96         wuutal                    substituer
# 97         xéewal                 bonne fortune
# 98         xéewlu          bénéficier d'un sort
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                          french                                    wolof
# 0                           xew                                événement
# 1                       jam-jam                                   piqûre
# 2                           xar                                   percer
# 3                       xar-xar                                    fente
# 4                     bëgg-bëgg                                    désir
# 5                     tooy-tooy                                 humidité
# 6                       xew-xew                                événement
# 7                         waalo                            nom de région
# 8                   waalo-waalo                        habitant du Oualo
# 9                       sax-sax                         chef de province
# 10                      sax-sax                             jeune pousse
# 11                         ñuul                                     noir
# 12                         biir                                   ventre
# 13                     ñuulbiir                                  méchant
# 14                     ñuulbiir                               méchanceté
# 15                         jaam                                  esclave
# 16                         buur                                      roi
# 17                      jaambur                              homme libre
# 18                          wër                            faire le tour
# 19                          sëg                                cimetière
# 20                       wërsëg                                   chance
# 21                      jambuur                              homme libre
# 22              jambuur-jambuur  habitant de la région des hommes libres
# 23                       kërbët                            pas de cheval
# 24                kërbët kërbët                          galop de cheval
# 25                jigéenu wérul           femme qui ne se porte pas bien
# 26                jigéenu wérul                           femme enceinte
# 27                     waru gar                   prestation obligatoire
# 28                     waru gar                                      dot
# 29                   naaru góor                 littéralement maure mâle
# 30                   naaru góor                    cheval pur sang arabe
# 31                  ñaari goroõ                             deux rythmes
# 32                  ñaari goroõ                         figures de danse
# 33                 moom-sa-réew                             indépendance
# 34                 moom-sa-réew        rentrer en possession de son pays
# 35                      na jaay                              qu'il vende
# 36                      na jaay                                    oncle
# 37                   jarabibaat               femme qui épouse son oncle
# 38                   jarabibaat               femme qui épouse son oncle
# 39                          bax                                      bon
# 40                    baxbax-lu             faire semblant d'être gentil
# 41                         góor                                     mâle
# 42                  góorgóor-lu                     se conduire en homme
# 43                          wër                            faire le tour
# 44                      wër-wër                              va et vient
# 45                   wër wër lu               aller à droite et à gauche
# 46                          xam                                   savoir
# 47                      xam-xam                                  science
# 48                   xam xam lu                          jouer au savant
# 49                          xar                                   fendre
# 50                      xar-xar                                    fente
# 51                   xar xar le                         simuler l'agonie
# 52                      daõ-daõ                              trépidation
# 53                      daõ daõ                                trépigner
# 54                   daõ daõ lu                                trépigner
# 55                      raõ-raõ                                   fracas
# 56                   raõ raõ lu                         faire du vacarme
# 57                      jaambur                              homme libre
# 58              jaambur-jaambur                     habitant du Diambour
# 59            jaambur jaamburlu                            jouer au sage
# 60                      xar xar                                    fente
# 61                     xarxarle                                 agoniser
# 62                  xarxarlekat                      qui simule l'agonie
# 63                      wër sëg                                   chance
# 64                    wërsëglóo              bénéficier de quelque chose
# 65                      daõ daõ                              trépidation
# 66                   daõdaõluji             aller s'exciter quelque part
# 67                     bëkknéeg                                courtisan
# 68                    bëkknéegu                 se conduire en courtisan
# 69                      warugar                                      dot
# 70                   warugarloo          considérer comme une obligation
# 71                  ñaari goroõ                          figure de danse
# 72                 ñaari goroõi                    aller danser le naari
# 73                    Nit bonul                  Homme n'est pas mauvais
# 74                    Nit bonul                L'homme n'est pas mauvais
# 75                   Nit dem na                      Quelqu'un est parti
# 76                   Nit dem na                          Homme est parti
# 77                   Nit dem na                       Un homme est parti
# 78               Gis naa gaynde                             J'ai vu lion
# 79               Gis naa gaynde                          J'ai vu un lion
# 80                       Nit la                           C'est un homme
# 81          Nit kii ci sama wet                    Cet homme près de moi
# 82         Nit kookuu ci sa wet                 Cet homme là près de toi
# 83             Gis õga nit kale                 Tu vois cet homme là-bas
# 84          Gis õga nit kookale                       Tu sais, cet homme
# 85          Gis õga nit kookale                       Tu sais, cet homme
# 86              Gis õga nit kee                     Tu vois cet homme là
# 87           Gis õga nit kookee                    Tu sais, cet homme là
# 88           Gis õga nit kookee                    Tu vois, cet homme là
# 89               Gis naa nit ki                          J'ai vu l'homme
# 90            Gis naa jigéen ju                         J'ai vu la femme
# 91               Xoolal mbër mu                       Regarde ce lutteur
# 92               Xoolal mbër mu           Regarde ce semblant de lutteur
# 93              Seetal sarax su                     Regarde cette aumône
# 94               Gis õga nit ka                         Tu as vu l'homme
# 95               Gis õga nit ka            Tu as vu, auparavant, l'homme
# 96           Xamoon õga jaõx ba            Tu connaissais la jeune fille
# 97         Xammee õga waa jooju             Tu reconnais cet individu-là
# 98  Xammeewoon õga jigéen jooju                Tu avais reconnu la femme
# 99              Nit kii jaõg na                       Cet homme a étudié
#
# Batch result
#                            french                                    wolof
# 0                             xew                                événement
# 1                         jam-jam                                   piqûre
# 2                             xar                                   percer
# 3                         xar-xar                                    fente
# 4                       bëgg-bëgg                                    désir
# 5                       tooy-tooy                                 humidité
# 6                         xew-xew                                événement
# 7                           waalo                            nom de région
# 8                     waalo-waalo                        habitant du Oualo
# 9                         sax-sax                         chef de province
# 10                        sax-sax                             jeune pousse
# 11                           ñuul                                     noir
# 12                           biir                                   ventre
# 13                       ñuulbiir                                  méchant
# 14                       ñuulbiir                               méchanceté
# 15                           jaam                                  esclave
# 16                           buur                                      roi
# 17                        jaambur                              homme libre
# 18                            wër                            faire le tour
# 19                            sëg                                cimetière
# 20                         wërsëg                                   chance
# 21                        jambuur                              homme libre
# 22                jambuur-jambuur  habitant de la région des hommes libres
# 23                         kërbët                            pas de cheval
# 24                  kërbët kërbët                          galop de cheval
# 25                  jigéenu wérul           femme qui ne se porte pas bien
# 26                  jigéenu wérul                           femme enceinte
# 27                       waru gar                   prestation obligatoire
# 28                       waru gar                                      dot
# 29                     naaru góor                 littéralement maure mâle
# 30                     naaru góor                    cheval pur sang arabe
# 31                    ñaari goroõ                             deux rythmes
# 32                    ñaari goroõ                         figures de danse
# 33                   moom-sa-réew                             indépendance
# 34                   moom-sa-réew        rentrer en possession de son pays
# 35                        na jaay                              qu'il vende
# 36                        na jaay                                    oncle
# 37                     jarabibaat               femme qui épouse son oncle
# 38                     jarabibaat               femme qui épouse son oncle
# 39                            bax                                      bon
# 40                      baxbax-lu             faire semblant d'être gentil
# 41                           góor                                     mâle
# 42                    góorgóor-lu                     se conduire en homme
# 43                            wër                            faire le tour
# 44                        wër-wër                              va et vient
# 45                     wër wër lu               aller à droite et à gauche
# 46                            xam                                   savoir
# 47                        xam-xam                                  science
# 48                     xam xam lu                          jouer au savant
# 49                            xar                                   fendre
# 50                        xar-xar                                    fente
# 51                     xar xar le                         simuler l'agonie
# 52                        daõ-daõ                              trépidation
# 53                        daõ daõ                                trépigner
# 54                     daõ daõ lu                                trépigner
# 55                        raõ-raõ                                   fracas
# 56                     raõ raõ lu                         faire du vacarme
# 57                        jaambur                              homme libre
# 58                jaambur-jaambur                     habitant du Diambour
# 59              jaambur jaamburlu                            jouer au sage
# 60                        xar xar                                    fente
# 61                       xarxarle                                 agoniser
# 62                    xarxarlekat                      qui simule l'agonie
# 63                        wër sëg                                   chance
# 64                      wërsëglóo              bénéficier de quelque chose
# 65                        daõ daõ                              trépidation
# 66                     daõdaõluji             aller s'exciter quelque part
# 67                       bëkknéeg                                courtisan
# 68                      bëkknéegu                 se conduire en courtisan
# 69                        warugar                                      dot
# 70                     warugarloo          considérer comme une obligation
# 71                    ñaari goroõ                          figure de danse
# 72                   ñaari goroõi                    aller danser le naari
# 73                     Nit bonul.                 Homme n'est pas mauvais.
# 74                     Nit bonul.               L'homme n'est pas mauvais.
# 75                    Nit dem na.                     Quelqu'un est parti.
# 76                    Nit dem na.                         Homme est parti.
# 77                    Nit dem na.                      Un homme est parti.
# 78                Gis naa gaynde.                            J'ai vu lion.
# 79                Gis naa gaynde.                         J'ai vu un lion.
# 80                        Nit la.                          C'est un homme.
# 81           Nit kii ci sama wet.                   Cet homme près de moi.
# 82          Nit kookuu ci sa wet.                Cet homme là près de toi.
# 83             Gis õga nit kale ?               Tu vois cet homme là-bas ?
# 84          Gis õga nit kookale ?                     Tu sais, cet homme ?
# 85          Gis õga nit kookale ?                     Tu sais, cet homme ?
# 86              Gis õga nit kee ?                   Tu vois cet homme là ?
# 87           Gis õga nit kookee ?                  Tu sais, cet homme là ?
# 88           Gis õga nit kookee ?                  Tu vois, cet homme là ?
# 89                Gis naa nit ki.                         J'ai vu l'homme.
# 90             Gis naa jigéen ju.                        J'ai vu la femme.
# 91                Xoolal mbër mu.                      Regarde ce lutteur.
# 92                Xoolal mbër mu.          Regarde ce semblant de lutteur.
# 93               Seetal sarax su.                    Regarde cette aumône.
# 94               Gis õga nit ka ?                       Tu as vu l'homme ?
# 95               Gis õga nit ka ?          Tu as vu, auparavant, l'homme ?
# 96           Xamoon õga jaõx ba ?          Tu connaissais la jeune fille ?
# 97         Xammee õga waa jooju ?           Tu reconnais cet individu-là ?
# 98  Xammeewoon õga jigéen jooju ?              Tu avais reconnu la femme ?
# 99               Nit kii jaõg na.                      Cet homme a étudié.
#
# --------------------
#
#
# Which of the groups of batch number 4 do you consider to be complete sentences (see the file batch.csv) ?
# You cannot combine the same type of command: Type of commands are 'end mark' and 'upper'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Oumar Kane\OneDrive\Documents\subject2\extract_new_sentences.ipynb Cell 53 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> new_sent_extraction.extract_sentences(group_range=(600, 1000), save=True, batch_size=100)
#
# c:\Users\Oumar Kane\OneDrive\Documents\subject2\extract_new_sentences.ipynb Cell 53 in 5
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=582'>583</a> cm_type = cm.split('+')[0]
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=584'>585</a> if cm_type == add_end_mark_cmd:
# --> <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=586'>587</a>     batch = self.add_end_mark(batch, cm.split("+")[1])
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=588'>589</a> elif cm_type == add_end_mark_on_all:
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=590'>591</a>     mark = cm.split("+")[1]
#
# c:\Users\Oumar Kane\OneDrive\Documents\subject2\extract_new_sentences.ipynb Cell 53 in 4
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=444'>445</a>     groups = list(range(int(groups[0]), int(groups[1]) + 1))
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=446'>447</a> else:
# --> <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=448'>449</a>     groups = [int(nb) for nb in tf.split(':')[0].split(',')]
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=450'>451</a> mark = tf.split(':')[1]
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=452'>453</a> for nb in groups:
#
# c:\Users\Oumar Kane\OneDrive\Documents\subject2\extract_new_sentences.ipynb Cell 53 in 4
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=444'>445</a>     groups = list(range(int(groups[0]), int(groups[1]) + 1))
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=446'>447</a> else:
# --> <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=448'>449</a>     groups = [int(nb) for nb in tf.split(':')[0].split(',')]
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=450'>451</a> mark = tf.split(':')[1]
#     <a href='vscode-notebook-cell:/c%3A/Users/Oumar%20Kane/OneDrive/Documents/subject2/extract_new_sentences.ipynb#Y111sZmlsZQ%3D%3D?line=452'>453</a> for nb in groups:
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# We provide an error let us add correction and repeat the last process.

# %%
new_sent_extraction.extract_sentences(save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
# You cannot combine the same type of command: Type of commands are 'end mark' and 'upper'
#
# Batch result
#                                  french  \
# 0                   xale yile yarunañu.
# 1                 jigéen jale laa wax !
# 2                     xale buu laa wax.
# 3                    jigéen jule demul.
# 4                   xale yule yaruwuñu.
# 5                    xam õga xale bee ?
# 6                          jigéen jale.
# 7                  téere yee laa jënd !
# 8   waxtaanal ag nit kookii ci sa wet !
# 9               gis õga jigéen ñooñii ?
# 10                     mayal nag wile !
# 11                 xam õga nit kookuu ?
# 12               gis õga xale yooyule ?
# 13            nit kookuu génn laa wax !
# 14            gisóon õga jigéen joojule
# 15              xamoon naa waa joojee !
# 16      xammeewoon naa jigéen joojale !
# 17                     Gis naa xale ba.
# 18                    Kile nit laa wax.
# 19                   Jile wax rafetul !
# 20                     Kee nit õgay gis
# 21                Yee téere la ma jóox.
# 22                      Gis naa am xar.
# 23                     Séen naa ak nit.
# 24                     Séen naa aw nit.
# 25                     Séen naa ay nit.
# 26                     Nit kan a réer ?
# 27                     Xar man a réer ?
# 28                     Fas wan a réer ?
# 29                  Jigéen jan a réer ?
# 30                    Doom ban a réer ?
# 31                     Lëf lan a réer ?
# 32                    Ndaw san a réer ?
# 33                   Nit ñan ñoo réer ?
# 34                   Xar yan ñoo réer ?
# 35                   Fas yan ñoo réer ?
# 36                Jigéen ñan ñoo réer ?
# 37                  Doom yan ñoo réer ?
# 38                   Yëf yan ñoo réer ?
# 39                 Saatu yan ñoo réer ?
# 40              Xar moomu man õga wax ?
# 41              Xar moomu man õga wax ?
# 42                        Xar mii man ?
# 43               Xar yii yan õga jënd ?
# 44               Xar yii yan õga jënd ?
# 45                       Xar yile yan ?
# 46                Ma japp nag yee yan ?
# 47              Mu japp nag yooyu yan ?
# 48             Boobu néeg ban õga wax ?
# 49               Bii néeg ban õga wax ?
# 50               Bii néeg ban õga wax ?
# 51          Jile jigéen jan õgeen wax ?
# 52          Jile jigéen jan õgeen wax ?
# 53           Woowale fas wan õga bëgg ?
# 54           Yooyale fas wan õga bëgg ?
# 55                   xarit yan ño ñëw ?
# 56                            xar mépp.
# 57                           néeg bépp.
# 58                            kër gépp.
# 59                            wax jépp.
# 60                            wax jépp.
# 61           génnéel képp nit koo gis !
# 62           génnéel mépp xar moo gis !
# 63           génnéel wépp fas woo gis !
# 64           génnéel bépp nag woo gis !
# 65                  teralal béppu nit !
# 66                         xar mi mépp.
# 67                      nag woowa wépp.
# 68                       wall wuu wépp.
# 69                        xar mii mépp.
# 70                     xar moomee mépp.
# 71                    xar woowalé wépp.
# 72                         mi xar mépp.
# 73                       man xar mépp ?
# 74                    xar moomule mépp.
# 75                    seetil nit ñépp !
# 76                    seetil xar yépp !
# 77                    seetil fas yépp !
# 78                    seetil nag yépp !
# 79           gisoon naa nit ñooña ñépp.
# 80           gisoon naa nit ñooña ñépp.
# 81          gisoon naa ñooñale nit ñan.
# 82              gisoon naa xar yi yépp.
# 83              gisoon naa xar yi yépp.
# 84              gisoon naa xar yi yépp.
# 85              gisoon naa xar yi yépp.
# 86                     nit kenn réerul.
# 87                     xar menn réerul.
# 88                     fas wenn réerul.
# 89                    doom benn réerul.
# 90                  jigéen jenn réerul.
# 91                    ndaw senn réerul.
# 92                     lëf lenn réerul.
# 93                  gayndé genn réerul.
# 94                     kenn nit réerul.
# 95                     menn xar réerul.
# 96                  jenn jigéen réerul.
# 97                      menn nit ñëwul.
# 98                      menn xar ñëwul.
# 99                jënd ñaa menn xar mi.
#
#                                          wolof
# 0                  ces jeunes gens sont sages.
# 1           je parle de cette dame que voilà !
# 2                        je parle de ce petit.
# 3             cette femme-ci n'est pas partie.
# 4     ces enfants que voilà ne sont pas sages.
# 5               tu connais cet enfant là-bas ?
# 6                           Cette dame là-bas.
# 7   c'est ces livres là-bas que j'ai achetés !
# 8        cause avec cet homme qui est à côté !
# 9                      tu vois ces femmes-là ?
# 10                    nourris cette vache-ci !
# 11                   tu connais cet homme-là ?
# 12                  tu as vu ces jeunes gens ?
# 13    je parle de la personne qui est sortie !
# 14                 tu avais vu cette femme[ ?]
# 15            je connaissais cet individu-là !
# 16             j'avais reconnu cette dame-là !
# 17                           J'ai vu l'enfant.
# 18                   Je parle de cet homme-ci.
# 19          Ce n'est pas là une belle parole !
# 20                Cet homme là-bas que tu vois
# 21       C'est ces livres-là qu'il m'a donnés.
# 22                          J'ai vu un mouton.
# 23                       J'ai aperçu un homme.
# 24                       J'ai aperçu un homme.
# 25                       J'ai aperçu des gens.
# 26                    Quel homme s'est égaré ?
# 27                   Quel mouton s'est égaré ?
# 28                   Quel cheval s'est égaré ?
# 29                 Quelle femme s'est égarée ?
# 30                   Quelle clé s'est égarée ?
# 31                 Quelle chose s'est égarée ?
# 32           Quelle jeune fille s'est égarée ?
# 33         Quelles personnes se sont égarées ?
# 34              Quels moutons se sont égarés ?
# 35              Quels chevaux se sont égarés ?
# 36            Quelles femmes se sont égarées ?
# 37              Quelles clés se sont égarées ?
# 38            Quelles choses se sont égarées ?
# 39             Quels couteaux se sont égarés ?
# 40                  Tu parles de quel mouton ?
# 41                    Tu parles de ce mouton ?
# 42                               quel mouton ?
# 43            Quels moutons avais-tu achetés ?
# 44    C'est ces moutons que tu avais achetés ?
# 45                             Quels moutons ?
# 46              Que j'attrape quelles vaches ?
# 47             Qu'il attrappe quelles vaches ?
# 48                Tu parles de quelle maison ?
# 49                Tu parles de quelle maison ?
# 50          Tu parles de quelle maison (ici) ?
# 51                Vous parlez de quelle dame ?
# 52          Vous parlez de quelle dame (ici) ?
# 53                       Quel cheval veux-tu ?
# 54                       Quel cheval veux-tu ?
# 55                   Quels amis sont arrivés ?
# 56                             tout le mouton.
# 57                           toute la chambre.
# 58                            toute la maison.
# 59                             tout le propos.
# 60                           tout ce discours.
# 61        fais sortir tout homme que tu vois !
# 62       fais sortir tout mouton que tu vois !
# 63       fais sortir tout cheval que tu vois !
# 64       fais sortir toute vache que tu vois !
# 65                         honore tout homme !
# 66                        le mouton en entier.
# 67                   ce boeuf-là, en totalité.
# 68                 toute cette part que voici.
# 69                     ce mouton-ci en entier.
# 70                             tout ce mouton.
# 71                         toute cette partie.
# 72                        ce mouton en entier.
# 73                     quel mouton en entier ?
# 74                     ce mouton-là en entier.
# 75                   va voir tous les hommes !
# 76                  va voir tous les moutons !
# 77                  va voir tous les chevaux !
# 78                 va voir toutes les vaches !
# 79                      j'ai vu tous ces gens.
# 80          j'ai vu tous ces gens, auparavant.
# 81                           j'ai vu ces gens.
# 82                j'ai vu tous ces moutons-ci.
# 83              j'ai déjà vu tous les moutons.
# 84           j'ai déjà vu tous ces moutons-ci.
# 85                j'ai vu tous ces moutons-ci.
# 86                 aucun homme ne s'est égaré.
# 87                aucun mouton ne s'est égaré.
# 88                aucun cheval ne s'est égaré.
# 89                   aucune clef n'est égarée.
# 90                aucune dame ne s'est égarée.
# 91         aucune jeune fille ne s'est égarée.
# 92                        rien ne s'est égaré.
# 93                  aucun lion ne s'est égaré.
# 94                 aucun homme ne s'est égaré.
# 95                aucun mouton ne s'est égaré.
# 96                aucune dame ne s'est égarée.
# 97                     aucun homme n'est venu.
# 98                  aucun mouton n'est arrivé.
# 99                      j'ai acheté le mouton.
#
# Batch result
#                                  french  \
# 0                   Xale yile yarunañu.
# 1                 Jigéen jale laa wax !
# 2                     Xale buu laa wax.
# 3                    Jigéen jule demul.
# 4                   Xale yule yaruwuñu.
# 5                    Xam õga xale bee ?
# 6                          Jigéen jale.
# 7                  Téere yee laa jënd !
# 8   Waxtaanal ag nit kookii ci sa wet !
# 9               Gis õga jigéen ñooñii ?
# 10                     Mayal nag wile !
# 11                 Xam õga nit kookuu ?
# 12               Gis õga xale yooyule ?
# 13            Nit kookuu génn laa wax !
# 14            Gisóon õga jigéen joojule
# 15              Xamoon naa waa joojee !
# 16      Xammeewoon naa jigéen joojale !
# 17                     Gis naa xale ba.
# 18                    Kile nit laa wax.
# 19                   Jile wax rafetul !
# 20                     Kee nit õgay gis
# 21                Yee téere la ma jóox.
# 22                      Gis naa am xar.
# 23                     Séen naa ak nit.
# 24                     Séen naa aw nit.
# 25                     Séen naa ay nit.
# 26                     Nit kan a réer ?
# 27                     Xar man a réer ?
# 28                     Fas wan a réer ?
# 29                  Jigéen jan a réer ?
# 30                    Doom ban a réer ?
# 31                     Lëf lan a réer ?
# 32                    Ndaw san a réer ?
# 33                   Nit ñan ñoo réer ?
# 34                   Xar yan ñoo réer ?
# 35                   Fas yan ñoo réer ?
# 36                Jigéen ñan ñoo réer ?
# 37                  Doom yan ñoo réer ?
# 38                   Yëf yan ñoo réer ?
# 39                 Saatu yan ñoo réer ?
# 40              Xar moomu man õga wax ?
# 41              Xar moomu man õga wax ?
# 42                        Xar mii man ?
# 43               Xar yii yan õga jënd ?
# 44               Xar yii yan õga jënd ?
# 45                       Xar yile yan ?
# 46                Ma japp nag yee yan ?
# 47              Mu japp nag yooyu yan ?
# 48             Boobu néeg ban õga wax ?
# 49               Bii néeg ban õga wax ?
# 50               Bii néeg ban õga wax ?
# 51          Jile jigéen jan õgeen wax ?
# 52          Jile jigéen jan õgeen wax ?
# 53           Woowale fas wan õga bëgg ?
# 54           Yooyale fas wan õga bëgg ?
# 55                   Xarit yan ño ñëw ?
# 56                            Xar mépp.
# 57                           Néeg bépp.
# 58                            Kër gépp.
# 59                            Wax jépp.
# 60                            Wax jépp.
# 61           Génnéel képp nit koo gis !
# 62           Génnéel mépp xar moo gis !
# 63           Génnéel wépp fas woo gis !
# 64           Génnéel bépp nag woo gis !
# 65                  Teralal béppu nit !
# 66                         Xar mi mépp.
# 67                      Nag woowa wépp.
# 68                       Wall wuu wépp.
# 69                        Xar mii mépp.
# 70                     Xar moomee mépp.
# 71                    Xar woowalé wépp.
# 72                         Mi xar mépp.
# 73                       Man xar mépp ?
# 74                    Xar moomule mépp.
# 75                    Seetil nit ñépp !
# 76                    Seetil xar yépp !
# 77                    Seetil fas yépp !
# 78                    Seetil nag yépp !
# 79           Gisoon naa nit ñooña ñépp.
# 80           Gisoon naa nit ñooña ñépp.
# 81          Gisoon naa ñooñale nit ñan.
# 82              Gisoon naa xar yi yépp.
# 83              Gisoon naa xar yi yépp.
# 84              Gisoon naa xar yi yépp.
# 85              Gisoon naa xar yi yépp.
# 86                     Nit kenn réerul.
# 87                     Xar menn réerul.
# 88                     Fas wenn réerul.
# 89                    Doom benn réerul.
# 90                  Jigéen jenn réerul.
# 91                    Ndaw senn réerul.
# 92                     Lëf lenn réerul.
# 93                  Gayndé genn réerul.
# 94                     Kenn nit réerul.
# 95                     Menn xar réerul.
# 96                  Jenn jigéen réerul.
# 97                      Menn nit ñëwul.
# 98                      Menn xar ñëwul.
# 99                Jënd ñaa menn xar mi.
#
#                                          wolof
# 0                  Ces jeunes gens sont sages.
# 1           Je parle de cette dame que voilà !
# 2                        Je parle de ce petit.
# 3             Cette femme-ci n'est pas partie.
# 4     Ces enfants que voilà ne sont pas sages.
# 5               Tu connais cet enfant là-bas ?
# 6                           Cette dame là-bas.
# 7   C'est ces livres là-bas que j'ai achetés !
# 8        Cause avec cet homme qui est à côté !
# 9                      Tu vois ces femmes-là ?
# 10                    Nourris cette vache-ci !
# 11                   Tu connais cet homme-là ?
# 12                  Tu as vu ces jeunes gens ?
# 13    Je parle de la personne qui est sortie !
# 14                 Tu avais vu cette femme[ ?]
# 15            Je connaissais cet individu-là !
# 16             J'avais reconnu cette dame-là !
# 17                           J'ai vu l'enfant.
# 18                   Je parle de cet homme-ci.
# 19          Ce n'est pas là une belle parole !
# 20                Cet homme là-bas que tu vois
# 21       C'est ces livres-là qu'il m'a donnés.
# 22                          J'ai vu un mouton.
# 23                       J'ai aperçu un homme.
# 24                       J'ai aperçu un homme.
# 25                       J'ai aperçu des gens.
# 26                    Quel homme s'est égaré ?
# 27                   Quel mouton s'est égaré ?
# 28                   Quel cheval s'est égaré ?
# 29                 Quelle femme s'est égarée ?
# 30                   Quelle clé s'est égarée ?
# 31                 Quelle chose s'est égarée ?
# 32           Quelle jeune fille s'est égarée ?
# 33         Quelles personnes se sont égarées ?
# 34              Quels moutons se sont égarés ?
# 35              Quels chevaux se sont égarés ?
# 36            Quelles femmes se sont égarées ?
# 37              Quelles clés se sont égarées ?
# 38            Quelles choses se sont égarées ?
# 39             Quels couteaux se sont égarés ?
# 40                  Tu parles de quel mouton ?
# 41                    Tu parles de ce mouton ?
# 42                               Quel mouton ?
# 43            Quels moutons avais-tu achetés ?
# 44    C'est ces moutons que tu avais achetés ?
# 45                             Quels moutons ?
# 46              Que j'attrape quelles vaches ?
# 47             Qu'il attrappe quelles vaches ?
# 48                Tu parles de quelle maison ?
# 49                Tu parles de quelle maison ?
# 50          Tu parles de quelle maison (ici) ?
# 51                Vous parlez de quelle dame ?
# 52          Vous parlez de quelle dame (ici) ?
# 53                       Quel cheval veux-tu ?
# 54                       Quel cheval veux-tu ?
# 55                   Quels amis sont arrivés ?
# 56                             Tout le mouton.
# 57                           Toute la chambre.
# 58                            Toute la maison.
# 59                             Tout le propos.
# 60                           Tout ce discours.
# 61        Fais sortir tout homme que tu vois !
# 62       Fais sortir tout mouton que tu vois !
# 63       Fais sortir tout cheval que tu vois !
# 64       Fais sortir toute vache que tu vois !
# 65                         Honore tout homme !
# 66                        Le mouton en entier.
# 67                   Ce boeuf-là, en totalité.
# 68                 Toute cette part que voici.
# 69                     Ce mouton-ci en entier.
# 70                             Tout ce mouton.
# 71                         Toute cette partie.
# 72                        Ce mouton en entier.
# 73                     Quel mouton en entier ?
# 74                     Ce mouton-là en entier.
# 75                   Va voir tous les hommes !
# 76                  Va voir tous les moutons !
# 77                  Va voir tous les chevaux !
# 78                 Va voir toutes les vaches !
# 79                      J'ai vu tous ces gens.
# 80          J'ai vu tous ces gens, auparavant.
# 81                           J'ai vu ces gens.
# 82                J'ai vu tous ces moutons-ci.
# 83              J'ai déjà vu tous les moutons.
# 84           J'ai déjà vu tous ces moutons-ci.
# 85                J'ai vu tous ces moutons-ci.
# 86                 Aucun homme ne s'est égaré.
# 87                Aucun mouton ne s'est égaré.
# 88                Aucun cheval ne s'est égaré.
# 89                   Aucune clef n'est égarée.
# 90                Aucune dame ne s'est égarée.
# 91         Aucune jeune fille ne s'est égarée.
# 92                        Rien ne s'est égaré.
# 93                  Aucun lion ne s'est égaré.
# 94                 Aucun homme ne s'est égaré.
# 95                Aucun mouton ne s'est égaré.
# 96                Aucune dame ne s'est égarée.
# 97                     Aucun homme n'est venu.
# 98                  Aucun mouton n'est arrivé.
# 99                      J'ai acheté le mouton.
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
# You cannot combine the same type of command: Type of commands are 'end mark' and 'upper'
#
# Batch result
#                                 french  \
# 0               jënd ñaa menn xar mi !
# 1               jënd ñaa menn xar mi !
# 2                  seetal nit keneen !
# 3                  seetal xar meneen !
# 4                  seetal fas weneen !
# 5                 seetal néeg beneen !
# 6               seetal gaynde geneen !
# 7                 seetal ndaw seneen !
# 8               seetal jigéen jeneen !
# 9                  seetal lëf leneen !
# 10                weneen fas la bëgg !
# 11              beneen néeg laa bëgg !
# 12            geneen gaynde laa bëgg !
# 13             jeneen jabar laa bëgg !
# 14              seneen ndaw laa bëgg !
# 15              beneen ndab laa bëgg !
# 16               meneen nit laa bëgg !
# 17               nit keneen ki ñëw na.
# 18            keneen nit kooka la wax.
# 19              fas weneen wu moo daw.
# 20            nit keneen kaa laa wax !
# 21          fas weneen wale moo baax !
# 22            weneen fas wan õga gis ?
# 23            meneen xar mépp moo gis.
# 24             yeneen xar yi yépp daw.
# 25                     sama xarit la !
# 26                       sa xarit la !
# 27                        xaritam la !
# 28                     suñu sarit la !
# 29                     seen xarit la !
# 30                     suñu xarit la !
# 31             gis naa sama xarit bi !
# 32             gis naa sana xarit yi !
# 33            gis naa sama xarit yee !
# 34                     sama aw xarit !
# 35                       samay xarit !
# 36                       samay xarit !
# 37           gis õga samay xarit yan ?
# 38           gis õga samay xarit yan ?
# 39             gis naa sa xarit yépp !
# 40              gis na sa xarit yépp !
# 41    gis naa seeni xarit yooyu yépp !
# 42     gis na seeni xarit yooyu yépp !
# 43         gis naa seen yeneen xarit !
# 44          gis na seen yeneen xarit !
# 45        gis naa sa xarit yeneen yi !
# 46         gis na sa xarit yeneen yi !
# 47  gis naa sama xarit yeneen yooyuu !
# 48   gis na sama xarit yeneen yooyuu !
# 49                     gis naa nit ki.
# 50                     gis naa nit ñi.
# 51                    gis naa jeeg bi.
# 52                    gis naa jeeg ji.
# 53                    xam naa xale bi.
# 54                    xam naa xale yi.
# 55                       am na am xar.
# 56                       am na ay xar.
# 57                                 bët
# 58                                 gët
# 59                                 bëñ
# 60                                 gëñ
# 61                    wekkil gëñ yii !
# 62                     deñcal yëf yi !
# 63                       seni gëñ la !
# 64                   ay bët yu rafet !
# 65                   ku teral nit la !
# 66                         yaral xar !
# 67                         yaral xar !
# 68                    gis õga nit ki ?
# 69               gis õga nit ki woon ?
# 70               gis õga nit ki woon ?
# 71      xammee õga jabaram joojuwoon ?
# 72      xammee õga jabaram joojuwoon ?
# 73            gis õga coroom la woon ?
# 74            gis õga coroom la woon ?
# 75                  gis õga xale bii ?
# 76             gis õga xale bii woon ?
# 77             gis õga xale bii woon ?
# 78    xammee õga sa far, woowee woon ?
# 79                             nit la.
# 80                        jigéen lanu.
# 81                        nit lawoon !
# 82                        nit lawoon !
# 83                     Laobe lañuwoon.
# 84                             dem õga
# 85                           nit õga !
# 86                           dem nañu.
# 87                          nit lañu !
# 88                       nit la woon !
# 89                           demoon na
# 90                           lawbe la.
# 91                        aw lawbe la.
# 92                       lawbe bi la !
# 93             seen lawbe ba woon la !
# 94                             dem na.
# 95                           dil nit !
# 96                       du sabar gi !
# 97                       dil jaõgkat !
# 98                  moo di jaõgkat bi.
# 99                     moo doon ganam.
#
#                                           wolof
# 0                  j'ai acheté ce seul mouton !
# 1             j'ai acheté cette unique mouton !
# 2                      cherche un autre homme !
# 3                     cherche un autre mouton !
# 4                     cherche un autre cheval !
# 5                    cherche une autre maison !
# 6                       cherche un autre lion !
# 7               cherche une autre jeune fille !
# 8                      cherche une autre dame !
# 9                     cherche une autre chose !
# 10          c'est un autre cheval que je veux !
# 11         c'est une autre maison que je veux !
# 12            c'est un autre lion que je veux !
# 13         c'est une autre épouse que je veux !
# 14    c'est une autre jeune fille que je veux !
# 15       c'est un autre récipient que je veux !
# 16           c'est un autre homme que je veux !
# 17                      l'autre homme est venu.
# 18                   il parle de l'autre homme.
# 19        c'est l'autre cheval qui s'est égaré.
# 20      je parle de cet autre homme que voilà !
# 21  c'est cet autre cheval là-bas qui est bon !
# 22                 quel autre cheval as-tu vu ?
# 23               tout autre mouton que tu vois.
# 24             tous les autres moutons fuirent.
# 25                              c'est mon ami !
# 26                              c'est ton ami !
# 27                              c'est son ami !
# 28                            c'est notre ami !
# 29                            c'est votre ami !
# 30                             c'est leur ami !
# 31                            j'ai vu mon ami !
# 32                           j'ai vu mes amis !
# 33                           j'ai vu mes amis !
# 34                               un ami à moi !
# 35                             des amis à moi !
# 36                                   mes amis !
# 37                  tu as vu quels amis à moi ?
# 38              tu as vu lesquels de mes amis ?
# 39                      j'ai vu tous tes amis !
# 40                      il a vu tous tes amis !
# 41          j'ai vu tous vos amis en question !
# 42          il a vu tous vos amis en question !
# 43               j'ai vu d'autres amis à vous !
# 44               il a vu d'autres amis à vous !
# 45                    j'ai vu tes autres amis !
# 46                    il a vu tes autres amis !
# 47                    j'ai vu mes autres amis !
# 48                    il a vu mes autres amis !
# 49                             je vois l'homme.
# 50                            je vois les gens.
# 51                             il a vu la dame.
# 52                           il a vu les dames.
# 53                         je connais l'enfant.
# 54                      je connais les enfants.
# 55                              il a un mouton.
# 56                            il a des moutons.
# 57                                         oeil
# 58                                         yeux
# 59                                         dent
# 60                                        dents
# 61                       arrache ces dents-là !
# 62                         range les affaires !
# 63                          c'est leurs dents !
# 64                              de beaux yeux !
# 65         c'est quelqu'un qui honore l'homme !
# 66                            élève un mouton !
# 67                          élève des moutons !
# 68                           tu as vu l'homme ?
# 69                           tu as vu l'homme ?
# 70      tu as vu l'homme dont il fut question ?
# 71                     tu as reconnu sa femme ?
# 72         tu as reconnu sa femme d'autrefois ?
# 73                  tu te rappelles son amour ?
# 74      tu te rappelles son amour d'autrefois ?
# 75                       tu vois ce garçon-là ?
# 76                      tu vois, ce garçon-là ?
# 77                       tu vois ce garçon-là ?
# 78         tu reconnais ton amour d'autrefois ?
# 79                              c'est un homme.
# 80                            c'est des femmes.
# 81                            ce fut un homme !
# 82                   ce fut un homme, un vrai !
# 83                       ils ont été bûcherons.
# 84                                  tu es parti
# 85                             tu es un homme !
# 86                          nous sommes partis.
# 87                     nous sommes des hommes !
# 88                            ce fut un homme !
# 89                                     il a été
# 90                           c'est un bûcheron.
# 91                           c'est un bûcheron.
# 92                          c'est le bûcheron !
# 93           c'est votre bûcheron d'autrefois !
# 94                                il est parti.
# 95                     sois un être de raison !
# 96                    ce n'est pas le tambour !
# 97                 sois quelqu'un de studieux !
# 98                            c'est l'étudiant.
# 99             c'était son hôte habituellement.
#
# Batch result
#                                 french  \
# 0               Jënd ñaa menn xar mi !
# 1               Jënd ñaa menn xar mi !
# 2                  Seetal nit keneen !
# 3                  Seetal xar meneen !
# 4                  Seetal fas weneen !
# 5                 Seetal néeg beneen !
# 6               Seetal gaynde geneen !
# 7                 Seetal ndaw seneen !
# 8               Seetal jigéen jeneen !
# 9                  Seetal lëf leneen !
# 10                Weneen fas la bëgg !
# 11              Beneen néeg laa bëgg !
# 12            Geneen gaynde laa bëgg !
# 13             Jeneen jabar laa bëgg !
# 14              Seneen ndaw laa bëgg !
# 15              Beneen ndab laa bëgg !
# 16               Meneen nit laa bëgg !
# 17               Nit keneen ki ñëw na.
# 18            Keneen nit kooka la wax.
# 19              Fas weneen wu moo daw.
# 20            Nit keneen kaa laa wax !
# 21          Fas weneen wale moo baax !
# 22            Weneen fas wan õga gis ?
# 23            Meneen xar mépp moo gis.
# 24             Yeneen xar yi yépp daw.
# 25                     Sama xarit la !
# 26                       Sa xarit la !
# 27                        Xaritam la !
# 28                     Suñu sarit la !
# 29                     Seen xarit la !
# 30                     Suñu xarit la !
# 31             Gis naa sama xarit bi !
# 32             Gis naa sana xarit yi !
# 33            Gis naa sama xarit yee !
# 34                     Sama aw xarit !
# 35                       Samay xarit !
# 36                       Samay xarit !
# 37           Gis õga samay xarit yan ?
# 38           Gis õga samay xarit yan ?
# 39             Gis naa sa xarit yépp !
# 40              Gis na sa xarit yépp !
# 41    Gis naa seeni xarit yooyu yépp !
# 42     Gis na seeni xarit yooyu yépp !
# 43         Gis naa seen yeneen xarit !
# 44          Gis na seen yeneen xarit !
# 45        Gis naa sa xarit yeneen yi !
# 46         Gis na sa xarit yeneen yi !
# 47  Gis naa sama xarit yeneen yooyuu !
# 48   Gis na sama xarit yeneen yooyuu !
# 49                     Gis naa nit ki.
# 50                     Gis naa nit ñi.
# 51                    Gis naa jeeg bi.
# 52                    Gis naa jeeg ji.
# 53                    Xam naa xale bi.
# 54                    Xam naa xale yi.
# 55                       Am na am xar.
# 56                       Am na ay xar.
# 57                                 Bët
# 58                                 Gët
# 59                                 Bëñ
# 60                                 Gëñ
# 61                    Wekkil gëñ yii !
# 62                     Deñcal yëf yi !
# 63                       Seni gëñ la !
# 64                   Ay bët yu rafet !
# 65                   Ku teral nit la !
# 66                         Yaral xar !
# 67                         Yaral xar !
# 68                    Gis õga nit ki ?
# 69               Gis õga nit ki woon ?
# 70               Gis õga nit ki woon ?
# 71      Xammee õga jabaram joojuwoon ?
# 72      Xammee õga jabaram joojuwoon ?
# 73            Gis õga coroom la woon ?
# 74            Gis õga coroom la woon ?
# 75                  Gis õga xale bii ?
# 76             Gis õga xale bii woon ?
# 77             Gis õga xale bii woon ?
# 78    Xammee õga sa far, woowee woon ?
# 79                             Nit la.
# 80                        Jigéen lanu.
# 81                        Nit lawoon !
# 82                        Nit lawoon !
# 83                     Laobe lañuwoon.
# 84                             Dem õga
# 85                           Nit õga !
# 86                           Dem nañu.
# 87                          Nit lañu !
# 88                       Nit la woon !
# 89                           Demoon na
# 90                           Lawbe la.
# 91                        Aw lawbe la.
# 92                       Lawbe bi la !
# 93             Seen lawbe ba woon la !
# 94                             Dem na.
# 95                           Dil nit !
# 96                       Du sabar gi !
# 97                       Dil jaõgkat !
# 98                  Moo di jaõgkat bi.
# 99                     Moo doon ganam.
#
#                                           wolof
# 0                  J'ai acheté ce seul mouton !
# 1             J'ai acheté cette unique mouton !
# 2                      Cherche un autre homme !
# 3                     Cherche un autre mouton !
# 4                     Cherche un autre cheval !
# 5                    Cherche une autre maison !
# 6                       Cherche un autre lion !
# 7               Cherche une autre jeune fille !
# 8                      Cherche une autre dame !
# 9                     Cherche une autre chose !
# 10          C'est un autre cheval que je veux !
# 11         C'est une autre maison que je veux !
# 12            C'est un autre lion que je veux !
# 13         C'est une autre épouse que je veux !
# 14    C'est une autre jeune fille que je veux !
# 15       C'est un autre récipient que je veux !
# 16           C'est un autre homme que je veux !
# 17                      L'autre homme est venu.
# 18                   Il parle de l'autre homme.
# 19        C'est l'autre cheval qui s'est égaré.
# 20      Je parle de cet autre homme que voilà !
# 21  C'est cet autre cheval là-bas qui est bon !
# 22                 Quel autre cheval as-tu vu ?
# 23               Tout autre mouton que tu vois.
# 24             Tous les autres moutons fuirent.
# 25                              C'est mon ami !
# 26                              C'est ton ami !
# 27                              C'est son ami !
# 28                            C'est notre ami !
# 29                            C'est votre ami !
# 30                             C'est leur ami !
# 31                            J'ai vu mon ami !
# 32                           J'ai vu mes amis !
# 33                           J'ai vu mes amis !
# 34                               Un ami à moi !
# 35                             Des amis à moi !
# 36                                   Mes amis !
# 37                  Tu as vu quels amis à moi ?
# 38              Tu as vu lesquels de mes amis ?
# 39                      J'ai vu tous tes amis !
# 40                      Il a vu tous tes amis !
# 41          J'ai vu tous vos amis en question !
# 42          Il a vu tous vos amis en question !
# 43               J'ai vu d'autres amis à vous !
# 44               Il a vu d'autres amis à vous !
# 45                    J'ai vu tes autres amis !
# 46                    Il a vu tes autres amis !
# 47                    J'ai vu mes autres amis !
# 48                    Il a vu mes autres amis !
# 49                             Je vois l'homme.
# 50                            Je vois les gens.
# 51                             Il a vu la dame.
# 52                           Il a vu les dames.
# 53                         Je connais l'enfant.
# 54                      Je connais les enfants.
# 55                              Il a un mouton.
# 56                            Il a des moutons.
# 57                                         Oeil
# 58                                         Yeux
# 59                                         Dent
# 60                                        Dents
# 61                       Arrache ces dents-là !
# 62                         Range les affaires !
# 63                          C'est leurs dents !
# 64                              De beaux yeux !
# 65         C'est quelqu'un qui honore l'homme !
# 66                            Élève un mouton !
# 67                          Élève des moutons !
# 68                           Tu as vu l'homme ?
# 69                           Tu as vu l'homme ?
# 70      Tu as vu l'homme dont il fut question ?
# 71                     Tu as reconnu sa femme ?
# 72         Tu as reconnu sa femme d'autrefois ?
# 73                  Tu te rappelles son amour ?
# 74      Tu te rappelles son amour d'autrefois ?
# 75                       Tu vois ce garçon-là ?
# 76                      Tu vois, ce garçon-là ?
# 77                       Tu vois ce garçon-là ?
# 78         Tu reconnais ton amour d'autrefois ?
# 79                              C'est un homme.
# 80                            C'est des femmes.
# 81                            Ce fut un homme !
# 82                   Ce fut un homme, un vrai !
# 83                       Ils ont été bûcherons.
# 84                                  Tu es parti
# 85                             Tu es un homme !
# 86                          Nous sommes partis.
# 87                     Nous sommes des hommes !
# 88                            Ce fut un homme !
# 89                                     Il a été
# 90                           C'est un bûcheron.
# 91                           C'est un bûcheron.
# 92                          C'est le bûcheron !
# 93           C'est votre bûcheron d'autrefois !
# 94                                Il est parti.
# 95                     Sois un être de raison !
# 96                    Ce n'est pas le tambour !
# 97                 Sois quelqu'un de studieux !
# 98                            C'est l'étudiant.
# 99             C'était son hôte habituellement.
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %%
new_sent_extraction.extract_sentences(save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                               french  \
# 0                Ya di ban jaõgkat ?
# 1                Ya di ban jaõgkat ?
# 2             Ya di seen ban xarit ?
# 3                       Soo dee góor
# 4                       Soo dee góor
# 5                 Dil nitu réew mi !
# 6                 Dil nitu réew mi !
# 7                  Dil nitu nit ñi !
# 8                  Dil nitu nit ñi !
# 9               Yaa daan ganu Mustaf
# 10                  Du sabar gu rëy.
# 11           Xammee naa nagu Tugël !
# 12           Xammee naa nagi Tugël !
# 13            Gis naa doomu ndaw si.
# 14          Gis naa doomi jigéen ja.
# 15        Gis õga doomu jigéen jan ?
# 16       Tann õga doomu benn jigéen.
# 17       Tann õga doomu benn jigéen.
# 18   Gis naa doomu nitu Gaanjóol gi.
# 19  Gis naa këru xaritu Biraayim wi.
# 20              Gis naa kër xaritam.
# 21                  Kër Biraayim la.
# 22                    Boroom kër la.
# 23             Dëkku Séeréer bii la.
# 24             Gii dëkku Séeréer la.
# 25       Gan dëkku Séeréer õga wax ?
# 26       Dëkku Séeréer ban õga wax ?
# 27      Béppu dëkku Séeréer set na !
# 28      Dëkku béppu Séeréer set na !
# 29  Amul ardo benn Jéeri boo xamul !
# 30                       nit ku góor
# 31                       nit ku góor
# 32                       nit ñu góor
# 33                       nit ñu góor
# 34           Gis naa xar mu góor ma.
# 35           Gis naa xar mu góor ma.
# 36          Ray na gaynde gu jigéen.
# 37       Ray na gaynde yu jigéen ya.
# 38      Tannal fasu Waalo wu jigéen.
# 39                   Nit ku góor la.
# 40                  Nit ku baax la !
# 41                  Nit ku baax la !
# 42               Nit ku baaxoon la !
# 43                Nit ku baaxul la !
# 44              Nit ku baaxkoon la !
# 45              Nit ki baaxkoon la !
# 46           Nit kooka baaxkoon la !
# 47                    Nit doõõ õga !
# 48                    Nit doõõ õga !
# 49               Xaleel rekk õgeen !
# 50                     Mag dëgg là !
# 51                     Góor gi dem ?
# 52                Ndax waa ji génn ?
# 53                          Maay dem
# 54                          Mu dem ?
# 55                            Ku dem
# 56                     Ndax lan am ?
# 57                   Ndax kenn dem ?
# 58                 Noona kooku dem !
# 59                   Góor gii demoon
# 60                   Maa õgii demoon
# 61                 Li mu waxoon la !
# 62                 Li mu waxoon la !
# 63                 Su góor gi bëggée
# 64                   Bi õga ñëwée la
# 65                       Moo demkoon
# 66                     Góor gi demul
# 67                     Yaa demulwoon
# 68                      Ku demkoonul
# 69                      Kooku dem na
# 70                   Ñeñeen dem nañu
# 71                       Moom dem na
# 72                 Góor gi demoon na
# 73                Góor gi demkoon na
# 74                       Góor gi dem
# 75                     Góor gi dem ?
# 76                     Gor gi dem na
# 77                 Góor ñi gisuñu la
# 78                     Na gor gi dem
# 79                        Na õga dem
# 80                        Yaa demoon
# 81                         Bu mu dem
# 82                        Buleen dem
# 83                      Noona mu dem
# 84                   Su waxee më ñëw
# 85                   Ba õga demee la
# 86             Bi jigéen ji ñëwée la
# 87                       Demkoon naa
# 88                     Deekoon õgeen
# 89                Góor gi deekoon na
# 90                Waa ji liggéeykoon
# 91                     Li mu defkoon
# 92                 Ndax yaa begkoon.
# 93    Ya õgi demkoon doo ka fa fekk.
# 94               Góor gi moo ñëwkóon
# 95     Mi õgiy laaj ndax demkoon õga
# 96                            Kaay !
# 97                          Dem fa !
# 98                        Seeti ka !
# 99                       Gisi leen !
#
#                                                 wolof
# 0                               Tu es quel étudiant ?
# 1                       Tu es quel genre d'étudiant ?
# 2                       Quel ami serais-tu pour eux ?
# 3                                      Si tu es homme
# 4                                   Si tu es un homme
# 5                             Sois homme de ce pays !
# 6                          Sois un homme de ce pays !
# 7                     Sois l'homme de tout le monde !
# 8                      Sois l'homme de la situation !
# 9              Tu étais d'habitude l'hôte de Mustapha
# 10                     Ce n'est pas un grand tambour.
# 11                  Je reconnais une vache d'Europe !
# 12                 Je reconnais les vaches d'Europe !
# 13                        J'ai vu le fils de la dame.
# 14                    J'ai vu les enfants de la dame.
# 15                 Tu as vu le fils de quelle femme ?
# 16                 Tu as choisi la fille d'une femme.
# 17           Tu as choisi la fille d'une autre femme.
# 18            J'ai vu le fils de l'homme de Gandiole.
# 19             J'ai vu la maison de l'ami de Birayim.
# 20                      J'ai vu la maison de son ami.
# 21                        C'est la maison de Birayim.
# 22                         C'est un maître de maison.
# 23                       C'est la ville de ce Sérère.
# 24                       C'est cette ville de Sérère.
# 25                 Tu parles de quelle ville Sérère ?
# 26             Tu parles de la ville de quel Sérère ?
# 27                   Tout village Sérère est propre !
# 28             Le village de tout Sérère est propre !
# 29  Il n'est Ardo d'aucun Dieri que tu ne connaiss...
# 30                       être humain de sexe masculin
# 31                                              homme
# 32                                             hommes
# 33                     êtres humains de sexe masculin
# 34                               J'ai vu l'ovin mâle.
# 35                            J'ai vu le mouton mâle.
# 36                               Il a tué une lionne.
# 37                              Il a tué les lionnes.
# 38                        Choisis une jument du Wâlo.
# 39                                    C'est un homme.
# 40                          C'est un homme généreux !
# 41                          C'est quelqu'un de bien !
# 42                       C'est un homme qui fut bon !
# 43                 C'est un homme qui n'est pas bon !
# 44                   C'est un homme qui eût été bon !
# 45                  C'est cet homme qui eût été bon !
# 46               C'est cet homme-là qui eût été bon !
# 47                        Tu es un homme simplement !
# 48                        Tu es uniquement un homme !
# 49                  Vous êtes des enfants seulement !
# 50                 C'est un homme mûr véritablement !
# 51                           L'homme peut-il partir ?
# 52                            Que la personne sorte ?
# 53                          C'est moi qui vais partir
# 54                                   Peut-il partir ?
# 55                                          Qui a été
# 56                         Afin qu'il se passe quoi ?
# 57                         Quelqu'un peut-il partir ?
# 58                         Alors celui-ci s'en alla !
# 59                                Cet homme qui a été
# 60                                 Voila que j'ai été
# 61                             C'est ce qu'il a dit !
# 62                C'est ce qu'il a dit qui est vrai !
# 63                                 Si l'homme accepte
# 64                             C'est quand tu es venu
# 65                          C'est lui qui serait allé
# 66                                L'homme n'a pas été
# 67                          C'est toi qui n'a pas été
# 68                             Qui ne serait pas allé
# 69                                 Celui-là est parti
# 70                                D'autre sont partis
# 71                                   Lui il est parti
# 72                                  L'homme avait été
# 73                                    L'homme eut été
# 74                                     L'homme partit
# 75                                Que l'homme parte ?
# 76                                  L'homme est parti
# 77                         Les hommes ne t'ont pas vu
# 78                                  Que l'homme parte
# 79                                      Que tu partes
# 80                             C'est toi qui es parti
# 81                                 Qu'il ne parte pas
# 82                                      Ne partez pas
# 83                                    Alors il partit
# 84                               S'il parle, je viens
# 85                        C'est lorsque tu t'en allas
# 86                      C'est lorsque la femme arriva
# 87                                    Je serais parti
# 88                                  Vous seriez morts
# 89                                L'homme serait mort
# 90                          L'homme qui eût travaillé
# 91                                  Ce qu'il eût fait
# 92              Car c'est toi qui eûsses été heureux.
# 93                    Tu aurais été sans l'y trouver.
# 94                      C'est l'homme qui serait venu
# 95                        Il demande si tu aurais été
# 96                                            Viens !
# 97                                            Vas-y !
# 98                                       Va le voir !
# 99                                      Va les voir !
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %%
new_sent_extraction.extract_sentences(save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                             french                                       wolof
# 0                 Wut leen ci biir                   Cherche-les à l'intérieur
# 1                          Démal !                                        Va !
# 2                         Génnal !                                      Sors !
# 3                          Génnéel                                 Fais sortir
# 4                       Kaayleen !                                     Venez !
# 5                  Demleen foofu !                              Allez là-bas !
# 6                        Nileen ka                                   Dites-lui
# 7                      Nileen leen                                  Dites-leur
# 8                      Gor gii dem                    Mais cet homme est parti
# 9                      Gor gii dem                         Cet homme qui a été
# 10                   Gor gii dem ?                       Que cet homme parte ?
# 11                         Moo dem                     C'est lui qui est parti
# 12           Maa õgi dem ci dara !              Voilà que j'ai été pour rien !
# 13                        Moo bëgg                          C'est lui qui aime
# 14           Mi õgii dem ba delusi       Voilà qu'il a été et qu'il est revenu
# 15                     Fu mu dem ?                             Où a-t-il été ?
# 16                      Fu mu bëgg                                  Où veut-il
# 17                      Fu mu bëgg                       Quelle partie veut-il
# 18                       Bu ñu dem                          Qu'il ne parte pas
# 19                 Góor gi bëgg na                                L'homme veut
# 20                  Yéen dem õgeen                         Vous, vous avez été
# 21                 Yéen bëgg õgeen                           Vous, vous voulez
# 22                   Góor gi demul                         L'homme n'a pas été
# 23                   Góor gi demul                         L'homme ne part pas
# 24                  Góor gi bëggul                         L'homme ne veut pas
# 25                  Góor gi bëggul                       L'homme n'a pas voulu
# 26                     Suñu bëggul                        S'ils ne veulent pas
# 27                          Demuma                               Je n'irai pas
# 28                          Demuma                             Je n'ai pas été
# 29                         Bëgguma                              Je ne veux pas
# 30    Su góor gi nëwée lépp baax !                Si l'homme vient, tout ira !
# 31         Bu nu demee lépp baax !                    Quand on ira, tout ira !
# 32                Bi õga demee la.                      C'est quand tu as été.
# 33               Ba waa ji dee la.       C'est à l'époque où mourut cet homme.
# 34                 Góor gii demoon                   Cet homme qui était parti
# 35                Góor gii bëggóon                        Cet homme qui aimait
# 36                Góor gii bëggóon                   Cet homme qui avait voulu
# 37                Góor gii bëggóon                       Cet homme qui voulait
# 38                      Moo demoon                     C'est lui qui avait été
# 39  Yaa õgii demoon fu ñu la tere.  Voilà que tu as été dans un lieu interdit.
# 40                  Fu mu demoon ?                           Où avait-il été ?
# 41           Noonu mu demoon foofa         Comme il avait ainsi été en ce lieu
# 42                       Su demoon                              S'il avait été
# 43                    Bu demulwoon                        S'il n'avait pas été
# 44                Waa ji demulwoon                         L'homme n'a pas été
# 45                 Góor gi demkoon                         L'homme qui eut été
# 46                     Yaa ñëwkóon                   C'est toi qui serais venu
# 47                   Li mu defkoon                     Ce qu'il aurait à faire
# 48                     Demkoon õga                             Tu serais parti
# 49               Waa ji demkoon na                     L'individu serait parti
# 50               Waa ji demkoon na                    L'individu devait partir
# 51                         Demal !                                        Va !
# 52                       Demleen !                                     Allez !
# 53                    Moo doon dem                        C'est lui qui allait
# 54                    Moo daan dem         C'est lui qui allait habituellement
# 55                      Maa di dem                          C'est moi qui pars
# 56                      Maa di dem                   C'est moi qui dois partir
# 57                Moo di Lawbe bi.                             C'est le Laobe.
# 58                  Góor gi di bày                             L'homme cultive
# 59                  Góor gi di bày                        Mais l'homme cultive
# 60                  Góor gi du bày                    L'homme ne cultivera pas
# 61                Góor gi dana dem                                 L'homme ira
# 62               Góor gi dana demi                                 L'homme ira
# 63                       Maa demul                  C'est moi qui n'ai pas été
# 64               Góor gi moo demul                         L'homme n'a pas été
# 65               Waa jii moo demul                  Cette personne n'a pas été
# 66                Yéena dikkulwoon                       Personne n'était venu
# 67                   Moo demkoonul                 C'est lui qui n'eût pas été
# 68                      Man demuma                         Moi je n'ai pas été
# 69                      Man demuma                           Moi je n'irai pas
# 70                 Yaa õgi demuloo                        Toi, tu n'as pas été
# 71                 Yaa õgi demuloo              Toi que voilà, tu n'as pas été
# 72             Góor gaa õgi dikkul              L'homme est là, il ne vint pas
# 73                 Giskóonuma leen                    Je ne vous eusse pas vus
# 74               Yéen demuleenwoon                   Vous, vous n'avez pas été
# 75                  Gisu leen woon                     Il ne les avait pas vus
# 76             Gisu leen leen woon                   Vous ne les aviez pas vus
# 77               Gisu leen fa kenn                  Vous n'y aviez vu personne
# 78           Gisuleen fa woon kenn                    Tu n'y avais vu personne
# 79                      Demkoonuma                         Je n'aurais pas été
# 80                      Waxkoonuñu                    Nous n'aurions pas parlé
# 81                   Giskoonuñu ka                   Nous ne l'eussions pas vu
# 82                    Gisu la woon                        Il ne t'avait pas vu
# 83                  Demuma fa woon                        Je n'y avais pas été
# 84           Maa di jaõgalékat bi.                    C'est moi le professeur.
# 85                   Loolu di guy.                       Cela c'est un baobab.
# 86                 Góor gii di wax                           L'homme qui parle
# 87                   Waa ji di wax                    Cette personne qui parle
# 88                  Góor gi di dem                            L'homme qui part
# 89                  Góor gi di dem                             L'homme partant
# 90                 Góor gii di dem                          Cet homme qui part
# 91                  Góor gi di dem                                Góor giy dem
# 92              Waa ji doon Lawbe.                  L'individu était un Laobe.
# 93              Mu doon Lebu Yoff.                     Il était Lebou de Yoff.
# 94              Mu doon Lebu Yoff.                           C'était un Lebou.
# 95                    Moo doon wax                       C'est lui qui parlait
# 96                Ma õgee doon dem                        Le voilà qui partait
# 97                  Yeena doon dem                C'est vous qui alliez partir
# 98                    Yaa daan dem      C'est toi qui avais l'habitude d'aller
# 99            Góor gi daan liggéey          L'homme qui travaillait d'habitude
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                                 french  \
# 0                      Yaa daawoon dem
# 1                    Kooku daawoon dem
# 2                 Góor gii daawoon dem
# 3                           Su dee dem
# 4                           Su dee dem
# 5                             Su demee
# 6                             Su demee
# 7                             Su demee
# 8                           Su dee dem
# 9                           Su dee dem
# 10                         Bi mu demee
# 11                        Su dee Lawbe
# 12                    Su dee Lawbe Rao
# 13            Su kii dee doomu Birayim
# 14                    Yaa doonkoon wax
# 15                   Yaa doonkoon falu
# 16                         Maa dul dem
# 17                Wool góor gi dul dem
# 18                    Wool kee dul dem
# 19                    Wool kee dul dem
# 20                Moo dul Lawbe Bawal.
# 21          Wool xale yi dul dem fenn.
# 22                 Su ñëwul dana xam !
# 23                 Su ñëwul dana xam !
# 24                    Su dulwoon Lawbe
# 25              Waa ji moo dulwoon dem
# 26                   Moo dawulwoon ñëw
# 27                 Góor gi daawul wax.
# 28                           Danaa dem
# 29                     Ñoom danañu wax
# 30                    Góor gi dana dem
# 31              Jigéen ñi danañu naõgu
# 32                     Dil nitu dëgg !
# 33                         Dil noppi !
# 34                            Duma dem
# 35                   Góor gi du ñibbi.
# 36             Góor gi du tëggu wurus.
# 37                           Doo ñëw ?
# 38                           Doo ñëw ?
# 39                     Doo nitu jamm !
# 40                     Doo nitu jamm !
# 41                        Duõgeen lekk
# 42                          Duñu lekki
# 43                 Du woon góoru Ndar.
# 44                         Du woon dem
# 45                    Duõgeen woon ñëw
# 46                   Yaw daawuloo coow
# 47                 Nit ñi daawuñu coow
# 48                  Daawuloo woon coow
# 49                     Ñii daawuñu dem
# 50  Góor gi doonkoon na boroom xamxam.
# 51        Yaw doonkoon õga suñu njiit.
# 52         Nit ñi doonkoonuñu ay kaaõ.
# 53                            Dafa dem
# 54                 Gor gi dafa demul ?
# 55                    Ñii dañu demul ?
# 56                 Nee dañu demul woon
# 57                    Kii dafa demkoon
# 58                    Kii dafa demkoon
# 59                  Ñee dañu demulkoon
# 60                   Dafa di nitu tay.
# 61                        Dafa di dem.
# 62                        Dafa di dem.
# 63                Dafa doon nitu dëgg.
# 64                  Dafa doon liggéey.
# 65               Daõga daawul liggéey.
# 66            Dañu doonkoon nitu alal.
# 67                             Maa dem
# 68                            Dama dem
# 69                            Dama dem
# 70                             Dem naa
# 71                            Maay dem
# 72                          Maa di dem
# 73                           Damay dem
# 74                         Dama di dem
# 75                           Dinaa dem
# 76                         Dana di dem
# 77                    Daan na di génn.
# 78                    Daawul di feeñu.
# 79             Moo daawoon di liggéey.
# 80                                 man
# 81                                moom
# 82                                 ñun
# 83                                yéen
# 84                                ñoom
# 85                   Gis na ma man mi.
# 86                   Gis na ma man mi.
# 87                  Yaw moomu laa wax.
# 88                    Ñun ñii lay set.
# 89                   Yéen ñan la wax ?
# 90                   Yéen ñan la wax ?
# 91                   Yéen ñan la wax ?
# 92                   Yéen ñan la wax ?
# 93                 Yéen ñépp laa wax !
# 94                   Yaw doõõ laa wax.
# 95                   Yaw doõõ laa wax.
# 96               Yawum Masaar laa wax.
# 97                         Yaw dem õga
# 98          Góor gi waxtaan na ag yaw.
# 99          Góor gi waxtaan na ag yaw.
#
#                                               wolof
# 0            C'est toi qui avais l'habitude d'aller
# 1             Celui-là qui avait l'habitude d'aller
# 2              L'homme qui avait l'habitude d'aller
# 3               Alors qu'il sera en train de partir
# 4                                         S'il part
# 5                                    S'il est parti
# 6                                   Une fois là-bas
# 7                                         S'il part
# 8                                Une fois en chemin
# 9                                  Quand il partira
# 10                                  Lorsqu'il a été
# 11                                   S'il est Laobe
# 12                            S'il est Laobe de Rao
# 13                  Si celui-ci est fils de Birayim
# 14                       C'est toi qui aurais parlé
# 15                     C'est toi qui eusses été élu
# 16                        C'est moi qui ne pars pas
# 17                  Appelle l'homme qui ne part pas
# 18                 Appelle celui-là qui ne part pas
# 19              Appelle celui-là qui ne partira pas
# 20           C'est lui qui n'est pas Laobe du Baol.
# 21      Appelle les enfants qui n'iront nulle part.
# 22                    S'il ne vient pas, il verra !
# 23           S'il ne vient pas, eh bien, il verra !
# 24                           S'il n'était pas Laobe
# 25      C'est ce personnage qui n'allait pas partir
# 26    C'est lui qui n'avait pas l'habitude de venir
# 27          L'homme ne parlait pas, habituellement.
# 28                                           J'irai
# 29                                    Eux parleront
# 30                                  L'homme partira
# 31                           Les femmes accepteront
# 32                           Sois homme de vérité !
# 33                                       Tais-toi !
# 34                                    Je n'irai pas
# 35                L'homme ne rentrera pas chez lui.
# 36                    L'homme n'est pas un orfèvre.
# 37                             Tu ne viendras pas ?
# 38                             Tu ne viendras pas ?
# 39                      Tu n'es pas homme de paix !
# 40                   Tu n'es pas un homme de paix !
# 41                               Vous ne mangez pas
# 42                           Ils ne vont pas manger
# 43          Ce n'était pas un homme de Saint-Louis.
# 44                           Il ne serait pas parti
# 45                         Vous ne seriez pas venus
# 46                   Tu ne bavardais pas en général
# 47  Les gens n'étaient pas, habituellement, bavards
# 48                Tu ne bavardais pas, généralement
# 49             Ceux-ci n'allaient pas, généralement
# 50                       L'homme eût été un savant.
# 51                   Toi tu eusses été notre guide.
# 52          Les gens n'eussent pas été des maîtres.
# 53                                     Il est parti
# 54                    L'homme, il n'est pas parti ?
# 55                     Ceux-ci ne sont pas partis ?
# 56                            Ceux-là n'ont pas été
# 57                            Celui-ci serait parti
# 58                           Celui-ci allait partir
# 59              C'est ceux-là qui n'eussent pas été
# 60                    C'est un homme de son époque.
# 61                              C'est lui qui part.
# 62                                  Il doit partir.
# 63                        C'est un homme de vérité.
# 64                                  Il travaillait.
# 65                Tu ne travaillais pas d'habitude.
# 66                Nous serions des gens de fortune.
# 67                             C'est moi qui ai été
# 68                               C'est que j'ai été
# 69                 C'est que j'ai effectivement été
# 70                                         J'ai été
# 71                               C'est moi qui pars
# 72                               C'est moi qui pars
# 73                                  Moi je partirai
# 74                                  Moi je partirai
# 75                                      Je partirai
# 76                          Il a l'habitude d'aller
# 77                   Il avait l'habitude de sortir.
# 78             Il ne se manifestait pas d'habitude.
# 79    C'est lui qui avait l'habitude de travailler.
# 80                                              moi
# 81                                              lui
# 82                                             nous
# 83                                             vous
# 84                                              eux
# 85                              Il m'a vu moi-même.
# 86                    Il m'a vu moi-même que voilà.
# 87                            Je parle de toi-même.
# 88                   C'est nous-même qu'il cherche.
# 89                               Il parle de vous ?
# 90                        Il parle de qui de vous ?
# 91                      Il parle desquels de vous ?
# 92                    Il parle desquelles de vous ?
# 93                          Je parle de vous tous !
# 94                          Je ne parle que de toi.
# 95                            Je parle de toi seul.
# 96                Je te parle à toi fils de Massar.
# 97                                    Toi tu as été
# 98                        L'homme a causé avec toi.
# 99                        L'homme a parlé avec toi.
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %%
new_sent_extraction.extract_sentences(save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                                 french  \
# 0                      Yaa daawoon dem
# 1                    Kooku daawoon dem
# 2                 Góor gii daawoon dem
# 3                           Su dee dem
# 4                           Su dee dem
# 5                             Su demee
# 6                             Su demee
# 7                             Su demee
# 8                           Su dee dem
# 9                           Su dee dem
# 10                         Bi mu demee
# 11                        Su dee Lawbe
# 12                    Su dee Lawbe Rao
# 13            Su kii dee doomu Birayim
# 14                    Yaa doonkoon wax
# 15                   Yaa doonkoon falu
# 16                         Maa dul dem
# 17                Wool góor gi dul dem
# 18                    Wool kee dul dem
# 19                    Wool kee dul dem
# 20                Moo dul Lawbe Bawal.
# 21          Wool xale yi dul dem fenn.
# 22                 Su ñëwul dana xam !
# 23                 Su ñëwul dana xam !
# 24                    Su dulwoon Lawbe
# 25              Waa ji moo dulwoon dem
# 26                   Moo dawulwoon ñëw
# 27                 Góor gi daawul wax.
# 28                           Danaa dem
# 29                     Ñoom danañu wax
# 30                    Góor gi dana dem
# 31              Jigéen ñi danañu naõgu
# 32                     Dil nitu dëgg !
# 33                         Dil noppi !
# 34                            Duma dem
# 35                   Góor gi du ñibbi.
# 36             Góor gi du tëggu wurus.
# 37                           Doo ñëw ?
# 38                           Doo ñëw ?
# 39                     Doo nitu jamm !
# 40                     Doo nitu jamm !
# 41                        Duõgeen lekk
# 42                          Duñu lekki
# 43                 Du woon góoru Ndar.
# 44                         Du woon dem
# 45                    Duõgeen woon ñëw
# 46                  Yaw daawuloo coow.
# 47                Nit ñi daawuñu coow.
# 48                 Daawuloo woon coow.
# 49                    Ñii daawuñu dem.
# 50  Góor gi doonkoon na boroom xamxam.
# 51        Yaw doonkoon õga suñu njiit.
# 52         Nit ñi doonkoonuñu ay kaaõ.
# 53                            Dafa dem
# 54                 Gor gi dafa demul ?
# 55                    Ñii dañu demul ?
# 56                 Nee dañu demul woon
# 57                    Kii dafa demkoon
# 58                    Kii dafa demkoon
# 59                  Ñee dañu demulkoon
# 60                   Dafa di nitu tay.
# 61                        Dafa di dem.
# 62                        Dafa di dem.
# 63                Dafa doon nitu dëgg.
# 64                  Dafa doon liggéey.
# 65               Daõga daawul liggéey.
# 66            Dañu doonkoon nitu alal.
# 67                             Maa dem
# 68                            Dama dem
# 69                            Dama dem
# 70                             Dem naa
# 71                            Maay dem
# 72                          Maa di dem
# 73                           Damay dem
# 74                         Dama di dem
# 75                           Dinaa dem
# 76                         Dana di dem
# 77                    Daan na di génn.
# 78                    Daawul di feeñu.
# 79             Moo daawoon di liggéey.
# 80                                 man
# 81                                moom
# 82                                 ñun
# 83                                yéen
# 84                                ñoom
# 85                   Gis na ma man mi.
# 86                   Gis na ma man mi.
# 87                  Yaw moomu laa wax.
# 88                    Ñun ñii lay set.
# 89                   Yéen ñan la wax ?
# 90                   Yéen ñan la wax ?
# 91                   Yéen ñan la wax ?
# 92                   Yéen ñan la wax ?
# 93                 Yéen ñépp laa wax !
# 94                   Yaw doõõ laa wax.
# 95                   Yaw doõõ laa wax.
# 96               Yawum Masaar laa wax.
# 97                         Yaw dem õga
# 98          Góor gi waxtaan na ag yaw.
# 99          Góor gi waxtaan na ag yaw.
#
#                                                wolof
# 0             C'est toi qui avais l'habitude d'aller
# 1              Celui-là qui avait l'habitude d'aller
# 2               L'homme qui avait l'habitude d'aller
# 3                Alors qu'il sera en train de partir
# 4                                          S'il part
# 5                                     S'il est parti
# 6                                    Une fois là-bas
# 7                                          S'il part
# 8                                 Une fois en chemin
# 9                                   Quand il partira
# 10                                   Lorsqu'il a été
# 11                                    S'il est Laobe
# 12                             S'il est Laobe de Rao
# 13                   Si celui-ci est fils de Birayim
# 14                        C'est toi qui aurais parlé
# 15                      C'est toi qui eusses été élu
# 16                         C'est moi qui ne pars pas
# 17                   Appelle l'homme qui ne part pas
# 18                  Appelle celui-là qui ne part pas
# 19               Appelle celui-là qui ne partira pas
# 20            C'est lui qui n'est pas Laobe du Baol.
# 21       Appelle les enfants qui n'iront nulle part.
# 22                     S'il ne vient pas, il verra !
# 23            S'il ne vient pas, eh bien, il verra !
# 24                            S'il n'était pas Laobe
# 25       C'est ce personnage qui n'allait pas partir
# 26     C'est lui qui n'avait pas l'habitude de venir
# 27           L'homme ne parlait pas, habituellement.
# 28                                            J'irai
# 29                                     Eux parleront
# 30                                   L'homme partira
# 31                            Les femmes accepteront
# 32                            Sois homme de vérité !
# 33                                        Tais-toi !
# 34                                     Je n'irai pas
# 35                 L'homme ne rentrera pas chez lui.
# 36                     L'homme n'est pas un orfèvre.
# 37                              Tu ne viendras pas ?
# 38                              Tu ne viendras pas ?
# 39                       Tu n'es pas homme de paix !
# 40                    Tu n'es pas un homme de paix !
# 41                                Vous ne mangez pas
# 42                            Ils ne vont pas manger
# 43           Ce n'était pas un homme de Saint-Louis.
# 44                            Il ne serait pas parti
# 45                          Vous ne seriez pas venus
# 46                  Tu ne bavardais pas, en général.
# 47  Les gens n'étaient pas, habituellement, bavards.
# 48                Tu ne bavardais pas, généralement.
# 49             Ceux-ci n'allaient pas, généralement.
# 50                        L'homme eût été un savant.
# 51                    Toi tu eusses été notre guide.
# 52           Les gens n'eussent pas été des maîtres.
# 53                                      Il est parti
# 54                     L'homme, il n'est pas parti ?
# 55                      Ceux-ci ne sont pas partis ?
# 56                             Ceux-là n'ont pas été
# 57                             Celui-ci serait parti
# 58                            Celui-ci allait partir
# 59               C'est ceux-là qui n'eussent pas été
# 60                     C'est un homme de son époque.
# 61                               C'est lui qui part.
# 62                                   Il doit partir.
# 63                         C'est un homme de vérité.
# 64                                   Il travaillait.
# 65                 Tu ne travaillais pas d'habitude.
# 66                 Nous serions des gens de fortune.
# 67                              C'est moi qui ai été
# 68                                C'est que j'ai été
# 69                  C'est que j'ai effectivement été
# 70                                          J'ai été
# 71                                C'est moi qui pars
# 72                                C'est moi qui pars
# 73                                   Moi je partirai
# 74                                   Moi je partirai
# 75                                       Je partirai
# 76                           Il a l'habitude d'aller
# 77                    Il avait l'habitude de sortir.
# 78              Il ne se manifestait pas d'habitude.
# 79     C'est lui qui avait l'habitude de travailler.
# 80                                               moi
# 81                                               lui
# 82                                              nous
# 83                                              vous
# 84                                               eux
# 85                               Il m'a vu moi-même.
# 86                     Il m'a vu moi-même que voilà.
# 87                             Je parle de toi-même.
# 88                    C'est nous-même qu'il cherche.
# 89                                Il parle de vous ?
# 90                         Il parle de qui de vous ?
# 91                       Il parle desquels de vous ?
# 92                     Il parle desquelles de vous ?
# 93                           Je parle de vous tous !
# 94                           Je ne parle que de toi.
# 95                             Je parle de toi seul.
# 96                 Je te parle à toi fils de Massar.
# 97                                     Toi tu as été
# 98                         L'homme a causé avec toi.
# 99                         L'homme a parlé avec toi.
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                     french                                   wolof
# 0         Yaa ka gis moom.             C'est toi qui l'as vu, lui.
# 1   Yaa ka gis moom Samba.      C'est toi qui l'as vu, lui, Samba.
# 2                       ma                                      me
# 3                       ka                                      te
# 4                     leen                                    vous
# 5                     leen                                     les
# 6              Gis na ma !                             Il m'a vu !
# 7                 Waxu la.                     Il ne te parle pas.
# 8          Gis na ma man !                         Il m'a vu moi !
# 9            Waxu la yaw !             Il ne te parle pas, à toi !
# 10          Yaa õgi tawax.                   Te voilà debout, ici.
# 11             Ñu õgi toog                        Nous voilà assis
# 12           Ma õgii toog.                  Le voilà assis là-bas.
# 13       Mu õgooguu di dem           Le voilà, là-bas, qui s'en va
# 14             Ñu õgoogee.                      Les voilà, là-bas.
# 15           Yaa õgoogule.                           Te voilà, là.
# 16         Ñoonu, ñu õgii.                     Ceux-là, les voilà.
# 17           Man, maa õgi.                          Moi, me voilà.
# 18         Góor gi mi õgi.                      L'homme, le voilà.
# 19           Góor gaa õgi.                      L'homme, le voilà.
# 20             Kenn a õgi.                            En voilà un.
# 21           Keneen a õgi.                      En voilà un autre.
# 22           Ñeneen a õgi.                      En voilà d'autres.
# 23            Ma õgii dem.                         Me voilà parti.
# 24                Maa dem.                     C'est moi qui pars.
# 25     Noonu, man, më dem.  Sur ces entrefaites, moi, je quittais.
# 26        Yaa õgi, dem õga                     Te voila, tu as été
# 27  Waxal góor gi mu dem !               Dis à l'homme de partir !
# 28  Waxal góor gi mu dem !             Dis à l'homme qu'il parte !
# 29   Waxal ñeñeen ñu dem !              Dis à d'autres de partir !
# 30              Mu dem ? ?                           Qu'il parte ?
# 31           Noonu ma dem.         Sur ces entrefaites, je partis.
# 32           Li ñu wax la.            C'est ce que nous avons dit.
# 33    Fi õgeen demkoon la.         C'est là que vous seriez allés.
# 34             Bu më dem !                   Que je ne parte pas !
# 35              Bu-l dem !                           Ne pars pas !
# 36             Bu ñu dem !                        Ne partons pas !
# 37           Bu-leen dem !                         Ne partez pas !
# 38             Bu ñu dem !                 Qu'ils ne partent pas !
# 39                   na ma                                  que je
# 40                     naa                                  que je
# 41                   na mu                                   qu'il
# 42                      na                                   qu'il
# 43                      ki                                   celui
# 44                      ku                                  lequel
# 45                      ku                               quiconque
# 46                      mi                                   celui
# 47                      ma                                   celui
# 48                      mu                                  lequel
# 49                      mu                               quiconque
# 50                      gi                                   celui
# 51                      ga                                   celui
# 52                      gu                                  lequel
# 53                      gu                               quiconque
# 54                  kookii                                   celui
# 55                   kooka                                   celui
# 56                   kooku                               quiconque
# 57                   kooku                                  lequel
# 58                  moomii                                   celui
# 59                   mooma                                   celui
# 60                   moomu                                  lequel
# 61                   moomu                               quiconque
# 62                  googii                                   celui
# 63                   googa                                   celui
# 64                   googu                                  lequel
# 65                   googu                               quiconque
# 66                     kii                                celui-ci
# 67                     kii                                  lequel
# 68                     kuu                      celui-ci tout près
# 69                     mee                                celui-là
# 70                    kile                                celle-ci
# 71                    kule                                celle-ci
# 72                    male                                celle-ci
# 73                     mii                                  lequel
# 74                     mii                                celui-là
# 75                     muu                                celle-ci
# 76                    mile                                celui-là
# 77                    mile                                  lequel
# 78                    mule                                celle-ci
# 79                    mule                                celle-ci
# 80                  kookii                                celui-ci
# 81                  kookii                    celui-ci près de toi
# 82                  kookuu                                celle-ci
# 83                  kookuu                    celle-ci près de toi
# 84                  kookee                                celle-ci
# 85                 moomile                                celui-ci
# 86                 moomule                                celle-ci
# 87                 moomale                                celle-ci
# 88                     nii                                 ceux-ci
# 89                     nuu                                 ceux-ci
# 90                     nuu                     ceux-ci près de toi
# 91                  ñooñee                                 ceux-là
# 92                      yi                               celles-ci
# 93                     yuu                               celles-ci
# 94                   joyee                               celles-là
# 95                  ñooñii                               celles-ci
# 96                  ñooñuu                               celles-ci
# 97                 ñooñale                               celles-là
# 98                  yooyii                               celles-ci
# 99                  Yooyuu                               Celles-ci
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                         french                                          wolof
# 0                      yooyale                                      celles-là
# 1    Yooyale deey bëggu leen !            Ceux-là, il ne les apprécie guère !
# 2    Yooyale deey bëggu leen !              Ceux-là, il ne les apprécie pas !
# 3                          yan                                            qui
# 4                          yan                                         lequel
# 5                          ñan                                            qui
# 6                          ñan                                         lequel
# 7                Gis õga kan ?                                 Tu as vu qui ?
# 8                       Ku dem                              Qui est parti[ ?]
# 9                       Yu daw                           Lesquels ont fui[ ?]
# 10              Ndax kan dem ?                           Afin que parte qui ?
# 11              Ndax kan dem ?                               Afin que parte ?
# 12              Ndax kan dem ?                           Afin que qui parte ?
# 13             Yan ñoo yeksi ?                        Lesquels sont arrivés ?
# 14             Daõga gis kan ?                                 Tu as vu qui ?
# 15             Daõga gis kan ?                          Quel homme as-tu vu ?
# 16                Jan õga gis?                              Lequel as-tu vu ?
# 17                 Kenn nëwul.                                Nul n'est venu.
# 18               Keneen demul.                       Aucun autre n'est parti.
# 19       Góor gi gisul meneen.                L'homme n'en a pas vu un autre.
# 20               Gisul yeneen.                     Il n'en a pas vu d'autres.
# 21                        képp                                        le tout
# 22                        képp                                           tout
# 23                        képp                                         chaque
# 24                        mépp                                        le tout
# 25                        mépp                                           tout
# 26                        mépp                                         chaque
# 27                        lépp                                        le tout
# 28                        lépp                                           tout
# 29                        lépp                                         chaque
# 30                        wépp                                        le tout
# 31                        wépp                                           tout
# 32                        wépp                                         chaque
# 33                        sépp                                        le tout
# 34                        sépp                                           tout
# 35                        sépp                                         chaque
# 36                        bépp                                        le tout
# 37                        bépp                                           tout
# 38                        bépp                                         chaque
# 39                        gépp                                        le tout
# 40                        gépp                                           tout
# 41                        gépp                                         chaque
# 42                        jépp                                        le tout
# 43                        jépp                                           tout
# 44                        jépp                                         chaque
# 45                        ñépp                                           tous
# 46                        ñépp                                    la totalité
# 47                        yépp                                           tous
# 48                        yépp                                    la totalité
# 49    Ana ndox mi õga duyóon ?             Où est l'eau que tu avais puisée ?
# 50              Lépp tuuru na.                        Le tout s'est renversé.
# 51               Lépp jeex na.                            Le tout est épuisé.
# 52     Ñooñu, ñépp dañuy dem !                  Tous ceux-là doivent partir !
# 53     Benn bi rëcc laay seet.            Je cherche celui qui s'est échappé.
# 54     Benn bi rëcc laay seet.       Je cherche celui l'un qui s'est échappé.
# 55    Benn boobule laa la may.                C'est celui-là que je te donne.
# 56    Benn boobule laa la may.  C'est celui-là celui-là l'un que je te donne.
# 57        Seetal ma ñenn ñuu !                        Surveille-moi ceux-là !
# 58        Seetal ma ñenn ñuu !              Surveille-moi les-uns que voilà !
# 59        Benn ban õga gisul ?                        Lequel n'as-tu pas vu ?
# 60        Benn ban õga gisul ?                   L'un lequel n'as-tu pas vu ?
# 61       Fabal benn bii bépp !                                  Prends l'un !
# 62       Fabal benn bii bépp !                        Prends l'un en entier !
# 63       Waxtaan ak kenn kan ?                        Converser avec lequel ?
# 64       Waxtaan ak kenn kan ?                   Converser avec l'un lequel ?
# 65     Fabal benn boobu bépp !                    Prends celui-là en entier !
# 66           Gis na keneen ki.                               Il a vu l'autre.
# 67  Keneen kookale xaritam la.                 Cet autre-là est un ami à lui.
# 68   Keneen kan moo bëgg dem ?                      Qui d'autre veut partir ?
# 69                Mépp mu rëcc                N'importe lequel, qui s'échappe
# 70          Ñépp ñan õga gis ?                           Lesquels as-tu vus ?
# 71          Ñépp ñan õga gis ?                      Tous lesquels as-tu vus ?
# 72                        kenn                                  un seul homme
# 73                   kennu nit                                  un seul homme
# 74                        ñenn                  quelques-uns parmi les hommes
# 75                        yenn                  quelques-uns parmi les hommes
# 76                        ñenn                                 certaines gens
# 77                        yenn                                 certaines gens
# 78                   ñennu nit                                 certaines gens
# 79                   yennu nit                                 certaines gens
# 80                   ñennu nit                  quelques-uns parmi les hommes
# 81                   yennu nit                  quelques-uns parmi les hommes
# 82             kenn ku góor ki                                        un mâle
# 83            keneen ku jigéen                                une autre femme
# 84            keneen ku jigéen                              une autre femelle
# 85            Menn doon na ñëw                             Un seul est arrivé
# 86         Gis naa kooku woon.                              J'ai vu celui-là.
# 87         Gis naa kooku woon.                  J'ai vu celui-là, auparavant.
# 88       Gis naa ñooñale woon.                               J'ai vu ceux-là.
# 89       Gis naa ñooñale woon.                   J'ai vu ceux-là, auparavant.
# 90            Gis naa ki woon.                     J'ai vu celui en question.
# 91            Gis naa ki woon.         J'ai vu celui en question, auparavant.
# 92            Gis naa ka woon.                              J'ai vu celui-là.
# 93            Gis naa ka woon.            J'ai vu celui dont il fut question.
# 94         Kenn ki woon dem na                                 L'un est parti
# 95         Kenn ki woon dem na          L'un, dont il fut question, est parti
# 96      Gis na keneen ki woon.                               J'ai vu l'autre.
# 97      Gis na keneen ki woon.         J'ai vu l'autre, dont il fut question.
# 98                  Kooku la !                               C'est celui-là !
# 99                  Kooku la !                                     Celui-là !
#
# --------------------
#
#
# Which of the groups of batch number 4 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %% [markdown]
# We forgot to replace the "[ ?]" sign by " ?" and add it on the first sentences. But we did it after directly in the csv file.

# %%
new_sent_extraction.extract_sentences(save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#               french                      wolof
# 0        Keneen õga.            Tu es un autre.
# 1        Keneen õga.              Autre, tu es.
# 2        Keneen õga.           Un autre, tu es.
# 3       Ñeñeen lañu.        Il s'agit d'autres.
# 4       Ñeñeen lañu.          Il sont d'autres.
# 5       Ñeñeen lañu.          Autres, ils sont.
# 6           Menn la.             Il est unique.
# 7           Menn la.                Un, il est.
# 8       Ñooñu õgeen.         Vous êtes ceux-là.
# 9       Ñeneen lañu.        Il s'agit d'autres.
# 10      Ñeneen lañu.          Autres, ils sont.
# 11        Ñeneen la.          Ce sont d'autres.
# 12        Ñan lañu ?             Qui sont-ils ?
# 13          Ñan la ?              Qui sont-ce ?
# 14          Ñan la ?               Qui est-ce ?
# 15          Kan la ?               Qui est-ce ?
# 16        Mu di kii.       Mais c'est celui-ci.
# 17   Mu doon kookee.     Mais c'était celui-là.
# 18          Du kenn.         Ce n'est personne.
# 19     Du keneen ki.      Ce n'est pas l'autre.
# 20       Ya di kan ?                Tu es qui ?
# 21       Ya di kan ?    Pour qui te prends-tu ?
# 22  Mu di ñeneen ñi.   Mais ce sont les autres.
# 23                fi                      là où
# 24                fi                  alors que
# 25                fi                    dès que
# 26             foofa                         là
# 27             foofa                      alors
# 28             foofa                à ce moment
# 29                fu                        ici
# 30                fu                         où
# 31             foofu                         là
# 32             foofu          alors à ce moment
# 33                fa                      là où
# 34                ci              à l'intérieur
# 35                ci                     dedans
# 36                ci                      parmi
# 37                ci                        sur
# 38                cu              à l'intérieur
# 39                ca              à l'intérieur
# 40                ca           à cet endroit-là
# 41                ca                        sur
# 42                li                     ce que
# 43                li                     ce qui
# 44             looli                       ceci
# 45             looli                le fait que
# 46                lu                     ce que
# 47                lu              qu'est-ce qui
# 48             loolu                    ce fait
# 49                la                       cela
# 50             loola                       cela
# 51             loola                 ce fait-là
# 52               fii                        ici
# 53            foofii           là a cet endroit
# 54              file           là a cet endroit
# 55           foofile           là a cet endroit
# 56               fuu                        ici
# 57            foofuu        là tout près de toi
# 58            foofuu  là tout près de toi alors
# 59              fule        là tout près de toi
# 60              fule  là tout près de toi alors
# 61           foofale        là tout près de toi
# 62           foofale  là tout près de toi alors
# 63               fee                     là-bas
# 64            foofee                     là-bas
# 65            foofee             à ce moment-là
# 66              fale             à ce moment-là
# 67              fale                     là-bas
# 68           foofale                     là-bas
# 69           foofale             à ce moment-là
# 70               nii                   comme ci
# 71               nii                      ainsi
# 72            noonii                   comme ça
# 73            noonii                      ainsi
# 74              nile                   de cette
# 75               nuu                   comme ci
# 76            noonuu                   comme ça
# 77            noonuu                      ainsi
# 78              nule           de cette manière
# 79               nee                 comme cela
# 80               nee        de cette manière-là
# 81            noonee                 comme cela
# 82              nale                         de
# 83           noonile        de cette manière-ci
# 84           noonule        de cette manière-là
# 85           noonale        de cette manière-là
# 86               lii                       ceci
# 87            loolii                       ceci
# 88              lile                       ceci
# 89           loolule                    ce fait
# 90               luu                       ceci
# 91            looluu                       ceci
# 92              lule                       ceci
# 93           loolule                 ce fait-ci
# 94                le                cela là-bas
# 95            loolee                       cela
# 96              lale                       cela
# 97              lale                     là-bas
# 98              lale                 de fait-là
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                  french                              wolof
# 0               loolale                                 ce
# 1                 Fan ?                          Comment ?
# 2                   fan                            comment
# 3                 Fan ?                De quelle manière ?
# 4                   fan                  de quelle manière
# 5                Naan ?                De quelle manière ?
# 6                  naan                  de quelle manière
# 7                Naan ?                          Comment ?
# 8                  naan                            comment
# 9         Fan õga jëm ?                        Où vas-tu ?
# 10        Nan õga def ?                   Comment vas-tu ?
# 11                 fenn                         en un lieu
# 12                 fenn                         nulle part
# 13                 nenn                  en aucune manière
# 14                 nenn                          une façon
# 15                 lenn                          une chose
# 16         demuloo fenn               tu ne vas nulle part
# 17       demuloo feneen             tu ne vas pas ailleurs
# 18       demuloo feneen   tu ne vas pas dans un autre lieu
# 19       Defal neneen !         Agis d'une autre manière !
# 20       Wutël leneen !              Cherche autre chose !
# 21         Xolal fépp !             Fouille tout endroit !
# 22         Xolal fépp !             Fouille en tout lieu !
# 23         Xolal fépp !           Fouille toute la place !
# 24         Jëlël lépp !                      Prends tout !
# 25         Jëlël lépp !               Prends la totalité !
# 26                 népp                     de toute façon
# 27    Foofu õga dem fu.              Là-même où tu as été.
# 28    Foofu õga dem fu.                Là où tu as été là.
# 29  Fi õga dem foofile.                   Là où tu as été.
# 30       La õga wax la.                  Ce que tu as dit.
# 31       La õga wax la.                    Tu as dit cela.
# 32    Li õga wax loolu.                  Ce que tu as dit.
# 33    Li õga wax loolu.               Tu as dit cela même.
# 34    Ni õga def noonu.               Cela que tu as fait.
# 35    Ni õga def noonu.          Cela même que tu as fait.
# 36            Lii lan ?                             Quoi ?
# 37            Lii lan ?                        Cela quoi ?
# 38         Foofee fan ?                               Où ?
# 39         Foofee fan ?                        Là-bas où ?
# 40         Noonee nan ?                          Comment ?
# 41         Noonee nan ?                    Ainsi comment ?
# 42         Noonee nan ?                  De quelle manière
# 43       Loolule lépp ?                        Tout cela ?
# 44       Foofule fépp ?              Tout cet endroit-là ?
# 45            leneen li                            l'autre
# 46            leneen li                     l'autre partie
# 47            lenn lale                    l'un là-basMark
# 48            lenn lale   l'une des parties qui est là-bas
# 49            lenn lale    l'une des choses qui est là-bas
# 50            lenn lale            l'une des choses là-bas
# 51           lepp loolu                          tout cela
# 52         Leneen lan ?                       Quel autre ?
# 53         Leneen lan ?                   Laquelle autre ?
# 54         Leneen lan ?               Quelle autre chose ?
# 55   Lenn loolule lan ?                 Cet autre lequel ?
# 56            Loolu la.                Voilà ce qu'il est.
# 57            Loolu la.             Voilà ce qu'il en est.
# 58              Fee la.                      C'est là-bas.
# 59       Noonu la woon.                     C'était ainsi.
# 60       Noonu la woon.                         Ainsi fut.
# 61           loolu woon                       cela qui fut
# 62              li woon                         ce qui fut
# 63              li woon                      le fait passé
# 64              fa woon                     cet endroit là
# 65              fa woon                 cet endroit là fut
# 66              na woon          de la manière dont ce fut
# 67      lépp loolu woon                          tout cela
# 68   leneen loolee woon                  cet autre fait-là
# 69   leneen loolee woon            cet autre chose qui fut
# 70       Moo di loola !                       Quel démon !
# 71       Moo di loola !                        Quel être !
# 72      Dafa di leneen.  C'est qu'il s'agit d'autre chose.
# 73      Dafa di leneen.       C'est que c'est autre chose.
# 74      Dafa di leneen.                 C'est autre chose.
# 75          leneen rekk              autre chose seulement
# 76           loolu doõõ                     cela seulement
# 77                 naka                      comme dès que
# 78                 naka                      du moment que
# 79              gannaaw                           derrière
# 80              gannaaw                          après que
# 81              gannaaw                      du moment que
# 82              gannaaw                              après
# 83              soobeek                           tant que
# 84                   ba                          après que
# 85                   ba                 jusqu'au moment où
# 86                   bi                            lorsque
# 87                   bi                       au moment où
# 88                   bu                            lorsque
# 89                   bu                              quand
# 90                   su                            lorsque
# 91                   su                                 si
# 92                   te                           sans que
# 93                   te                          alors que
# 94                   te                               mais
# 95                 ndax                           afin que
# 96                 ndax                         est-ce que
# 97            ndax itam                         afin aussi
# 98                walla                            sauf si
# 99              ba itam                        à moins que
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %% [markdown]
# We forgot to reply one mark in one of the first sentences.

# %%
new_sent_extraction.extract_sentences(save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                             french  \
# 0                          ba itam
# 1                               ni
# 2                           ndegam
# 3                          kon nag
# 4                          kon nag
# 5                               ci
# 6                               ci
# 7                               ak
# 8                               ak
# 9                               ak
# 10                           balaa
# 11                              te
# 12                              te
# 13                            itam
# 14                              ag
# 15                           walla
# 16                           walla
# 17                           waaye
# 18                           wante
# 19                           wante
# 20                           wante
# 21                         te itam
# 22                         ag itam
# 23                         ag itam
# 24                       walla nak
# 25                       walla nak
# 26                              te
# 27                       noona nak
# 28                       noona nak
# 29                              te
# 30                              te
# 31                       noona nak
# 32                           ndeke
# 33                           ndeke
# 34                           ndeke
# 35                           waaye
# 36                           waaye
# 37                           waaye
# 38                              bu
# 39                              na
# 40                         moontin
# 41                         moontin
# 42                         moontin
# 43                         moontin
# 44                Moontin, dem naa
# 45       Gaynde gi dawul, moontin.
# 46       Moontin, xale yi ñëw nañu
# 47                     moontin dey
# 48         Moontin dey, gis naa ka
# 49                     moontin nag
# 50        Moontin nag, bëgg na dem
# 51        Te moontin xamante nañu.
# 52                         bon nag
# 53                         bon nag
# 54            Bon nag, maa õgi dem
# 55             Bonag, dey mu ñibbi
# 56                         kon nag
# 57                         kon nag
# 58                Kon nag, dàwul !
# 59                     kon nag dey
# 60         Kon nag dey, buleen dem
# 61                           waaye
# 62                           waaye
# 63                           waaye
# 64               Waaye, kenn demul
# 65                       waaye sax
# 66                       waaye sax
# 67                       waaye sax
# 68    Waaye sax, kenn dafa dul dem
# 69                       waaye nag
# 70                       waaye nag
# 71                       waaye nag
# 72      Waaye nag, xale yi bëggunu
# 73                        waaye de
# 74    Waaye de, ku mu gis, õga de.
# 75                      wante itam
# 76                      wante itam
# 77             Wante itam, demuloo
# 78   Wande it, xale yi dañu soxor.
# 79                       wande nag
# 80     Wande nag, kenn dégluwu ka.
# 81   Moom daal, ñépp ñibbisi nañu.
# 82                            waaw
# 83                            waaw
# 84                            waaw
# 85       Waaw nak, kenn bëggul dem
# 86        Waaw, waaw ndax dem na ?
# 87                        moom nag
# 88           Moom nak, kenn du wax
# 89                              ba
# 90          Ba, góor gi bëggul dem
# 91                          ba nag
# 92                          ba nag
# 93   Ba nag, sama yaay fafu la gis
# 94               Te demuloo fenn ?
# 95  Te nag, kenn manu fi gis dara.
# 96           Te sax, ma õgii dem !
# 97                          te kat
# 98         Te kat, na õga ma nég !
# 99                           foofu
#
#                                           wolof
# 0                                  ou alors que
# 1                                           que
# 2                                            si
# 3                                   dans ce cas
# 4                                         alors
# 5                                         parmi
# 6                                          dans
# 7                                          avec
# 8                               en compagnie de
# 9                                       grâce à
# 10                                    avant que
# 11                                           et
# 12                                     et aussi
# 13                                        aussi
# 14                                         avec
# 15                                           ou
# 16                                      ou bien
# 17                                    cependant
# 18                                    toutefois
# 19                                    cependant
# 20                                         mais
# 21                                   mais aussi
# 22                                     et aussi
# 23                                    et encore
# 24                                     ou alors
# 25                                     ou enfin
# 26                                        alors
# 27                                        alors
# 28                                   de ce fait
# 29                                   de ce fait
# 30                                       sur ce
# 31                                       sur ce
# 32                                         mais
# 33                                    cependant
# 34                                    toutefois
# 35                                         mais
# 36                                    cependant
# 37                                    toutefois
# 38                                   que ne pas
# 39                                          que
# 40                                  et pourtant
# 41                                    cependant
# 42                           quoi qu'il en soit
# 43                                      en fait
# 44                        Et pourtant, j'ai été
# 45               Le lion n'a pas fui, pourtant.
# 46          Et pourtant, les enfants sont venus
# 47                                  et pourtant
# 48                      Et pourtant, je l'ai vu
# 49                             en dépit de tout
# 50                  Et pourtant, il veut partir
# 51              Et pourtant ils se connaissent.
# 52                                  dans ce cas
# 53                                        alors
# 54                         Dans ce cas, je pars
# 55                    Dans ce cas, qu'il rentre
# 56                                  dans ce cas
# 57                            s'il en est ainsi
# 58                          Dans ce cas, fuis !
# 59                            dans ce cas alors
# 60                         Alors, ne partez pas
# 61                                         mais
# 62                                    cependant
# 63                              malheureusement
# 64                 Malheureusement, nul n'a été
# 65                                   par contre
# 66                                   d'ailleurs
# 67                                     du reste
# 68                          Du reste, nul n'ira
# 69                                   d'ailleurs
# 70                                    toutefois
# 71                              malheureusement
# 72  Malheureusement, les enfants ne veulent pas
# 73                           mais (avec menace)
# 74               Mais, celui qu'il voit, meurt.
# 75                                   mais aussi
# 76                                mais non plus
# 77                    Tu n'as pas été, non plus
# 78  Mais, les enfants sont toute-fois méchants.
# 79                                         mais
# 80            Mais, nul ne lui a prêté oreille.
# 81    Mais, c'est tout le monde qui est rentré.
# 82                                          oui
# 83                                        alors
# 84                                      et puis
# 85          Ainsi donc, personne ne veut partir
# 86            Eh bien, est-ce qu'il est parti ?
# 87                                        ainsi
# 88                          Ainsi, nul ne parle
# 89                                        ainsi
# 90            Ainsi, l'homme ne veut pas partir
# 91                                 de sorte que
# 92                                   ainsi donc
# 93                Ainsi, ma mère n'a pu te voir
# 94                  Et tu n'as été nulle part ?
# 95          D'ailleurs, on ne peut rien y voir.
# 96                   D'ailleurs, je m'en vais !
# 97                                   et surtout
# 98                    Et surtout, attends-moi !
# 99                                           là
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
# You didn't provide a right command ! Please retry
#
# Batch result
#                          french                                     wolof
# 0                     foofu nak                               à ce moment
# 1                     foofu nak                                     alors
# 2   xale yi, foofu nag, ñu mer.           les enfants alors se fâchèrent.
# 3                         Noonu                                     Alors
# 4                         noonu                                     ainsi
# 5                Noonu, mu jog.                    Alors, il se redressa.
# 6                    noonu itam                                     alors
# 7                    noonu itam                       sur ces entrefaites
# 8         Noonu itam, ma noppi.           Sur ces entrefaites, je me tus.
# 9       Noonu itam, ma bañ génn          Mais alors, je refusai de sortir
# 10                    dem õga ?                               tu as été ?
# 11                    déedéed !                                     non !
# 12                      xanaa !                                bien sur !
# 13                      xëyna !                               peut-être !
# 14              Loo gis ci biti                      Qu'as-tu vu dehors ?
# 15                          nit                                     homme
# 16                          nit                                  un homme
# 17                 Kooy waxal ?                         À qui parles-tu ?
# 18                         buur                                       roi
# 19                         buur                                    au roi
# 20                         Ndar                               Saint-Louis
# 21                  Ki kan la ?                     Qui est-ce celui-ci ?
# 22                      jaambur                                 un quidam
# 23                      jaambur                       un certain individu
# 24               Loo bëgg def ?                       Que veux-tu faire ?
# 25                          dem                                    partir
# 26                  Looy ñaan ?                      Tu pries pour quoi ?
# 27                        rafet                                    beauté
# 28                        rafet                            pour la beauté
# 29                     Ku ñëw ?                            Qui est venu ?
# 30                         kenn                                  personne
# 31                     Ku wax ?                             Qui a parlé ?
# 32                       kookuu                                  celui-là
# 33                    Neex na ?                               C'est bon ?
# 34                        Cam !                                   Pouah !
# 35                    Baax na ?                               C'est bon ?
# 36                         Ex !                                      Oh !
# 37                Ana góor gi ?                      Où est le Monsieur ?
# 38                       Dem na                              Il est parti
# 39           Xoolal gii garab !                       Regarde cet arbre !
# 40                      Guy la.                          C'est un boabab.
# 41          Ana boroom kër gi ?              Où est le maître de maison ?
# 42                     Kile la.                           C'est celui-là.
# 43                    Foo jëm ?                               Où vas-tu ?
# 44                     Ci biir.                            À l'intérieur.
# 45                  Ana õgoor ?                             Où est NGor ?
# 46                   Õgoor dem.                           NGor est parti.
# 47                   Õgoor dem.                      Mais NGor est parti.
# 48                    Koo gis ?                            Qui as-tu vu ?
# 49                        Musaa                                    Moussa
# 50                   Loo jënd ?                         Qu'as-tu acheté ?
# 51                        mbubb                                    boubou
# 52                        mbubb                                 un boubou
# 53                      ci biir                             à l'intérieur
# 54                     Du góor.                    Ce n'est pas un homme.
# 55                Ana góor gi ?                          Où est l'homme ?
# 56                    Koo gis ?                             Qu'as-tu vu ?
# 57                      ci biir                             vers celui-ci
# 58                      ci biir                               vers dedans
# 59                     mi õgile                                  le voici
# 60                    Ana kooku                         Où est celui-là ?
# 61                Lu muy jooy ?                         Que pleure-t-il ?
# 62                        rafet                       de n'être pas belle
# 63                        rafet                          d'être pas belle
# 64                    Doo dem ?                          Tu ne pars pas ?
# 65                      Dem naa                                   Je pars
# 66                      Nit la.                           C'est un homme.
# 67           Nit la ci lu wér !                 C'est vraiment un homme !
# 68             Nit la ku baax !                   C'est un homme gentil !
# 69                    Loo gis ?                            Qui as-tu vu ?
# 70                          nit                                  un homme
# 71                   Nit ki ñëw                      L'homme qui est venu
# 72                     Ko gis ?                            Qui as-tu vu ?
# 73                        kooku                                  celui-là
# 74               Kooku ci biir.                   Celui-là à l'intérieur.
# 75                      Koo wax                        De qui parles-tu ?
# 76                    keneen ki                                de l'autre
# 77      Keneen kookule muy woo.               De cet autre qu'on appelle.
# 78                      ca ñoom                                  vers eux
# 79      Mi õgi foofule ci biir.                  Il est là à l'intérieur.
# 80              Dem na ci biir.                Il est allé à l'intérieur.
# 81              Bëgg na õga dem                    Il veut que tu viennes
# 82                   Õgor dem ?                     Ngor peut-il partir ?
# 83                     Ku dem ?                           Qui est parti ?
# 84            Góor gi dem Rao ?             L'homme peut-il aller à Rao ?
# 85          Ku bëgg bii téere ?                       Qui veut ce livre ?
# 86        Ku la may bii téere ?                  Qui t'a donné ce livre ?
# 87                       Ku dem                           Qui est parti ?
# 88                  Góor gu dem                    Quel homme est parti ?
# 89                      Moo dem                 C'est lui qui est parti ?
# 90              Góor gi nit la.                L'homme est sain d'esprit.
# 91        Góor gi nitu Ndar la.            L'homme est un Saint-Louisien.
# 92         Góor gi di xel doõõ.          Cet homme n'est qu'intelligence.
# 93  Berëb yi berëb yu yaa lañu.        Ces lieux sont de vastes étendues.
# 94  Góor gaa õgi, nitu Ndar la.  L'homme le voici, il est Saint-Louisien.
# 95             Góor gi kenn la.                       L'homme est unique.
# 96              Kooku keneen la                   Celui-là c'est un autre
# 97           Berëb bi du foofu.            L'endroit ce n'est pas par-là.
# 98   Mi õgi, benn la ci ndàyam.     Le voilà, il est unique en son genre.
# 99         Ndaje mi ci biir la.           La réunion c'est à l'intérieur.
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# --------------------
#
#
# Finished !

# %%
new_sent_extraction.extract_sentences(save=True, batch_size=100)
# Out:
# Which of the groups of batch number 1 do you consider to be complete sentences (see the file batch.csv) ?
# You didn't provide a right command ! Please retry
#
# Batch result
#                                                french  \
# 0                                         Góor gi dem
# 1                                              Mu dem
# 2                                              Mu dem
# 3                                         Ma ngii dem
# 4                               Góor ñi deekoon nanu.
# 5                                       Maa demulkoon
# 6                                          Góor demul
# 7                                          Góor demul
# 8                                          Góor demul
# 9                                       Góor gi demul
# 10                           Xar yu ñuul dinañu feeñ.
# 11                              Góor gi moo demulwoon
# 12                                 Dem, rafetoon na !
# 13                                Sarxe baaxkoon na !
# 14                                         Man dem në
# 15                                     Man mii demuma
# 16                                     Kooku du nit !
# 17                                         Maa demoon
# 18                                   Më õgile demkoon
# 19                                         Kenn demul
# 20                                     Yéen dem õgeen
# 21                                           Ku dem ?
# 22                                           Ku dem ?
# 23                                   Ñooñii dunu demi
# 24                              Wóoy ! taxul mu yabbi
# 25                                     Dem naa doyunu
# 26                         Demkoon doon na ma fi war.
# 27                                   Bëgguma du yar !
# 28                                        Góor dem na
# 29                                   Góor ñi dem nañu
# 30                             Seen gaynde gi xar la.
# 31                        Seni gaynde yi ay xar lañu.
# 32                         Nit ag gaynde duñu dëkkóo.
# 33                         Nit ag gaynde duñu dëkkóo.
# 34                         Nit ag gaynde duñu dëkkóo.
# 35                       Liggéeykat yi man ag yaw la.
# 36                              Liggéeykat yi ñun la.
# 37                     Liggéeykat ya xale ya la woon.
# 38                                      Dama bëgg dem
# 39                                  Dafa bëgg xaalis.
# 40                                  Dafa bañ rewande.
# 41                                    Bëgg na gëléem.
# 42                                       Gis na ndaw.
# 43                   Góor gi gisul xale boobale woon.
# 44                            Négël xale bu rafet bi.
# 45                             Góor gi bëgg na di dem
# 46  Sërin bi bëgg na mayewoon alalam ji ba mënkoon...
# 47                        Góor gi ragal na juubuwoon.
# 48                            Ndaw si réccu na amoon.
# 49                        Ragal naa joxoon ka doom bi
# 50                               Góor gi bëgg na kii.
# 51                            Góor gi gis na kookale.
# 52                                   Yaw xamuloo kenn
# 53                                  Seetal beneen bi.
# 54                             Góor gi nee mi õgi fi.
# 55                                    Góor gi gisu la
# 56                               Góor gi gisu la woon
# 57                               Góor gi gisóon na la
# 58                              Góor gi giskoon na la
# 59                               Góor gi moo la gisul
# 60                                  Góor gi di la gis
# 61                             Góor gi daan na la gis
# 62                               Góor gi daawu la gis
# 63                              Góor gi giskoon na la
# 64                      Góor gi nee na ma : ci biti !
# 65                                         Waaji nee.
# 66                                       Nil : wóoy !
# 67                                       Nil : wóoy !
# 68                             Góor gi ni : dawleen !
# 69                                Jox na nit ki dara.
# 70                              May na waa ji xaalis.
# 71                           Deõk na jigéen ji walis.
# 72                                  Wax na Musa dara.
# 73                               Góor gi may na Bacc.
# 74           Joxal téere bi doomu nit ku yaru kooku !
# 75                            Deõkël lëf li kenn ki !
# 76                            Deõkël lëf li kenn ki !
# 77                            Deõkël lëf li kenn ki !
# 78                                Jox na la dagit wi.
# 79                                 Abalu la xalima gi
# 80                                 Wutëli leen gaal !
# 81                              Joxoon na la juuti bi
# 82                              Joxu la woon juuti bi
# 83                                    Duma ka ka jox.
# 84                            Wattaliwuma la ka woon.
# 85                                      Gis õga lan ?
# 86                        Aw gaynde ci biir néeg bi !
# 87                                  Wax na ba mi õgi.
# 88                            Laajal ndax mi õgi fi !
# 89                              Sindax bi ci foofuu !
# 90                                   Kañ õga ka gis ?
# 91                                      Tay ci õgoon.
# 92                                     Bëgg õga lan ?
# 93                                tuuti xaalis ci yaw
# 94                                     Kañ ñgay dem ?
# 95                                      Tay, ci subë.
# 96                                       Tay ci subë.
# 97                                          Àna õga ?
# 98                                   Maa õgi ci biti.
# 99                             Maa õgi ci bir kär gi.
#
#                                                 wolof
# 0                               Le Monsieur est parti
# 1                                        Il est parti
# 2                                   Mais il est parti
# 3                               Voilà qu'il est parti
# 4                      Les gens en eussent été morts.
# 5                      C'est moi qui n'aurais pas été
# 6                                       Homme n'a été
# 7                                    Un homme n'a été
# 8                                         Nul n'a été
# 9                                 L'homme n'a pas été
# 10                Les moutons noirs seront retrouvés.
# 11                      C'est l'homme qui n'a pas été
# 12                           Avoir été, eût été bon !
# 13                 L'aumône eut été une bonne chose !
# 14                                       Moi j'ai été
# 15                           Moi-même je n'ai pas été
# 16                 Celui-là n'est pas sain d'esprit !
# 17                               C'est moi qui ai été
# 18                             Voilà que j'aurais été
# 19                                        Nul n'a été
# 20                                      Vous avez été
# 21                                        Qui a été ?
# 22                                    Qui est parti ?
# 23                                Ceux-là n'iront pas
# 24               Aïe ! ne suffit pas pour qu'il lâche
# 25                    « j'ai été » ne nous suffit pas
# 26      J'ai failli être dans l'obligation d'y aller.
# 27             Je ne veux pas est une forme impolie !
# 28                                 Un homme est parti
# 29                             Les hommes sont partis
# 30                         Leur lion c'est un mouton.
# 31                     Leurs lions c'est des moutons.
# 32                       Homme et lion ne cohabitent.
# 33                   Homme et lion ne cohabitent pas.
# 34       Homme et lion ne peuvent cohabiter ensemble.
# 35                 Les travailleurs c'est toi et moi.
# 36                       Les travailleurs c'est nous.
# 37              Les travailleurs c'était les enfants.
# 38                           C'est que je veux partir
# 39                      C'est qu'il veut de l'argent.
# 40                 C'est qu'il déteste l'impolitesse.
# 41                                Il aime le chameau.
# 42                               Il a vu un messager.
# 43                  L'homme n'a pas vu cet enfant-là.
# 44                      Attends la belle jeune fille.
# 45               L'homme veut partir de temps à autre
# 46  Le maître souhaiterait avoir donné toute sa fo...
# 47  L'homme craint d'avoir interrompu son jeûne pa...
# 48          La femme regrette d'avoir eu une fortune.
# 49                Je crains de lui avoir donné la clé
# 50                             L'homme aime celui-là.
# 51                         L'homme a vu cet autre-là.
# 52                            Toi tu connais personne
# 53                                   Cherche l'autre.
# 54                      L'homme affirme qu'il est là.
# 55                              L'homme ne t'a pas vu
# 56                          L'homme ne t'avait pas vu
# 57                                 L'homme t'avait vu
# 58                                L'homme t'aurait vu
# 59                    C'est l'homme qui ne t'a pas vu
# 60                                    L'homme te voit
# 61                                  L'homme te voyait
# 62                           L'homme ne te voyait pas
# 63                                   L'homme t'eût vu
# 64                         L'homme m'a dit : dehors !
# 65                                    Mi õgi ci biti.
# 66                                    Dis : « woy » !
# 67                                             Crie !
# 68                          L'homme de dire : fuyez !
# 69            Il a donné à la personne quelque chose.
# 70                 Il a offert à l'homme de l'argent.
# 71                 Il a confié à la femme une valise.
# 72                   Il a dit à Moussa quelque chose.
# 73                  L'homme a fait un cadeau à Bathe.
# 74             Donnes le livre à ce fils bien élevé !
# 75                           Confie la chose à l'un !
# 76                     Confie la chose à l'un d'eux !
# 77               Confie la chose à l'un d'entre eux !
# 78                           Il t'a donné le morceau.
# 79                       Il ne t'a pas prêté la plume
# 80                      Va leur chercher une barque !
# 81                           Il t'avait remis la taxe
# 82                    Il ne t'avait pas remis la taxe
# 83                         Je ne le lui donnerai pas.
# 84                 Je n'avais pas été te le cueillir.
# 85                                    Tu as vu quoi ?
# 86                          Un lion dans la chambre !
# 87                      Il a tant parlé que le voilà.
# 88                              Demande s'il est là !
# 89                                 Un lézard par là !
# 90                                 Quand l'as-tu vu ?
# 91                        Aujourd'hui dans la soirée.
# 92                                     Tu veux quoi ?
# 93                             un peu d'argent de toi
# 94                                    Quand pars-tu ?
# 95                             Aujourd'hui, le matin.
# 96                             Aujourd'hui, le matin.
# 97                                         Où es-tu ?
# 98                            Me voilà à l'extérieur.
# 99                            Je suis dans la maison.
#
# --------------------
#
#
# Which of the groups of batch number 2 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                            french  \
# 0                Kenn ki ci kaw !
# 1                 Nit la ci lan ?
# 2            Mag la ndax iy atam.
# 3           Dóor na ka ba mi õgi.
# 4           Dóor na ka ba mi õgi.
# 5             Kookule la ci biir.
# 6             Kookule la ci biti.
# 7                      Loo bëgg ?
# 8                 Demoon ba Ndar.
# 9                Dem naa ba Ndar.
# 10          Woo naa ka, ba mi õgi
# 11                           ndax
# 12                           ndax
# 13              Dikk na ndax yaw.
# 14            Waxul ndax góor gi.
# 15        Ñaaw na ndax keneen ki.
# 16         Rusël ndax jigeen ñi !
# 17                             na
# 18                             na
# 19           Dafa reew na xaleel.
# 20                Solul na góor !
# 21       Wayafuloo na sa nday ji.
# 22      Defal naka sa moroom yi !
# 23   Daõga tayal naka keneen kee.
# 24      Daõgeen bëggé naka ñoom !
# 25                           õgir
# 26                           õgir
# 27            May na ka õgir yaw.
# 28          Bayyi ma õgir yalla !
# 29       Dimëlé leen õgir ñooñe !
# 30                        gannaaw
# 31                        gannaaw
# 32   Gis naa xale yi gannaaw yaw.
# 33                             ci
# 34                             ci
# 35                             ci
# 36        Góor gi dem na ci biir.
# 37                 Waxal ci ñii !
# 38            Bul bàkk ci ñooñu !
# 39                Demal ci moom !
# 40                             cu
# 41            Dogul cu seen biir.
# 42              Waxul cu li dara.
# 43                             ca
# 44                             ca
# 45            Demuloowoon ca biir
# 46    Waxuloowoon ca loola dara !
# 47                Dem na ca subë.
# 48                             ba
# 49                             ba
# 50                Negal ba ëlëk !
# 51                Demal ba subë !
# 52                Yéegël ba fii !
# 53            Dem naa ba ci moom.
# 54       Liggéey naa ba ci õgoon.
# 55                             ak
# 56                             ak
# 57                             ak
# 58                 Àndal ak yar !
# 59                 Àndal ak yar !
# 60             Waxal ak ñooñule !
# 61           Jubënti ko ak bant !
# 62       Yobul na fi góor gi xar.
# 63             Waa ji gor la fi !
# 64    Xale ya mbër lañu fa woon !
# 65                     Mi õgi fi.
# 66             Ma õgoogule foofu.
# 67             Ma õgoogule foofu.
# 68           Buur bi buur la fii.
# 69            Bumi bi du fi buur.
# 70      Góor gi dem fee, ana mu ?
# 71                   Là bëggóon ?
# 72                    Demoon fôfu
# 73                     Tukki ëlëk
# 74                    Demna saõx.
# 75          Góor gi rekk a ñëwul.
# 76          Góor gi rekk a ñëwul.
# 77             Góor dëgg du fen !
# 78           Nit doõõ tiitëlu ko.
# 79                Tay danaa dem !
# 80          Waxal ag Samba rekk !
# 81             Gisal Musaa doõõ !
# 82         Defaral ci biir rekk !
# 83                   Musaa rekk !
# 84                 Ci biir doõõ !
# 85                 Nit rekk õga !
# 86              Góor doõõ õgeen !
# 87              Kooku rekk ñëwul.
# 88               Loolu doõõ doyul
# 89              Mi õgi noonu rekk
# 90             Mi õgi noonu rekk.
# 91         Setal keneen ki rekk !
# 92      Waxtaanal ag ñooñu doõõ !
# 93  Joxeel foofu doõõ ñari yoon !
# 94  Joxeel foofu doõõ ñari yoon !
# 95              Yaa õgoogu rekk !
# 96              Yaa õgoogu rekk !
# 97               Loolu laa bëgg !
# 98                   Loolu doõõ !
# 99                Kooku rekk la !
#
#                                               wolof
# 0                           Celui qui est en haut !
# 1             C'est un homme pour quelles raisons ?
# 2             C'est un homme âgé de par ses années.
# 3       Il l'a battu à telle enseigne qu'il est là.
# 4            Il l'a battu à tel point qu'il est là.
# 5                     C'est celui-là à l'intérieur.
# 6                    C'est celui-là qui est dehors.
# 7                                     Que veux-tu ?
# 8               Avoir pu aller jusqu'à Saint-Louis.
# 9                     J'ai été jusqu'à Saint-Louis.
# 10                  Je l'ai appelé, aussi est-il là
# 11                                       à cause de
# 12                                          grâce à
# 13                      Il est venu à cause de toi.
# 14              Il n'a rien dit à cause de l'homme.
# 15                Ce n'est pas gentil pour l'autre.
# 16               Aie de la pudeur pour ces femmes !
# 17                                        comme tel
# 18                                            aussi
# 19                 Il est mal élevé comme un gosse.
# 20                          Habille-toi en garçon !
# 21           Tu n'es pas aussi modeste que ta mère.
# 22                           Fais comme tes pairs !
# 23             Tu es paresseuse comme cet autre-là.
# 24                  Vous êtes aussi avares qu'eux !
# 25                                       à cause de
# 26                                          grâce à
# 27                   Il lui a donné à cause de toi.
# 28            Laisse-moi de grâce, au nom de Dieu !
# 29                    Aide-les à cause de ceux-là !
# 30                                             sauf
# 31                                          excepté
# 32                    J'ai vu les enfants sauf toi.
# 33                                             dans
# 34                                            parmi
# 35                                         au sujet
# 36                  L'homme est allé à l'intérieur.
# 37                      Parle au sujet de ceux-ci !
# 38                  Ne fais pas partie de ceux-là !
# 39                                 Va jusqu'à lui !
# 40                                               de
# 41                      Il ne s'est pas mêlé à eux.
# 42                          Il ne dit rien de cela.
# 43                                                à
# 44                                            parmi
# 45                 Tu n'avais pas été à l'intérieur
# 46                    Tu n'avais rien dit de cela !
# 47                           Il est parti ce matin.
# 48                                                à
# 49                                          jusqu'à
# 50                         Attends jusqu'à demain !
# 51                              Va jusqu'à demain !
# 52                                Monte jusqu'ici !
# 53                            J'ai été jusqu'à lui.
# 54                    J'ai travaillé jusqu'au soir.
# 55                                          grâce à
# 56                                              par
# 57                                             avec
# 58                                      Sois poli !
# 59                            Sois avec politesse !
# 60                             Parle avec ceux-là !
# 61                      Redresse-le avec un baton !
# 62               Il y amena un mouton pour l'homme.
# 63                       L'homme y est magnifique !
# 64                Les gosses y furent formidables !
# 65                                        Il y est.
# 66                                       Il est là.
# 67                                    Le voilà, là.
# 68                        Le roi est souverain ici.
# 69                   Le prétendant n'y est pas roi.
# 70            L'homme qui a été là-bas, où est-il ?
# 71                              Que souhaitais-tu ?
# 72                                      Y avoir été
# 73                                   Voyager demain
# 74                  Il est parti il y a un instant.
# 75                          L'homme n'est pas venu.
# 76                     Seul l'homme n'est pas venu.
# 77                   Un homme de bien ne ment pas !
# 78  Un homme tout simplement ne saurait l'effrayer.
# 79                             J'irai aujourd'hui !
# 80                     Parle avec Samba seulement !
# 81                         Vois Moussa simplement !
# 82        Mets de l'ordre à l'intérieur seulement !
# 83                               Moussa seulement !
# 84                  À l'intérieur tout simplement !
# 85                Tu es un mortel tout simplement !
# 86           Vous êtes des hommes tout simplement !
# 87                    Celui-là n'est pas venu seul.
# 88                     Cela seulement ne suffit pas
# 89                         Le voilà tout simplement
# 90                   Le voilà, là, tout simplement.
# 91                Cherche l'autre tout simplement !
# 92             Cause tout simplement avec ceux-là !
# 93                   Rien que là, donne deux fois !
# 94                    Donne deux fois rien que là !
# 95                       Te voilà tout simplement !
# 96                                 Te voilà, quoi !
# 97                        C'est là ce que je veux !
# 98                                Cela simplement !
# 99                 C'est celui-là tout simplement !
#
# --------------------
#
#
# Which of the groups of batch number 3 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                                 french  \
# 0                 Lëf ki weex na tàll.
# 1                 Lëf ki ñuul na kukk.
# 2                 Lëf ki leer na nàññ.
# 3                Góor gi Musaa dem na.
# 4               Gis naa góor gi Musaa.
# 5                Góor gi, moom demul !
# 6            Jigéen ji, moom waxatul !
# 7                          Góor gi dem
# 8                          Góor gi dem
# 9          Wooyil Musaa moom mi di dem
# 10                    Góor gi mi õgi !
# 11                 Moom, Musaa, dem na
# 12             Gis na ka, moom, Musâ !
# 13             Demal ça moom góor gi !
# 14           Kookule, moom, du naõgu !
# 15        Kii moom dafa naqadi deret !
# 16                      Yaw, yaa õgi !
# 17       Góor gi ak xale bi génn nañu.
# 18  Waa ji ag gëléemam gi dañu niróo !
# 19               Man ak yaw ñooy ànd !
# 20            Kooka ak kile, bokkuñu !
# 21            Kooka ak kile, bokkuñu !
# 22            Kooka ak kile, bokkuñu !
# 23      Yaw walla moom am na ci ku dem
# 24              Góor u Nafi ak Soxna !
# 25           Gis na góor gi ag doomam.
# 26         Bëggulóo xaalis walla alal.
# 27        Duggël ci biir mbaa ci fii !
# 28           Dana tukki tay mbaa ëlëk.
# 29         Jënd na xar, bëy, ganaar...
# 30                           Ibraayima
# 31                                 Dem
# 32                           Ana õga ?
# 33                       Maa õgii... !
# 34                        Kooy waxal ?
# 35                             Musaa !
# 36                         Xalel õga !
# 37                            Demõga ?
# 38                            Yaw la ?
# 39              Góor googule mi õgii !
# 40                            Koo gis?
# 41                    Nit kookule woon
# 42                    Ci biir fiy leer
# 43                 Ci biir kër googule
# 44                          Ku def lii
# 45                           Góor gi !
# 46                       Ana góor gi ?
# 47               Nit la woon ci dagg !
# 48              Õga dem la ñooñu bëgg.
# 49                   Yaw mile mi fii !
# 50                              Ci fii
# 51                   Ci keneen ki ñëw.
# 52      Yéena õgoogule foofu ci biir !
# 53                    Mi õgi foofule !
# 54                       Yaw mile la !
# 55                      Yéen ñile la !
# 56        Góor gi dem ci biir kër gi ?
# 57        Demumawoon fenn tày ci suba.
# 58                        Aminta ñëw ?
# 59                     Su bëggée kañ !
# 60                      Mi õgii dem na
# 61             Na dem ca Laamin Ngom !
# 62        Waaye man sax dama dul ñëw !
# 63        Waaye man sax dama dul ñëw !
# 64        Waaye man sax dama dul ñëw !
# 65                Te bu fi kenn jogé !
# 66            Te nag õgeen dem ñibbi !
# 67                   Ba õga ñëw rekk !
# 68            Te bul ñëw jaõgu ba de !
# 69                Ba yaa õgii di dem !
# 70                   Góor gi waxoon na
# 71                    Te õga dem kat !
# 72                         Góor gi dem
# 73                  Góor gi waxkoon na
# 74                     Samba  mi ñëw ?
# 75                       Góor gi ñëw ?
# 76                 Góor gi xale bi woo
# 77              Ci bir : foofu di leer
# 78                Ana waa ji muy wax ?
# 79                        Koo woowul ?
# 80                     Góor gi mu àndi
# 81               Googu góor mu àndal !
# 82                Kookule õgay waxal !
# 83                    Keneen, ki ñëw !
# 84                  Ci foofu õga jëm !
# 85         Ci foofu ba õgeen dellusi !
# 86                Keneen la ku yeksi ?
# 87                                Waaw
# 88               Yooyu la góor gi bëgg
# 89                 Yaw la ndaw si sopp
# 90                Bëgg naa góor gi ñëw
# 91             Xale bi ne õgeen dugg !
# 92                         Kooy seet ?
# 93                  Góor gi waa ji wax
# 94                Ci kër gi waa ji wax
# 95              Góor gi kenn xamu ko !
# 96             Ci biir foofu, mu bënn.
# 97                       Ci ki mu wax.
# 98                           Baax na ?
# 99                           Baax na ?
#
#                                              wolof
# 0                La chose est d'un blanc éclatant.
# 1                   La chose est d'un noir obscur.
# 2             La chose est d'une clarté lumineuse.
# 3                       Monsieur Moussa est parti.
# 4                         J'ai vu Monsieur Moussa.
# 5                 L'homme, lui, ne s'en alla pas !
# 6                La vieille, elle, ne parla plus !
# 7                            L'homme qui est parti
# 8                            L'homme qui s'en alla
# 9                      Rappelle Moussa qui s'en va
# 10                                 Voila l'homme !
# 11                          Lui, Moussa, est parti
# 12                        Il l'a vu, lui, Moussa !
# 13                      Va voir l'homme lui-même !
# 14                    Celui-là, lui, il refusera !
# 15                  Celui-là a mauvais caractère !
# 16                                 Toi, tu es là !
# 17                L'homme et l'enfant sont partis.
# 18      L'individu et son chameau se ressemblent !
# 19                     Toi et moi irons ensemble !
# 20     Celui-là et celui-ci n'ont rien de commun !
# 21      Celui-là et celui-ci ne se ressemble pas !
# 22  Celui-là et celui-ci ne se ressemble en rien !
# 23          Toi ou lui, il en est un qui est parti
# 24                       Frère de Nafi et Sokkna !
# 25                  Il a vu l'homme et son enfant.
# 26               Tu ne veux ni argent, ni fortune.
# 27                  Pénètre à l'intérieur ou ici !
# 28              Il voyagera aujourd'hui ou demain.
# 29        Il a acheté moutons, chèvres, poulets...
# 30                                        Ibrahima
# 31                                          Partir
# 32                                      Où es-tu ?
# 33                                   Me voici... !
# 34                               A qui parles-tu ?
# 35                                      A Moussa !
# 36                                   Tu es jeune !
# 37                                       Tu pars ?
# 38                                     C'est toi ?
# 39                            Cet homme le voilà !
# 40                                   Qui vois-tu ?
# 41                Cet homme dont il était question
# 42                      Là où il y a de la lumière
# 43                   À l'intérieur de cette maison
# 44                               Qui a fait ceci ?
# 45                                   Le Monsieur !
# 46                            Où est le Monsieur ?
# 47                    C'était un homme en vérité !
# 48    Que tu partes, c'est ce que ceux-là veulent.
# 49                               À toi qui es-là !
# 50                                         Par ici
# 51                    Chez l'autre qui est arrivé.
# 52                   Vous voilà là à l'intérieur !
# 53                                 Il est par-là !
# 54                                C'est toi-même !
# 55                              C'est vous-mêmes !
# 56          L'homme peut-il aller dans la maison ?
# 57             Je n'avais été nulle part ce matin.
# 58                       Aminata peut-elle venir ?
# 59                        Si elle veut, bien sûr !
# 60                          Le voilà, il est parti
# 61                  Qu'il aille chez Lamine NGom !
# 62                    Mais, moi, je n'ai pas été !
# 63               Mais, même moi, je n'ai pas été !
# 64            Mais, même moi, je ne viendrai pas !
# 65                           Et que nul ne bouge !
# 66                     Surtout rentrez chez vous !
# 67                              Que tu approches !
# 68             Et ne viens surtout pas à l'école !
# 69                      Ainsi, tu vas t'en aller !
# 70                             L'homme avait parlé
# 71                                  Surtout pars !
# 72                                   L'homme a été
# 73                               L'homme eût parlé
# 74                           Samba  qui est venu ?
# 75                          L'homme qui est venu ?
# 76                   L'homme que l'enfant a appelé
# 77                À l'intérieur : où il fait clair
# 78                    Où est celui dont il parle ?
# 79                        Qui n'as-tu pas appelé ?
# 80                           L'homme qu'il a amené
# 81                    Cet homme qui l'accompagne !
# 82                   Celui-là avec qui tu parles !
# 83                 L'autre, celui qui est arrivé !
# 84                                  Là où tu vas !
# 85           Là-bas jusqu'à ce que vous reveniez !
# 86                   C'est un autre qui est venu ?
# 87                                             Oui
# 88                C'est ceux-là que l'homme désire
# 89              C'est toi qui aimes la jeune femme
# 90                      Je veux que l'homme vienne
# 91                         L'enfant dit d'entrer !
# 92                               Qui cherches-tu ?
# 93                 L'homme dont parle cet individu
# 94           Dans la maison dont parle le Monsieur
# 95                   Cet homme nul ne le connaît !
# 96                       Là, où il a fait un trou.
# 97                     Chez celui qu'il a indiqué.
# 98                                    C'est bien ?
# 99                                     C'est bon ?
#
# --------------------
#
#
# Which of the groups of batch number 4 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                                  french  \
# 0                            Looy def ?
# 1                         Li waa ji wax
# 2                    Ci foofu õga taxaw
# 3             Góor gi niwul mi õgi fi !
# 4              Góor gii la xale yi wax.
# 5                       Samba õga woo ?
# 6                    Soo demée, mu ñëw.
# 7                     Ci biir õga wax ?
# 8                   Ci biir la ñu jëm ?
# 9              Ci biir la góor gi dugg.
# 10                  Ci biir õgeen jëm ?
# 11                 Ana góor gi mu wax ?
# 12              Kooku la xale yiy wax ?
# 13          Feneen fi la góor gi dëkk ?
# 14                 Man la góor gi woo ?
# 15                 Keneen ki la ñu xam.
# 16                        Man õga woo ?
# 17                         Yaw la bëgg.
# 18               Defe naa mi õgiy ñëw !
# 19                             Lan la ?
# 20              Bëgg na góor gi dellusi
# 21                 Wax naa ko mu ñibbi.
# 22               Góor gi nee ñépp dem !
# 23                   Soo demee, mu ñëw.
# 24               Demal góor gi gis la !
# 25             Góor gi bëgg na õga ñëw.
# 26              Nit ñi nee nañu mu dem.
# 27                       Nit ki ñëw la.
# 28                            Loo gis ?
# 29                        Nit ku baax !
# 30                        Foo kay def ?
# 31                   Ci teen boobu bënn
# 32                       Nit ki ñëw la.
# 33                Xale bi tawat la wax.
# 34               Góor gu baax réer na !
# 35      Góor googule ga nëwoon dellu na
# 36                Gis naa góor gi ñëw !
# 37     Gis naa googii gan gi doon wax !
# 38     Gis naa googii gan gi doon wax !
# 39              Dem naa ci kër gu yaa !
# 40          Keneen ki ñëwulwoon kookee.
# 41                            Foo wax ?
# 42             Feneen fi bëttóon foofu.
# 43                 Feneen fi bëttul la.
# 44             Kenn kooku yeksi lawoon.
# 45            Kenn ki génn ki yeksi na.
# 46                  Gis naa kenn ki ñëw
# 47              Dem na feneen fu rafet.
# 48           Dem naa ci keneen ku baax.
# 49            Toogal ci fépp, fu leer !
# 50               Toogal fépp, fu leer !
# 51                   Ma seetal la lan ?
# 52           Liggéey bii, ba mu sotti !
# 53               Ci biir ! ndax mu dugg
# 54              Jambaar la ba mu dooy !
# 55               Jambaar la ba mu ëpp !
# 56                    Ci fii, ba ma ñëw
# 57                        Ma toog fan ?
# 58                         Ma def lan ?
# 59                 Loolu, ba mu sotti !
# 60               Maa õgi fi ba mu ñëw !
# 61                       Demal ba ñëw !
# 62               Dana dem ba õgeen beg.
# 63                      Ni ka bu mu ñëw
# 64                    Nil waa ji na ñëw
# 65             Tay jii góor gi dana dem
# 66              Góor gi dana dem tay ji
# 67                   Tay jii, bul dem !
# 68                    Bul dem tay jii !
# 69                 Ci biir soo bëggul !
# 70                Soo bëggul, ci biir !
# 71                      Tay, Faatim la.
# 72                      Faatim la, tay.
# 73                    Faatim la, mu ni.
# 74                     Mu ni Faatim la.
# 75                  Ku dem, gaynde la !
# 76             Yaakaar naa góor gi la !
# 77               Mi õgi fi, soo demee !
# 78            Cii fii kon, soo bëggul !
# 79               Kookule la soo demee !
# 80               Kookule la soo demee !
# 81               Soo demee kookule la !
# 82              Soo demee, kookule la !
# 83             Keneen ki la, defe naa !
# 84           Defe naa ni keneen ki la !
# 85             Keneen ki la, defe naa !
# 86                    Defe naa du kii !
# 87                   Na dem su bëggul !
# 88                    Defe naa du ñëw !
# 89            Góor gi dem na, ma defe !
# 90            Góor gi dem la, ma defe !
# 91          Na dugg ci biir su bëggée !
# 92          Na dugg ci biir su bëggée !
# 93          Na dugg su bëggée ci biir !
# 94          Na dugg su bëggée ci biir !
# 95              Defe naa tày dana ñëw !
# 96              Defe naa dana ñëw tày !
# 97        Sa yay nee dana ñëw ci õgoon.
# 98     Sa yay nee na ci õgoon dana ñëw.
# 99  Góor gi nee na soo demee mi õgi fi.
#
#                                            wolof
# 0                                  Que fais-tu ?
# 1                         Ce que cet homme a dit
# 2                                    Là où tu es
# 3              L'homme ne dit pas qu'il est là !
# 4      C'est de l'homme que parlent les enfants.
# 5                  C'est Samba que tu appelles ?
# 6                          Si tu pars, il vient.
# 7               C'est à l'intérieur que tu dis ?
# 8                    Nous allons à l'intérieur ?
# 9      C'est à l'intérieur qu'est entré l'homme.
# 10          C'est à l'intérieur que vous allez ?
# 11                Où est l'homme dont il parle ?
# 12   C'est de celui-là que parlent les enfants ?
# 13     C'est de l'autre côté qu'habite l'homme ?
# 14               C'est moi que l'homme appelle ?
# 15           C'est l'autre que nous connaissons.
# 16                   C'est moi que tu appelles ?
# 17                       C'est toi qu'elle veut.
# 18                        Je crois qu'il vient !
# 19                         Qu'est-ce qu'il y a ?
# 20                  Il veut que l'homme revienne
# 21                     Je lui ai dit de rentrer.
# 22            L'homme demande à tous de partir !
# 23                         Si tu pars, il vient.
# 24                      Va que l'homme te voie !
# 25                  L'homme veut que tu viennes.
# 26            Les gens demandent qu'ils partent.
# 27                   C'est l'homme qui est venu.
# 28                                 Qu'as-tu vu ?
# 29                           Quelqu'un de bien !
# 30                               Où le mets-tu ?
# 31                       Dans ce puits qui coule
# 32                   C'est l'homme qui est venu.
# 33             Il parle de l'enfant qui souffre.
# 34                 Un homme vertueux a disparu !
# 35                L'homme qui vint s'en est allé
# 36                J'ai vu l'homme qui est venu !
# 37               J'ai vu cet homme qui parlait !
# 38             J'ai vu ce visiteur qui parlait !
# 39          J'ai été dans une maison spacieuse !
# 40               Cet autre qui n'était pas venu.
# 41                                   Où dis-tu ?
# 42    Cet autre endroit où il y avait une fuite.
# 43    C'est l'autre endroit qui n'a pas de trou.
# 44               C'est cet autre qui était venu.
# 45        Cet autre-ci qui est sorti est arrivé.
# 46                  J'ai vu l'autre qui est venu
# 47           Il a été dans un autre bel endroit.
# 48        J'ai été chez un autre qui est gentil.
# 49     Mets-toi n'importe où, où il fait clair !
# 50     Mets-toi n'importe où, où il fait clair !
# 51                          Je veille sur quoi ?
# 52  Sur le travail, jusqu'à ce qu'il soit fait !
# 53              À l'intérieur ! pour qu'il entre
# 54            C'est un brave à n'en pas douter !
# 55          Il est « excessivement » courageux !
# 56                Ici, jusqu'à ce qu'il vienne !
# 57                        Où puis-je m'asseoir ?
# 58                           Que dois-je faire ?
# 59        Cela, jusqu'à ce que ce soit terminé !
# 60        Je reste ici jusqu'à ce qu'il vienne !
# 61                               Va et reviens !
# 62           Il ira afin que vous soyez heureux.
# 63                   Dis-lui qu'il ne vienne pas
# 64              Dis à la personne qu'elle vienne
# 65                   Aujourd'hui l'homme partira
# 66                   L'homme partira aujourd'hui
# 67                    Aujourd'hui, ne sors pas !
# 68                     Ne sors pas aujourd'hui !
# 69             À l'intérieur si tu ne veux pas !
# 70            Si tu ne veux pas, à l'intérieur !
# 71                     Aujourd'hui, c'est Fatim.
# 72                     C'est Fatim, aujourd'hui.
# 73                          C'est Fatim, dit-il.
# 74                       Il dit que c'est Fatim.
# 75                     C'est peut-être un lion !
# 76                  Je crois que c'est l'homme !
# 77                        Il est là, peut-être !
# 78                    Ici alors, si tu refuses !
# 79                   C'est celui-là, peut-être !
# 80                    C'est peut-être celui-là !
# 81                    C'est peut-être celui-là !
# 82                   C'est celui-là, peut-être !
# 83                     C'est l'autre, je crois !
# 84                  Je crois que c'est l'autre !
# 85                  Je crois que c'est l'autre !
# 86          Je crois que ce n'est pas celui-ci !
# 87                Qu'il parte s'il ne veut pas !
# 88               Je crois qu'il ne viendra pas !
# 89                 L'homme est parti, je crois !
# 90            C'est l'homme qui part, je crois !
# 91                                 Qu'il entre !
# 92         Qu'il entre à l'intérieur s'il veut !
# 93                       S'il veut qu'il entre !
# 94         S'il veut qu'il entre à l'intérieur !
# 95          Je croie qu'aujourd'hui il viendra !
# 96          Je crois qu'il viendra aujourd'hui !
# 97          Ta mère dit qu'elle viendra ce soir.
# 98          Ta mère dit qu'elle viendra ce soir.
# 99        L'homme dit qu'il serait peut-être là.
#
# --------------------
#
#
# Which of the groups of batch number 5 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                                                french  \
# 0                 Góor gi née na mi õgi fi soo demee.
# 1                             Yan bes õga fa demoon ?
# 2                               Tay, demb, bërki demb
# 3                                   Foo jaõge xerëm ?
# 4                                    Ci ñan õga jëm ?
# 5                              Ci kii, ci kuu, ci kee
# 6                                        Ma may ñan ?
# 7                                     Ñii, ñee, ñooñu
# 8                                     Yaa õgi, mi õgi
# 9                                   Foo jaõge xërëm ?
# 10                                 Ya õgi te mi õgi !
# 11                                 Nit la, nit õga...
# 12                    Ci biir la, ci biir a biir la !
# 13                      Kookule la kookule taxaw la !
# 14                             Kenn la kenn doõõ la !
# 15                        Dem naa, dem õga, dem na...
# 16                    Dem naa, te dem õga, te dem na.
# 17                     Õga dem õga bañ dem dana ñëw !
# 18                                             Fo jëm
# 19                            Ci Séeréer yi ag Pël yi
# 20                                           Té jëm ?
# 21                                    Ci ñi ak ca nee
# 22                               Nit la te góor õga !
# 23                            Kooku la, te keneen la.
# 24                               Dem naa te demuloo !
# 25  Ñëwël ndax xale yi di mbër te it ñu di ay jamb...
# 26  Soppi leen ba ñu di ñeñeen te seeni xalaat di ...
# 27                           Tay ag demb yépp ñëw na.
# 28                                                 te
# 29                                                 te
# 30                                                 te
# 31                                               mbaa
# 32                                               mbaa
# 33                     Daõgeen di naõgu mbaa du dem !
# 34                                     Gis naa Samba.
# 35                                            Samba ?
# 36                                       Waaw Samba !
# 37                                 Gis naa ka ci bir.
# 38                                       Ci bir sax ?
# 39                                      Waaw ci bir !
# 40                                   Xam na kookule ?
# 41                                              Kii ?
# 42                                      Waw kookule !
# 43                                   Gis naa ka fii !
# 44                                           Ci fii ?
# 45                                      Waaw ci fii !
# 46                                       Mi õgi fii ?
# 47                                       Gor gi dem ?
# 48                                          Dem õga ?
# 49                                        Keneen la ?
# 50                                       Kookule la ?
# 51                                         Samba la ?
# 52                                          Góor la ?
# 53                                       Kan dem na ?
# 54                                      Gis õga kan ?
# 55                                     Yan ñoo réer ?
# 56                           Ag ñan õga doon xeexal ?
# 57                                       Fan õga jëm?
# 58                                   Koo jox xaalis ?
# 59                                        Ñu dikkul ?
# 60                                        Fu mu jëm ?
# 61                                            Fu mu ?
# 62                                            Ku mu ?
# 63                                 Góor gan moo dem ?
# 64                                  Nit ñan õga wax ?
# 65                                    Keneen kan la ?
# 66                               Keneen kan õga wax ?
# 67                                           Ana mu ?
# 68                                      Ana foo jëm ?
# 69                                               Ndax
# 70                                      Ndax dem na ?
# 71                             Ndax góor gi moo dem ?
# 72                          Ndax réew mi am na alal ?
# 73                          Réew mi am na alal ndax ?
# 74                                            Xanaa ?
# 75                                   Doo dem, xanaa ?
# 76                                    Xanaa doo dem ?
# 77                                    Xanaa doo dem ?
# 78                                   Doo dem, xanaa ?
# 79                                  Xand kenn demul ?
# 80                                            Ñaata ?
# 81                                      Ñaata õgeen ?
# 82                                               Na ?
# 83                                     Na õgeen def ?
# 84                                             Naka ?
# 85                                             Naka ?
# 86                                     Naka õga def ?
# 87                                Naka góor gi tudd ?
# 88             Naka õgeen bëggé góor gi dimëlé leen ?
# 89                                            Mbaa...
# 90                          Mbaa xale yi yeksi nañu ?
# 91                                 Mbaa kenn génnul ?
# 92                                     Mbaa móo dem ?
# 93                                              amees
# 94                                              ameef
# 95                                              amoon
# 96                                              amoon
# 97                                           àndandoo
# 98                                               addu
# 99                                               addu
#
#                                                 wolof
# 0              L'homme dit qu'il serait peut-être là.
# 1                           Tu y as été quels jours ?
# 2                       Hier, aujourd'hui, avant-hier
# 3            Où t'es-tu initié en sciences occultes ?
# 4                                   Tu vas vers qui ?
# 5   Vers celui que voilà, vers celui-ci, vers celu...
# 6                                    Je donne à qui ?
# 7          À ceux-ci, ceux-là, à ceux qui sont là-bas
# 8                                  Te voilà, le voilà
# 9          Où as-tu été initié en sciences occultes ?
# 10                             Le voilà et le voilà !
# 11                       Il est homme, tu es homme...
# 12          C'est à l'intérieur, à l'intérieur même !
# 13                  C'est celui-là, celui-là debout !
# 14                           C'est un seul, un seul !
# 15                   J'ai été, tu as été, il a été...
# 16             J'ai été et tu as été et lui il a été.
# 17                Il viendra que tu veuilles ou non !
# 18                                        Où vas-tu ?
# 19                        Chez les Sérère et les Peul
# 20                                        Où vas-tu ?
# 21                            Chez ceux-ci et ceux-là
# 22  C'est un homme de chair et d'os et tu es un ho...
# 23                  C'est celui-là et c'est un autre.
# 24                      J'ai été et tu n'as pas été !
# 25  Viens pour que les enfants soient des travaill...
# 26  Change-les à tel point qu'ils soient autres et...
# 27                   Il est venu hier et aujourd'hui.
# 28                                                 et
# 29                                            ensuite
# 30                                                 or
# ...
# 2                   May na ka lëg, doomam ak nopp ya.
# 3          Séetal ci bir, ci biti, ci suuf ak ci kaw.
# 4      Moontin góor gi jambaar la lool ci liggéey bi.
# 5                       Jigéen ñi demuñu Ndar ba tày.
# 6                                     Nit ku baax la.
# 7                                     Nit la ku baax.
# 8                             Ndaw la góor gi di wut.
# 9                           Õga dem la, góor gi bëgg.
# 10                         Ci ki ñëw ba ñu xammee ka.
# 11                            Góor gi dem ba mu ñëw ?
# 12                   Na góor gi dem ba xale yi yeksi.
# 13                 Xale bi ne õgeen dugg mu gis leen.
# 14                       Li õga wax la ndaw si taamu.
# 15                            Bëggóon õgeen dem rekk.
# 16               Góor gi nee xale yi demkoon nañu fa.
# 17                      Góor googule ñëwóon, mi õgi !
# 18                      Jox naa téere bi góor gi ñëw.
# 19             Abal naa téere bi góor googule gi dem.
# 20                     Lépp lu baax la góor gii bëgg.
# 21                       Keneen kooku génn yeksiwul !
# 22                         Jox na ka keneen ku sawar.
# 23                       May naa ka keneen ku ka gën.
# 24                      Ci kooku, ndax mu wettëliku !
# 25             Góor gaa õgoogule ndax kenn bañ génn !
# 26                       Ñawoon la ba bi mu fiy joge.
# 27                     Foofu la ba ba ñuy gis feneen.
# 28                    Ci fii la ba ba ñuy gis feneen.
# 29                        Amal õgor ba mën nekk nit !
# 30                              Faatim la soo demee !
# 31                              Faatim la soo demee !
# 32                              Faatim la soo demee !
# 33                             Soo demee, Faatim la !
# 34                             Soo demee, Faatim la !
# 35                             Soo demee, Faatim la !
# 36                                Gaynde la, ku dem !
# 37                          Góor gi la, yaakaar naa !
# 38                            So demee, mi õgiy wax !
# 39                            So demee, mi õgiy wax !
# 40                          Soo bëggul, ci fii kóon !
# 41                            Soo demee, kookule la !
# 42                          Defe naa, keneen kii la !
# 43                                 Du kii, defe naa !
# 44                                Su bëggul, na dem !
# 45                                 Du ñëw, defe naa !
# 46                           Ma defe góor gi dem na !
# 47                          Ma defe góor gii dem la !
# 48                       Dellu biir Ndar, soo bëggée.
# 49                     Dellu, soo bëggée, biir Ndar !
# 50                 Góor gee ni mi õgi fi, soo demee !
# 51                 Soo demee, góor gee ni mi õgi fi !
# 52                Góor gee ni, soo demee, mi õgi fi !
# 53                    Góor gee ni nit la, soo demee !
# 54                     Soo demee góor gee ni nit la !
# 55                     Góor gee ni soo demee nit la !
# 56                Góor gee ni kookule la, soo demee !
# 57                 Soo demee góor gee ni kookule la !
# 58                Góor gee ni kookule la, soo demee !
# 59                Sa yay nee soo yeggee dana dellusi.
# 60                Sa yay nee dana dellusi soo yeggee.
# 61         Ci Séeréer si, ci Pël yi, ci Ñomiõka yi...
# 62      Ci Pël yi ag ci Séeréer si, ag ci Ñomiõka yi.
# 63         Noona góor gi seet lëf ki, seetat mbir mi.
# 64                    Dem õga, te dem na, te dem naa.
# 65  Noona góor gi dugg, xale yi gis ka, mu toog, ñ...
# 66  Bëgg naa góor ñi ñëw, xale yi ñëw, jigéen ñi t...
# 67           Nee waa jii gor la, goor la, jambe la...
# 68                 Defe naa du kookuu, du kookee... !
# 69              Demal ndax mu ñëw, ndax mu meddi... !
# 70  Ñëwël ndax xale yi di ay liggéeykat, di ay jam...
# 71       Demal, ndax mu di, leneen, mu di feneen... !
# 72                     Dana ñëw õga bañ dem õga dem !
# 73            Tày ci suba, tày ci õgoon ma fiy nekk !
# 74           Maa fiy nekk tày ci õgoon, tày ci suba !
# 75          Bëgg në õga ñëw, mu bañ dem su nëjul... !
# 76          Bëgg naa õga ñëw mu dem su õgeen noppée !
# 77  Bëgg në õga ñëw ci subë ci juróomi waxtu ci se...
# 78      Bëgg naa ci juróomi waxtu, ci subë, õga ñëw !
# 79      Defewoon na, ci subë si, ci bes bi, daa dem !
# 80       Defewoon na, daa dem, ci bes bi ci subë si !
# 81            Dans góor gi bëgg na õga dem te mu ñëw.
# 82                                 Dem õga te ñëw na.
# 83                      Góor gi dem te xale yi dugg !
# 84           Góor gi bëgg na õga dem te xale yi toog.
# 85                       Ne jigéen ji ñëw te mu toog.
# 86    Defewoon naa góor gi mag la te ndaw si nit la !
# 87  Defewoon naa góor gi kenn ki la, te xale bi ko...
# 88                Demal ndax mu ñëw ndax it mu génn !
# 89             Soo demee ag soo demul itam, dana ñëw.
# 90              Dana ñëw soo demul ag soo demee itam.
# 91                           Ñëw na demb yépp ag tay.
# 92      Bëgg na soo demee, mu dellusi te góor gi ñëw.
# 93       Bëgg na góor gi ñëw te mu dellusi soo demee.
# 94  Dañu defewoon ni daa dem ci subë ag ci õgoon y...
# 95    Dañu defewoon ci õgoon ag ci suba yépp da dem !
# 96      Góor ñi dañu tayel te jigéen ñi du ñu deglóo.
# 97  Xale yi bëgg nañu dikk, te mag ni ñaan nañu õg...
# 98  Gis naa góor googu demoon Ndar te õga abaloon ...
# 99       Gis naa góor gi doon wax te toogoon ci suuf.
#
#                                                 wolof
# 0   Les enfants ont cherché à l'intérieur, à l'ext...
# 1   Homme, lion, mouton et hyène, ne vont pas ense...
# 2   Il lui a donné le lièvre, ses petits et leurs ...
# 3   Regarde à l'intérieur, à l'extérieur, en bas e...
# 4             Et pourtant l'homme est dur à la tâche.
# 5       Les femmes n'ont été à Saint-Louis jusqu'ici.
# 6                              C'est un homme gentil.
# 7                              C'est un homme gentil.
# 8              C'est un messager que cherche l'homme.
# 9         Que tu partes, c'est ce que désire l'homme.
# 10        Chez celui qui est venu et qu'on a reconnu.
# 11   L'homme peut-il partir jusqu'à ce qu'il vienne ?
# 12  L'homme doit s'en aller jusqu'à ce que les enf...
# 13        L'enfant dit d'entrer pour qu'il vous voie.
# 14  C'est ce que tu as dit que la jeune femme préf...
# 15           Le désir non exaucé de vous voir partir.
# 16    L'homme soutient que les enfants y eussent été.
# 17           Cet homme qui vint autrefois, le voilà !
# 18        J'ai donné le livre à l'homme qui est venu.
# 19             J'ai prêté le livre à cet homme parti.
# 20   C'est tout ce qui est beau qui séduit cet homme.
# 21  Cet autre qui est sorti n'est pas encore arrivé !
# 22    Il l'a donné à quelqu'un d'autre de très actif.
# 23     Je l'ai donné à quelqu'un de meilleur que lui.
# 24       Avec celui-là, afin qu'il ne soit pas seul !
# 25               Voilà l'homme ainsi nul ne bougera !
# 26       C'était ceux-là même jusqu'à ce qu'il parte.
# 27  C'est là jusqu'au moment où nous trouverons un...
# 28  C'est là jusqu'à ce qu'on trouve un autre endr...
# 29  Aie assez de sérénité pour conserver ta dignité !
# 30         C'est Fatim, si on va au fond des choses !
# 31                           C'est Fatim, peut-être !
# 32                            C'est peut-être Fatim !
# 33         Si on va au fond des choses, c'est Fatim !
# 34         C'est Fatim, si on va au fond des choses !
# 35                            C'est peut-être Fatim !
# 36                          C'est peut-être un lion !
# 37                       Je crois que c'est l'homme !
# 38              Il est entrain de parler, peut-être !
# 39               Il est peut-être entrain de parler !
# 40                         Ici alors, si tu refuses !
# 41                         C'est celui-là peut-être !
# 42                           C'est l'autre je crois !
# 43               Je crois que ce n'est pas celui-ci !
# 44                     Qu'il parte s'il ne veut pas !
# 45                    Je crois qu'il ne viendra pas !
# 46                       L'homme est parti je crois !
# 47                  C'est l'homme qui part je crois !
# 48     Retourne au centre de Saint-Louis, si tu veux.
# 49    Si tu veux, retourne au centre de Saint-Louis !
# 50  C'est l'homme qui a dit qu'il est là, certaine...
# 51  Certainement, c'est l'homme qui a dit qu'il es...
# 52  C'est l'homme, certainement, qui a dit qu'il e...
# 53  C'est l'homme qui a soutenu qu'il est sain d'e...
# 54  Peut-être est-ce l'homme qui a dit qu'il est s...
# 55  L'homme a peut-être soutenu qu'il est sain d'e...
# 56  C'est l'homme qui a dit que c'est celui-là, pe...
# 57  Peut-être l'homme a-t-il dit que c'est celui-là !
# 58      L'homme a dit que c'est celui-là, peut-être !
# 59  Ta mère promet de revenir si tu vas jusqu'au b...
# 60  Ta mère dit qu'elle reviendra si tu vas jusqu'...
# 61         Chez les Sérère, les Peul, les Niominka...
# 62        Chez les Peul, les Sérère, et les Niominka.
# 63  Alors l'homme reconsidéra la chose, reconsidér...
# 64       Tu as été et il a été et moi aussi j'ai été.
# 65  Alors l'homme entra, les enfants le virent, il...
# 66  Je souhaite que les hommes viennent, que les e...
# 67  Il dit que ce Monsieur est un homme, il est no...
# 68  Je crois que ce n'est pas celui-ci, ce n'est p...
# 69  Vas-y pour qu'il vienne, pour qu'il ne soit pl...
# 70  Viens pour que les enfants soient des travaill...
# 71  Vas-y pour que ce soit autre chose, que ce soi...
# 72                Il viendra que tu veuilles ou non !
# 73       Ce matin ou ce soir c'est moi qui suis ici !
# 74       Ce matin ou ce soir c'est moi qui suis ici !
# 75  Je veux que tu viennes, qu'il refuse de partir...
# 76  Je veux, si vous avez fini, que tu viennes et ...
# 77  Je veux que tu viennes le matin à cinq heures ...
# 78  Je veux que tu viennes le matin à cinq heures ...
# 79    Je croyais que tu irais, ce matin, ce jour... !
# 80    Je croyais que tu irais, ce matin, ce jour... !
# 81        L'homme veut que tu ailles et qu'il vienne.
# 82                          Tu as été et il est venu.
# 83     Que l'homme parte et que les enfants entrent !
# 84  L'homme souhaite que tu partes et que les enfa...
# 85  Il demande que la femme vienne et que lui il r...
# 86  Je croyais que l'homme était mûr et que la fem...
# 87  Je croyais que l'homme c'était cet autre et qu...
# 88  Vas-y afin qu'il vienne et aussi afin qu'il so...
# 89  Que tu partes ou que tu ne partes pas, il vien...
# 90  Que tu partes ou que tu ne partes pas il viendra.
# 91                   Il est venu hier et aujourd'hui.
# 92  Il veut, lorsque tu iras que lui, il revienne ...
# 93  Il veut que l'homme vienne et que lui, il revi...
# 94    On croyait que tu allais partir matin et soir !
# 95    On croyait que tu allais partir matin et soir !
# 96  Les hommes sont des paresseux et les femmes ne...
# 97  Les enfants veulent venir et les adultes souha...
# 98  J'ai vu l'homme qui était parti à Saint-Louis ...
# 99  J'ai vu cet homme qui parlait et qui était ass...
#
# --------------------
#
#
# Which of the groups of batch number 11 do you consider to be complete sentences (see the file batch.csv) ?
#
# Batch result
#                                                french  \
# 0                 Góor gee dem walla xale yee noppi ?
# 1          Xale yee ñaan walla mag née bëgg õga dem ?
# 2             Demal Ndar mu mën ñëw walla mu yonnée !
# 3                    Géew bi day taxaw walla ma dem !
# 4                     Góor gee dem mba xale yee toog.
# 5                 Sa baay né õga dem mba õga nibbisi.
# 6                Góor gi dem na waaye xale yi demuñu.
# 7         Sa bay bëggul õgeen di génn ag di wëndéelu.
# 8                  Bëgg naa õga dem te it õga noppi !
# 9    May na la ndax xale yi beg te it õga ànd ak ñom.
# 10       Jëgg day wut fu mu jaar ag itam na mu laqoo.
# 11  Jigéen ji ñaan na ndax xale yi agg te itam see...
# 12            Bëgg na sa waajur ñëw te nak ñu fay kà.
# 13  Góor gi dem na ndax õgeen ñëw te nak kenn bañ ...
# 14  Na õgeen dem ndax gerte gi ñëw te nak ñjaay mi...
# 15   Du bañ boo naõgoo ag it boo yaboo ci liggéey bi.
# 16   Du bañ boo naõgoo ag it boo yaboo ci liggéey bi.
# 17  Yaakaaroon na ni, mag ñi du ñu ci agg foofu te...
# 18                                            te itam
# 19                                            te itam
# 20                                             te nak
# 21                                             te nak
# 22                                             te nak
# 23                                             te nak
# 24                                             te nak
# 25                                             te nak
# 26                                              ag it
# 27                                              ag it
# 28  Jigéen ji bëgg na õgeen am waaye it õgeen di m...
# 29  Jigéen ji bëgg na õgeen am waaye it õgeen di m...
# 30                                          Mbaa... !
# 31                                    Kenn demul mbaa
# 32                                    Kenn demul mbaa
# 33                                    Mbaa kenn demul
# 34                                    Mbaa kenn demul
# 35                                           Lu tax ?
# 36                                           Lu tax ?
# 37                                         Lu waral ?
# 38                                         Lu waral ?
#
#                                                 wolof
# 0   C'est l'homme qui est parti ou bien ce sont le...
# 1   Ce sont les enfants qui ont demandé ou les adu...
# 2   Va à Saint-Louis pour qu'il puisse venir ou qu...
# 3                Le cercle se forme ou je m'en vais !
# 4     Ou l'homme est parti ou les enfants sont assis.
# 5   Ton père te demande de partir ou de rester à l...
# 6   L'homme est parti mais les enfants ne le sont ...
# 7   Ton père n'aime pas que vous sortiez et que vo...
# 8   Je veux que tu partes et aussi que tu te taises !
# 9   Il t'a fait un cadeau pour que les enfants soi...
# 10  Le convoyeur doit chercher où passer et aussi ...
# 11  La femme pria pour que les enfants arrivent et...
# 12  Il veut que tes parents viennent et surtout qu...
# 13  L'homme est parti pour que vous veniez sans qu...
# 14  Allez pour que l'arachide arrive et qu'enfin l...
# 15  Il ne refusera pas si tu acceptes et aussi t'e...
# 16  Il ne refusera pas si tu acceptes et aussi si ...
# 17  Il espérait que les gens d'âge n'en seraient p...
# 18                                           et aussi
# 19                                         et surtout
# 20                                                 et
# 21                                           et aussi
# 22                                          et encore
# 23                                         et surtout
# 24                                        et sans que
# 25                                           et enfin
# 26                                         mais aussi
# 27                                           et aussi
# 28  La dame voudrait bien que vous ayez mais aussi...
# 29  La dame voudrait bien que vous ayez des riches...
# 30                 Est-ce comme je le crains que... !
# 31                           Que personne n'est parti
# 32                  J'espère que personne n'est parti
# 33                           Que personne n'est parti
# 34                  J'espère que personne n'est parti
# 35                                         Pourquoi ?
# 36                      Qu'est-ce, qui est la cause ?
# 37                                         Pourquoi ?
# 38                      Qu'est-ce, qui est la cause ?
#
# --------------------
#
#
# Finished !

# %% [markdown]
# #### Drop duplicated translations

# %%
new_sent_extraction.load()

# %% [markdown]
# Let us show the number of duplicated translations.

# %%
pd.DataFrame(new_sent_extraction.extractions).duplicated().sum()
# Out:
# 98

# %% [markdown]
# Let us drop the duplicated translations in our dataset.

# %%
new_sent_extraction.remove_duplicated_sentences(save=True)

# %% [markdown]
# Let us the final number of sentences that we got.

# %%
len(new_sent_extraction.extractions[new_sent_extraction.corpus_1])
# Out:
# 2967

# %% [markdown]
# We finally extracted **2967** sentences.
